# %% [markdown]
# # CCLE - Pilot
# ```
# pi:ababaian
# files: ~/Crown/data2/ccle/
# start: 2019 05 28
# complete : 2019 06 02
# ```
# ## Introduction
#
# With the TCGA data analysis complete and some left over Amazon credits, I'm looking at some other datasets which I can analyze.
#
# The **Cancer Cell Line Encyclopedia** (CCLE) is RNAseq from ~1000 cell lines and WGS DNAseq from ~380 of those lines.
#
# This data is on the SRA so it will require a tweaked download script, otherwise technically the data will be processed the same.

# %% [markdown]
# ## Objective
#
# 1. Pilot: Align 2x RNAseq and 2xWGS datato the `hgr1` reference sequence and QC the output.
# 2. Set-up a full run for the entire CCLE data cohorts.

# %% [markdown]
# ## Materials and Methods

# %% [markdown]
# ### Data Initialization

# %% [markdown]
# From the SRA website, the CCLE project was selected: [SRP186687](https://trace.ncbi.nlm.nih.gov/Traces/sra/sra.cgi?study=SRP186687)
#
# The data was imported into excel for filtering and prioritization. For the pilot, RNA and WGS will be analyzed from HT115 and HCT116
#
# The output of this parsing is copied to the input file: `ccle_pilot.input`
#
# Input columns are (see below):
#
# 1. Library Name
# 2. Data Type
# 3. Sample ID
# 4. SRA Accesion
# 5. Experiment Accession

# %% [markdown]
# ### Scripts and Localization

# %% [markdown]
# #### 1 - Localization

# %%
WORKDIR='/home/artem/Crown/data2/ccle'
cd $WORKDIR
ls

# Amazon AWS S3 Home URL
S3URL='s3://crownproject/ccle'
# Out:
# ccle_pilot2.input      HCT116.rna.flagstat       logs
# ccle_pilot.input       HCT116.rna.hgr1.flagstat  metadata
# CCLE_SraRunTable.xlsx  HCT116.wgs.screenlog      old_scripts
# droneB.sh              hgr1_align_v4.ccle.sh     queenB.sh

# %%
INPUT='ccle_pilot.input'
# Note the different column requirements for SRA data access

cat $INPUT
# Out:
# HCT116	rna	SAMN10988251	SRR8615282	SRX5414471
# HCT116	wgs	SAMN10988251	SRR8639145	SRX5437588
# HCT15	rna	SAMN10987770	SRR8615281	SRX5414472
# HCT15	wgs	SAMN10987770	SRR8639146	SRX5437587

# %% [markdown]
# #### 2 - Script Versions

# %%
cd $WORKDIR
# Echo scripts to be used for this analysis for version control.
# Note these need to be manually copied to the $WORKDIR

cat hgr1_align_v3.ccle.sh
echo 
echo
cat queenB.sh
echo 
echo
cat droneB.sh
echo 
echo
# Out:
# #!/bin/bash
# # hgr1_align_v3.ccle.sh
# # rDNA alignment pipeline - SRA version
# PIPE_VERSION='190528 build -- CCLE'
# AMI_VERSION='crown-180813 - ami-0031fd61f932bdef9'
# # EC2: c4.2xlarge (8cpu / 15 gb)
# # EC2: c4.xlarge  (4cpu / 8  gb)
# # Storage: 200 Gb
# #
#
# # Input Requirements --------------------------
#
# ## get SRA toolkit
# # wget http://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/2.9.6-1/sratoolkit.2.9.6-1-ubuntu64.tar.gz
# # aws s3 cp sratoolkit.2.9.6-1-ubuntu64.tar.gz s3://crownproject/ccle/scripts/sratoolkit.tar.gz
# aws s3 cp s3://crownproject/ccle/scripts/sratoolkit.tar.gz ./
# gzip -dc sratoolkit.tar.gz | tar -xf -
# SRABIN="$HOME/sratoolkit.2.9.6-1-ubuntu64/bin" # binary path
#
# # $1 : Library name + Output name(unique)
# # $2 : Seq-read type (wgs|rna)
# # $3 : BioSample ID
# # $4 : Library SRA Accession
#
# # Control Panel -------------------------------
# # Amazon AWS S3 Home URL
#   S3URL='s3://crownproject/ccle'
#
# # CPU
# 	THREADS='3'
#
# # Terminate instances upon completion (for debuggin)
#   TERMINATE='TRUE'
#
# # Read Group Data
#   LIBRARY=$1    # Library Name / File prefix
#   TYPE=$2       # wgs OR rna data-type
# 	RGPO='ccle'   # Patient Population - CCLE
# 	RGSM=$3       # Sample / Patient Identifer
# 	RGID=$4       # Read Group ID. SRA Accession Number
#   RGLB=$LIBRARY # Library Name. Accession Number
#   RGPL='ILLUMINA' # Seq Platform
#   RGPU=$5       # Read Group. Platform Unit (SRA Experiment)
#
#
#   SRA=$4
#   OUTPUT="$LIBRARY.$TYPE" # Output filename
#
#   # Fastq files from fastq-dump
#   # FQ1=<SRR>_1.fastq.gz
#   # FQ2=<SRR>_2.fastq.gz
#
# echo " -- hgr1 Alignment Pipeline -- "
# echo " version: $PIPE_VERSION "
# echo " ami:     $AMI_VERSION  "
# echo " s3:      $S3URL  "
# echo " library: $LIBRARY -- $TYPE"
# echo " date:    $(date)"
# echo ''
#
# # Initialize wordir ---------------------------
# echo 'Initializing ...'
#
# # Make working directory
#   mkdir -p align; cd align
#
# # Copy hgrX genome and create bowtie2 index
#   cp ~/resources/hgr1/* ./
#
# # Load updated GDC token to instance
# #aws s3 cp $S3URL/scripts/gdc.token gdc.token
# #chmod 600 gdc.token
#
# echo "Download fastq files: $SRA"
# echo "  cmd: $SRABIN/fastq-dump --gzip --split-files $SRA"
#
# $SRABIN/fastq-dump --gzip --split-files $SRA
#
# FQ1=$(ls *_1.fastq.gz)
# FQ2=$(ls *_2.fastq.gz)
# FQ0=$(ls *_0.fastq.gz)
#
# echo "  fastq_1: $FQ1"
# echo "  fastq_2: $FQ2"
#
# # SINGLE END READS ====================================================
#
# if [ -s $FQ0 ]
# then
#     echo "Single-end Reads Detected."
#     echo ''
#     echo "ERROR"
#     exit 666
# fi
#
# # PAIRED END READS ====================================================
#
# if [ -s $FQ1 ]
# then
#     echo "Paired-end Reads Detected."
#     echo ''
#     echo "Starting hgr1 alignment"
#     # Paired-End Extracted Reads Alignment
#
#     # Bowtie2: align to genome
#     bowtie2 --very-sensitive-local -p $THREADS \
#       --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \
#       --rg PL:$RGPL --rg PU:$RGPU \
#       -x hgr1 -1 $FQ1 -2 $FQ2 | \
#       ~/bin/samtools view -bS - > aligned_unsorted.bam
#
#     echo "Alignment complete."
#     echo "Calculate flagstats."
#
#     # Calcualte library flagstats
#       ~/bin/samtools flagstat aligned_unsorted.bam > aligned_unsorted.flagstat
#
#       rm $FQ1 $FQ2 # Remove fastq files to save space
#
#
#     # Read Subset ------------------------------
#     echo "Subset reads (retain mapped & their pairs, remove unmapped)."
#
#     # Extract mapped reads, and their unmapped pairs
#
#       # Extract Header
#       ~/bin/samtools view -H aligned_unsorted.bam > align.header.tmp
#
#       # Unmapped reads with mapped pairs
#       # Extract Mapped Reads
#       # and their unmapped pairs
#       ~/bin/samtools view -b -F 4 aligned_unsorted.bam > align.F4.bam #mapped
#       ~/bin/samtools view -b -f 4 -F 8 aligned_unsorted.bam > align.f4F8.bam #unmapped pairs
#
#       echo "Recompiling mapped bam file."
#
#       # Re-compile bam file
#       ~/bin/samtools cat -h align.header.tmp -o align.hgr1.tmp.bam align.F4.bam align.f4F8.bam
#         ~/bin/samtools sort -@ $THREADS -O BAM align.hgr1.tmp.bam > align.hgr1.bam
#         ~/bin/samtools index align.hgr1.bam
#         ~/bin/samtools flagstat align.hgr1.bam > align.hgr1.flagstat
#
#       # Clean up
#       rm *tmp* align.F4.bam align.f4F8.bam
#
#     echo "Processing complete. Copy files to S3"
#     # Rename the total Bam Files
#       mv aligned_unsorted.bam $OUTPUT.bam
#       #mv aligned_unsorted.bam.bai $OUTPUT.bam.bai
#       mv aligned_unsorted.flagstat $OUTPUT.flagstat
#
#     # Rename the hgr-aligned Bam files
#       mv align.hgr1.bam $OUTPUT.hgr1.bam
#       mv align.hgr1.bam.bai $OUTPUT.hgr1.bam.bai
#       mv align.hgr1.flagstat $OUTPUT.hgr1.flagstat
#
#     # Copy output to AWS S3
#     # Alignments (Full)
#       aws s3 cp $OUTPUT.flagstat $S3URL/hgr1/
#
#     # Alignments (Aligned)
#       aws s3 cp $OUTPUT.hgr1.bam $S3URL/hgr1/
#       aws s3 cp $OUTPUT.hgr1.bam.bai $S3URL/hgr1/
#       aws s3 cp $OUTPUT.hgr1.flagstat $S3URL/hgr1/
#
# fi
#
# echo "Create log files and copy to S3"
# # Copy screen log file to AWS S3
# cp ~/screenlog.0 ./$OUTPUT.screenlog
# aws s3 cp $OUTPUT.screenlog $S3URL/logs/
#
# # Shutdown and Terminate instance
# EC2ID=$(ec2metadata --instance-id)
# sleep 20s # to catch errors
#
# if [ "$TERMINATE" = TRUE ]
# then
#   echo "Run Complete -- Shutting down instance."
#   aws ec2 terminate-instances --instance-ids $EC2ID
# else
#   echo "Run Complete -- Instance is online."
# fi
#
# # Script complete
#
#
# #!/bin/bash
# # queenB.sh
# # 20180814 build
# # EC2 Launch / Control Script
# #
#
# # 1. queenB script is initialized locally and input files
# #    are parsed ready for cluster analaysis
# # 2. queenB launches instances, logs in to it and runs the
# #    droneB.sh script remotely.
# # 3. The droneB script is executed on the instance and it
# #    launches a `screen` on the instance and loads and
# #    starts to perform the $TASK (gather.sh) script.
# # 4. TASK script should include a instance shut-down
# #    command to close instance upon completion.
# #
#
# # Control Panel =========================
# # Amazon AWS S3 Home URL
# S3URL='s3://crownproject/ccle'
#
# # EC2 TASK Script - script for droneB to execute
# TASK="$S3URL/scripts/hgr1_align_v3.ccle.sh"
#
# # Parameter file:
# # Each line of PARAMETERS will be input to STDIN of
# # the droneB script which can then be used to run the
# # TASK script.
# # i.e. bash droneB.sh <line_N_of_PARAMETERS>
# # PARAMETERS="tcga0_input.txt"
# PARAMETERS=$1
#
# # EC2 Set-up
# instanceTYPE='c4.xlarge'
# imageID='ami-0031fd61f932bdef9' #AMI TCGA
#
# devNAME='/dev/sda1' # /dev/sda1 for Crown-AMI
# volSIZE='200' # in Gb
#
# # Maximum number of EC2 instances to run simultaniously
# MAX_INSTANCE='20'
#
# # Number of instances to launch
# #COUNT=2 # predetermined number
# COUNT=$(awk 'END{print NR}' $PARAMETERS) # for each input argument
#
# # Security
# keyNAME='CrownKey'
# keyPATH="/home/ec2-user/.ssh/CrownKey.pem"
# secGROUP='crown-group'
#
# # Input Validation ======================
# # Test input file for duplicate sample ID (which will cause file collisions downstream)
# # exit with error 1 if collision exists
#
# SAMPLEIDS=$(cut -f1 $1 | uniq -d )
#
# if [ -n "$SAMPLEIDS" ]
# then
#   # If there are duplicate sample IDs exit
#   echo "Error 02 - Duplicate Sample ID detected in input"
#   echo " I hope you know what you're doing"
#   echo " script will not exit in this version"
#   echo " re-run with unique ID or outputs will overwrite"
#   echo ""
#   #echo "$SAMPLEIDS"
#   #exit 2
# fi
#
# # Script Core ===========================
#
# for ITER in $(seq 1 $COUNT)
# do
#
#   # Count the total number of instances
#   running_instance=$(aws ec2 describe-instances |\
#     grep '"Name": "running"' - |\
#     wc -l - | cut -f1 -d' ' - )
#
#   while [ $running_instance -ge $MAX_INSTANCE ];
#   do
#
#   	echo "Reached max of $running_instance, wait."
#   	echo ''
#
#   	# If there are greater then 25 instances
#   	# wait for instance to close
#   	sleep 5m
#
#   	running_instance=$(aws ec2 describe-instances |\
#     grep '"Name": "running"' - |\
#     wc -l - | cut -f1 -d' ' - )
#   done
#
#   # Extract Parameters/Arguments ----------
#
#   ARGS=$(sed -n "$ITER"p $PARAMETERS | sed 's/\t/ /g' - )
#
#   echo "Launch instance # $ITER"
#   date
#   echo "Instance Type: $instanceTYPE"
#   echo "AMI Image: $imageID"
#   echo "Run Script: $TASK"
#   echo "Parameters: $ARGS"
#
#   # Launch an instance --------------------
#   # NOTE: each iteration of the for loop launches one instance
#   # therefore each loop launches only one instance
#   aws ec2 run-instances --image-id $imageID --count 1 \
#    --instance-type $instanceTYPE --key-name $keyNAME \
#    --block-device-mappings DeviceName=$devNAME,Ebs={VolumeSize=$volSIZE} \
#    --security-groups $secGROUP > launch.tmp
#
#   # Another alternative is to use --user-data droneB.sh
#   # which will run at instance boot-up
#   # passing arguments to it may be challenging
#
#   # Retrieve instance ID
#   instanceID=$(cat launch.tmp | \
#     egrep -o -e 'InstanceId[":/A-Za-z0-9_ \\-]*' - |\
#     cut -f2 -d' ' - | xargs)
#
#   echo "Instance ID: $instanceID"
#
#
#   # Add a few minute wait here to allow for Public DNS to be assigned
#   # otherwise ssh doesn't work
#   # CURRENT BOTTLENECK
#   sleep 180s
#
#   # Check that the instance is 'running' and not pending
#   pending_instance=$(aws ec2 describe-instances |\
#    grep '"Name": "pending"' - |\
#    wc -l - | cut -f1 -d' ' - )
#
#   while [ $pending_instance -gt 0 ];
#   do
#
#   	echo "Launchign instance not ready yet, chill"
#   	# Instance still pending
#   	sleep 180s
#
#     pending_instance=$(aws ec2 describe-instances |\
#      grep '"Name": "pending"' - |\
#      wc -l - | cut -f1 -d' ' - )
#   done
#
#
#   # Retrieve public DNS
#   aws ec2 describe-instances --instance-ids $instanceID > launch2.tmp
#
#   pubDNS=$(cat launch2.tmp | \
#     egrep -o -m 1 -e 'PublicDnsName[.":/A-Za-z0-9_ \\-]*' - |\
#     cut -f2 -d' ' - | xargs)
#
#   echo "Public DNS: $pubDNS"
#
#   # Access the instance -------------------
#
#   LOGIN="ubuntu@$pubDNS"
#
#   ssh -i $keyPATH \
#     -o StrictHostKeyChecking=no \
#     $LOGIN 'bash -s' < droneB.sh $TASK $(echo $ARGS)
#
#   # Cleanup
#   rm *.tmp
#
#   echo ''
#   echo ''
#
# done
#
# # end of script
#
# #!/bin/bash
# # droneB.sh
# #
#
# # This script-layer is neccesary to launch a screen session
# # on each ec2-machine. The pipeline is run within that session
# # and the output is logged. This allows 'looking in' on sessions
# # as they are running.
#
# # Commands to run on server-side
# # ===============================================================
#
# SCRIPTPATH=$1
#
# SCRIPT=$(basename $1)
#
# shift # drop first (TASK or SCRIPT variable)
#
# # Download pipeline / droneB's function
#   aws s3 cp $SCRIPTPATH ./
#
#   chmod 777 *.sh
#
# # open screen; run gather.sh function. -L logged
#   screen -Ldmt sh ~/$SCRIPT $@
#
#
# # ===============================================================

# %% [markdown]
# ## Results - CCLE Pilot Run I

# %% [markdown]
# #### 3 - Copy local to S3

# %%
# Local Folder Operations -----------------------------
# LOCAL:
cd $WORKDIR

#NOTE For pilot run, AWS s3 shutdown commented out. Re-upload hgr1 script upon full run

aws s3 cp queenB.sh $S3URL/scripts/
aws s3 cp droneB.sh $S3URL/scripts/
aws s3 cp hgr1_align_v3.ccle.sh $S3URL/scripts/
aws s3 cp $INPUT $S3URL/scripts/
#aws s3 cp ../../gdc.token.txt $S3URL/scripts/gdc.token
# Out:
# upload: ./queenB.sh to s3://crownproject/ccle/scripts/queenB.sh
# upload: ./droneB.sh to s3://crownproject/ccle/scripts/droneB.sh
# upload: ./hgr1_align_v3.ccle.sh to s3://crownproject/ccle/scripts/hgr1_align_v3.ccle.sh
# upload: ./ccle_pilot.input to s3://crownproject/ccle/scripts/ccle_pilot.input

# %%
# start
date
date -u
# Out:
# Wed May 29 18:50:27 PDT 2019
# Thu May 30 01:50:27 UTC 2019

# %% [markdown]
# #### 4 - Launch and run master EC2 node

# %%
# Remote EC2 Instance Operations ----------------------

# Remote:
# Manually open an Amazon Linux 2 AMI
# ami-061392db613a6357b
# t2.micro
#
# ssh login:
# ssh -i "crown.pem" ec2-user@PUBLICDNS
#

# Commands on EC2 machine to set-up AWS
# enter personal login info:

# REMOTE:
#aws configure
  # AWS Key ID
  # AWS Secret Key ID
  # Region: us-west-2
  
# Copy local run files to S3 and download them on EC2

# REMOTE:
# aws s3 cp --recursive s3://crownproject/ccle/scripts/ ./
#
# mv <KEY>.pem ~/.ssh/
# chmod 400 ~/.ssh/<KEY>.pem

# REMOTE:
# Open logging screen and being launchign EC2 instances
# screen -L
# 
# bash queenB.sh ccl2_pilot.input
#
# aws s3 cp screenlog.0 s3://crownproject/ccle/logs/ccle_pilot.log

aws s3 cp s3://crownproject/ccle/logs/ccle_pilot.log ./
cat ccle_pilot.log
date -u

# Run completed successfully
# Out:
# download: s3://crownproject/ccle/logs/ccle_pilot.log to ./ccle_pilot.log
# kec2-user@ip-172-31-17-5:~\[ec2-user@ip-172-31-17-5 ~]$ ls
# ccle_pilot.input  droneB.sh		 queenB.sh    sratoolkit.tar.gz
# CrownKey.pem	  hgr1_align_v3.ccle.sh  screenlog.0
# bash queenB.sh ccle_pilot.input
# Error 02 - Duplicate Sample ID detected in input
#  I hope you know what you're doing
#  script will not exit in this version
#  re-run with unique ID or outputs will overwrite
#
# Launch instance # 1
# Thu May 30 01:50:46 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/ccle/scripts/hgr1_align_v3.ccle.sh
# Parameters: HCT116 rna SAMN10988251 SRR8615282 SRX5414471
# Instance ID: i-081e0951d2b25ecda
# Public DNS: ec2-54-245-171-125.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-245-171-125.us-west-2.compute.amazonaws.com,172.31.23.92' (ECDSA) to the list of known hosts.
# download: s3://crownproject/ccle/scripts/hgr1_align_v3.ccle.sh to ./hgr1_align_v3.ccle.sh
#
#
# Launch instance # 2
# Thu May 30 01:53:52 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/ccle/scripts/hgr1_align_v3.ccle.sh
# Parameters: HCT116 wgs SAMN10988251 SRR8639145 SRX5437588
# Instance ID: i-02cfcc6f406eaecc7
# Public DNS: ec2-18-236-137-37.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-236-137-37.us-west-2.compute.amazonaws.com,172.31.17.192' (ECDSA) to the list of known hosts.
# download: s3://crownproject/ccle/scripts/hgr1_align_v3.ccle.sh to ./hgr1_align_v3.ccle.sh
#
#
# Launch instance # 3
# Thu May 30 01:56:59 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/ccle/scripts/hgr1_align_v3.ccle.sh
# Parameters: HCT15 rna SAMN10987770 SRR8615281 SRX5414472
# Instance ID: i-00b89c1fc1b8f6c39
# Public DNS: ec2-54-188-15-75.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-188-15-75.us-west-2.compute.amazonaws.com,172.31.16.61' (ECDSA) to the list of known hosts.
# download: s3://crownproject/ccle/scripts/hgr1_align_v3.ccle.sh to ./hgr1_align_v3.ccle.sh
#
#
# Launch instance # 4
# Thu May 30 02:00:07 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/ccle/scripts/hgr1_align_v3.ccle.sh
# Parameters: HCT15 wgs SAMN10987770 SRR8639146 SRX5437587
# Instance ID: i-0bcafd6c172a8e2e4
# Public DNS: ec2-52-43-79-213.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-43-79-213.us-west-2.compute.amazonaws.com,172.31.18.102' (ECDSA) to the list of known hosts.
# download: s3://crownproject/ccle/scripts/hgr1_align_v3.ccle.sh to ./hgr1_align_v3.ccle.sh
#
#
# kec2-user@ip-172-31-17-5:~\[ec2-user@ip-172-31-17-5 ~]$ Thu May 30 02:19:35 UTC 2019

# %% [markdown]
# **Thu May 30 03:15:34 UTC 2019:**
#
# On instance 1, fastq files are still downloading. This is over an hour this instance has been running (c4.xlarge) and the bottleneck is downloading the data. This would be very inefficient on a larger cohort.
#
# `1.1G May 30 03:15 SRR8615282_1.fastq.gz`.
#
# **Thu May 30 03:46:53 UTC 2019:**
# `-rw-rw-r--  1 ubuntu ubuntu 1.4G May 30 03:46 SRR8615282_1.fastq.gz`
#
# **Thu May 30 16:13:58 UTC 2019**
#
# Next AM, runs did not work. Need to remove/fix the single end read detection, as it fails with this script. Also it takes far too long to download the data from SRA. I need to use a swarm of t2.micro machines to download the data, store it on S3 and then run C4.aligners from that t2.micro machine. One more level of abstraction.
#
# **Fri May 31 02:08:23 UTC 2019**
#
# The RNA runs are both complete. The WGS runs are both still downloading (>24 hours). Haven't even set-up the manual alignments yet. These files will require even longer downloads.
#
# ```
# -rw-rw-r-- 1 ubuntu ubuntu 16G May 31 02:08 SRR8639145_1.fastq.gz
# -rw-rw-r-- 1 ubuntu ubuntu 17G May 31 02:08 SRR8639145_2.fastq.gz
# ...
# -rw-rw-r--  1 ubuntu ubuntu  15G May 31 02:09 SRR8639146_1.fastq.gz
# -rw-rw-r--  1 ubuntu ubuntu  16G May 31 02:09 SRR8639146_2.fastq.gz
# ```
#
# **Fri May 31 15:15:56 UTC 2019**
#
# DNA WGS data still not downloaded, the rate of download is also at a standstill it seems. This may be a rate-limiting step with serer-side I/O in making fastq files. PREFETCH of straight SRA files is likely to be faster.
#
# ```
# -rw-rw-r--  1 ubuntu ubuntu  18G May 31 15:17 SRR8639146_1.fastq.gz
# -rw-rw-r--  1 ubuntu ubuntu  19G May 31 15:17 SRR8639146_2.fastq.gz
# ```
#
# **Fri May 31 19:39:16 UTC 2019:**
#
# Accidently logged into the wrong node (HCT116 wgs) and stopped the screen
# ```
# -rw-rw-r--  1 ubuntu ubuntu  21G May 31 19:37 SRR8639145_1.fastq.gz
# -rw-rw-r--  1 ubuntu ubuntu  21G May 31 19:37 SRR8639145_2.fastq.gz
#
# ubuntu@ip-172-31-17-192:~/ncbi$ du -ch
# 395M	./public/refseq
# 31G	./public/sra
# 32G	./public
# 32G	.
# 32G	total
#
# ```
#
# Will have to re-start. Note the inefficiency fo fastq-dump, it's totally unfeasible. shut down node. Keep HT115 WGS running.

# %%
date -u
aws s3 cp s3://crownproject/ccle/tmp/screen.fail.1 ./
cat screen.fail.1
# Out:
# Thu May 30 16:13:58 UTC 2019
# download: s3://crownproject/ccle/tmp/screen.fail.1 to ./screen.fail.1
# download: s3://crownproject/ccle/scripts/sratoolkit.tar.gz to ./sratoolkit.tar.gz
#  -- hgr1 Alignment Pipeline --
#  version: 190528 build -- CCLE
#  ami:     crown-180813 - ami-0031fd61f932bdef9
#  s3:      s3://crownproject/ccle
#  library: HCT116 -- rna
#  date:    Thu May 30 01:53:55 UTC 2019
#
# Initializing ...
# Download fastq files: SRR8615282
#   cmd: /home/ubuntu/sratoolkit.2.9.6-1-ubuntu64/bin/fastq-dump --gzip --split-files SRR8615282
# 2019-05-30T03:19:06 fastq-dump.2.9.6 sys: timeout exhausted while reading file within network system module - mbedtls_ssl_read returned -76 ( NET - Reading information from the socket failed )
# 2019-05-30T03:46:09 fastq-dump.2.9.6 sys: timeout exhausted while reading file within network system module - mbedtls_ssl_read returned -76 ( NET - Reading information from the socket failed )
# 2019-05-30T04:01:24 fastq-dump.2.9.6 sys: timeout exhausted while reading file within network system module - mbedtls_ssl_read returned -76 ( NET - Reading information from the socket failed )
# 2019-05-30T04:05:53 fastq-dump.2.9.6 sys: timeout exhausted while reading file within network system module - mbedtls_ssl_read returned -76 ( NET - Reading information from the socket failed )
# 2019-05-30T06:20:39 fastq-dump.2.9.6 sys: connection not found while validating within network system module - Failed to Make Connection in KClientHttpOpen to 'sra-download-internal.ncbi.nlm.nih.gov:443'
# 2019-05-30T06:20:39 fastq-dump.2.9.6 err: connection not found while validating within network system module - error with https open 'https://sra-download-internal.ncbi.nlm.nih.gov/traces/refseq/CM000681.1'
# 2019-05-30T06:20:40 fastq-dump.2.9.6 sys: connection not found while validating within network system module - Failed to Make Connection in KClientHttpOpen to 'sra-download-internal.ncbi.nlm.nih.gov:443'
# 2019-05-30T06:20:40 fastq-dump.2.9.6 err: connection not found while validating within network system module - error with https open 'https://sra-download-internal.ncbi.nlm.nih.gov/traces/refseq/CM000681.1'
# 2019-05-30T06:20:41 fastq-dump.2.9.6 sys: connection not found while validating within network system module - Failed to Make Connection in KClientHttpOpen to 'sra-download-internal.ncbi.nlm.nih.gov:443'
# 2019-05-30T06:20:41 fastq-dump.2.9.6 err: connection not found while validating within network system module - error with https open 'https://sra-download-internal.ncbi.nlm.nih.gov/traces/refseq/CM000681.1'
# 2019-05-30T06:20:43 fastq-dump.2.9.6 sys: connection not found while validating within network system module - Failed to Make Connection in KClientHttpOpen to 'sra-download-internal.ncbi.nlm.nih.gov:443'
# 2019-05-30T06:20:43 fastq-dump.2.9.6 err: connection not found while validating within network system module - error with https open 'https://sra-download-internal.ncbi.nlm.nih.gov/traces/refseq/CM000681.1'
# 2019-05-30T07:15:40 fastq-dump.2.9.6 sys: connection not found while validating within network system module - Failed to Make Connection in KClientHttpOpen to 'sra-download-internal.ncbi.nlm.nih.gov:443'
# 2019-05-30T07:15:40 fastq-dump.2.9.6 err: connection not found while validating within network system module - error with https open 'https://sra-download-internal.ncbi.nlm.nih.gov/traces/refseq/GL000249.1'
# 2019-05-30T07:15:44 fastq-dump.2.9.6 sys: connection not found while validating within network system module - Failed to Make Connection in KClientHttpOpen to 'sra-download-internal.ncbi.nlm.nih.gov:443'
# 2019-05-30T07:15:44 fastq-dump.2.9.6 err: connection not found while validating within network system module - error with https open 'https://sra-download-internal.ncbi.nlm.nih.gov/traces/refseq/GL000240.1'
# 2019-05-30T07:15:45 fastq-dump.2.9.6 sys: connection not found while validating within network system module - Failed to Make Connection in KClientHttpOpen to 'sra-download-internal.ncbi.nlm.nih.gov:443'
# 2019-05-30T07:15:45 fastq-dump.2.9.6 err: connection not found while validating within network system module - error with https open 'https://sra-download-internal.ncbi.nlm.nih.gov/traces/refseq/GL000241.1'
# 2019-05-30T07:15:56 fastq-dump.2.9.6 sys: connection not found while validating within network system module - Failed to Make Connection in KClientHttpOpen to 'sra-download-internal.ncbi.nlm.nih.gov:443'
# 2019-05-30T07:15:56 fastq-dump.2.9.6 err: connection not found while validating within network system module - error with https open 'https://sra-download-internal.ncbi.nlm.nih.gov/traces/refseq/GL000227.1'
# Read 83894908 spots for SRR8615282
# Written 83894908 spots for SRR8615282
# ls: cannot access '*_0.fastq.gz': No such file or directory
#   fastq_1: SRR8615282_1.fastq.gz
#   fastq_2: SRR8615282_2.fastq.gz
# Single-end Reads Detected.
#
# ERROR

# %%
# HCT116 RNA run finished and looks good
date -u
aws s3 cp s3://crownproject/ccle/hgr1/HCT116.rna.flagstat ./
aws s3 cp s3://crownproject/ccle/hgr1/HCT116.rna.hgr1.flagstat ./

cat HCT116.rna.flagstat
echo '------------------'
cat HCT116.rna.hgr1.flagstat
# Out:
# Thu May 30 18:17:14 UTC 2019
# download: s3://crownproject/ccle/hgr1/HCT116.rna.flagstat to ./HCT116.rna.flagstat
# download: s3://crownproject/ccle/hgr1/HCT116.rna.hgr1.flagstat to ./HCT116.rna.hgr1.flagstat
# 167789816 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 381747 + 0 mapped (0.23% : N/A)
# 167789816 + 0 paired in sequencing
# 83894908 + 0 read1
# 83894908 + 0 read2
# 367836 + 0 properly paired (0.22% : N/A)
# 373224 + 0 with itself and mate mapped
# 8523 + 0 singletons (0.01% : N/A)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ------------------
# 390270 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 381747 + 0 mapped (97.82% : N/A)
# 390270 + 0 paired in sequencing
# 195135 + 0 read1
# 195135 + 0 read2
# 367836 + 0 properly paired (94.25% : N/A)
# 373224 + 0 with itself and mate mapped
# 8523 + 0 singletons (2.18% : N/A)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)

# %% [markdown]
# ## Materials and Methods II
#
# The old architecture for AWS doesn't work here. Will update AMI to accomodate SRA.

# %%
date -u
# Out:
# Fri May 31 15:41:25 UTC 2019

# %%
## Test download speeds
## prefetch only vs. fastq split
## Open 2 of the same nodes and download two files of ~equal size with
## different commands.
##


## REMOTE
## On T3A test nodes

## Common
#aws s3 cp s3://crownproject/ccle/scripts/sratoolkit.tar.gz ./
#gzip -dc sratoolkit.tar.gz | tar -xf -
#SRABIN="$HOME/sratoolkit.2.9.6-1-ubuntu64/bin" # binary path

## Test prefetch:
## Jurkat 6304Mb SRR8615712
## K562 8212Mb SRR8615717

#screen -L
#mkdir -p align; cd align;
#SRABIN="$HOME/sratoolkit.2.9.6-1-ubuntu64/bin"
#echo Jurkat; date; $SRABIN/prefetch -X 100G -O ./ SRR8615712; date;\
#        echo K562; $SRABIN/prefetch -X 100G -O ./ SRR8615717; date

## -O option copies sra to local dir; use regular cache instead
# aws s3 cp --recursive ./ s3://crownproject/ccle/sra/

# Use `fasterq-dump`


## START: Fri May 31 15:43:02 UTC 2019
## FILE:  Fri May 31 15:50:29 UTC 2019
## END:   Fri May 31 15:58:20 UTC 2019

## Test fastq-dump
## KMH2 6271Mb SRR8615908
## HL60 8281Mb SRR8616133

#screen -L
#mkdir -p align; cd align;
#SRABIN="$HOME/sratoolkit.2.9.6-1-ubuntu64/bin"
#echo KMH2; date; $SRABIN/fastq-dump --gzip --split-files SRR8615908; date;\
#        echo HL60; $SRABIN/fastq-dump --gzip --split-files SRR8616133; date

## START: Fri May 31 15:43:09 UTC 2019
## ..   : Fri May 31 18:02:11 UTC 2019
## ..   : Fri May 31 19:37:45 UTC 2019 (still not done)

## fastq didn't even finish the first file.
## killing prematurely, this is obviously far less efficient

# %%
cd ~/Crown/data2/ccle/
cat prefetch.log
# Out:
# artem@glitch[Desktop] [ 6:53PM]=ssh -i "~/.ssh/CrownKey.pem" ubuntu@ec2-54-212-204-255.us-west-2.compute.amazonaws.com>
# ^C
# compute.amazonaws.com>
# Welcome to Ubuntu 16.04.1 LTS (GNU/Linux 4.4.0-130-generic x86_64)
#
#  * Documentation:  https://help.ubuntu.com
#  * Management:     https://landscape.canonical.com
#  * Support:        https://ubuntu.com/advantage
#
#   Get cloud support with Ubuntu Advantage Cloud Guest:
#     http://www.ubuntu.com/business/services/cloud
#
# 171 packages can be updated.
# 1 update is a security update.
#
# New release '18.04.2 LTS' available.
# Run 'do-release-upgrade' to upgrade to it.
#
#
# Last login: Thu May 30 01:52:00 2019 from 75.155.240.245
# ubuntu@ip-172-31-23-92:~$ ls
# align  hct116.rna             ncbi       screenlog.0  sratoolkit.2.9.6-1-ubuntu64
# bin    hgr1_align_v3.ccle.sh  resources  software     sratoolkit.tar.gz
# ubuntu@ip-172-31-23-92:~$ screen -r
# d
# -- hgr1 Alignment Pipeline --
# version: 190528 build -- CCLE
# ami:crown-180813 - ami-0031fd61f932bdef9
# s3:s3://crownproject/ccle
# library: HCT116 -- rna
# date:Thu May 30 01:53:55 UTC 2019
#
# Initializing ...
# Do
# cmd: /home/ubuntu/sratoolkit.2.9.6-1-ubuntu64/bin/fastq-dump --gzip --split-files SRR8615282
# 2019-05-30T03:19:06 fastq-dump.2.9.6 sys: timeout exhausted while reading file within network system module - mbedtls_ssl_read returned -76 ( NET - Reading information from the socket failed )
# 2019-05-30T03:46:09 fastq-dump.2.9.6 sys: timeout exhausted while reading file within network system module - mbedtls_ssl_read returned -76 ( NET - Reading information from the socket failed )
# 2019-05-30T04:01:24 fastq-dump.2.9.6 sys: timeout exhausted while reading file within network system module - mbedtls_ssl_read returned -76 ( NET - Reading information from the socket failed )
# 2019-05-30T04:05:53 fastq-dump.2.9.6 sys: timeout exhausted while reading file within network system module - mbedtls_ssl_read returned -76 ( NET - Reading information from the socket failed )
# 2019-05-30T06:20:39 fastq-dump.2.9.6 sys: connection not found while validating within network system module - Failed to Make Connection in KClientHttpOpen to 'sra-download-internal.ncbi.nlm.nih.gov:443'
# 2019-05-30T06:20:39 fastq-dump.2.9.6 err: connection not found while validating within network system module - error with https open 'https://sra-download-internal.ncbi.nlm.nih.gov/traces/refseq/CM000681.1'
# 2019-05-30T06:20:40 fastq-dump.2.9.6 sys: connection not found while validating within network system module - Failed to Make Connection in KClientHttpOpen to 'sra-download-internal.ncbi.nlm.nih.gov:443'
# 2019-05-30T06:20:40 fastq-dump.2.9.6 err: connection not found while validating within network system module - error with https open 'https://sra-download-internal.ncbi.nlm.nih.gov/traces/refseq/CM000681.1'
# 2019-05-30T06:20:41 fastq-dump.2.9.6 sys: connection not found while validating within network system module - Failed to Make Connection in KClientHttpOpen to 'sra-download-internal.ncbi.nlm.nih.gov:443'
# 2019-05-30T06:20:41 fastq-dump.2.9.6 err: connection not found while validating within network system module - error with https open 'https://sra-download-internal.ncbi.nlm.nih.gov/traces/refseq/CM000681.1'
# 2019-05-30T06:20:43 fastq-dump.2.9.6 sys: connection not found while validating within network system module - Failed to Make Connection in KClientHttpOpen to 'sra-download-internal.ncbi.nlm.nih.gov:443'
# 2019-05-30T06:20:43 fastq-dump.2.9.6 err: connection not found while validating within network system module - error with https open 'https://sra-download-internal.ncbi.nlm.nih.gov/traces/refseq/CM000681.1'
# 2019-05-30T07:15:40 fastq-dump.2.9.6 sys: connection not found while validating within network system module - Failed to Make Connection in KClientHttpOpen to 'sra-download-internal.ncbi.nlm.nih.gov:443'
# 2019-05-30T07:15:40 fastq-dump.2.9.6 err: connection not found while validating within network system module - error with https open 'https://sra-download-internal.ncbi.nlm.nih.gov/traces/refseq/GL000249.1'
# 2019-05-30T07:15:44 fastq-dump.2.9.6 sys: connection not found while validating within network system module - Failed to Make Connection in KClientHttpOpen to 'sra-download-internal.ncbi.nlm.nih.gov:443'
# 2019-05-30T07:15:44 fastq-dump.2.9.6 err: connection not found while validating within network system module - error with https open 'https://sra-download-internal.ncbi.nlm.nih.gov/traces/refseq/GL000240.1'
# 2019-05-30T07:15:45 fastq-dump.2.9.6 sys: connection not found while validating within network system module - Failed to Make Connection in KClientHttpOpen to 'sra-download-internal.ncbi.nlm.nih.gov:443'
# 2019-05-30T07:15:45 fastq-dump.2.9.6 err: connection not found while validating within network system module - error with https open 'https://sra-download-internal.ncbi.nlm.nih.gov/traces/refseq/GL000241.1'
# 2019-05-30T07:15:56 fastq-dump.2.9.6 sys: connection not found while validating within network system module - Failed to Make Connection in KClientHttpOpen to 'sra-download-internal.ncbi.nlm.nih.gov:443'
# 2019-05-30T07:15:56 fastq-dump.2.9.6 err: connection not found while validating within network system module - error with https open 'https://sra-download-internal.ncbi.nlm.nih.gov/traces/refseq/GL000227.1'
# Read 83894908 spots for SRR8615282
# Written 83894908 spots for SRR8615282
# ls: cannot access '*_0.fastq.gz': No such file or directory
#   fastq_1: SRR8615282_1.fastq.gz
#   fastq_2: SRR8615282_2.fastq.gz
# Single-end Reads Detected.
#
# ERROR
# >
# [screen is terminating]
# ubuntu@ip-172-31-23-92:~$ ls
# align  hct116.rna             ncbi       screenlog.0  sratoolkit.2.9.6-1-ubuntu64
# bin    hgr1_align_v3.ccle.sh  resources  software     sratoolkit.tar.gz
# ubuntu@ip-172-31-23-92:~$ ubuntu@ip-172-31-23-92:~$ cd align/
# ubuntu@ip-172-31-23-92:~/align$ ls
# hgr1.1.bt2  hgr1.3.bt2  hgr1.fa      hgr1.rev.1.bt2  SRR8615282_1.fastq.gz
# hgr1.2.bt2  hgr1.4.bt2  hgr1.fa.fai  hgr1.rev.2.bt2  SRR8615282_2.fastq.gz
# ubuntu@ip-172-31-23-92:~/align$ screen -r
# There is no screen to be resumed.
# ubuntu@ip-172-31-23-92:~/align$ ubuntu@ip-172-31-23-92:~/align$ ls
# hgr1.1.bt2  hgr1.3.bt2  hgr1.fa      hgr1.rev.1.bt2  SRR8615282_1.fastq.gz
# hgr1.2.bt2  hgr1.4.bt2  hgr1.fa.fai  hgr1.rev.2.bt2  SRR8615282_2.fastq.gz
# ubuntu@ip-172-31-23-92:~/align$ ls -alh
# total 9.9G
# drwxrwxr-x  2 ubuntu ubuntu 4.0K May 30 01:54 .
# drwxr-xr-x 12 ubuntu ubuntu 4.0K May 30 02:20 ..
# -rw-rw-r--  1 ubuntu ubuntu 4.1M May 30 01:53 hgr1.1.bt2
# -rw-rw-r--  1 ubuntu ubuntu 4.0K May 30 01:53 hgr1.2.bt2
# -rw-rw-r--  1 ubuntu ubuntu   71 May 30 01:53 hgr1.3.bt2
# -rw-rw-r--  1 ubuntu ubuntu 4.0K May 30 01:53 hgr1.4.bt2
# -rw-rw-r--  1 ubuntu ubuntu 1.1M May 30 01:53 hgr1.fa
# -rw-rw-r--  1 ubuntu ubuntu  16K May 30 01:53 hgr1.fa.fai
# -rw-rw-r--  1 ubuntu ubuntu 4.1M May 30 01:53 hgr1.rev.1.bt2
# -rw-rw-r--  1 ubuntu ubuntu 4.0K May 30 01:53 hgr1.rev.2.bt2
# -rw-rw-r--  1 ubuntu ubuntu 4.7G May 30 08:02 SRR8615282_1.fastq.gz
# -rw-rw-r--  1 ubuntu ubuntu 5.2G May 30 08:02 SRR8615282_2.fastq.gz
# ubuntu@ip-172-31-23-92:~/align$ cd ..
# ubuntu@ip-172-31-23-92:~$ ubuntu@ip-172-31-23-92:~$ ls
# align  hct116.rna             ncbi       screenlog.0  sratoolkit.2.9.6-1-ubuntu64
# bin    hgr1_align_v3.ccle.sh  resources  software     sratoolkit.tar.gz
# gr1_align_v3.ccle.sh
# =▽  "hgr1_align_v3.ccle.sh" 185L, 5305C#!/bin/bash
# # hgr1_align_v3.ccle.sh
# # rDNA alignment pipeline - SRA version
# PIPE_VERSION='190528 build -- CCLE'
# AMI_VERSION='crown-180813 - ami-0031fd61f932bdef9'
# # EC2: c4.2xlarge (8cpu / 15 gb)
# # EC2: c4.xlarge  (4cpu / 8  gb)
# # Storage: 200 Gb
# #
#
# # Input Requirements --------------------------
#
# ## get SRA toolkit
# # wget http://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/2.9.6-1/sratoolkit.2.9.6-1-ubuntu64.taar.gz
# # aws s3 cp sratoolkit.2.9.6-1-ubuntu64.tar.gz s3://crownproject/ccle/scripts/sratoolkiit.tar.gz
# aws s3 cp s3://crownproject/ccle/scripts/sratoolkit.tar.gz ./
# gzip -dc sratoolkit.tar.gz | tar -xf -
# SRABIN="$HOME/sratoolkit.2.9.6-1-ubuntu64/bin" # binary path
#
# # $1 : Library name + Output name(unique)
# # $2 : Seq-read type (wgs|rna)
# # $3 : BioSample ID
# # $4 : Library SRA Accession
#
# # Control Panel -------------------------------
# # Amazon AWS S3 Home URL
#   S3URL='s3://crownproject/ccle'
#
# # CPUTHREADS='3'
#
# # Terminate instances upon completion (for debuggin)
#   TERMINATE='TRUE'
#
# # Read Group Data
#   LIBRARY=$1    # Library Name / File prefix
#   TYPE=$2# wgs OR rna data-typeRGPO='ccle'   # Patient Population - CCLERGSM=$3# Sample / Patient IdentiferRGID=$4# Read Group ID. SRA Accession Number
#   RGLB=$LIBRARY # Library Name. Accession Number
#   RGPL='ILLUMINA' # Seq Platform
#   RGPU=$5# Read Group. Platform Unit (SRA Experiment)1,1Top2345678910,0-11,1  2,0-13,1  456789,0-120,1  1234,0-15,1  678,0-19,1  30,1-81,0-12,1  345678,1-89401,1  23
# 44,0-10%
# 45,0-11%
# SRA=$446,12%
# OUTPUT="$LIBRARY.$TYPE" # Output filename47,12%
# 48,0-13%
# # Fastq files from fastq-dump49,14%
# # FQ1=<SRR>_1.fastq.gz50,14%
# # FQ2=<SRR>_2.fastq.gz51,15%
# 52,0-16%
# echo " -- hgr1 Alignment Pipeline -- "53,17%
# echo " version: $PIPE_VERSION "54,17%
# echo " ami:     $AMI_VERSION  "55,18%
# echo " s3:      $S3URL  "56,19%echo " library: $LIBRARY -- $TYPE"
# echo " date:    $(date)"57,19%8echo ''59,110%60,0-1
# # Initialize wordir ---------------------------61,111%
# echo 'Initializing ...'62,112%
# 63,0-112%
# # Make working directory64,113%
# mkdir -p align; cd align65,114%
# 66,0-115%
# # Copy hgrX genome and create bowtie2 index67,115%
# cp ~/resources/hgr1/* ./68,116%
# 69,0-117%
# # Load updated GDC token to instance70,117%
# #aws s3 cp $S3URL/scripts/gdc.token gdc.token71,118%
# #chmod 600 gdc.token72,119%
# 73,0-120%
# echo "Download fastq files: $SRA"74,120%
# echo "  cmd: $SRABIN/fastq-dump --gzip --split-files $SRA"75,121%
# 76,0-122%
# $SRABIN/fastq-dump --gzip --split-files $SRA77,122%
# 78,0-123%
# FQ1=$(ls *_1.fastq.gz)79,124%
# FQ2=$(ls *_2.fastq.gz)80,125%
# FQ0=$(ls *_0.fastq.gz)81,125%
# 82,0-126%
# echo "  fastq_1: $FQ1"  83,127%
# echo "  fastq_2: $FQ2"84,127%
# 85,0-128%
# # SINGLE END READS ====================================================86,129%
# 87,0-130%
# if [ -s $FQ0 ]88,130%
# then89,131%
# echo "Single-end Reads Detected."90,132%
# echo ''91,132%
# echo "ERROR"92,133%
# exit 66693,134%
# fi94,135%
# 95,0-135%
# # PAIRED END READS ====================================================96,136%
# 97,0-137%
# if [ -s $FQ1 ]98,137%
# then99,138%
# echo "Paired-end Reads Detected."100,139%
# echo ''101,140%
# echo "Starting hgr1 alignment"102,140%
# # Paired-End Extracted Reads Alignment103,141%
# 104,0-142%
# # Bowtie2: align to genome105,142%
# bowtie2 --very-sensitive-local -p $THREADS \106,143%
# --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \107,144%
# --rg PL:$RGPL --rg PU:$RGPU \108,145%
# -x hgr1 -1 $FQ1 -2 $FQ2 | \109,145%
# >ubuntu@ip-172-31-23-92:~$ ubuntu@ip-172-31-23-92:~$ ls
# align  hct116.rna             ncbi       screenlog.0  sratoolkit.2.9.6-1-ubuntu64
# bin    hgr1_align_v3.ccle.sh  resources  software     sratoolkit.tar.gz
# ubuntu@ip-172-31-23-92:~$ ec2-18-236-137-37.us-west-2.compute.amazonaws.com^C
# 0
# ls: cannot access '_0': No such file or directory
# 0
# ls: cannot access '*_0': No such file or directory
# [1@t[1@e[1@s[1@t[1@=[1@$[1@()
# ls: cannot access '*_0': No such file or directory
# ubuntu@ip-172-31-23-92:~$ echo $test
#
# vim hgr1_align_v3.ccle.sh
# =▽  "hgr1_align_v3.ccle.sh" 185L, 5305C#!/bin/bash
# # hgr1_align_v3.ccle.sh
# # rDNA alignment pipeline - SRA version
# PIPE_VERSION='190528 build -- CCLE'
# AMI_VERSION='crown-180813 - ami-0031fd61f932bdef9'
# # EC2: c4.2xlarge (8cpu / 15 gb)
# # EC2: c4.xlarge  (4cpu / 8  gb)
# # Storage: 200 Gb
# #
#
# # Input Requirements --------------------------
#
# ## get SRA toolkit
# # wget http://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/2.9.6-1/sratoolkit.2.9.6-1-ubuntu64.taar.gz
# # aws s3 cp sratoolkit.2.9.6-1-ubuntu64.tar.gz s3://crownproject/ccle/scripts/sratoolkiit.tar.gz
# aws s3 cp s3://crownproject/ccle/scripts/sratoolkit.tar.gz ./
# gzip -dc sratoolkit.tar.gz | tar -xf -
# SRABIN="$HOME/sratoolkit.2.9.6-1-ubuntu64/bin" # binary path
#
# # $1 : Library name + Output name(unique)
# # $2 : Seq-read type (wgs|rna)
# # $3 : BioSample ID
# # $4 : Library SRA Accession
#
# # Control Panel -------------------------------
# # Amazon AWS S3 Home URL
#   S3URL='s3://crownproject/ccle'
#
# # CPUTHREADS='3'
#
# # Terminate instances upon completion (for debuggin)
#   TERMINATE='TRUE'
#
# # Read Group Data
#   LIBRARY=$1    # Library Name / File prefix
#   TYPE=$2# wgs OR rna data-typeRGPO='ccle'   # Patient Population - CCLERGSM=$3# Sample / Patient IdentiferRGID=$4# Read Group ID. SRA Accession Number
#   RGLB=$LIBRARY # Library Name. Accession Number
#   RGPL='ILLUMINA' # Seq Platform
#   RGPU=$5# Read Group. Platform Unit (SRA Experiment)1,1Top2345678910,0-11,1  2,0-13,1  456789,0-120,1  1234,0-15,1  678,0-19,1  30,1-81,0-12,1  345678,1-89401,1  23
# 44,0-10%3,1  4,0-1
# 45,0-11%
# SRA=$446,12%
# OUTPUT="$LIBRARY.$TYPE" # Output filename47,12%
# 48,0-13%
# # Fastq files from fastq-dump49,14%
# # FQ1=<SRR>_1.fastq.gz50,14%
# # FQ2=<SRR>_2.fastq.gz51,15%
# 52,0-16%
# echo " -- hgr1 Alignment Pipeline -- "53,17%
# echo " version: $PIPE_VERSION "54,17%
# echo " ami:     $AMI_VERSION  "55,18%
# echo " s3:      $S3URL  "56,19%echo " library: $LIBRARY -- $TYPE"
# echo " date:    $(date)"57,19%8echo ''59,110%60,0-1
# # Initialize wordir ---------------------------61,111%
# echo 'Initializing ...'62,112%
# 63,0-112%
# # Make working directory64,113%
# mkdir -p align; cd align65,114%
# 66,0-115%
# # Copy hgrX genome and create bowtie2 index67,115%
# cp ~/resources/hgr1/* ./68,116%
# 69,0-117%
# # Load updated GDC token to instance70,117%
# #aws s3 cp $S3URL/scripts/gdc.token gdc.token71,118%
# #chmod 600 gdc.token72,119%
# 73,0-120%
# echo "Download fastq files: $SRA"74,120%
# echo "  cmd: $SRABIN/fastq-dump --gzip --split-files $SRA"75,121%
# 76,0-122%
# $SRABIN/fastq-dump --gzip --split-files $SRA77,122%
# 78,0-123%
# FQ1=$(ls *_1.fastq.gz)79,124%
# FQ2=$(ls *_2.fastq.gz)80,125%
# FQ0=$(ls *_0.fastq.gz)81,125%
# 82,0-126%
# echo "  fastq_1: $FQ1"  83,127%
# echo "  fastq_2: $FQ2"84,127%
# 85,0-128%
# # SINGLE END READS ====================================================86,129%
# 87,0-130%
# if [ -s $FQ0 ]88,130%
# then89,131%
# echo "Single-end Reads Detected."90,132%
# echo ''91,132%
# echo "ERROR"92,133%
# ; then echo hi; fi
# hi
# cho $test
#
# [1@z
# hi
# [1@e
# hi
# [1@'[1@ [1@'[1@ [1@q
# -bash: [:  : unary operator expected
# [1@"[1@"
# -bash: [: : unary operator expected
# [1@"[1@"
# -bash: [: : integer expression expected
# ubuntu@ip-172-31-23-92:~$ ubuntu@ip-172-31-23-92:~$ ls -alh
# total 81M
# drwxr-xr-x 12 ubuntu ubuntu 4.0K May 30 16:07 .
# drwxr-xr-x  3 root   root   4.0K Nov  6  2016 ..
# drwxrwxr-x  2 ubuntu ubuntu 4.0K May 30 01:54 align
# drwxrwxr-x  2 ubuntu ubuntu 4.0K Nov  6  2016 .aws
# -rw-------  1 ubuntu ubuntu 6.9K May 30 16:03 .bash_history
# -rw-r--r--  1 ubuntu ubuntu  220 Aug 31  2015 .bash_logout
# -rw-r--r--  1 ubuntu ubuntu 3.9K Nov  6  2016 .bashrc
# drwxrwxr-x  2 ubuntu ubuntu 4.0K Aug 13  2018 bin
# drwx------  2 ubuntu ubuntu 4.0K Nov  6  2016 .cache
# drwxrwxr-x 19 ubuntu ubuntu 4.0K Aug 13  2018 .ccache
# -rw-rw-r--  1 ubuntu ubuntu    0 May 30 01:52 hct116.rna
# -rwxrwxrwx  1 ubuntu ubuntu 5.2K May 30 01:47 hgr1_align_v3.ccle.sh
# drwxrwxr-x  3 ubuntu ubuntu 4.0K May 30 01:53 ncbi
# -rw-r--r--  1 ubuntu ubuntu  655 Jun 24  2016 .profile
# drwxrwxr-x  5 ubuntu ubuntu 4.0K Jul 30  2018 resources
# -rw-rw-r--  1 ubuntu ubuntu 5.2K May 30 08:02 screenlog.0
# drwxrwxr-x  6 ubuntu ubuntu 4.0K Aug 13  2018 software
# drwxrwxr-x  5 ubuntu ubuntu 4.0K Mar 18 18:59 sratoolkit.2.9.6-1-ubuntu64
# -rw-rw-r--  1 ubuntu ubuntu  81M May 28 20:22 sratoolkit.tar.gz
# drwx------  2 ubuntu ubuntu 4.0K Nov  6  2016 .ssh
# -rw-r--r--  1 ubuntu ubuntu    0 Nov  6  2016 .sudo_as_admin_successful
# -rw-------  1 ubuntu ubuntu 6.6K May 30 16:07 .viminfo
# -rw-rw-r--  1 ubuntu ubuntu  206 Aug 13  2018 .wget-hsts
# -rw-------  1 ubuntu ubuntu  553 May 30 02:20 .Xauthority
# ubuntu@ip-172-31-23-92:~$ cd align/
# ubuntu@ip-172-31-23-92:~/align$ ubuntu@ip-172-31-23-92:~/align$ ls
# hgr1.1.bt2  hgr1.3.bt2  hgr1.fa      hgr1.rev.1.bt2  SRR8615282_1.fastq.gz
# hgr1.2.bt2  hgr1.4.bt2  hgr1.fa.fai  hgr1.rev.2.bt2  SRR8615282_2.fastq.gz
# ubuntu@ip-172-31-23-92:~/align$
#
# upload: ./SRR8615282_1.fastq.gz to s3://crownproject/ccle/fq/SRR8615282_1.fastq.gz
# ubuntu@ip-172-31-23-92:~/align$
#
# upload: ./SRR8615282_2.fastq.gz to s3://crownproject/ccle/fq/SRR8615282_2.fastq.gz
# ubuntu@ip-172-31-23-92:~/align$ ls
# hgr1.1.bt2  hgr1.3.bt2  hgr1.fa      hgr1.rev.1.bt2  SRR8615282_1.fastq.gz
# hgr1.2.bt2  hgr1.4.bt2  hgr1.fa.fai  hgr1.rev.2.bt2  SRR8615282_2.fastq.gz
# ubuntu@ip-172-31-23-92:~/align$ cd ..
# ubuntu@ip-172-31-23-92:~$ ubuntu@ip-172-31-23-92:~$ ls
# align  hct116.rna             ncbi       screenlog.0  sratoolkit.2.9.6-1-ubuntu64
# bin    hgr1_align_v3.ccle.sh  resources  software     sratoolkit.tar.gz
# less -NS screenlog.0
#       1 Completed 1 of 10 part(s) with 1 file(s) remaining^MCompleted 2 of 10 part(s) w
#       2  -- hgr1 Alignment Pipeline --
#       3  version: 190528 build -- CCLE
#       4  ami:     crown-180813 - ami-0031fd61f932bdef9
#       5  s3:      s3://crownproject/ccle
#       6  library: HCT116 -- rna
#       7  date:    Thu May 30 01:53:55 UTC 2019
#       8
#       9 Initializing ...
#      10 Download fastq files: SRR8615282
#      11   cmd: /home/ubuntu/sratoolkit.2.9.6-1-ubuntu64/bin/fastq-dump --gzip --split-f
#      12 2019-05-30T03:19:06 fastq-dump.2.9.6 sys: timeout exhausted while reading file
#      13 2019-05-30T03:46:09 fastq-dump.2.9.6 sys: timeout exhausted while reading file
#      14 2019-05-30T04:01:24 fastq-dump.2.9.6 sys: timeout exhausted while reading file
#      15 2019-05-30T04:05:53 fastq-dump.2.9.6 sys: timeout exhausted while reading file
#      16 2019-05-30T06:20:39 fastq-dump.2.9.6 sys: connection not found while validating
#      17 2019-05-30T06:20:39 fastq-dump.2.9.6 err: connection not found while validating
#      18 2019-05-30T06:20:40 fastq-dump.2.9.6 sys: connection not found while validating
#      19 2019-05-30T06:20:40 fastq-dump.2.9.6 err: connection not found while validating
#      20 2019-05-30T06:20:41 fastq-dump.2.9.6 sys: connection not found while validating
#      21 2019-05-30T06:20:41 fastq-dump.2.9.6 err: connection not found while validating
#      22 2019-05-30T06:20:43 fastq-dump.2.9.6 sys: connection not found while validating
#      23 2019-05-30T06:20:43 fastq-dump.2.9.6 err: connection not found while validating
#      24 2019-05-30T07:15:40 fastq-dump.2.9.6 sys: connection not found while validating
#      25 2019-05-30T07:15:40 fastq-dump.2.9.6 err: connection not found while validating
#      26 2019-05-30T07:15:44 fastq-dump.2.9.6 sys: connection not found while validating
#      27 2019-05-30T07:15:44 fastq-dump.2.9.6 err: connection not found while validating
#      28 2019-05-30T07:15:45 fastq-dump.2.9.6 sys: connection not found while validating
#      29 2019-05-30T07:15:45 fastq-dump.2.9.6 err: connection not found while validating
#      30 2019-05-30T07:15:56 fastq-dump.2.9.6 sys: connection not found while validating
#      31 2019-05-30T07:15:56 fastq-dump.2.9.6 err: connection not found while validating
#      32 Read 83894908 spots for SRR8615282
#      33 Written 83894908 spots for SRR8615282
#      34 ls: cannot access '*_0.fastq.gz': No such file or directory
#      35   fastq_1: SRR8615282_1.fastq.gz
#      36   fastq_2: SRR8615282_2.fastq.gz
#      37 Single-end Reads Detected.
#      38
#      39 ERROR
# ...skipping...
#       1 Completed 1 of 10 part(s) with 1 file(s) remaining^MCompleted 2 of 10 part(s) w
#       2  -- hgr1 Alignment Pipeline --
#       3  version: 190528 build -- CCLE
#       4  ami:     crown-180813 - ami-0031fd61f932bdef9
#       5  s3:      s3://crownproject/ccle
#       6  library: HCT116 -- rna
#       7  date:    Thu May 30 01:53:55 UTC 2019
#       8
#       9 Initializing ...
#      10 Download fastq files: SRR8615282
#      11   cmd: /home/ubuntu/sratoolkit.2.9.6-1-ubuntu64/bin/fastq-dump --gzip --split-f
#      12 2019-05-30T03:19:06 fastq-dump.2.9.6 sys: timeout exhausted while reading file
#      13 2019-05-30T03:46:09 fastq-dump.2.9.6 sys: timeout exhausted while reading file
#      14 2019-05-30T04:01:24 fastq-dump.2.9.6 sys: timeout exhausted while reading file
#      15 2019-05-30T04:05:53 fastq-dump.2.9.6 sys: timeout exhausted while reading file
#      16 2019-05-30T06:20:39 fastq-dump.2.9.6 sys: connection not found while validating
#      17 2019-05-30T06:20:39 fastq-dump.2.9.6 err: connection not found while validating
#      18 2019-05-30T06:20:40 fastq-dump.2.9.6 sys: connection not found while validating
#      19 2019-05-30T06:20:40 fastq-dump.2.9.6 err: connection not found while validating
#      20 2019-05-30T06:20:41 fastq-dump.2.9.6 sys: connection not found while validating
#      21 2019-05-30T06:20:41 fastq-dump.2.9.6 err: connection not found while validating
#      22 2019-05-30T06:20:43 fastq-dump.2.9.6 sys: connection not found while validating
#      23 2019-05-30T06:20:43 fastq-dump.2.9.6 err: connection not found while validating
#      24 2019-05-30T07:15:40 fastq-dump.2.9.6 sys: connection not found while validating
#      25 2019-05-30T07:15:40 fastq-dump.2.9.6 err: connection not found while validating
#      26 2019-05-30T07:15:44 fastq-dump.2.9.6 sys: connection not found while validating
#      27 2019-05-30T07:15:44 fastq-dump.2.9.6 err: connection not found while validating
#      28 2019-05-30T07:15:45 fastq-dump.2.9.6 sys: connection not found while validating
#      29 2019-05-30T07:15:45 fastq-dump.2.9.6 err: connection not found while validating
#      30 2019-05-30T07:15:56 fastq-dump.2.9.6 sys: connection not found while validating
#      31 2019-05-30T07:15:56 fastq-dump.2.9.6 err: connection not found while validating
#      32 Read 83894908 spots for SRR8615282
#      33 Written 83894908 spots for SRR8615282
#      34 ls: cannot access '*_0.fastq.gz': No such file or directory
#      35   fastq_1: SRR8615282_1.fastq.gz
#      36   fastq_2: SRR8615282_2.fastq.gz
#      37 Single-end Reads Detected.
#      38
#      39 ERROR
# ~
# ~
# ~
# ~
# ~
# ~
# reen.fail1
# 1
# upload: ./screenlog.0 to s3://crownproject/ccle/tmp/screen.fail.1
# ubuntu@ip-172-31-23-92:~$ ^C
# ubuntu@ip-172-31-23-92:~$ ubuntu@ip-172-31-23-92:~$ ls
# align  bin  hct116.rna  hgr1_align_v3.ccle.sh  ncbi  resources  screenlog.0  software  sratoolkit.2.9.6-1-ubuntu64  sratoolkit.tar.gz
# rm screenlog.0
# vim hgr1_align_v3.ccle.sh
# =▽  "hgr1_align_v3.ccle.sh" 185L, 5305C#!/bin/bash
# # hgr1_align_v3.ccle.sh
# # rDNA alignment pipeline - SRA version
# PIPE_VERSION='190528 build -- CCLE'
# AMI_VERSION='crown-180813 - ami-0031fd61f932bdef9'
# # EC2: c4.2xlarge (8cpu / 15 gb)
# # EC2: c4.xlarge  (4cpu / 8  gb)
# # Storage: 200 Gb
# #
#
# # Input Requirements --------------------------
#
# ## get SRA toolkit
# # wget http://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/2.9.6-1/sratoolkit.2.9.6-1-ubuntu64.tar.gz
# # aws s3 cp sratoolkit.2.9.6-1-ubuntu64.tar.gz s3://crownproject/ccle/scripts/sratoolkit.tar.gz
# aws s3 cp s3://crownproject/ccle/scripts/sratoolkit.tar.gz ./
# gzip -dc sratoolkit.tar.gz | tar -xf -
# SRABIN="$HOME/sratoolkit.2.9.6-1-ubuntu64/bin" # binary path
#
# # $1 : Library name + Output name(unique)
# # $2 : Seq-read type (wgs|rna)
# # $3 : BioSample ID
# # $4 : Library SRA Accession
#
# # Control Panel -------------------------------
# # Amazon AWS S3 Home URL
#   S3URL='s3://crownproject/ccle'
#
# # CPUTHREADS='3'
#
# # Terminate instances upon completion (for debuggin)
#   TERMINATE='TRUE'
#
# # Read Group Data
#   LIBRARY=$1    # Library Name / File prefix
#   TYPE=$2# wgs OR rna data-typeRGPO='ccle'   # Patient Population - CCLERGSM=$3# Sample / Patient IdentiferRGID=$4# Read Group ID. SRA Accession Number
#   RGLB=$LIBRARY # Library Name. Accession Number
#   RGPL='ILLUMINA' # Seq Platform
#   RGPU=$5# Read Group. Platform Unit (SRA Experiment)SRA=$4
#   OUTPUT="$LIBRARY.$TYPE" # Output filename1,1Top2345678910,0-11,1  2,0-13,1  456789,0-18,1  7676
# 16,1Top
# # Fastq files from fastq-dump16,1Top
# # FQ1=<SRR>_1.fastq.gz16,0-1Top7,1  89201,0-12,1  345,0-16,1  7,1-88,0-19,1  30293012345,1-8678,1  9401,0-123,1  45,0-16,1  7
# # FQ2=<SRR>_2.fastq.gz48,10%
# 49,0-11%
# echo " -- hgr1 Alignment Pipeline -- "50,12%
# echo " version: $PIPE_VERSION "51,12%
# echo " ami:     $AMI_VERSION  "52,13%
# echo " s3:      $S3URL  "53,14%
# echo " library: $LIBRARY -- $TYPE"54,15%
# echo " date:    $(date)"55,15%
# echo ''56,16%
# 57,0-17%
# # Initialize wordir ---------------------------58,18%
# echo 'Initializing ...'59,18%
# 60,0-19%
# # Make working directory61,110%
# mkdir -p align; cd align62,111%
# 63,0-111%
# # Copy hgrX genome and create bowtie2 index64,112%3,0-12,1  10,0-159,1  87,0-16,1  54321049,0-18,1  765,0-14,1  5,0-16,1  789,0-150,1  1234567,0-18,1  960,0-11,1  23,0-14,1
# cp ~/resources/hgr1/* ./65,113%
# 66,0-114%
# # Load updated GDC token to instance67,114%
# #aws s3 cp $S3URL/scripts/gdc.token gdc.token68,115%
# #chmod 600 gdc.token69,116%
# 70,0-117%
# echo "Download fastq files: $SRA"71,117%
# echo "  cmd: $SRABIN/fastq-dump --gzip --split-files $SRA"72,118%
# 73,0-119%
# $SRABIN/fastq-dump --gzip --split-files $SRA74,120%
# 75,0-120%
# FQ1=$(ls *_1.fastq.gz)76,121%
# FQ2=$(ls *_2.fastq.gz)77,122%
# FQ0=$(ls *_0.fastq.gz)78,122%
# 79,0-123%
# echo "  fastq_1: $FQ1"  80,124%79,0-18,1  765,0-14,1  3,0-12,1  10,0-169,1  70,0-169,1  876,0-17,1  8970,0-11,1  23,0-14,1  5,0-16,1  789,0-180,1
# echo "  fastq_2: $FQ2"81,125%
# 82,0-125%
# # SINGLE END READS ====================================================83,126%
# 84,0-127%
# if [ -s $FQ0 ]85,128%
# then86,128%
# echo "Single-end Reads Detected."87,129%
# echo ''88,130%7654,0-13,1  2,0-11,1  079,0-18,1  765,0-14,1
# echo "ERROR"74,0-130%3
# exit 66673,0-130%4,1  56
# fi76,0-131%7,1  89,0-180,1  1,0-12,1  345678
# 89,0-131%
# # PAIRED END READS ====================================================90,132%
# 91,0-133%
# if [ -s $FQ1 ]92,134%
# then93,134%
# echo "Paired-end Reads Detected."94,135%
# echo ''95,136%
# echo "Starting hgr1 alignment"96,137%
# # Paired-End Extracted Reads Alignment97,137%
# 98,0-138%
# # Bowtie2: align to genome99,139%
# bowtie2 --very-sensitive-local -p $THREADS \100,140%
# --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \101,140%
# --rg PL:$RGPL --rg PU:$RGPU \102,141%
# -x hgr1 -1 $FQ1 -2 $FQ2 | \103,142%
# ~/bin/samtools view -bS - > aligned_unsorted.bam104,143%321099,1 8,0-17,1  654321,0-10,1  89,0-18,1  7654326 fewer linesfiecho "Alignment complete."
# 6 fewer lines82,145%
# "hgr1_align_v3.ccle.sh" 172L, 4975C written
# >ubuntu@ip-172-31-23-92:~$ ubuntu@ip-172-31-23-92:~$ ls
# align  bin  hct116.rna  hgr1_align_v3.ccle.sh  ncbi  resources  software  sratoolkit.2.9.6-1-ubuntu64  sratoolkit.tar.gz
# ubuntu@ip-172-31-23-92:~$ screen -L
# 2 SRX5414471
#  -- hgr1 Alignment Pipeline --
#  version: 190528 build -- CCLE
#  ami:     crown-180813 - ami-0031fd61f932bdef9
#  s3:      s3://crownproject/ccle
#  library: HCT116 -- rna
#  date:    Thu May 30 16:18:25 UTC 2019
#
# Initializing ...
# Download fastq files: SRR8615282
#   cmd: /fastq-dump --gzip --split-files SRR8615282
#   fastq_1: SRR8615282_1.fastq.gz
#   fastq_2: SRR8615282_2.fastq.gz
# Paired-end Reads Detected.
#
# Starting hgr1 alignment
# packet_write_wait: Connection to 54.245.171.125 port 22: Broken pipe
# ssh -i "~/.ssh/CrownKey.pem" ec2-user@ec2-54-188-166-62.us-west-2.compute.amazonaws.com      >
# X11 forwarding request failed on channel 0
# Last login: Fri May 31 17:53:45 2019 from dhcp-206-87-209-247.ubcsecure.wireless.ubc.ca
#
#        __|  __|_  )
#        _|  (     /   Amazon Linux 2 AMI
#       ___|\___|___|
#
# https://aws.amazon.com/amazon-linux-2/
# 36 package(s) needed for security, out of 347 available
# Run "sudo yum update" to apply all updates.
# cat screenlog.0
# kec2-user@ip-172-31-38-171:~\[ec2-user@ip-172-31-38-171 ~]$ cd align/
# kec2-user@ip-172-31-38-171:~/align\[ec2-user@ip-172-31-38-171 align]$ SRABIN="$HOME/sratoolkit.2.9.6-1-ubuntu64/bin"
# kec2-user@ip-172-31-38-171:~/align\[ec2-user@ip-172-31-38-171 align]$ echo Jurkat; date; $SRABIN/prefetch -X 100G -O ./ SRR8615712; date;\
# >         echo K562; $SRABIN/prefetch -X 100G -O ./ SRR8615717; date
# Jurkat
# Fri May 31 15:43:02 UTC 2019
#
# 2019-05-31T15:43:03 prefetch.2.9.3: 1) Downloading 'SRR8615712'...
# 2019-05-31T15:43:03 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:47:51 prefetch.2.9.3: 1) 'SRR8615712' was downloaded successfully
# 2019-05-31T15:48:17 prefetch.2.9.3: 'SRR8615712' has 77 unresolved dependencies
# 2019-05-31T15:48:18 prefetch.2.9.3: 2) Downloading 'ncbi-acc:CM000663.1?vdb-ctx=refseq'...
# 2019-05-31T15:48:18 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:48:21 prefetch.2.9.3: 2) 'ncbi-acc:CM000663.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:48:21 prefetch.2.9.3: 3) Downloading 'ncbi-acc:CM000664.1?vdb-ctx=refseq'...
# 2019-05-31T15:48:21 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:48:25 prefetch.2.9.3: 3) 'ncbi-acc:CM000664.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:48:25 prefetch.2.9.3: 4) Downloading 'ncbi-acc:CM000665.1?vdb-ctx=refseq'...
# 2019-05-31T15:48:25 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:48:28 prefetch.2.9.3: 4) 'ncbi-acc:CM000665.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:48:29 prefetch.2.9.3: 5) Downloading 'ncbi-acc:CM000666.1?vdb-ctx=refseq'...
# 2019-05-31T15:48:29 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:48:32 prefetch.2.9.3: 5) 'ncbi-acc:CM000666.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:48:32 prefetch.2.9.3: 6) Downloading 'ncbi-acc:CM000667.1?vdb-ctx=refseq'...
# 2019-05-31T15:48:32 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:48:35 prefetch.2.9.3: 6) 'ncbi-acc:CM000667.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:48:36 prefetch.2.9.3: 7) Downloading 'ncbi-acc:CM000668.1?vdb-ctx=refseq'...
# 2019-05-31T15:48:36 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:48:38 prefetch.2.9.3: 7) 'ncbi-acc:CM000668.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:48:39 prefetch.2.9.3: 8) Downloading 'ncbi-acc:CM000669.1?vdb-ctx=refseq'...
# 2019-05-31T15:48:39 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:48:42 prefetch.2.9.3: 8) 'ncbi-acc:CM000669.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:48:42 prefetch.2.9.3: 9) Downloading 'ncbi-acc:CM000670.1?vdb-ctx=refseq'...
# 2019-05-31T15:48:42 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:48:44 prefetch.2.9.3: 9) 'ncbi-acc:CM000670.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:48:45 prefetch.2.9.3: 10) Downloading 'ncbi-acc:CM000671.1?vdb-ctx=refseq'...
# 2019-05-31T15:48:45 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:48:47 prefetch.2.9.3: 10) 'ncbi-acc:CM000671.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:48:48 prefetch.2.9.3: 11) Downloading 'ncbi-acc:CM000672.1?vdb-ctx=refseq'...
# 2019-05-31T15:48:48 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:48:50 prefetch.2.9.3: 11) 'ncbi-acc:CM000672.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:48:51 prefetch.2.9.3: 12) Downloading 'ncbi-acc:CM000673.1?vdb-ctx=refseq'...
# 2019-05-31T15:48:51 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:48:53 prefetch.2.9.3: 12) 'ncbi-acc:CM000673.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:48:54 prefetch.2.9.3: 13) Downloading 'ncbi-acc:CM000674.1?vdb-ctx=refseq'...
# 2019-05-31T15:48:54 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:48:56 prefetch.2.9.3: 13) 'ncbi-acc:CM000674.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:48:57 prefetch.2.9.3: 14) Downloading 'ncbi-acc:CM000675.1?vdb-ctx=refseq'...
# 2019-05-31T15:48:57 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:48:59 prefetch.2.9.3: 14) 'ncbi-acc:CM000675.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:00 prefetch.2.9.3: 15) Downloading 'ncbi-acc:CM000676.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:00 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:01 prefetch.2.9.3: 15) 'ncbi-acc:CM000676.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:02 prefetch.2.9.3: 16) Downloading 'ncbi-acc:CM000677.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:02 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:04 prefetch.2.9.3: 16) 'ncbi-acc:CM000677.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:04 prefetch.2.9.3: 17) Downloading 'ncbi-acc:CM000678.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:04 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:06 prefetch.2.9.3: 17) 'ncbi-acc:CM000678.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:07 prefetch.2.9.3: 18) Downloading 'ncbi-acc:CM000679.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:07 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:08 prefetch.2.9.3: 18) 'ncbi-acc:CM000679.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:09 prefetch.2.9.3: 19) Downloading 'ncbi-acc:CM000680.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:09 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:10 prefetch.2.9.3: 19) 'ncbi-acc:CM000680.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:11 prefetch.2.9.3: 20) Downloading 'ncbi-acc:CM000681.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:11 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:12 prefetch.2.9.3: 20) 'ncbi-acc:CM000681.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:13 prefetch.2.9.3: 21) Downloading 'ncbi-acc:CM000682.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:13 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:15 prefetch.2.9.3: 21) 'ncbi-acc:CM000682.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:15 prefetch.2.9.3: 22) Downloading 'ncbi-acc:CM000683.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:15 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:16 prefetch.2.9.3: 22) 'ncbi-acc:CM000683.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:17 prefetch.2.9.3: 23) Downloading 'ncbi-acc:CM000684.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:17 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:18 prefetch.2.9.3: 23) 'ncbi-acc:CM000684.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:18 prefetch.2.9.3: 24) Downloading 'ncbi-acc:CM000685.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:18 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:21 prefetch.2.9.3: 24) 'ncbi-acc:CM000685.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:21 prefetch.2.9.3: 25) Downloading 'ncbi-acc:CM000686.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:21 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:22 prefetch.2.9.3: 25) 'ncbi-acc:CM000686.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:23 prefetch.2.9.3: 26) Downloading 'ncbi-acc:GL000191.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:23 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:24 prefetch.2.9.3: 26) 'ncbi-acc:GL000191.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:24 prefetch.2.9.3: 27) Downloading 'ncbi-acc:GL000192.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:24 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:25 prefetch.2.9.3: 27) 'ncbi-acc:GL000192.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:26 prefetch.2.9.3: 28) Downloading 'ncbi-acc:GL000193.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:26 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:26 prefetch.2.9.3: 28) 'ncbi-acc:GL000193.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:26 prefetch.2.9.3: 29) Downloading 'ncbi-acc:GL000194.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:26 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:27 prefetch.2.9.3: 29) 'ncbi-acc:GL000194.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:27 prefetch.2.9.3: 30) Downloading 'ncbi-acc:GL000195.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:27 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:28 prefetch.2.9.3: 30) 'ncbi-acc:GL000195.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:29 prefetch.2.9.3: 31) Downloading 'ncbi-acc:GL000196.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:29 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:29 prefetch.2.9.3: 31) 'ncbi-acc:GL000196.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:30 prefetch.2.9.3: 32) Downloading 'ncbi-acc:GL000197.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:30 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:30 prefetch.2.9.3: 32) 'ncbi-acc:GL000197.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:30 prefetch.2.9.3: 33) Downloading 'ncbi-acc:GL000198.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:30 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:31 prefetch.2.9.3: 33) 'ncbi-acc:GL000198.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:31 prefetch.2.9.3: 34) Downloading 'ncbi-acc:GL000199.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:31 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:32 prefetch.2.9.3: 34) 'ncbi-acc:GL000199.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:32 prefetch.2.9.3: 35) Downloading 'ncbi-acc:GL000200.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:32 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:33 prefetch.2.9.3: 35) 'ncbi-acc:GL000200.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:34 prefetch.2.9.3: 36) Downloading 'ncbi-acc:GL000201.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:34 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:34 prefetch.2.9.3: 36) 'ncbi-acc:GL000201.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:34 prefetch.2.9.3: 37) Downloading 'ncbi-acc:GL000203.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:34 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:35 prefetch.2.9.3: 37) 'ncbi-acc:GL000203.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:35 prefetch.2.9.3: 38) Downloading 'ncbi-acc:GL000204.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:35 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:36 prefetch.2.9.3: 38) 'ncbi-acc:GL000204.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:36 prefetch.2.9.3: 39) Downloading 'ncbi-acc:GL000205.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:36 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:37 prefetch.2.9.3: 39) 'ncbi-acc:GL000205.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:37 prefetch.2.9.3: 40) Downloading 'ncbi-acc:GL000206.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:37 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:38 prefetch.2.9.3: 40) 'ncbi-acc:GL000206.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:38 prefetch.2.9.3: 41) Downloading 'ncbi-acc:GL000208.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:38 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:39 prefetch.2.9.3: 41) 'ncbi-acc:GL000208.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:39 prefetch.2.9.3: 42) Downloading 'ncbi-acc:GL000209.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:39 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:40 prefetch.2.9.3: 42) 'ncbi-acc:GL000209.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:40 prefetch.2.9.3: 43) Downloading 'ncbi-acc:GL000210.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:40 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:41 prefetch.2.9.3: 43) 'ncbi-acc:GL000210.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:41 prefetch.2.9.3: 44) Downloading 'ncbi-acc:GL000211.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:41 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:41 prefetch.2.9.3: 44) 'ncbi-acc:GL000211.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:42 prefetch.2.9.3: 45) Downloading 'ncbi-acc:GL000212.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:42 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:42 prefetch.2.9.3: 45) 'ncbi-acc:GL000212.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:43 prefetch.2.9.3: 46) Downloading 'ncbi-acc:GL000213.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:43 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:44 prefetch.2.9.3: 46) 'ncbi-acc:GL000213.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:44 prefetch.2.9.3: 47) Downloading 'ncbi-acc:GL000214.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:44 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:45 prefetch.2.9.3: 47) 'ncbi-acc:GL000214.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:45 prefetch.2.9.3: 48) Downloading 'ncbi-acc:GL000215.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:45 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:45 prefetch.2.9.3: 48) 'ncbi-acc:GL000215.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:46 prefetch.2.9.3: 49) Downloading 'ncbi-acc:GL000216.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:46 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:46 prefetch.2.9.3: 49) 'ncbi-acc:GL000216.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:47 prefetch.2.9.3: 50) Downloading 'ncbi-acc:GL000217.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:47 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:47 prefetch.2.9.3: 50) 'ncbi-acc:GL000217.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:48 prefetch.2.9.3: 51) Downloading 'ncbi-acc:GL000218.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:48 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:49 prefetch.2.9.3: 51) 'ncbi-acc:GL000218.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:49 prefetch.2.9.3: 52) Downloading 'ncbi-acc:GL000219.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:49 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:50 prefetch.2.9.3: 52) 'ncbi-acc:GL000219.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:50 prefetch.2.9.3: 53) Downloading 'ncbi-acc:GL000220.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:50 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:51 prefetch.2.9.3: 53) 'ncbi-acc:GL000220.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:51 prefetch.2.9.3: 54) Downloading 'ncbi-acc:GL000221.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:51 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:52 prefetch.2.9.3: 54) 'ncbi-acc:GL000221.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:52 prefetch.2.9.3: 55) Downloading 'ncbi-acc:GL000222.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:52 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:52 prefetch.2.9.3: 55) 'ncbi-acc:GL000222.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:53 prefetch.2.9.3: 56) Downloading 'ncbi-acc:GL000223.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:53 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:54 prefetch.2.9.3: 56) 'ncbi-acc:GL000223.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:54 prefetch.2.9.3: 57) Downloading 'ncbi-acc:GL000224.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:54 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:55 prefetch.2.9.3: 57) 'ncbi-acc:GL000224.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:55 prefetch.2.9.3: 58) Downloading 'ncbi-acc:GL000225.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:55 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:56 prefetch.2.9.3: 58) 'ncbi-acc:GL000225.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:56 prefetch.2.9.3: 59) Downloading 'ncbi-acc:GL000226.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:56 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:57 prefetch.2.9.3: 59) 'ncbi-acc:GL000226.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:57 prefetch.2.9.3: 60) Downloading 'ncbi-acc:GL000227.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:57 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:58 prefetch.2.9.3: 60) 'ncbi-acc:GL000227.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:58 prefetch.2.9.3: 61) Downloading 'ncbi-acc:GL000228.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:58 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:49:59 prefetch.2.9.3: 61) 'ncbi-acc:GL000228.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:49:59 prefetch.2.9.3: 62) Downloading 'ncbi-acc:GL000229.1?vdb-ctx=refseq'...
# 2019-05-31T15:49:59 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:00 prefetch.2.9.3: 62) 'ncbi-acc:GL000229.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:00 prefetch.2.9.3: 63) Downloading 'ncbi-acc:GL000230.1?vdb-ctx=refseq'...
# 2019-05-31T15:50:00 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:01 prefetch.2.9.3: 63) 'ncbi-acc:GL000230.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:01 prefetch.2.9.3: 64) Downloading 'ncbi-acc:GL000231.1?vdb-ctx=refseq'...
# 2019-05-31T15:50:01 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:01 prefetch.2.9.3: 64) 'ncbi-acc:GL000231.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:02 prefetch.2.9.3: 65) Downloading 'ncbi-acc:GL000232.1?vdb-ctx=refseq'...
# 2019-05-31T15:50:02 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:02 prefetch.2.9.3: 65) 'ncbi-acc:GL000232.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:03 prefetch.2.9.3: 66) Downloading 'ncbi-acc:GL000234.1?vdb-ctx=refseq'...
# 2019-05-31T15:50:03 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:03 prefetch.2.9.3: 66) 'ncbi-acc:GL000234.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:04 prefetch.2.9.3: 67) Downloading 'ncbi-acc:GL000235.1?vdb-ctx=refseq'...
# 2019-05-31T15:50:04 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:04 prefetch.2.9.3: 67) 'ncbi-acc:GL000235.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:05 prefetch.2.9.3: 68) Downloading 'ncbi-acc:GL000237.1?vdb-ctx=refseq'...
# 2019-05-31T15:50:05 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:05 prefetch.2.9.3: 68) 'ncbi-acc:GL000237.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:06 prefetch.2.9.3: 69) Downloading 'ncbi-acc:GL000238.1?vdb-ctx=refseq'...
# 2019-05-31T15:50:06 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:06 prefetch.2.9.3: 69) 'ncbi-acc:GL000238.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:07 prefetch.2.9.3: 70) Downloading 'ncbi-acc:GL000240.1?vdb-ctx=refseq'...
# 2019-05-31T15:50:07 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:07 prefetch.2.9.3: 70) 'ncbi-acc:GL000240.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:08 prefetch.2.9.3: 71) Downloading 'ncbi-acc:GL000241.1?vdb-ctx=refseq'...
# 2019-05-31T15:50:08 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:08 prefetch.2.9.3: 71) 'ncbi-acc:GL000241.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:09 prefetch.2.9.3: 72) Downloading 'ncbi-acc:GL000242.1?vdb-ctx=refseq'...
# 2019-05-31T15:50:09 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:09 prefetch.2.9.3: 72) 'ncbi-acc:GL000242.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:10 prefetch.2.9.3: 73) Downloading 'ncbi-acc:GL000243.1?vdb-ctx=refseq'...
# 2019-05-31T15:50:10 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:10 prefetch.2.9.3: 73) 'ncbi-acc:GL000243.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:11 prefetch.2.9.3: 74) Downloading 'ncbi-acc:GL000244.1?vdb-ctx=refseq'...
# 2019-05-31T15:50:11 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:11 prefetch.2.9.3: 74) 'ncbi-acc:GL000244.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:11 prefetch.2.9.3: 75) Downloading 'ncbi-acc:GL000246.1?vdb-ctx=refseq'...
# 2019-05-31T15:50:11 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:12 prefetch.2.9.3: 75) 'ncbi-acc:GL000246.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:12 prefetch.2.9.3: 76) Downloading 'ncbi-acc:GL000249.1?vdb-ctx=refseq'...
# 2019-05-31T15:50:12 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:13 prefetch.2.9.3: 76) 'ncbi-acc:GL000249.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:13 prefetch.2.9.3: 77) Downloading 'ncbi-acc:NC_007605.1?vdb-ctx=refseq'...
# 2019-05-31T15:50:13 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:14 prefetch.2.9.3: 77) 'ncbi-acc:NC_007605.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:14 prefetch.2.9.3: 78) Downloading 'ncbi-acc:NC_012920.1?vdb-ctx=refseq'...
# 2019-05-31T15:50:14 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:15 prefetch.2.9.3: 78) 'ncbi-acc:NC_012920.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:50:16 prefetch.2.9.3: 'SRR8615712' has remote vdbcache
# 2019-05-31T15:50:16 prefetch.2.9.3:  Downloading vdbcache...
# 2019-05-31T15:50:16 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:50:29 prefetch.2.9.3:  vdbcache was downloaded successfully
# Fri May 31 15:50:29 UTC 2019
# K562
#
# 2019-05-31T15:50:31 prefetch.2.9.3: 1) Downloading 'SRR8615717'...
# 2019-05-31T15:50:31 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:56:40 prefetch.2.9.3: 1) 'SRR8615717' was downloaded successfully
# 2019-05-31T15:57:05 prefetch.2.9.3: 'SRR8615717' has 78 unresolved dependencies
# 2019-05-31T15:57:07 prefetch.2.9.3: 2) 'ncbi-acc:CM000663.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:08 prefetch.2.9.3: 3) 'ncbi-acc:CM000664.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:08 prefetch.2.9.3: 4) 'ncbi-acc:CM000665.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:09 prefetch.2.9.3: 5) 'ncbi-acc:CM000666.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:10 prefetch.2.9.3: 6) 'ncbi-acc:CM000667.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:11 prefetch.2.9.3: 7) 'ncbi-acc:CM000668.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:11 prefetch.2.9.3: 8) 'ncbi-acc:CM000669.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:12 prefetch.2.9.3: 9) 'ncbi-acc:CM000670.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:13 prefetch.2.9.3: 10) 'ncbi-acc:CM000671.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:13 prefetch.2.9.3: 11) 'ncbi-acc:CM000672.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:14 prefetch.2.9.3: 12) 'ncbi-acc:CM000673.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:15 prefetch.2.9.3: 13) 'ncbi-acc:CM000674.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:15 prefetch.2.9.3: 14) 'ncbi-acc:CM000675.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:16 prefetch.2.9.3: 15) 'ncbi-acc:CM000676.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:16 prefetch.2.9.3: 16) 'ncbi-acc:CM000677.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:17 prefetch.2.9.3: 17) 'ncbi-acc:CM000678.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:17 prefetch.2.9.3: 18) 'ncbi-acc:CM000679.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:18 prefetch.2.9.3: 19) 'ncbi-acc:CM000680.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:19 prefetch.2.9.3: 20) 'ncbi-acc:CM000681.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:19 prefetch.2.9.3: 21) 'ncbi-acc:CM000682.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:20 prefetch.2.9.3: 22) 'ncbi-acc:CM000683.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:21 prefetch.2.9.3: 23) 'ncbi-acc:CM000684.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:21 prefetch.2.9.3: 24) 'ncbi-acc:CM000685.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:22 prefetch.2.9.3: 25) 'ncbi-acc:CM000686.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:22 prefetch.2.9.3: 26) 'ncbi-acc:GL000191.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:23 prefetch.2.9.3: 27) 'ncbi-acc:GL000192.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:23 prefetch.2.9.3: 28) 'ncbi-acc:GL000193.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:24 prefetch.2.9.3: 29) 'ncbi-acc:GL000194.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:25 prefetch.2.9.3: 30) 'ncbi-acc:GL000195.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:25 prefetch.2.9.3: 31) 'ncbi-acc:GL000196.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:26 prefetch.2.9.3: 32) 'ncbi-acc:GL000197.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:26 prefetch.2.9.3: 33) 'ncbi-acc:GL000198.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:27 prefetch.2.9.3: 34) 'ncbi-acc:GL000199.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:27 prefetch.2.9.3: 35) 'ncbi-acc:GL000200.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:28 prefetch.2.9.3: 36) Downloading 'ncbi-acc:GL000202.1?vdb-ctx=refseq'...
# 2019-05-31T15:57:28 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:57:28 prefetch.2.9.3: 36) 'ncbi-acc:GL000202.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:57:29 prefetch.2.9.3: 37) 'ncbi-acc:GL000203.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:29 prefetch.2.9.3: 38) 'ncbi-acc:GL000204.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:30 prefetch.2.9.3: 39) 'ncbi-acc:GL000205.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:31 prefetch.2.9.3: 40) 'ncbi-acc:GL000208.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:31 prefetch.2.9.3: 41) 'ncbi-acc:GL000209.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:32 prefetch.2.9.3: 42) 'ncbi-acc:GL000211.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:32 prefetch.2.9.3: 43) 'ncbi-acc:GL000212.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:33 prefetch.2.9.3: 44) 'ncbi-acc:GL000213.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:34 prefetch.2.9.3: 45) 'ncbi-acc:GL000214.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:34 prefetch.2.9.3: 46) 'ncbi-acc:GL000215.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:35 prefetch.2.9.3: 47) 'ncbi-acc:GL000216.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:35 prefetch.2.9.3: 48) 'ncbi-acc:GL000217.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:36 prefetch.2.9.3: 49) 'ncbi-acc:GL000218.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:36 prefetch.2.9.3: 50) 'ncbi-acc:GL000219.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:37 prefetch.2.9.3: 51) 'ncbi-acc:GL000220.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:38 prefetch.2.9.3: 52) 'ncbi-acc:GL000221.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:38 prefetch.2.9.3: 53) 'ncbi-acc:GL000222.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:39 prefetch.2.9.3: 54) 'ncbi-acc:GL000223.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:39 prefetch.2.9.3: 55) 'ncbi-acc:GL000224.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:40 prefetch.2.9.3: 56) 'ncbi-acc:GL000225.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:41 prefetch.2.9.3: 57) 'ncbi-acc:GL000227.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:41 prefetch.2.9.3: 58) 'ncbi-acc:GL000228.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:42 prefetch.2.9.3: 59) 'ncbi-acc:GL000229.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:42 prefetch.2.9.3: 60) 'ncbi-acc:GL000230.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:43 prefetch.2.9.3: 61) 'ncbi-acc:GL000231.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:44 prefetch.2.9.3: 62) 'ncbi-acc:GL000232.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:44 prefetch.2.9.3: 63) Downloading 'ncbi-acc:GL000233.1?vdb-ctx=refseq'...
# 2019-05-31T15:57:44 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:57:45 prefetch.2.9.3: 63) 'ncbi-acc:GL000233.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:57:45 prefetch.2.9.3: 64) 'ncbi-acc:GL000234.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:46 prefetch.2.9.3: 65) 'ncbi-acc:GL000235.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:46 prefetch.2.9.3: 66) Downloading 'ncbi-acc:GL000236.1?vdb-ctx=refseq'...
# 2019-05-31T15:57:46 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:57:47 prefetch.2.9.3: 66) 'ncbi-acc:GL000236.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:57:47 prefetch.2.9.3: 67) 'ncbi-acc:GL000237.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:48 prefetch.2.9.3: 68) 'ncbi-acc:GL000238.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:49 prefetch.2.9.3: 69) Downloading 'ncbi-acc:GL000239.1?vdb-ctx=refseq'...
# 2019-05-31T15:57:49 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:57:49 prefetch.2.9.3: 69) 'ncbi-acc:GL000239.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:57:49 prefetch.2.9.3: 70) 'ncbi-acc:GL000240.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:50 prefetch.2.9.3: 71) 'ncbi-acc:GL000241.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:51 prefetch.2.9.3: 72) 'ncbi-acc:GL000243.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:51 prefetch.2.9.3: 73) 'ncbi-acc:GL000244.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:52 prefetch.2.9.3: 74) Downloading 'ncbi-acc:GL000245.1?vdb-ctx=refseq'...
# 2019-05-31T15:57:52 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:57:52 prefetch.2.9.3: 74) 'ncbi-acc:GL000245.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:57:53 prefetch.2.9.3: 75) 'ncbi-acc:GL000246.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:54 prefetch.2.9.3: 76) Downloading 'ncbi-acc:GL000247.1?vdb-ctx=refseq'...
# 2019-05-31T15:57:54 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:57:54 prefetch.2.9.3: 76) 'ncbi-acc:GL000247.1?vdb-ctx=refseq' was downloaded successfully
# 2019-05-31T15:57:55 prefetch.2.9.3: 77) 'ncbi-acc:GL000249.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:55 prefetch.2.9.3: 78) 'ncbi-acc:NC_007605.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:56 prefetch.2.9.3: 79) 'ncbi-acc:NC_012920.1?vdb-ctx=refseq' is found locally
# 2019-05-31T15:57:57 prefetch.2.9.3: 'SRR8615717' has remote vdbcache
# 2019-05-31T15:57:57 prefetch.2.9.3:  Downloading vdbcache...
# 2019-05-31T15:57:57 prefetch.2.9.3:  Downloading via https...
# 2019-05-31T15:58:20 prefetch.2.9.3:  vdbcache was downloaded successfully
# Fri May 31 15:58:20 UTC 2019
# kec2-user@ip-172-31-38-171:~/align\[ec2-user@ip-172-31-38-171 align]$ kec2-user@ip-172-31-38-171:~\[ec2-user@ip-172-31-38-171 ~]$

# %%
# Install Aspera ASCP for faster DL (possibly)
# https://download.asperasoft.com/download/sw/connect/3.9.1/ibm-aspera-connect-3.9.1.171801-linux-g2.12-64.tar.gz

wget https://download.asperasoft.com/download/sw/connect/3.9.1/ibm-aspera-connect-3.9.1.171801-linux-g2.12-64.tar.gz
mv ibm-aspera-connect-3.9.1.171801-linux-g2.12-64.tar.gz ascp.tar.gz
aws s3 cp ascp.tar.gz 

aws s3 cp s3://crownproject/ccle/scripts/ascp.tar.gz ./
gzip -dc ascp.tar.gz | tar -xf -
bash ibm-aspera-connect-3.9.1.171801-linux-g2.12-64.sh

SRABIN="$HOME/sratoolkit.2.9.6-1-ubuntu64/bin" # binary path
/home/ec2-user/.aspera/connect

$SRABIN/prefetch --ascp-path \
  '$HOME/.aspera/connect/bin/ascp|$HOME/.aspera/connect/etc/asperaweb_id_dsa.openssh"' \
  $SRA

## Test fastq-dump
## KMH2 6271Mb SRR8615908
## HL60 8281Mb SRR8616133

SRABIN="$HOME/sratoolkit.2.9.6-1-ubuntu64/bin" # binary path
echo KMH2; date -u; $SRABIN/prefetch --ascp-path \
  "$HOME/.aspera/connect/bin/ascp|$HOME/.aspera/connect/etc/asperaweb_id_dsa.openssh"\
  SRR8615908; date -u;\
echo HL60; $SRABIN/prefetch --ascp-path \
  "$HOME/.aspera/connect/bin/ascp|$HOME/.aspera/connect/etc/asperaweb_id_dsa.openssh" \
  SRR8616133;\ date -u
  
  
## START: Fri May 31 19:23:10 UTC 2019
## FILE:  Fri May 31 19:35:15 UTC 2019
## END:    ~  May 31 19:47

#test fasterq-dump
# memory; threads; split
#$SRABIN/fasterq-dump --mem 500MB -e 2 -S

# SRA Files are stored with 'reference sequence' requisites
# download times can be minimized if an update of the TCGA run node is made with
# the reference files already pre-downloaded. They won't have to re-download.
#
# 418M May 31 19:27 SRR8615908.sra.vdbcache.cache #SRR file finished here.

# %%
## Update EC2 Instance for rapid SRA compatibility
## Launch AMI: crown-180914 (ami-096bcb9d18c32d4d5)
## t2.large
## 

# sudo apt-get update

## Clear out unneccesary TCGA data (this isn't a data instance) ==========================
## -128 Gb
# rm -r ~/tcga/*
# rmdir ~/tcga
# rm ~/logs/*

## Install Software Updates
# cd software

## SRA TOOLKIT 2.9.6-1-ubuntu64 ============================================================
# wget https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-ubuntu64.tar.gz
# gzip -dc sratoolkit.current-ubuntu64.tar.gz | tar -xf -
# mv sratoolkit.current-ubuntu64.tar.gz zips/
# ln -fs /home/ubuntu/software/sratoolkit.2.9.6-1-ubuntu64/bin/* ~/bin/

## ASCP 3.9.1.171801.linux ================================================================
# wget https://download.asperasoft.com/download/sw/connect/3.9.1/ibm-aspera-connect-3.9.1.171801-linux-g2.12-64.tar.gz
# gzip -dc ibm-aspera-connect-3.9.1.171801-linux-g2.12-64.tar.gz | tar -xf -
# bash ibm-aspera-connect-3.9.1.171801-linux-g2.12-64.sh
# rm ibm-aspera-connect-3.9.1.171801-linux-g2.12-64.sh

## Download refseq reference files for SRA (hg38 I think)
# mkdir -p ~/tmp; cd ~/tmp

## SRA prefetch resources - RNAseq
# prefetch --ascp-path "$HOME/.aspera/connect/bin/ascp|$HOME/.aspera/connect/etc/asperaweb_id_dsa.openssh" SRR8615908
# prefetch --ascp-path "$HOME/.aspera/connect/bin/ascp|$HOME/.aspera/connect/etc/asperaweb_id_dsa.openssh" SRR8616133

## SRA prefetch resources - DNAseq
# prefetch --ascp-path -X 100G "$HOME/.aspera/connect/bin/ascp|$HOME/.aspera/connect/etc/asperaweb_id_dsa.openssh" SRR8639145

## clear SRA files (retaining refseq files)
# rm /home/ubuntu/ncbi/public/sra/*

## Bowtie2 SRA ============================================================================
## NOTE: Update bowtie2 to newest version and it can read SRA files directly for alignment
## this will bypass alignment dump steps completely.

# wget https://downloads.sourceforge.net/project/bowtie-bio/bowtie2/2.3.5.1/bowtie2-2.3.5.1-sra-linux-x86_64.zip?r=https%3A%2F%2Fsourceforge.net%2Fprojects%2Fbowtie-bio%2Ffiles%2Fbowtie2%2F2.3.5.1%2Fbowtie2-2.3.5.1-sra-linux-x86_64.zip%2Fdownload&ts=1559337015
# unzip bowtie2-2.3.5.1-sra-linux-x86_64
# cd ~/software/bowtie2-2.3.5.1-sra-linux-x86_64
# mv bowtie* ~/bin/
# which bowtie2 ## /home/ubuntu/bin/bowtie2

## Test new bowtie2 with SRA
# testing SRA align
# cd ~/tmp
# bowtie2 --very-fast -p 1 \
#      --rg-id TEST --rg LB:TEST --rg SM:TEST \
#      --rg PL:TEST --rg PU:TEST \
#      -x hgr1 --sra SRR8639145 | \
#      ~/bin/samtools view -bS - > aligned_unsorted.bam

## Appears to work transparently... will take too long to run the entire process here
      

## Copy to S3 Zips
# aws s3 cp bowtie2-2.3.5.1-sra-linux-x86_64.zip s3://crownproject/software/
# aws s3 cp ibm-aspera-connect-3.9.1.171801-linux-g2.12-64.tar.gz s3://crownproject/software/
# aws s3 cp sratoolkit.2.9.6-1-ubuntu64/sratoolkit.current-ubuntu64.tar.gz s3://crownproject/software/

# Final du -ch
# 8.5G    total


## Take AMI image
## Save AMI: crown-190601 (ami-0b375c9c58cb4a7a2)
## description: aligner drone -- sra compatible

# %% [markdown]
# ### Test Run II
#
# Test the WGS files for alignment. This should be very very much faster.

# %% [markdown]
# #### Input Files / Scripts

# %%
cd $WORKDIR

INPUT='ccle_pilot2.input'
cat $INPUT

echo ''
echo ''
# Out:
# HCT116	wgs	SAMN10988251	SRR8639145	SRX5437588
# HCT15	wgs	SAMN10987770	SRR8639146	SRX5437587

# %%
# Echo scripts to be used for this analysis for version control.
# Note these need to be manually copied to the $WORKDIR


cat hgr1_align_v4.ccle.sh
echo 
echo
cat queenB.sh
echo 
echo
cat droneB.sh
echo 
echo
# Out:
# #!/bin/bash
# # hgr1_align_v4.ccle.sh
# # rDNA alignment pipeline - SRA version
# PIPE_VERSION='190531 build -- CCLE'
# AMI_VERSION='crown-190601 - ami-0b375c9c58cb4a7a2'
# # EC2: c4.2xlarge (8cpu / 15 gb)
# # EC2: c4.xlarge  (4cpu / 8  gb)
# # Storage: 200 Gb
# #
#
# # Input Requirements --------------------------
#
# # $1 : Library name + Output name(unique)
# # $2 : Seq-read type (wgs|rna)
# # $3 : BioSample ID
# # $4 : Library SRA Accession
#
# # Control Panel -------------------------------
# # Amazon AWS S3 Home URL
#   S3URL='s3://crownproject/ccle'
#
# # CPU
# 	THREADS='3'
#
# # Terminate instances upon completion (for debuggin)
#   TERMINATE='TRUE'
#
# # Read Group Data
#   LIBRARY=$1    # Library Name / File prefix
#   TYPE=$2       # wgs OR rna data-type
# 	RGPO='ccle'   # Patient Population - CCLE
# 	RGSM=$3       # Sample / Patient Identifer
# 	RGID=$4       # Read Group ID. SRA Accession Number
#   RGLB=$LIBRARY # Library Name. Accession Number
#   RGPL='ILLUMINA' # Seq Platform
#   RGPU=$5       # Read Group. Platform Unit (SRA Experiment)
#
#
#   SRA=$4
#   OUTPUT="$LIBRARY.$TYPE" # Output filename
#
#   # Fastq files from fastq-dump
#   # FQ1=<SRR>_1.fastq.gz
#   # FQ2=<SRR>_2.fastq.gz
#
# echo " -- hgr1 Alignment Pipeline -- "
# echo " version: $PIPE_VERSION "
# echo " ami:     $AMI_VERSION  "
# echo " s3:      $S3URL  "
# echo " library: $LIBRARY -- $TYPE"
# echo " date:    $(date)"
# echo ''
#
# # Initialize wordir ---------------------------
# echo 'Initializing ...'
#
# # Make working directory
#   mkdir -p align; cd align
#
# # Copy hgrX genome and create bowtie2 index
#   cp ~/resources/hgr1/* ./
#
# # Load updated GDC token to instance
# #aws s3 cp $S3URL/scripts/gdc.token gdc.token
# #chmod 600 gdc.token
#
# echo "Download SRA file: $SRA"
# echo "  cmd: prefetch -X 100G --ascp-path <PATH> $SRA"
#
# prefetch -X 100G --ascp-path \
#   "$HOME/.aspera/connect/bin/ascp|$HOME/.aspera/connect/etc/asperaweb_id_dsa.openssh"\
#   $SRA
#
# # SRA INPUT ====================================================
#
# #if [ -s $FQ1 ]
# #then
#     echo "SRA Input Pipe"
#     echo ''
#     echo "Starting hgr1 alignment"
#     # Paired-End Extracted Reads Alignment
#
#     # Bowtie2: align to genome
#     bowtie2 --very-sensitive-local -p $THREADS \
#       --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \
#       --rg PL:$RGPL --rg PU:$RGPU \
#       -x hgr1 -sra $SRA | \
#       ~/bin/samtools view -bS - > aligned_unsorted.bam
#
#     echo "Alignment complete."
#     echo "Calculate flagstats."
#
#     # Calcualte library flagstats
#       ~/bin/samtools flagstat aligned_unsorted.bam > aligned_unsorted.flagstat
#
#     # Read Subset ------------------------------
#     echo "Subset reads (retain mapped & their pairs, remove unmapped)."
#
#     # Extract mapped reads, and their unmapped pairs
#
#       # Extract Header
#       ~/bin/samtools view -H aligned_unsorted.bam > align.header.tmp
#
#       # Unmapped reads with mapped pairs
#       # Extract Mapped Reads
#       # and their unmapped pairs
#       ~/bin/samtools view -b -F 4 aligned_unsorted.bam > align.F4.bam #mapped
#       ~/bin/samtools view -b -f 4 -F 8 aligned_unsorted.bam > align.f4F8.bam #unmapped pairs
#
#       echo "Recompiling mapped bam file."
#
#       # Re-compile bam file
#       ~/bin/samtools cat -h align.header.tmp -o align.hgr1.tmp.bam align.F4.bam align.f4F8.bam
#         ~/bin/samtools sort -@ $THREADS -O BAM align.hgr1.tmp.bam > align.hgr1.bam
#         ~/bin/samtools index align.hgr1.bam
#         ~/bin/samtools flagstat align.hgr1.bam > align.hgr1.flagstat
#
#       # Clean up
#       rm *tmp* align.F4.bam align.f4F8.bam
#
#     echo "Processing complete. Copy files to S3"
#     # Rename the total Bam Files
#       mv aligned_unsorted.bam $OUTPUT.bam
#       #mv aligned_unsorted.bam.bai $OUTPUT.bam.bai
#       mv aligned_unsorted.flagstat $OUTPUT.flagstat
#
#     # Rename the hgr-aligned Bam files
#       mv align.hgr1.bam $OUTPUT.hgr1.bam
#       mv align.hgr1.bam.bai $OUTPUT.hgr1.bam.bai
#       mv align.hgr1.flagstat $OUTPUT.hgr1.flagstat
#
#     # Copy output to AWS S3
#     # Alignments (Full)
#       aws s3 cp $OUTPUT.flagstat $S3URL/hgr1/
#
#     # Alignments (Aligned)
#       aws s3 cp $OUTPUT.hgr1.bam $S3URL/hgr1/
#       aws s3 cp $OUTPUT.hgr1.bam.bai $S3URL/hgr1/
#       aws s3 cp $OUTPUT.hgr1.flagstat $S3URL/hgr1/
#
# #fi
#
# echo "Create log files and copy to S3"
# # Copy screen log file to AWS S3
# cp ~/screenlog.0 ./$OUTPUT.screenlog
# aws s3 cp $OUTPUT.screenlog $S3URL/logs/
#
# # Shutdown and Terminate instance
# EC2ID=$(ec2metadata --instance-id)
# sleep 20s # to catch errors
#
# if [ "$TERMINATE" = TRUE ]
# then
#   echo "Run Complete -- Shutting down instance."
#   aws ec2 terminate-instances --instance-ids $EC2ID
# else
#   echo "Run Complete -- Instance is online."
# fi
#
# # Script complete
#
#
# #!/bin/bash
# # queenB.sh
# # 20180814 build
# # EC2 Launch / Control Script
# #
#
# # 1. queenB script is initialized locally and input files
# #    are parsed ready for cluster analaysis
# # 2. queenB launches instances, logs in to it and runs the
# #    droneB.sh script remotely.
# # 3. The droneB script is executed on the instance and it
# #    launches a `screen` on the instance and loads and
# #    starts to perform the $TASK (gather.sh) script.
# # 4. TASK script should include a instance shut-down
# #    command to close instance upon completion.
# #
#
# # Control Panel =========================
# # Amazon AWS S3 Home URL
# S3URL='s3://crownproject/ccle'
#
# # EC2 TASK Script - script for droneB to execute
# TASK="$S3URL/scripts/hgr1_align_v4.ccle.sh"
#
# # Parameter file:
# # Each line of PARAMETERS will be input to STDIN of
# # the droneB script which can then be used to run the
# # TASK script.
# # i.e. bash droneB.sh <line_N_of_PARAMETERS>
# # PARAMETERS="tcga0_input.txt"
# PARAMETERS=$1
#
# # EC2 Set-up
# instanceTYPE='c4.xlarge'
# imageID='ami-0b375c9c58cb4a7a2' #AMI Crown CCLE/SRA
#
# devNAME='/dev/sda1' # /dev/sda1 for Crown-AMI
# volSIZE='200' # in Gb
#
# # Maximum number of EC2 instances to run simultaniously
# MAX_INSTANCE='20'
#
# # Number of instances to launch
# #COUNT=2 # predetermined number
# COUNT=$(awk 'END{print NR}' $PARAMETERS) # for each input argument
#
# # Security
# keyNAME='CrownKey'
# keyPATH="/home/ec2-user/.ssh/CrownKey.pem"
# secGROUP='crown-group'
#
# # Input Validation ======================
# # Test input file for duplicate sample ID (which will cause file collisions downstream)
# # exit with error 1 if collision exists
#
# SAMPLEIDS=$(cut -f1 $1 | uniq -d )
#
# if [ -n "$SAMPLEIDS" ]
# then
#   # If there are duplicate sample IDs exit
#   echo "Error 02 - Duplicate Sample ID detected in input"
#   echo " I hope you know what you're doing"
#   echo " script will not exit in this version"
#   echo " re-run with unique ID or outputs will overwrite"
#   echo ""
#   #echo "$SAMPLEIDS"
#   #exit 2
# fi
#
# # Script Core ===========================
#
# for ITER in $(seq 1 $COUNT)
# do
#
#   # Count the total number of instances
#   running_instance=$(aws ec2 describe-instances |\
#     grep '"Name": "running"' - |\
#     wc -l - | cut -f1 -d' ' - )
#
#   while [ $running_instance -ge $MAX_INSTANCE ];
#   do
#
#   	echo "Reached max of $running_instance, wait."
#   	echo ''
#
#   	# If there are greater then 25 instances
#   	# wait for instance to close
#   	sleep 5m
#
#   	running_instance=$(aws ec2 describe-instances |\
#     grep '"Name": "running"' - |\
#     wc -l - | cut -f1 -d' ' - )
#   done
#
#   # Extract Parameters/Arguments ----------
#
#   ARGS=$(sed -n "$ITER"p $PARAMETERS | sed 's/\t/ /g' - )
#
#   echo "Launch instance # $ITER"
#   date
#   echo "Instance Type: $instanceTYPE"
#   echo "AMI Image: $imageID"
#   echo "Run Script: $TASK"
#   echo "Parameters: $ARGS"
#
#   # Launch an instance --------------------
#   # NOTE: each iteration of the for loop launches one instance
#   # therefore each loop launches only one instance
#   aws ec2 run-instances --image-id $imageID --count 1 \
#    --instance-type $instanceTYPE --key-name $keyNAME \
#    --block-device-mappings DeviceName=$devNAME,Ebs={VolumeSize=$volSIZE} \
#    --security-groups $secGROUP > launch.tmp
#
#   # Another alternative is to use --user-data droneB.sh
#   # which will run at instance boot-up
#   # passing arguments to it may be challenging
#
#   # Retrieve instance ID
#   instanceID=$(cat launch.tmp | \
#     egrep -o -e 'InstanceId[":/A-Za-z0-9_ \\-]*' - |\
#     cut -f2 -d' ' - | xargs)
#
#   echo "Instance ID: $instanceID"
#
#
#   # Add a few minute wait here to allow for Public DNS to be assigned
#   # otherwise ssh doesn't work
#   # CURRENT BOTTLENECK
#   sleep 180s
#
#   # Check that the instance is 'running' and not pending
#   pending_instance=$(aws ec2 describe-instances |\
#    grep '"Name": "pending"' - |\
#    wc -l - | cut -f1 -d' ' - )
#
#   while [ $pending_instance -gt 0 ];
#   do
#
#   	echo "Launchign instance not ready yet, chill"
#   	# Instance still pending
#   	sleep 180s
#
#     pending_instance=$(aws ec2 describe-instances |\
#      grep '"Name": "pending"' - |\
#      wc -l - | cut -f1 -d' ' - )
#   done
#
#
#   # Retrieve public DNS
#   aws ec2 describe-instances --instance-ids $instanceID > launch2.tmp
#
#   pubDNS=$(cat launch2.tmp | \
#     egrep -o -m 1 -e 'PublicDnsName[.":/A-Za-z0-9_ \\-]*' - |\
#     cut -f2 -d' ' - | xargs)
#
#   echo "Public DNS: $pubDNS"
#
#   # Access the instance -------------------
#
#   LOGIN="ubuntu@$pubDNS"
#
#   ssh -i $keyPATH \
#     -o StrictHostKeyChecking=no \
#     $LOGIN 'bash -s' < droneB.sh $TASK $(echo $ARGS)
#
#   # Cleanup
#   rm *.tmp
#
#   echo ''
#   echo ''
#
# done
#
# # end of script
#
# #!/bin/bash
# # droneB.sh
# #
#
# # This script-layer is neccesary to launch a screen session
# # on each ec2-machine. The pipeline is run within that session
# # and the output is logged. This allows 'looking in' on sessions
# # as they are running.
#
# # Commands to run on server-side
# # ===============================================================
#
# SCRIPTPATH=$1
#
# SCRIPT=$(basename $1)
#
# shift # drop first (TASK or SCRIPT variable)
#
# # Download pipeline / droneB's function
#   aws s3 cp $SCRIPTPATH ./
#
#   chmod 777 *.sh
#
# # open screen; run gather.sh function. -L logged
#   screen -Ldmt sh ~/$SCRIPT $@
#
#
# # ===============================================================

# %%
# Local Folder Operations -----------------------------
# LOCAL:
cd $WORKDIR

#NOTE For pilot run, AWS s3 shutdown commented out. Re-upload hgr1 script upon full run

aws s3 cp queenB.sh $S3URL/scripts/
aws s3 cp droneB.sh $S3URL/scripts/
aws s3 cp hgr1_align_v4.ccle.sh $S3URL/scripts/
aws s3 cp $INPUT $S3URL/scripts/
#aws s3 cp ../../gdc.token.txt $S3URL/scripts/gdc.token
# Out:
# upload: ./queenB.sh to s3://crownproject/ccle/scripts/queenB.sh
# upload: ./droneB.sh to s3://crownproject/ccle/scripts/droneB.sh
# upload: ./hgr1_align_v4.ccle.sh to s3://crownproject/ccle/scripts/hgr1_align_v4.ccle.sh
# upload: ./ccle_pilot2.input to s3://crownproject/ccle/scripts/ccle_pilot2.input

# %% [markdown]
# #### Remote Node Launch

# %%
# Remote EC2 Instance Operations ----------------------

# Remote:
# Manually open an Amazon Linux 2 AMI
# ami-061392db613a6357b
# t2.micro
#
# ssh login:
# ssh -i "crown.pem" ec2-user@PUBLICDNS
#

# Commands on EC2 machine to set-up AWS
# enter personal login info:

# REMOTE:
#aws configure
  # AWS Key ID
  # AWS Secret Key ID
  # Region: us-west-2
  
# Copy local run files to S3 and download them on EC2

# REMOTE:
# aws s3 cp --recursive s3://crownproject/ccle/scripts/ ./
#
# mv <KEY>.pem ~/.ssh/
# chmod 400 ~/.ssh/<KEY>.pem

# REMOTE:
# Open logging screen and being launchign EC2 instances
# screen -L
# 
# bash queenB.sh ccle_pilot2.input; aws s3 cp screenlog.0 s3://crownproject/ccle/logs/ccle_pilot2.log

date -u
aws s3 cp s3://crownproject/ccle/logs/ccle_pilot2.log ./
cat ccle_pilot2.log


# Run completed successfully

# %% [markdown]
# Post error fix re-launch
#
# ```
#   2 Launch instance # 1
#       3 Sat Jun  1 00:06:24 UTC 2019
#       4 Instance Type: c4.xlarge
#       5 AMI Image: ami-0b375c9c58cb4a7a2
#       6 Run Script: s3://crownproject/ccle/scripts/hgr1_align_v4.ccle.sh
#       7 Parameters: HCT15 wgs SAMN10987770 SRR8639146 SRX5437587
#       8 Instance ID: i-082c3fa46aeb746b5
#       9 Public DNS: ec2-54-218-77-163.us-west-2.compute.amazonaws.com
#      10 Warning: Permanently added 'ec2-54-218-77-163.us-west-2.compute.amazonaws.com,172.31.27.17'
#      11 download: s3://crownproject/ccle/scripts/hgr1_align_v4.ccle.sh to ./hgr1_align_v4.ccle.sh
#      12
#
# ```

# %% [markdown]
# #### Errors
# HCT116 wgs pipe failed. looks like prefetch command didn't work. Stay and play on HCT116 drone node to fix.
#
# Possible issue is that prefetch in ~/bin/ is a link to the binary in software folder. Will try an explicit call.
#
# Line 70: `prefetch ...` changed to `%HOME/bin/prefetch`. And it works. Re-try the HT115 node from CCLE queen.
#
# ```
# 1  -- hgr1 Alignment Pipeline --
#       2  version: 190531 build -- CCLE
#       3  ami:     crown-190601 - ami-0b375c9c58cb4a7a2
#       4  s3:      s3://crownproject/ccle
#       5  library: HCT116 -- wgs
#       6  date:    Fri May 31 23:50:04 UTC 2019
#       7
#       8 Initializing ...
#       9 Download SRA file: SRR8639145
#      10   cmd: prefetch -X 100G --ascp-path <PATH> SRR8639145
#      11 /home/ubuntu/hgr1_align_v4.ccle.sh: line 70: prefetch: command not found
#      12 SRA Input Pipe
#      13
#      14 Starting hgr1 alignment
#      15 Warning: Could not open read file "SRR8639145" for reading; skipping...
#      16 Error: No input read files were valid
#      17 (ERR): bowtie2-align exited with value 1
#      18 Alignment complete.
#      19 Calculate flagstats.
#      20 Subset reads (retain mapped & their pairs, remove unmapped).
#      21 Recompiling mapped bam file.
#      22 Processing complete. Copy files to S3
#      23 upload: ./HCT116.wgs.flagstat to s3://crownproject/ccle/hgr1/HCT116.wgs.flagstat
#      24 upload: ./HCT116.wgs.hgr1.bam to s3://crownproject/ccle/hgr1/HCT116.wgs.hgr1.bam
#      25 upload: ./HCT116.wgs.hgr1.bam.bai to s3://crownproject/ccle/hgr1/HCT116.wgs.hgr1.bam.bai
#      26 upload: ./HCT116.wgs.hgr1.flagstat to s3://crownproject/ccle/hgr1/HCT116.wgs.hgr1.flagstat
#      27 Create log files and copy to S3
#      28 upload: ./HCT116.wgs.screenlog to s3://crownproject/ccle/logs/HCT116.wgs.screenlog
#      29 ^C
# ```

# %%
## post bug-fix
cat hgr1_align_v4.ccle.sh
aws s3 cp hgr1_align_v4.ccle.sh s3://crownproject/ccle/scripts/
# Out:
# #!/bin/bash
# # hgr1_align_v4.ccle.sh
# # rDNA alignment pipeline - SRA version
# PIPE_VERSION='190531 build -- CCLE'
# AMI_VERSION='crown-190601 - ami-0b375c9c58cb4a7a2'
# # EC2: c4.2xlarge (8cpu / 15 gb)
# # EC2: c4.xlarge  (4cpu / 8  gb)
# # Storage: 200 Gb
# #
#
# # Input Requirements --------------------------
#
# # $1 : Library name + Output name(unique)
# # $2 : Seq-read type (wgs|rna)
# # $3 : BioSample ID
# # $4 : Library SRA Accession
#
# # Control Panel -------------------------------
# # Amazon AWS S3 Home URL
#   S3URL='s3://crownproject/ccle'
#
# # CPU
# 	THREADS='3'
#
# # Terminate instances upon completion (for debuggin)
#   TERMINATE='TRUE'
#
# # Read Group Data
#   LIBRARY=$1    # Library Name / File prefix
#   TYPE=$2       # wgs OR rna data-type
# 	RGPO='ccle'   # Patient Population - CCLE
# 	RGSM=$3       # Sample / Patient Identifer
# 	RGID=$4       # Read Group ID. SRA Accession Number
#   RGLB=$LIBRARY # Library Name. Accession Number
#   RGPL='ILLUMINA' # Seq Platform
#   RGPU=$5       # Read Group. Platform Unit (SRA Experiment)
#
#
#   SRA=$4
#   OUTPUT="$LIBRARY.$TYPE" # Output filename
#
#   # Fastq files from fastq-dump
#   # FQ1=<SRR>_1.fastq.gz
#   # FQ2=<SRR>_2.fastq.gz
#
# echo " -- hgr1 Alignment Pipeline -- "
# echo " version: $PIPE_VERSION "
# echo " ami:     $AMI_VERSION  "
# echo " s3:      $S3URL  "
# echo " library: $LIBRARY -- $TYPE"
# echo " date:    $(date)"
# echo ''
#
# # Initialize wordir ---------------------------
# echo 'Initializing ...'
#
# # Make working directory
#   mkdir -p align; cd align
#
# # Copy hgrX genome and create bowtie2 index
#   cp ~/resources/hgr1/* ./
#
# # Load updated GDC token to instance
# #aws s3 cp $S3URL/scripts/gdc.token gdc.token
# #chmod 600 gdc.token
#
# echo "Download SRA file: $SRA"
# echo "  cmd: prefetch -X 100G --ascp-path <PATH> $SRA"
#
# $HOME/bin/prefetch -X 100G --ascp-path \
#   "$HOME/.aspera/connect/bin/ascp|$HOME/.aspera/connect/etc/asperaweb_id_dsa.openssh"\
#   $SRA
#
# # SRA INPUT ====================================================
#
# #if [ -s $FQ1 ]
# #then
#     echo "SRA Input Pipe"
#     echo ''
#     echo "Starting hgr1 alignment"
#     # Paired-End Extracted Reads Alignment
#
#     # Bowtie2: align to genome
#     bowtie2 --very-sensitive-local -p $THREADS \
#       --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \
#       --rg PL:$RGPL --rg PU:$RGPU \
#       -x hgr1 -sra $SRA | \
#       ~/bin/samtools view -bS - > aligned_unsorted.bam
#
#     echo "Alignment complete."
#     echo "Calculate flagstats."
#
#     # Calcualte library flagstats
#       ~/bin/samtools flagstat aligned_unsorted.bam > aligned_unsorted.flagstat
#
#     # Read Subset ------------------------------
#     echo "Subset reads (retain mapped & their pairs, remove unmapped)."
#
#     # Extract mapped reads, and their unmapped pairs
#
#       # Extract Header
#       ~/bin/samtools view -H aligned_unsorted.bam > align.header.tmp
#
#       # Unmapped reads with mapped pairs
#       # Extract Mapped Reads
#       # and their unmapped pairs
#       ~/bin/samtools view -b -F 4 aligned_unsorted.bam > align.F4.bam #mapped
#       ~/bin/samtools view -b -f 4 -F 8 aligned_unsorted.bam > align.f4F8.bam #unmapped pairs
#
#       echo "Recompiling mapped bam file."
#
#       # Re-compile bam file
#       ~/bin/samtools cat -h align.header.tmp -o align.hgr1.tmp.bam align.F4.bam align.f4F8.bam
#         ~/bin/samtools sort -@ $THREADS -O BAM align.hgr1.tmp.bam > align.hgr1.bam
#         ~/bin/samtools index align.hgr1.bam
#         ~/bin/samtools flagstat align.hgr1.bam > align.hgr1.flagstat
#
#       # Clean up
#       rm *tmp* align.F4.bam align.f4F8.bam
#
#     echo "Processing complete. Copy files to S3"
#     # Rename the total Bam Files
#       mv aligned_unsorted.bam $OUTPUT.bam
#       #mv aligned_unsorted.bam.bai $OUTPUT.bam.bai
#       mv aligned_unsorted.flagstat $OUTPUT.flagstat
#
#     # Rename the hgr-aligned Bam files
#       mv align.hgr1.bam $OUTPUT.hgr1.bam
#       mv align.hgr1.bam.bai $OUTPUT.hgr1.bam.bai
#       mv align.hgr1.flagstat $OUTPUT.hgr1.flagstat
#
#     # Copy output to AWS S3
#     # Alignments (Full)
#       aws s3 cp $OUTPUT.flagstat $S3URL/hgr1/
#
#     # Alignments (Aligned)
#       aws s3 cp $OUTPUT.hgr1.bam $S3URL/hgr1/
#       aws s3 cp $OUTPUT.hgr1.bam.bai $S3URL/hgr1/
#       aws s3 cp $OUTPUT.hgr1.flagstat $S3URL/hgr1/
#
# #fi
#
# echo "Create log files and copy to S3"
# # Copy screen log file to AWS S3
# cp ~/screenlog.0 ./$OUTPUT.screenlog
# aws s3 cp $OUTPUT.screenlog $S3URL/logs/
#
# # Shutdown and Terminate instance
# EC2ID=$(ec2metadata --instance-id)
# sleep 20s # to catch errors
#
# if [ "$TERMINATE" = TRUE ]
# then
#   echo "Run Complete -- Shutting down instance."
#   aws ec2 terminate-instances --instance-ids $EC2ID
# else
#   echo "Run Complete -- Instance is online."
# fi
#
# # Script complete
# upload: ./hgr1_align_v4.ccle.sh to s3://crownproject/ccle/scripts/hgr1_align_v4.ccle.sh

# %%
## Ran into error with bowtie2 alignment
## need to de-bug
##
## Download was successful, so the explicit prefetch works.
## problem may be with bowtie2 scripts since it was 'installed'
## with a mv command instead of a ln command
##

cd $WORKDIR
cat HCT116.wgs.screenlog
# Out:
#  SRX5437588
#  -- hgr1 Alignment Pipeline --
#  version: 190531 build -- CCLE
#  ami:     crown-190601 - ami-0b375c9c58cb4a7a2
#  s3:      s3://crownproject/ccle
#  library: HCT116 -- wgs
#  date:    Fri May 31 23:55:55 UTC 2019
#
# Initializing ...
# Download SRA file: SRR8639145
#   cmd: prefetch -X 100G --ascp-path <PATH> SRR8639145
#
# 2019-05-31T23:55:58 prefetch.2.9.3: 1) Downloading 'SRR8639145'...
# 2019-05-31T23:55:58 prefetch.2.9.3:  Downloading via fasp...
# SRR8639145
# 2019-06-01T03:30:48 prefetch.2.9.3:  fasp download succeed
# 2019-06-01T03:30:48 prefetch.2.9.3: 1) 'SRR8639145' was downloaded successfully
# 2019-06-01T03:31:13 prefetch.2.9.3: 'SRR8639145' has 0 unresolved dependencies
# 2019-06-01T03:31:14 prefetch.2.9.3: 'SRR8639145' has remote vdbcache
# 2019-06-01T03:31:14 prefetch.2.9.3:  Downloading vdbcache...
# 2019-06-01T03:31:14 prefetch.2.9.3:  Downloading via https...
# 2019-06-01T03:31:56 prefetch.2.9.3:  vdbcache was downloaded successfully
# SRA Input Pipe
#
# Starting hgr1 alignment
# stat: Bad file descriptor
# Warning: Could not open read file "SRR8639145" for reading; skipping...
# Error: No input read files were valid
# (ERR): bowtie2-align exited with value 1
# Alignment complete.
# Calculate flagstats.
# Subset reads (retain mapped & their pairs, remove unmapped).
# Recompiling mapped bam file.
# Processing complete. Copy files to S3
# upload: ./HCT116.wgs.flagstat to s3://crownproject/ccle/hgr1/HCT116.wgs.flagstat
# upload: ./HCT116.wgs.hgr1.bam to s3://crownproject/ccle/hgr1/HCT116.wgs.hgr1.bam

# %%
cat ccle_pilot3.input
echo ''

## re-run with a KMH2 RNAseq test set
## set "TERMINATE=FALSE"
## 
## change bowtie2 command to: "~/bin/bowtie2 --very-sensitive-local -p $THREADS \"...

cd $WORKDIR

aws s3 cp queenB.sh $S3URL/scripts/
aws s3 cp droneB.sh $S3URL/scripts/
aws s3 cp hgr1_align_v4.ccle.sh $S3URL/scripts/
aws s3 cp ccle_pilot3.input $S3URL/scripts/

# Download on remote head node
# Out:
# KMH2	rna	SAMN10988578	SRR8615908	SRX5415142
# upload: ./queenB.sh to s3://crownproject/ccle/scripts/queenB.sh
# upload: ./droneB.sh to s3://crownproject/ccle/scripts/droneB.sh
# upload: ./hgr1_align_v4.ccle.sh to s3://crownproject/ccle/scripts/hgr1_align_v4.ccle.sh
# upload: ./ccle_pilot3.input to s3://crownproject/ccle/scripts/ccle_pilot3.input

# %% [markdown]
# ```
# Launch instance # 1
# Sun Jun  2 19:17:34 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/ccle/scripts/hgr1_align_v4.ccle.sh
# Parameters: KMH2 rna SAMN10988578 SRR8615908 SRX5415142
# Instance ID: i-0ee9fe81089d31795
# ```
#
# Error appears on line 87: `-x hgr1 -sra $SRA | ` should be  `-x hgr1 --sra-acc $SRA | `
#
# Will fix locally and re-run above box.
#
# ```
# Launch instance # 1
# Sun Jun  2 19:45:11 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/ccle/scripts/hgr1_align_v4.ccle.sh
# Parameters: KMH2 rna SAMN10988578 SRR8615908 SRX5415142
# Instance ID: i-009efec44e015cd87
# Public DNS: ec2-35-155-253-153.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-155-253-153.us-west-2.compute.amazonaws.com,172.31.18.88' (ECDSA) to the list of known hosts.
# download: s3://crownproject/ccle/scripts/hgr1_align_v4.ccle.sh to ./hgr1_align_v4.ccle.sh
# ```
#
# It worked! =D Manual inspection the alignments look good. I don't anticipate (lol) a difference between RNA and WGS so I can open up the analysis to a wider pipe.
#
# Time to set-up shop.

# %%
ls -alh bam/
# Out:
# total 155M
# drwxr-xr-x 2 artem artem 4.0K Jun  2 14:53 .
# drwxrwxr-x 6 artem artem 4.0K Jun  2 14:42 ..
# -rw-rw-r-- 1 artem artem  25M May 30 11:13 HCT116.rna.hgr1.bam
# -rw-rw-r-- 1 artem artem  632 May 30 11:13 HCT116.rna.hgr1.bam.bai
# -rw-r--r-- 1 artem artem  33M May 30 11:53 HCT15.rna.hgr1.bam
# -rw-r--r-- 1 artem artem  632 May 30 11:53 HCT15.rna.hgr1.bam.bai
# -rw-rw-r-- 1 artem artem  97M Jun  2 14:44 KMH2.rna.hgr1.bam
# -rw-rw-r-- 1 artem artem  632 Jun  2 14:42 KMH2.rna.hgr1.bam.bai
