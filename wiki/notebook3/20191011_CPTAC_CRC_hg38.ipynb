# %% [markdown]
# # CPTAC - CRC Cohort 5 hg38 align
# ```
# pi:ababaian
# files: ~/Crown/data2/crc_cptac/
# start: 2019 10 11
# complete : 2019 -- --
# ```
# ## Introduction
#
# There isn't an available CPTAC-CRC RNA-seq quantification. Align to hg38 and perform differential expression analysis on these 66 RNA-seq samples.

# %%
# Initialize
WORKDIR='/home/artem/Crown/data2/crc_cptac/hg38'
mkdir -p $WORKDIR; cd $WORKDIR

# %% [markdown]
# ## Objective
#
# 1. Pilot: Align 2x CRC5 RNA-seq libraries to hg38. Confirm OK.
# 2. Full : Align remaining CRC5 libraries to hg38

# %% [markdown]
# ## Materials and Methods

# %% [markdown]
# ### Data Initialization

# %% [markdown]
# See `20190918 CPTAC CRC`.

# %% [markdown]
# ### Scripts and Localization

# %% [markdown]
# #### 1 - Localization

# %%
WORKDIR='/home/artem/Crown/data2/crc_cptac/hg38'
cd $WORKDIR
ls

# Amazon AWS S3 Home URL
S3URL='s3://crownproject/cptac'
# Out:
# cptac_2.input       droneB.sh               hgr1_align_v4.cptac.sh
# cptac_pilot0.input  hg38_align_v4.cptac.sh  queenB.sh

# %%
INPUT='cptac_pilot0.input'
# Note the different column requirements from CCLE

cat $INPUT
# Out:
# 01CO001	crc5	SAMN03453626	SRR1999563	SRX1011590
# 01CO005	crc5	SAMN03453627	SRR1999549	SRX1011576

# %% [markdown]
# #### 2 - Script Versions

# %%
cd $WORKDIR
# Echo scripts to be used for this analysis for version control.
# Note these need to be manually copied to the $WORKDIR

cat hgr38_align_v4.cptac.sh
echo 
echo
cat queenB.shS
echo 
echo
cat droneB.sh
echo 
echo
# Out:
# cat: hgr38_align_v4.cptac.sh: No such file or directory
#
#
# cat: queenB.shS: No such file or directory
#
#
# #!/bin/bash
# # droneB.sh
# #
#
# # This script-layer is neccesary to launch a screen session
# # on each ec2-machine. The pipeline is run within that session
# # and the output is logged. This allows 'looking in' on sessions
# # as they are running.
#
# # Commands to run on server-side
# # ===============================================================
#
# SCRIPTPATH=$1
#
# SCRIPT=$(basename $1)
#
# shift # drop first (TASK or SCRIPT variable)
#
# # Download pipeline / droneB's function
#   aws s3 cp $SCRIPTPATH ./
#
#   chmod 777 *.sh
#
# # open screen; run gather.sh function. -L logged
#   screen -Ldmt sh ~/$SCRIPT $@
#
#
# # ===============================================================

# %% [markdown]
# ## Results - CCLE Pilot Run I

# %% [markdown]
# #### 3 - Copy local to S3

# %%
# Local Folder Operations -----------------------------
# LOCAL:
cd $WORKDIR

#NOTE For pilot run, AWS s3 shutdown commented out. Re-upload hgr1 script upon full run

aws s3 cp queenB.sh $S3URL/scripts/
aws s3 cp droneB.sh $S3URL/scripts/
aws s3 cp hg38_align_v4.cptac.sh $S3URL/scripts/
aws s3 cp $INPUT $S3URL/scripts/
aws s3 cp dbgap.key $S3URL/scripts/
# Out:
# upload: ./queenB.sh to s3://crownproject/cptac/scripts/queenB.sh
# upload: ./droneB.sh to s3://crownproject/cptac/scripts/droneB.sh
# upload: ./hg38_align_v4.cptac.sh to s3://crownproject/cptac/scripts/hg38_align_v4.cptac.sh
# upload: ./cptac_pilot0.input to s3://crownproject/cptac/scripts/cptac_pilot0.input
#
# The user-provided path dbgap.key does not exist.

# %%
# start
date
date -u
# Out:
# Thu Oct  3 09:47:47 PDT 2019
# Thu Oct  3 16:47:47 UTC 2019

# %% [markdown]
# #### 4 - Launch and run master EC2 node

# %%
# Remote EC2 Instance Operations ----------------------

# Remote:
# Manually open an Amazon Linux 2 AMI
# ami-061392db613a6357b
# t2.micro
#
# ssh login:
# ssh -i "crown.pem" ec2-user@PUBLICDNS
#

# Commands on EC2 machine to set-up AWS
# enter personal login info:

# REMOTE:
#aws configure
  # AWS Key ID
  # AWS Secret Key ID
  # Region: us-west-2
  
# Copy local run files to S3 and download them on EC2

# REMOTE:
# aws s3 cp --recursive s3://crownproject/cptac/scripts/ ./
#
# mv <KEY>.pem ~/.ssh/
# chmod 400 ~/.ssh/<KEY>.pem

# REMOTE:
# Open logging screen and being launchign EC2 instances
# screen -L
# 
# bash queenB.sh cptac_pilot0.input
#
# aws s3 cp screenlog.0 s3://crownproject/cptac/logs/cptac_pilot0.hg38.log

aws s3 cp s3://crownproject/cptac/logs/cptac_pilot0.hg38.log ./
cat cptac_pilot0.hg38.log
date -u

# Run completed successfully!
# Out:
# download: s3://crownproject/cptac/logs/cptac_pilot0.log to ./cptac_pilot0.log
# kec2-user@ip-172-31-40-172:~\[ec2-user@ip-172-31-40-172 ~]$ ls
# ADcalc_ccle2.sh     CrownKey.pem  droneB.sh		  queenB.sh
# cptac_pilot0.input  dbgap.key	  hgr1_align_v4.cptac.sh  screenlog.0
# bash queenB.sh cptac_pilot0.input
# Launch instance # 1
# Thu Oct  3 16:50:00 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01CO001 crc5 SAMN03453626 SRR1999563 SRX1011590
# Instance ID: i-0e576ba89c5776da1
# Public DNS: ec2-54-185-143-115.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-185-143-115.us-west-2.compute.amazonaws.com,172.31.38.0' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 2
# Thu Oct  3 16:53:07 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01CO005 crc5 SAMN03453627 SRR1999549 SRX1011576
# Instance ID: i-03d13fd048191b399
# Public DNS: ec2-34-210-89-222.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-210-89-222.us-west-2.compute.amazonaws.com,172.31.32.180' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# kec2-user@ip-172-31-40-172:~\[ec2-user@ip-172-31-40-172 ~]$ Thu Oct  3 21:06:39 UTC 2019

# %% [markdown]
# ## CRC - CPTAC Full Run

# %%
# Repeat above with entire cohort, 45 nodes ~3x run
cd $WORKDIR
INPUT="cptac_crc.input"

cat $INPUT
# Out:
# 01CO006	crc5	SAMN04111321	SRR2518440	SRX1288089
# 01CO008	crc5	SAMN04111439	SRR2518441	SRX1288090
# 01CO013	crc5	SAMN05127283	SRR9861902	SRX6616551
# 01CO014	crc5	SAMN06208758	SRR9861950	SRX6616680
# 01CO019	crc5	SAMN05127298	SRR9862138	SRX6615968
# 01CO022	crc5	SAMN06208530	SRR9861951	SRX6616681
# 05CO002	crc5	SAMN03453636	SRR1999486	SRX1011513
# 05CO003	crc5	SAMN03453647	SRR1999570	SRX1011597
# 05CO005	crc5	SAMN06208707	SRR9861979	SRX6615528
# 05CO006	crc5	SAMN03453668	SRR1999616	SRX1011643
# 05CO007	crc5	SAMN03453645	SRR1999590	SRX1011617
# 05CO011	crc5	SAMN03453615	SRR1999580	SRX1011607
# 05CO014	crc5	SAMN03453622	SRR1999556	SRX1011583
# 05CO020	crc5	SAMN04111397	SRR2518460	SRX1288109
ws s3 cp queenB.sh $S3URL/scripts/
aws s3 cp droneB.sh $S3URL/scripts/
aws s3 cp hg38_align_v4.cptac.sh $S3URL/scripts/
aws s3 cp $INPUT $S3URL/scripts/
aws s3 cp dbgap.key $S3URL/scripts/
# Out:
# upload: ./queenB.sh to s3://crownproject/cptac/scripts/queenB.sh
# upload: ./droneB.sh to s3://crownproject/cptac/scripts/droneB.sh
# upload: ./hg38_align_v4.cptac.sh to s3://crownproject/cptac/scripts/hg38_align_v4.cptac.sh
# upload: ./cptac_crc.input to s3://crownproject/cptac/scripts/cptac_crc.input
#
# The user-provided path dbgap.key does not exist.

# %%
# Remote EC2 Instance Operations ----------------------

# Remote:
# Manually open an Amazon Linux 2 AMI
# ami-061392db613a6357b
# t2.micro
#
# ssh login:
# ssh -i "crown.pem" ec2-user@PUBLICDNS
#

# Commands on EC2 machine to set-up AWS
# enter personal login info:

# REMOTE:
#aws configure
  # AWS Key ID
  # AWS Secret Key ID
  # Region: us-west-2
  
# Copy local run files to S3 and download them on EC2

# REMOTE:
# aws s3 cp --recursive s3://crownproject/cptac/scripts/ ./
#
# mv <KEY>.pem ~/.ssh/
# chmod 400 ~/.ssh/<KEY>.pem

# REMOTE:
# Open logging screen and being launchign EC2 instances
# screen -L
# 
# bash queenB.sh cptac_pilot0.input
#
# aws s3 cp screenlog.0 s3://crownproject/cptac/logs/cptac_crc.log

aws s3 cp s3://crownproject/cptac/logs/cptac_crc.log ./
cat cptac_crc.log
date -u

# Run completed successfully!
# Out:
# download: s3://crownproject/cptac/logs/cptac_crc.log to ./cptac_crc.log
# kec2-user@ip-172-31-40-172:~\[ec2-user@ip-172-31-40-172 ~]$ cat queenB.sh
# #!/bin/bash
# # queenB.sh
# # 20180814 build
# # EC2 Launch / Control Script
# #
#
# # 1. queenB script is initialized locally and input files
# #    are parsed ready for cluster analaysis
# # 2. queenB launches instances, logs in to it and runs the
# #    droneB.sh script remotely.
# # 3. The droneB script is executed on the instance and it
# #    launches a `screen` on the instance and loads and
# #    starts to perform the $TASK (gather.sh) script.
# # 4. TASK script should include a instance shut-down
# #    command to close instance upon completion.
# #
#
# # Control Panel =========================
# # Amazon AWS S3 Home URL
# S3URL='s3://crownproject/cptac'
#
# # EC2 TASK Script - script for droneB to execute
# TASK="$S3URL/scripts/hgr1_align_v4.cptac.sh"
#
# # Parameter file:
# # Each line of PARAMETERS will be input to STDIN of
# # the droneB script which can then be used to run the
# # TASK script.
# # i.e. bash droneB.sh <line_N_of_PARAMETERS>
# # PARAMETERS="tcga0_input.txt"
# PARAMETERS=$1
#
# # EC2 Set-up
# instanceTYPE='c4.xlarge'
# imageID='ami-0b375c9c58cb4a7a2' #AMI Crown CCLE/SRA
#
# devNAME='/dev/sda1' # /dev/sda1 for Crown-AMI
# volSIZE='300' # in Gb
#
# # Maximum number of EC2 instances to run simultaniously
# MAX_INSTANCE='45'
#
# # Number of instances to launch
# #COUNT=2 # predetermined number
# COUNT=$(awk 'END{print NR}' $PARAMETERS) # for each input argument
#
# # Security
# keyNAME='CrownKey'
# keyPATH="/home/ec2-user/.ssh/CrownKey.pem"
# secGROUP='crown-group'
#
# # Input Validation ======================
# # Test input file for duplicate sample ID (which will cause file collisions downstream)
# # exit with error 1 if collision exists
#
# SAMPLEIDS=$(cut -f1 $1 | uniq -d )
#
# if [ -n "$SAMPLEIDS" ]
# then
#   # If there are duplicate sample IDs exit
#   echo "Error 02 - Duplicate Sample ID detected in input"
#   echo " I hope you know what you're doing"
#   echo " script will not exit in this version"
#   echo " re-run with unique ID or outputs will overwrite"
#   echo ""
#   #echo "$SAMPLEIDS"
#   #exit 2
# fi
#
# # Script Core ===========================
#
# for ITER in $(seq 1 $COUNT)
# do
#
#   # Count the total number of instances
#   running_instance=$(aws ec2 describe-instances |\
#     grep '"Name": "running"' - |\
#     wc -l - | cut -f1 -d' ' - )
#
#   while [ $running_instance -ge $MAX_INSTANCE ];
#   do
#
#   	echo "Reached max of $running_instance, wait."
#   	echo ''
#
#   	# If there are greater then 25 instances
#   	# wait for instance to close
#   	sleep 5m
#
#   	running_instance=$(aws ec2 describe-instances |\
#     grep '"Name": "running"' - |\
#     wc -l - | cut -f1 -d' ' - )
#   done
#
#   # Extract Parameters/Arguments ----------
#
#   ARGS=$(sed -n "$ITER"p $PARAMETERS | sed 's/\t/ /g' - )
#
#   echo "Launch instance # $ITER"
#   date
#   echo "Instance Type: $instanceTYPE"
#   echo "AMI Image: $imageID"
#   echo "Run Script: $TASK"
#   echo "Parameters: $ARGS"
#
#   # Launch an instance --------------------
#   # NOTE: each iteration of the for loop launches one instance
#   # therefore each loop launches only one instance
#   aws ec2 run-instances --image-id $imageID --count 1 \
#    --instance-type $instanceTYPE --key-name $keyNAME \
#    --block-device-mappings DeviceName=$devNAME,Ebs={VolumeSize=$volSIZE} \
#    --security-groups $secGROUP > launch.tmp
#
#   # Another alternative is to use --user-data droneB.sh
#   # which will run at instance boot-up
#   # passing arguments to it may be challenging
#
#   # Retrieve instance ID
#   instanceID=$(cat launch.tmp | \
#     egrep -o -e 'InstanceId[":/A-Za-z0-9_ \\-]*' - |\
#     cut -f2 -d' ' - | xargs)
#
#   echo "Instance ID: $instanceID"
#
#
#   # Add a few minute wait here to allow for Public DNS to be assigned
#   # otherwise ssh doesn't work
#   # CURRENT BOTTLENECK
#   sleep 180s
#
#   # Check that the instance is 'running' and not pending
#   pending_instance=$(aws ec2 describe-instances |\
#    grep '"Name": "pending"' - |\
#    wc -l - | cut -f1 -d' ' - )
#
#   while [ $pending_instance -gt 0 ];
#   do
#
#   	echo "Launchign instance not ready yet, chill"
#   	# Instance still pending
#   	sleep 180s
#
#     pending_instance=$(aws ec2 describe-instances |\
#      grep '"Name": "pending"' - |\
#      wc -l - | cut -f1 -d' ' - )
#   done
#
#
#   # Retrieve public DNS
#   aws ec2 describe-instances --instance-ids $instanceID > launch2.tmp
#
#   pubDNS=$(cat launch2.tmp | \
#     egrep -o -m 1 -e 'PublicDnsName[.":/A-Za-z0-9_ \\-]*' - |\
#     cut -f2 -d' ' - | xargs)
#
#   echo "Public DNS: $pubDNS"
#
#   # Access the instance -------------------
#
#   LOGIN="ubuntu@$pubDNS"
#
#   ssh -i $keyPATH \
#     -o StrictHostKeyChecking=no \
#     $LOGIN 'bash -s' < droneB.sh $TASK $(echo $ARGS)
#
#   # Cleanup
#   rm *.tmp
#
#   echo ''
#   echo ''
#
# done
#
# # end of scriptkec2-user@ip-172-31-40-172:~\[ec2-user@ip-172-31-40-172 ~]$ ls
# ADcalc_ccle2.sh  cptac_pilot0.input  dbgap.key	hgr1_align_v4.cptac.sh	screenlog.0
# cptac_crc.input  CrownKey.pem	     droneB.sh	queenB.sh
# queenB.sh cptac_crc.input
# Launch instance # 1
# Thu Oct  3 21:13:02 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters:
49 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11CO057 crc5 SAMN06208831 SRR9861978 SRX6615527
# Instance ID: i-098c1f1010e46789f
# Public DNS: ec2-34-216-81-107.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-216-81-107.us-west-2.compute.amazonaws.com,172.31.47.89' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 51
# Thu Oct  3 23:47:55 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11CO058 crc5 SAMN06208731 SRR9861980 SRX6615529
# Instance ID: i-0ccf5b3154b111a7d
# Public DNS: ec2-34-222-25-77.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-222-25-77.us-west-2.compute.amazonaws.com,172.31.40.94' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 52
# Thu Oct  3 23:51:00 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11CO059 crc5 SAMN06208756 SRR9862018 SRX6615625
# Instance ID: i-0418c5739800b2d07
# Public DNS: ec2-54-202-28-228.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-202-28-228.us-west-2.compute.amazonaws.com,172.31.32.43' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 53
# Thu Oct  3 23:54:06 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11CO072 crc5 SAMN06208458 SRR9861985 SRX6615534
# Instance ID: i-0941393095e2d9738
# Public DNS: ec2-54-185-150-145.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-185-150-145.us-west-2.compute.amazonaws.com,172.31.34.41' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 54
# Thu Oct  3 23:57:11 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11CO077 crc5 SAMN06208654 SRR9861986 SRX6615535
# Instance ID: i-0e38e6b3e6c36914d
# Public DNS: ec2-54-218-255-137.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-218-255-137.us-west-2.compute.amazonaws.com,172.31.39.77' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 55
# Fri Oct  4 00:00:17 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11CO079 crc5 SAMN06208545 SRR9861987 SRX6615536
# Instance ID: i-08a7c95b5c901c84d
# Public DNS: ec2-34-220-54-85.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-220-54-85.us-west-2.compute.amazonaws.com,172.31.40.117' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 56
# Fri Oct  4 00:03:23 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 14CO002 crc5 SAMN05127427 SRR9861894 SRX6615523
# Instance ID: i-0bbd0e358ddd0a41b
# Public DNS: ec2-54-190-144-202.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-190-144-202.us-west-2.compute.amazonaws.com,172.31.43.226' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 57
# Fri Oct  4 00:06:29 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 14CO003 crc5 SAMN05127272 SRR9861895 SRX6615524
# Instance ID: i-061fa90ade9a5bdb2
# Public DNS: ec2-34-219-216-161.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-219-216-161.us-west-2.compute.amazonaws.com,172.31.43.26' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 58
# Fri Oct  4 00:09:36 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 15CO001 crc5 SAMN05127128 SRR9861897 SRX6615526
# Instance ID: i-0d28b20beabb53089
# Public DNS: ec2-52-38-229-39.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-38-229-39.us-west-2.compute.amazonaws.com,172.31.46.129' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 59
# Fri Oct  4 00:12:42 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 16CO012 crc5 SAMN06208455 SRR9862026 SRX6615661
# Instance ID: i-0ea08cd7a01672081
# Public DNS: ec2-34-220-77-202.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-220-77-202.us-west-2.compute.amazonaws.com,172.31.33.174' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 60
# Fri Oct  4 00:15:48 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 20CO001 crc5 SAMN04111332 SRR2518477 SRX1288126
# Instance ID: i-004d92b015294420d
# Public DNS: ec2-54-71-132-211.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-71-132-211.us-west-2.compute.amazonaws.com,172.31.40.82' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 61
# Fri Oct  4 00:18:53 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 20CO003 crc5 SAMN05127329 SRR9861898 SRX6616547
# Instance ID: i-02f67d5a3531a9401
# Public DNS: ec2-34-223-244-162.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-223-244-162.us-west-2.compute.amazonaws.com,172.31.40.7' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 62
# Fri Oct  4 00:21:59 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 20CO004 crc5 SAMN06208698 SRR9861993 SRX6615542
# Instance ID: i-05af157daa785accb
# Public DNS: ec2-34-219-228-170.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-219-228-170.us-west-2.compute.amazonaws.com,172.31.42.4' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 63
# Fri Oct  4 00:25:05 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 20CO007 crc5 SAMN06208628 SRR9861994 SRX6615574
# Instance ID: i-0f6c454161ade4463
# Public DNS: ec2-34-216-131-222.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-216-131-222.us-west-2.compute.amazonaws.com,172.31.36.14' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 64
# Fri Oct  4 00:28:11 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 22CO006 crc5 SAMN05127402 SRR9861900 SRX6616549
# Instance ID: i-090fbc91a1b1be513
# Public DNS: ec2-52-36-47-186.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-36-47-186.us-west-2.compute.amazonaws.com,172.31.8.113' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Fri Oct  4 02:03:39 UTC 2019

# %%
aws s3 ls s3://crownproject/cptac/hg38/
aws s3 ls s3://crownproject/cptac/hg38/ > hg38.filelist
# Out:
# 2019-10-12 20:37:41 6388802782 01CO001.crc5.hg38.bam
# 2019-10-12 20:37:55    3661208 01CO001.crc5.hg38.bam.bai
# 2019-10-12 20:38:24        452 01CO001.crc5.hg38.flagstat
# 2019-10-12 20:31:48        420 01CO001.crc5.hg38.stats
# 2019-10-12 20:38:36 4454509268 01CO005.crc5.hg38.bam
# 2019-10-12 20:39:07    3250664 01CO005.crc5.hg38.bam.bai
# 2019-10-12 20:39:17        450 01CO005.crc5.hg38.flagstat
# 2019-10-12 20:29:52        420 01CO005.crc5.hg38.stats
# 2019-10-12 21:22:31  133562641 01CO006.crc5.hg38.bam
# 2019-10-12 21:22:33    2062760 01CO006.crc5.hg38.bam.bai
# 2019-10-12 21:22:33        431 01CO006.crc5.hg38.flagstat
# 2019-10-12 22:36:44 1720106244 01CO008.crc5.hg38.bam
# 2019-10-12 22:37:00    4162704 01CO008.crc5.hg38.bam.bai
# 2019-10-12 22:37:01        446 01CO008.crc5.hg38.flagstat
# 2019-10-13 01:04:47 2710662377 01CO013.crc5.hg38.bam
# 2019-10-13 01:05:30    3074728 01CO013.crc5.hg38.bam.bai
# 2019-10-13 01:05:31        449 01CO013.crc5.hg38.flagstat
# 2019-10-13 01:20:41 3194160116 01CO014.crc5.hg38.bam
# 2019-10-13 01:21:14    3068304 01CO014.crc5.hg38.bam.bai
# 2019-10-13 01:21:15        449 01CO014.crc5.hg38.flagstat
# 2019-10-13 02:25:15 5404085610 01CO019.crc5.hg38.bam
# 2019-10-13 02:26:07    3942360 01CO019.crc5.hg38.bam.bai
# 2019-10-13 02:26:08        455 01CO019.crc5.hg38.flagstat
# 2019-10-13 01:27:03 3289457942 01CO022.crc5.hg38.bam
# 2019-10-13 01:27:34    3123576 01CO022.crc5.hg38.bam.bai
# 2019-10-13 01:27:35        449 01CO022.crc5.hg38.flagstat
# 2019-10-13 02:16:13 4668856740 05CO002.crc5.hg38.bam
# 2019-10-13 02:17:00    3715352 05CO002.crc5.hg38.bam.bai
# 2019-10-13 02:17:00        450 05CO002.crc5.hg38.flagstat
# 2019-10-13 02:22:21 4655571078 05CO003.crc5.hg38.bam
ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_31/gencode.v31.basic.annotation.gtf.gz
gzip -d *.gtf.gz

# Download RNA-seq files for CPTAC
mkdir -p cptac;
cd cptac
aws s3 cp --recursive s3://crownproject/cptac/hg38/ ./


# Install R Base + XML
sudo apt-get install r-base-core
sudo apt-get install libxml2-dev
sudo apt-get install r-cran-xml

sudo chmod -R 777 /usr/lib/R/
sudo chmod -R 777 /home/ubuntu/R/
  
R

fi

# %% [markdown]
# ```
# # {in R}
# install.packages("BiocManager")
# library("BiocManager")
#
# install("Rsubread")
# install("DESeq2")
# install("biomaRt")
# install("Rsamtools")
# install("GenomicFeatures")
# ```

# %% [markdown]
# ```
# # {in R}
# library("biomaRt")
# # Import Read Counts for DEseq2
#   ensembl = useMart("ensembl")
#   ensembl = useDataset("hsapiens_gene_ensembl",mart=ensembl)
#
# # Import bamlist
# library("Rsamtools")
#   bam.list = read.table('cptac.bam.list', header = F)
#   bam.list = as.character(bam.list$V1)
#   bamfiles <- BamFileList(bam.list, yieldSize = 200000000)
#
#
# # Import annotation
# library("GenomicFeatures")
#   gtffile <- file.path("gencode.v31.basic.annotation.gtf")
#   txdb <- makeTxDbFromGFF(gtffile, format="auto",
#                           dataSource='gencode.31',
#                           organism='Homo sapiens',
#                           dbxrefTag = 'gene_id')
#
#
#   gencode = transcripts(txdb, columns = c("tx_id", "tx_name", "gene_id", "cds_id"))
#   gencode$gene_id2 = unlist(strsplit(as.character(gencode$gene_id),
#                                      split = '\\.[0-9_PARY]*', fixed = F, perl = T))
#     #gencode$id = gencode$tx_name
#
#   # Subset to protein coding genes only
#   gencode_pc = gencode[which(sum(is.na(gencode$cds_id)) == 0),]
#
#
#   # Add Gene Metadata
#   geneSymbols = getBM(attributes=c('ensembl_gene_id','hgnc_symbol','description'),
#                       filters = 'ensembl_gene_id',
#                       values = gencode_pc$gene_id2,
#                       mart = ensembl)
#
#   whichGrepl = function(lookup, VECTOR){
#     key = which(grepl(lookup, VECTOR))
#
#     if (length(key) == 0){
#       return(0)
#     }else{
#       return(key[1])
#     }}
#
#   # genecode --> bioMart Conversion Key
#   keyVector = unlist(lapply(gencode_pc$gene_id2,
#                             FUN = whichGrepl,
#                             VECTOR = geneSymbols$ensembl_gene_id))
#
#     # Dealing with no-match in Ensembl
#     noMatch = (length(geneSymbols$ensembl_gene_id) + 1)
#     keyVector2 = keyVector
#     keyVector2[which(keyVector2 == 0)] = noMatch
#
#   gencode_pc$symbol = c(geneSymbols$hgnc_symbol,NA)[keyVector2]
#   gencode_pc$description = c(geneSymbols$description,NA)[keyVector2]
#
#
# # Count Reads per bamfile
# library("Rsubread")
#   # gencode = createAnnotationFile(gencode)
#   # gencode1 = gencode[1:100,]
#
#   # Feature counts is performed over the entire gencode file
#   # including lincRNA
#   # exon --> gene level mapping
#   fc_SE <- featureCounts(bam.list,
#                          nthreads = 7,
#                          isPairedEnd = TRUE,
#                          annot.ext = gtffile,
#                          isGTFAnnotationFile = TRUE,
#                          GTF.featureType = "exon",
#                          GTF.attrType = "gene_id")
#
#
#   # Save input calculations
#
#   save(bam.list, bamfiles, fc_SE, gencode, gencode_pc,
#        geneSymbols, keyVector,
#        gtffile, txdb, file = 'deseqInitialize_cptac_191015.Rdata')
#
# ```

# %%
aws s3 cp deseqInitialize_cptac_191015.Rdata s3://crownproject/cptac/
