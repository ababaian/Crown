# %% [markdown]
# # TCGA - WXS Control Experiment
# ```
# pi:ababaian
# files: ~/Crown/data2/tcga_wxs/
# start: 2019 12 20
# complete : YYYY MM DD
# ```
# ## Introduction
#
# For the MACP-Psi paper, a reviewer asked if there is DNA-level variation at 18S.1248.U (RNA45S.4908.T) which underlies the 'hypo-modification' phenotype.
#
#
# ### Reviewer Comment
# ```
# 1. The authors describe an rRNA base that varies at the RNA level in RNA-seq data, reflective of a modification that is caused by the RT enzyme generating a base change during cDNA synthesis. In order to conclude that this rRNA variant is due to loss of a modification being lost in colorectal cancer, rather than a somatic DNA variant, it is important that the variant is only detected at the RNA and not at the DNA level. The authors cite their own study to say that at the DNA level that RNA45S:1248.T is invariable. While this may be true, these are just based on normal human samples the author used in his previous study. It would be useful to confirm this in cancer samples at the DNA level with WGS data.
# ```
#
# ### Initial Response
# ```
# We can include this analysis for TCGA-COAD as a single panel in S figure 1. We would like to note, the cancer-specific hypo-modification is an increase in the (invariable) reference T/U allele. If there was an rDNA variation it would be masked by the modification in the RNA-seq data and thus we did not include this experiment. What we can conclude is that the loss of modification is not caused by a DNA-level change, as any change from the reference T would appear as a modified rRNA. This statement will be added to the paper to make this explicit. Our pilot experiment of TCGA-COAD whole exome sequencing data analysis shows no DNA-level variation in cancer, we will require ~2 weeks to complete the analysis of all 947 samples.
# ```

# %% [markdown]
# ## Hypothesis
#
# 1. The RNA45S.4908.T nucleotide is invariable in normal and cancer patient rDNA. That is the level of variation will be that of sequencing-error (>1%) and the same for normal and cancer.

# %% [markdown]
# ## Matererials and Methods

# %% [markdown]
# ### Data Initialization
#
#
# - The initial plan was to use `bam slicing` capability to extract the hg38 `chrUn_GL000220v1:102,084-122,119` region from TCGA WXS data. This will then be re-aligned to hgr1 to measure _RNA45S.4908.T_ variation levels in each of the ~940 samples.
#
# - There is an error and GDC helpdesk confirmed that the `_` character in chr name does not match the server-side REGEX limit for slicing. I'll have to download whole WXS files and use samtools to extract the region of interest.
#
# The REGEX: `^[a-zA-Z0-9]+(:([0-9]+)?(-[0-9]+`
#
# should read:
#
# `^[a-zA-Z0-9_\-]+(:([0-9]+)?(-[0-9]+`
#
# or ideally:
#
# `^[\S]+(:([0-9]+)?(-[0-9]+`

# %%
# See: https://docs.gdc.cancer.gov/API/Users_Guide/BAM_Slicing/

# Set token as variable
token=$(cat gdc.token)

# Use GDC-API to download region
curl --header "X-Auth-Token: $token" \
  'https://api.gdc.cancer.gov/slicing/view/df80679e-c4d3-487b-934c-fcc782e5d46e?region=chrUn_GL000220v1' \
  --output get_RNA45S.bam

# Use GDC-API via POST
curl --header "X-Auth-Token: $token" \
  --request POST https://api.gdc.cancer.gov/slicing/view/9ca90dfa-e62f-4f9c-9946-dfcecfd3ca4d \
  --header "Content-Type: application/json" \
  -d@data.json \
  --output post_regions_slice.bam

## Where data.json is a file of format:
##
#{
#    "regions": [
#        "chrUn_GL000220v1"
#    ]
#}


## Error return:
#{
#"error": "u'chrUn_GL000220v1' does not match '^[a-zA-Z0-9]+(:([0-9]+)?(-[0-9]+
# "message": "u'chrUn_GL000220v1' does not match '^[a-zA-Z0-9]+(:([0-9]+)?(-[0-9
# }

# %% [markdown]
# From the GDC/TCGA website, this cohort of data was selected with the following filter command.
#
# ```
# cases.project.project_id in ["TCGA-COAD"] and files.data_format in ["bam"] and files.experimental_strategy in ["WGS","WXS"]
# ```
#
# Yielding 973 files in 443 cases in 22.95 Tb 0_0
#
# The `Sample Sheet`, `File Manifest`, and `Biospecimen` data for this selection was downloaded. This is stored in `$PWD\metadata`
#
# In the `TCGA_WXS1_File_Selection.xlsx` spreadsheet, this set of files was filtered/parsed to
#
# 1. If there is a technical replicate of the same sample, they will share a SampleID (`TCGA-XX-####-01A`), add a replicate suffix to make naming unique downstream (`TCGA-XX-####-01Ax`) where x = {_,b,c...}
#
#
# The output of this parsing is copied to the input files: `tcga_wxs_pilot.input` and tcga_wxs.input`

# %% [markdown]
# ### Scripts and Localization

# %% [markdown]
# #### 1 - Localization

# %%
WORKDIR='/home/artem/Crown/data2/tcga_wxs'
cd $WORKDIR
ls

# Amazon AWS S3 Home URL
S3URL='s3://crownproject/tcga_wxs'
# Out:
# droneB.sh             queenB.sh              tcga_wxs_pilot.input
# hgr1_align_v5.wxs.sh  tcga_wxs.input         tcga_wxs_pilot.input1.log
# metadata              tcga_wxs_errors.input  tcga_wxs_pilot.input2.log

# %%
INPUT='tcga_wxs_pilot.input'

cat $INPUT
# Out:
# TCGA-3L-AA1B-01A	TCGA-COAD	cbbbce29-1e5e-4dbc-b3fb-a96b69ba0bfe
# TCGA-3L-AA1B-10A	TCGA-COAD	cb0a27a1-2fb4-4dd4-b036-9ead9492b404
# TCGA-4N-A93T-01A	TCGA-COAD	81b63768-e633-4a6c-8ccb-2ebd174b45e7
# TCGA-4N-A93T-10A	TCGA-COAD	9a8a5552-205a-4cb5-9a1c-0a3ae7c48a29
# TCGA-4T-AA8H-01A	TCGA-COAD	78b6ebc3-95c4-42d3-b924-2787b06e0643
# TCGA-4T-AA8H-10B	TCGA-COAD	b2e53fd1-b2f3-4b36-af43-9eb0165f519d
# TCGA-5M-AAT4-01A	TCGA-COAD	75f75e67-8f41-42e2-9bb7-6fde50135aa8
# TCGA-5M-AAT4-10A	TCGA-COAD	a0f5856e-d5e5-4bf7-8e8d-9af5281a7ef8
# TCGA-5M-AAT5-01A	TCGA-COAD	4a9b3630-a447-435f-b633-8774748a6316
# TCGA-5M-AAT5-10A	TCGA-COAD	e3557e59-b709-4b1b-8e50-3635e8683534

# %% [markdown]
# #### 2 - Script Versions

# %%
cd $WORKDIR
# Echo scripts to be used for this analysis for version control.
# Note these need to be manually copied to the $WORKDIR

cat hgr1_align_v5.wxs.sh
echo 
echo
cat queenB.sh
echo 
echo
cat droneB.sh
echo 
echo
# Out:
# #!/bin/bash
# # hgr1_align_v5.tcga-wxs.sh
# # rDNA alignment pipeline - WXS extraction version
# PIPE_VERSION='191220 build -- TCGA-WXS'
# AMI_VERSION='crown-190601 - ami-0b375c9c58cb4a7a2'
# # EC2: c4.2xlarge (8cpu / 15 gb)
# # EC2: c4.xlarge  (4cpu / 8  gb)
# # Storage: 200 Gb
# #
#
# # Input Requirements --------------------------
#
# # $1 : Library name and file-output name (unique)
# # $2 : Library population/analysis set
# # $3 : Library UUID
# # -- : Seq-read type = 'wxs'
#
# # Control Panel -------------------------------
# # Amazon AWS S3 Home URL
# S3URL='s3://crownproject/tcga_wxs'
#
# # CPU
# 	THREADS='3'
#
# # Sequencing Data
# 	LIBRARY=$1 # Library/ File name
#
# # Terminate instances upon completion (for debuggin)
#   TERMINATE='FALSE'
#
# # TCGA FILE UUID
#   UUID=$3
#
# # Region to extract
#   REGION='chrUn_GL000220v1:1-161802'
#
#  # FastQ File-names
#     FQ0="$LIBRARY.tmp.sort.0.fq"
#     FQ1="$LIBRARY.tmp.sort.1.fq"
#     FQ2="$LIBRARY.tmp.sort.2.fq"
#     FQR="$LIBRARY.region.fq"
#
# # Read Group Data
# # Extract from downloaded BAM file / input
# 	RGPO=$2 # Patient Population
#
# 	#RGSM= # Sample. Patient Identifer
# 	#RGID= # Read Group ID. Accession Number
#
# 	RGLB=$LIBRARY # Library Name. Accession Number
# 	RGPL='ILLUMINA'  # Sequencing Platform.
#
# 	# Extract Sequencing Run Info
# 	#  RGPU=$(gzip -dc $FQ1 | head -n1 - | cut -f1 -d':' | cut -f2 -d' ')
#
# # Print
# echo " -- hgr1 Alignment Pipeline -- "
# echo " version: $PIPE_VERSION "
# echo " ami:     $AMI_VERSION  "
# echo " s3:      $S3URL  "
# echo " library: $LIBRARY"
# echo " type:    wxs"
# echo " pop.:    $RGPO"
# echo " date:    $(date)"
# echo ''
#
# # Initialize wordir ---------------------------
# echo 'Initializing ...'
#
# # Make working directory
#   mkdir -p align; cd align
#
# # Copy hgrX genome and create bowtie2 index
#   cp ~/resources/hgr1/* ./
#
# # Load updated GDC token to instance
# aws s3 cp $S3URL/scripts/gdc.token gdc.token
# chmod 600 gdc.token
#
# echo 'Downloading'
#
# # Download RNAseq BAM file
# # with a UUID as input
#   ~/bin/gdc-client download -t gdc.token -d ./ \
#   -n $THREADS $UUID
#
# # Link the RNA-seq bamfile which is called by its UID to workdir
#   ln -s */*.bam input.bam
#   ln -s */*.bai input.bam.bai
#
# # Extract ReadGroup Sample Name (SM)
#   RGSM=$(~/bin/samtools view -H input.bam | grep '^@RG' | sed "s/.*SM:\([^\t]*\).*/\1/g" | uniq )
#
# # Extract ReadGroup identifier (ID)
#   #RGID=$(~/bin/samtools view -H input.bam | grep '^@RG' | sed "s/.*ID:\([^\t]*\).*/\1/g" | uniq )
#   RGID=$(~/bin/samtools view -H input.bam | grep '^@RG' | sed "s/.*ID:\([^\t]*\).*/\1/g" | head -n1 - )
#
# # Convert input bam file to fastq files for re-alignment
# ~/bin/samtools view -b -o input.bam $REGION| \
#   ~/bin/samtools fastq -O\
#   -0 $FQ0 \
#   -1 $FQ1 \
#   -2 $FQ2 -
#
#   # Append \1 and \2 to each read name in fq files
#   sed -i 's/^@.*/&1\/1/g' $FQ1
#   sed -i 's/^@.*/&1\/2/g' $FQ2
#
#   cat $FQ0 $FQ1 $FQ2 > $FQR
#
#
# # For extraction; treat as if single-end reads (due to un-even)========
# # SINGLE END READS ====================================================
# echo 'Aligning'
#
# if [ -s $FQR ]
# then
#     # Extract Sequencing Run Info
#     #RGPU=$(gzip -dc $FQ0| head -n1 - | cut -f1 -d':' | cut -f2 -d' ')
#     RGPU=$(head -n1 $FQR | cut -f1 -d':' | cut -f2 -d' ')
#
#     # Bowtie2: align to genome
#     bowtie2 --very-sensitive-local -p $THREADS \
#       --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \
#       --rg PL:$RGPL --rg PU:$RGPU \
#       -x hgr1 -U $FQR | \
#       ~/bin/samtools view -bS - > aligned_unsorted.bam
#
#     echo "Alignment complete."
#     echo "Calculate flagstats."
#
#     # Sort all reads (including unmapped chrUn reads)
#     ~/bin/samtools sort -@ $THREADS -O BAM aligned_unsorted.bam \
#       > align.hgr1.bam #mapped + unmapped
#
#     # Calculate library flagstats
#     ~/bin/samtools flagstat align.hgr1.bam > align.hgr1.flagstat
#
#     # Index library flagstats
#     ~/bin/samtools index align.hgr1.bam
#
#     # Rename the hgr-aligned Bam files
#       mv align.hgr1.bam $LIBRARY.hgr1.wxs.bam
#       mv align.hgr1.bam.bai $LIBRARY.hgr1.wxs.bam.bai
#       mv align.hgr1.flagstat $LIBRARY.hgr1.wxs.flagstat
#
#     echo "Processing complete. Copy files to S3"
#     # Alignments (Aligned)
#     aws s3 cp $LIBRARY.hgr1.wxs.bam $S3URL/$RGPO/
#     aws s3 cp $LIBRARY.hgr1.wxs.bam.bai $S3URL/$RGPO/
#     aws s3 cp $LIBRARY.hgr1.wxs.flagstat $S3URL/$RGPO/
#
# fi
#
# echo "Create log files and copy to S3"
# # Copy screen log file to AWS S3
# cp ~/screenlog.0 ./$LIBRARY.screenlog
# aws s3 cp $OUTPUT.screenlog $S3URL/logs/
#
# # Shutdown and Terminate instance
# EC2ID=$(ec2metadata --instance-id)
# sleep 20s # to catch errors
#
# if [ "$TERMINATE" = TRUE ]
# then
#   echo "Run Complete -- Shutting down instance."
#   aws ec2 terminate-instances --instance-ids $EC2ID
# else
#   echo "Run Complete -- Instance is online."
# fi
#
# # Script complete
#
#
#
# #!/bin/bash
# # queenB.sh
# # 20180814 build
# # EC2 Launch / Control Script
# #
#
# # 1. queenB script is initialized locally and input files
# #    are parsed ready for cluster analaysis
# # 2. queenB launches instances, logs in to it and runs the
# #    droneB.sh script remotely.
# # 3. The droneB script is executed on the instance and it
# #    launches a `screen` on the instance and loads and
# #    starts to perform the $TASK (gather.sh) script.
# # 4. TASK script should include a instance shut-down
# #    command to close instance upon completion.
# #
#
# # Control Panel =========================
# # Amazon AWS S3 Home URL
# S3URL='s3://crownproject/tcga_wxs'
#
# # EC2 TASK Script - script for droneB to execute
# TASK="$S3URL/scripts/hgr1_align_v5.wxs.sh"
#
# # Parameter file:
# # Each line of PARAMETERS will be input to STDIN of
# # the droneB script which can then be used to run the
# # TASK script.
# # i.e. bash droneB.sh <line_N_of_PARAMETERS>
# # PARAMETERS="tcga0_input.txt"
# PARAMETERS=$1
#
# # EC2 Set-up
# instanceTYPE='c4.xlarge'
# imageID='ami-0b375c9c58cb4a7a2' #AMI Crown CCLE/SRA
#
# devNAME='/dev/sda1' # /dev/sda1 for Crown-AMI
# volSIZE='200' # in Gb
#
# # Maximum number of EC2 instances to run simultaniously
# MAX_INSTANCE='45'
#
# # Number of instances to launch
# #COUNT=2 # predetermined number
# COUNT=$(awk 'END{print NR}' $PARAMETERS) # for each input argument
#
# # Security
# keyNAME='CrownKey'
# keyPATH="/home/ec2-user/.ssh/CrownKey.pem"
# secGROUP='crown-group'
#
# # Input Validation ======================
# # Test input file for duplicate sample ID (which will cause file collisions downstream)
# # exit with error 1 if collision exists
#
# SAMPLEIDS=$(cut -f1 $1 | uniq -d )
#
# if [ -n "$SAMPLEIDS" ]
# then
#   # If there are duplicate sample IDs exit
#   echo "Error 02 - Duplicate Sample ID detected in input"
#   echo " I hope you know what you're doing"
#   echo " script will not exit in this version"
#   echo " re-run with unique ID or outputs will overwrite"
#   echo ""
#   #echo "$SAMPLEIDS"
#   #exit 2
# fi
#
# # Script Core ===========================
#
# for ITER in $(seq 1 $COUNT)
# do
#
#   # Count the total number of instances
#   running_instance=$(aws ec2 describe-instances |\
#     grep '"Name": "running"' - |\
#     wc -l - | cut -f1 -d' ' - )
#
#   while [ $running_instance -ge $MAX_INSTANCE ];
#   do
#
#     echo "Reached max of $running_instance, wait."
#     echo ''
#
#     # If there are greater then 25 instances
#     # wait for instance to close
#     sleep 5m
#
#     running_instance=$(aws ec2 describe-instances |\
#     grep '"Name": "running"' - |\
#     wc -l - | cut -f1 -d' ' - )
#   done
#
#   # Extract Parameters/Arguments ----------
#
#   ARGS=$(sed -n "$ITER"p $PARAMETERS | sed 's/\t/ /g' - )
#
#   echo "Launch instance # $ITER"
#   date
#   echo "Instance Type: $instanceTYPE"
#   echo "AMI Image: $imageID"
#   echo "Run Script: $TASK"
#   echo "Parameters: $ARGS"
#
#   # Launch an instance --------------------
#   # NOTE: each iteration of the for loop launches one instance
#   # therefore each loop launches only one instance
#   aws ec2 run-instances --image-id $imageID --count 1 \
#    --instance-type $instanceTYPE --key-name $keyNAME \
#    --block-device-mappings DeviceName=$devNAME,Ebs={VolumeSize=$volSIZE} \
#    --security-groups $secGROUP > launch.tmp
#
#   # Another alternative is to use --user-data droneB.sh
#   # which will run at instance boot-up
#   # passing arguments to it may be challenging
#
#   # Retrieve instance ID
#   instanceID=$(cat launch.tmp | \
#     egrep -o -e 'InstanceId[":/A-Za-z0-9_ \\-]*' - |\
#     cut -f2 -d' ' - | xargs)
#
#   echo "Instance ID: $instanceID"
#
#   # Add a few minute wait here to allow for Public DNS to be assigned
#   # otherwise ssh doesn't work
#   # CURRENT BOTTLENECK
#   sleep 180s
#
#   # Check that the instance is 'running' and not pending
#   pending_instance=$(aws ec2 describe-instances |\
#    grep '"Name": "pending"' - |\
#    wc -l - | cut -f1 -d' ' - )
#
#   while [ $pending_instance -gt 0 ];
#   do
#
#     echo "Launchign instance not ready yet, chill"
#     # Instance still pending
#     sleep 180s
#
#     pending_instance=$(aws ec2 describe-instances |\
#      grep '"Name": "pending"' - |\
#      wc -l - | cut -f1 -d' ' - )
#   done
#
#
#   # Retrieve public DNS
#   aws ec2 describe-instances --instance-ids $instanceID > launch2.tmp
#
#   pubDNS=$(cat launch2.tmp | \
#     egrep -o -m 1 -e 'PublicDnsName[.":/A-Za-z0-9_ \\-]*' - |\
#     cut -f2 -d' ' - | xargs)
#
#   echo "Public DNS: $pubDNS"
#
#   # Access the instance -------------------
#
#   LOGIN="ubuntu@$pubDNS"
#
#   ssh -i $keyPATH \
#     -o StrictHostKeyChecking=no \
#     $LOGIN 'bash -s' < droneB.sh $TASK $(echo $ARGS)
#
#   # Cleanup
#   rm *.tmp
#
#   echo ''
#   echo ''
#
# done
#
# # end of script
#
# #!/bin/bash
# # droneB.sh
# #
#
# # This script-layer is neccesary to launch a screen session
# # on each ec2-machine. The pipeline is run within that session
# # and the output is logged. This allows 'looking in' on sessions
# # as they are running.
#
# # Commands to run on server-side
# # ===============================================================
#
# SCRIPTPATH=$1
#
# SCRIPT=$(basename $1)
#
# shift # drop first (TASK or SCRIPT variable)
#
# # Download pipeline / droneB's function
#   aws s3 cp $SCRIPTPATH ./
#
#   chmod 777 *.sh
#
# # open screen; run gather.sh function. -L logged
#   screen -Ldmt sh ~/$SCRIPT $@
#
#
# # ===============================================================

# %% [markdown]
# ## Results - TCGA-WXS Pilot Run

# %% [markdown]
# #### 3 - Copy local to S3

# %%
# Local Folder Operations -----------------------------
# LOCAL:
cd $WORKDIR

#NOTE For pilot run, AWS s3 shutdown commented out. Re-upload hgr1 script upon full run

aws s3 cp queenB.sh $S3URL/scripts/
aws s3 cp droneB.sh $S3URL/scripts/
aws s3 cp hgr1_align_v5.wxs.sh $S3URL/scripts/
aws s3 cp $INPUT $S3URL/scripts/
aws s3 cp ../../gdc.token.txt $S3URL/scripts/gdc.token
# Out:
# upload: ./queenB.sh to s3://crownproject/tcga_wxs/scripts/queenB.sh
# upload: ./droneB.sh to s3://crownproject/tcga_wxs/scripts/droneB.sh
# upload: ./hgr1_align_v5.wxs.sh to s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh
# upload: ./tcga_wxs_pilot.input to s3://crownproject/tcga_wxs/scripts/tcga_wxs_pilot.input
# upload: ../../gdc.token.txt to s3://crownproject/tcga_wxs/scripts/gdc.token

# %% [markdown]
# #### 4 - Launch and run master EC2 node

# %%
# Remote EC2 Instance Operations ----------------------

# Remote:
# Manually open an Amazon Linux 2 AMI
# ami-061392db613a6357b
# t2.micro
#
# ssh login:
# ssh -i "crown.pem" ec2-user@PUBLICDNS
# ssh -i "~/.ssh/CrownKey.pem" ec2-user@ec2-34-221-178-164.us-west-2.compute.amazonaws.com 

# Commands on EC2 machine to set-up AWS
# enter personal login info:

# REMOTE:
#aws configure
  # AWS Key ID
  # AWS Secret Key ID
  # Region: us-west-2
  
# Copy local run files to S3 and download them on EC2

# REMOTE:
# aws s3 cp --recursive s3://crownproject/tcga_wxs/scripts/ ./
#
# mv <KEY>.pem ~/.ssh/
# chmod 400 ~/.ssh/<KEY>.pem

# REMOTE:
# Open logging screen and being launchign EC2 instances
# screen -L
# 
# bash queenB.sh tcga_wxs_pilot.input
#
# aws s3 cp screenlog.0 s3://crownproject/tcga_wxs/logs/tcga_wxs_pilot.input.log

aws s3 cp s3://crownproject/tcga_wxs/logs/tcga_wxs_pilot.input1.log ./
cat tcga_wxs_pilot.input1.log

aws s3 cp s3://crownproject/tcga_wxs/logs/tcga_wxs_pilot.input2.log ./
cat tcga_wxs_pilot.input2.log

# Run completed successfully
# Out:
# download: s3://crownproject/tcga_wxs/logs/tcga_wxs_pilot.input1.log to ./tcga_wxs_pilot.input1.log
# kec2-user@ip-172-31-29-116:~\[ec2-user@ip-172-31-29-116 ~]$ ls
# CrownKey.pem  gdc.token             queenB.sh    tcga_wxs_pilot.input
# droneB.sh     hgr1_align_v5.wxs.sh  screenlog.0
# kec2-user@ip-172-31-29-116:~\[ec2-user@ip-172-31-29-116 ~]$ bash queenB.sh tcga_wxs_pilot.input
# Launch instance # 1
# Sat Dec 21 02:41:12 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh
# Parameters: TCGA-3L-AA1B-01A TCGA-COAD cbbbce29-1e5e-4dbc-b3fb-a96b69ba0bfe
# Instance ID: i-0cd929e5bd12ab5cc
# Public DNS: ec2-54-187-201-238.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-187-201-238.us-west-2.compute.amazonaws.com,172.31.3.163' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh to ./hgr1_align_v5.wxs.sh
#
#
# Launch instance # 2
# Sat Dec 21 02:44:18 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh
# Parameters: TCGA-3L-AA1B-10A TCGA-COAD cb0a27a1-2fb4-4dd4-b036-9ead9492b404
# Instance ID: i-0dd76dec25fd0e817
# Public DNS: ec2-54-71-123-120.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-71-123-120.us-west-2.compute.amazonaws.com,172.31.15.71' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh to ./hgr1_align_v5.wxs.sh
#
#
# kec2-user@ip-172-31-29-116:~\[ec2-user@ip-172-31-29-116 ~]$ [ec2-user@ip-172-31-29-116 ~]$ ls
# CrownKey.pem  gdc.token             queenB.sh    tcga_wxs_pilot.input
# droneB.sh     hgr1_align_v5.wxs.sh  screenlog.0
# download: s3://crownproject/tcga_wxs/logs/tcga_wxs_pilot.input2.log to ./tcga_wxs_pilot.input2.log
# [20@cat tcga_wxs_pilot.input
# TCGA-4N-A93T-01A	TCGA-COAD	81b63768-e633-4a6c-8ccb-2ebd174b45e7
# TCGA-4N-A93T-10A	TCGA-COAD	9a8a5552-205a-4cb5-9a1c-0a3ae7c48a29
# TCGA-4T-AA8H-01A	TCGA-COAD	78b6ebc3-95c4-42d3-b924-2787b06e0643
# TCGA-4T-AA8H-10B	TCGA-COAD	b2e53fd1-b2f3-4b36-af43-9eb0165f519d
# TCGA-5M-AAT4-01A	TCGA-COAD	75f75e67-8f41-42e2-9bb7-6fde50135aa8
# TCGA-5M-AAT4-10A	TCGA-COAD	a0f5856e-d5e5-4bf7-8e8d-9af5281a7ef8
# TCGA-5M-AAT5-01A	TCGA-COAD	4a9b3630-a447-435f-b633-8774748a6316
# TCGA-5M-AAT5-10A	TCGA-COAD	e3557e59-b709-4b1b-8e50-3635e8683534
# bash queenB.sh tcga_wxs_pilot.input
# Launch instance # 1
# Sat Dec 21 03:07:37 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh
# Parameters: TCGA-4N-A93T-01A TCGA-COAD 81b63768-e633-4a6c-8ccb-2ebd174b45e7
# Instance ID: i-07b751f3d17d72a25
# Public DNS: ec2-52-34-52-169.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-34-52-169.us-west-2.compute.amazonaws.com,172.31.5.251' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh to ./hgr1_align_v5.wxs.sh
#
#
# Launch instance # 2
# Sat Dec 21 03:10:43 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh
# Parameters: TCGA-4N-A93T-10A TCGA-COAD 9a8a5552-205a-4cb5-9a1c-0a3ae7c48a29
# Instance ID: i-086d3cada5530487b
# Public DNS: ec2-54-148-177-106.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-148-177-106.us-west-2.compute.amazonaws.com,172.31.2.207' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh to ./hgr1_align_v5.wxs.sh
#
#
# Launch instance # 3
# Sat Dec 21 03:13:51 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh
# Parameters: TCGA-4T-AA8H-01A TCGA-COAD 78b6ebc3-95c4-42d3-b924-2787b06e0643
# Instance ID: i-0c35642c42946d4ec
# Public DNS: ec2-34-214-160-55.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-214-160-55.us-west-2.compute.amazonaws.com,172.31.11.74' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh to ./hgr1_align_v5.wxs.sh
#
#
# Launch instance # 4
# Sat Dec 21 03:16:56 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh
# Parameters: TCGA-4T-AA8H-10B TCGA-COAD b2e53fd1-b2f3-4b36-af43-9eb0165f519d
# Instance ID: i-0163b8a0eaa1e94cd
# ^[[1;6BPublic DNS: ec2-34-208-64-21.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-208-64-21.us-west-2.compute.amazonaws.com,172.31.1.174' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh to ./hgr1_align_v5.wxs.sh
#
#
# Launch instance # 5
# Sat Dec 21 03:20:02 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh
# Parameters: TCGA-5M-AAT4-01A TCGA-COAD 75f75e67-8f41-42e2-9bb7-6fde50135aa8
# Instance ID: i-0d9256c330b18b141
# Public DNS: ec2-35-162-172-143.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-162-172-143.us-west-2.compute.amazonaws.com,172.31.10.162' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh to ./hgr1_align_v5.wxs.sh
#
#
# Launch instance # 6
# Sat Dec 21 03:23:08 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh
# Parameters: TCGA-5M-AAT4-10A TCGA-COAD a0f5856e-d5e5-4bf7-8e8d-9af5281a7ef8
# Instance ID: i-01cfc3b38858a7940
# Public DNS: ec2-18-236-220-80.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-236-220-80.us-west-2.compute.amazonaws.com,172.31.8.78' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh to ./hgr1_align_v5.wxs.sh
#
#
# Launch instance # 7
# Sat Dec 21 03:26:13 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh
# Parameters: TCGA-5M-AAT5-01A TCGA-COAD 4a9b3630-a447-435f-b633-8774748a6316
# Instance ID: i-08fb05bccde26d59f
# Public DNS: ec2-54-149-148-92.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-149-148-92.us-west-2.compute.amazonaws.com,172.31.12.131' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh to ./hgr1_align_v5.wxs.sh
#
#
# Launch instance # 8
# Sat Dec 21 03:29:19 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh
# Parameters: TCGA-5M-AAT5-10A TCGA-COAD e3557e59-b709-4b1b-8e50-3635e8683534
# Instance ID: i-02f9fdfa1315f63a5
# Public DNS: ec2-54-214-230-132.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-214-230-132.us-west-2.compute.amazonaws.com,172.31.0.244' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh to ./hgr1_align_v5.wxs.sh
#
#
# [ec2-user@ip-172-31-29-116 ~]$ ls
# CrownKey.pem  gdc.token             queenB.sh    tcga_wxs_pilot.input
# droneB.sh     hgr1_align_v5.wxs.sh  screenlog.0  tcga_wxs_pilot.input1.log
# kec2-user@ip-172-31-29-116:~\[ec2-user@ip-172-31-29-116 ~]$ exit
# exit

# %% [markdown]
# ## Results - TCGA-WXS Full Run
#
# Run same as above but with TCGA-COAD list.

# %%
INPUT='tcga_wxs.input'
cat $INPUT
# Out:
# TCGA-5M-AAT6-01A	TCGA-COAD	e2fbd373-e44e-4d18-920a-58b5b7c35e67
# TCGA-5M-AAT6-10A	TCGA-COAD	f1cabc65-4b00-44b6-80f0-fbb9193d25fc
# TCGA-5M-AATA-01A	TCGA-COAD	4b9e0e99-808d-4cc6-8b7b-1b7e91dd1b54
# TCGA-5M-AATA-10A	TCGA-COAD	ddd32176-6911-49c0-8d6d-904c69607019
# TCGA-5M-AATE-01A	TCGA-COAD	0bb88200-c1e2-4417-ba37-b5d0248dd5ce
# TCGA-5M-AATE-10A	TCGA-COAD	999ab1ab-d0e7-474e-82e0-3ef088c4def5
# TCGA-A6-2671-01A	TCGA-COAD	90da5386-eac1-4f9b-8715-b101521819e2
# TCGA-A6-2671-10A	TCGA-COAD	40924be9-a705-462d-a9ee-6d1fc956a06b
# TCGA-A6-2671-11A	TCGA-COAD	5ae75803-dfad-4a48-92a7-2ef88356aaff
# TCGA-A6-2672-01B	TCGA-COAD	cf44a424-5687-4164-beb2-1c68f9a78028
# TCGA-A6-2672-01Bb	TCGA-COAD	1d7bb87a-0b9e-4ed6-98e1-d0bc11d62a73
# TCGA-A6-2672-11A	TCGA-COAD	8c23361b-828d-42d6-a7e7-91034b303664
# TCGA-A6-2674-01A	TCGA-COAD	9d2fb270-0601-4ac9-89d6-1c5b13079fe6
# TCGA-A6-2674-01Ab	TCGA-COAD	9e070142-cf47-4217-9ca3-ff0c5d0b06a3
# TCGA-A6-2674-01B	TCGA-COAD	92470c68-a390-4603-a4f4-6f5210cc1fcc
# TCGA-A6-2674-10A	TCGA-COAD	949a5cfd-516e-47fb-a60b-efd93952d338
# TCGA-A6-2674-11A	TCGA-COAD	85689e93-80d9-46b9-aeb4-da788205d619
# TCGA-A6-2675-01A	TCGA-COAD	f13ac225-04c7-45a0-9f52-d6e9c6f74ba7
# TCGA-A6-2675-10A	TCGA-COAD	20734308-449b-4679-ba15-2864cef7f397
# TCGA-A6-2675-11A	TCGA-COAD	e971453b-7f65-4bd2-b528-a6440ef9f414
# TCGA-A6-2676-11A	TCGA-COAD	e7c630aa-cae4-445d-a078-9c0741059aab
# TCGA-A6-2677-01A	TCGA-COAD	9dc399e8-7e7e-4484-92cb-96da47f8a870
# TCGA-A6-2677-01B	TCGA-COAD	f0d6325f-463a-4f46-9480-aa2c69a80b98
# TCGA-A6-2677-10A	TCGA-COAD	20cdef88-1b7e-4a71-9245-dd0a88f9e8ff
# TCGA-A6-2677-11A	TCGA-COAD	1fb4a301-8529-4359-bf74-ba0c4c0ea2ce
# TCGA-A6-2678-01A	TCGA-COAD	aa11d993-f16c-49cc-bd69-86ff048362b2
# TCGA-A6-2678-10A	TCGA-COAD	32f54007-cc22-472b-9752-cdf99211a755
# TCGA-A6-2678-11A	TCGA-COAD	bef9fb5b-b039-42f6-8211-0d731bbf8a9b
# TCGA-A6-2679-01A	TCGA-COAD	5e92af85-fabc-4242-a264-a8dacec64351
# TCGA-A6-2679-10A	TCGA-COAD	4b4502d4-27c3-4bd6-9f37-229efd347756
# TCGA-A6-2679-11A	TCGA-COAD	68b23b5d-f7b7-4a09-af9a-44e1cf284f32
# TCGA-A6-2680-01A	TCGA-COAD	9bc99c0d-3e1c-462c-9f30-18522fd211f8
# TCGA-A6-2680-10A	TCGA-COAD	00ec5e0d-ffb4-4975-9bec-75d88a5a5411
# TCGA-A6-2680-11A	TCGA-COAD	a4eb0f9c-20da-48b8-a7cc-f0b3204cf98d
# TCGA-A6-2681-01A	TCGA-COAD	c59d91c0-0f55-42af-97cf-f689e5aec864
# TCGA-A6-2681-10A	TCGA-COAD	e52fa5db-671e-4f0f-8279-01b66bd71069
# TCGA-A6-2681-11A	TCGA-COAD	0da1dd78-ec6b-44e9-8e6f-473c008118aa
# TCGA-A6-2682-01A	TCGA-COAD	dd2672ed-088f-4785-aa7d-52765d28c05a
# TCGA-A6-2682-10A	TCGA-COAD	c6980d7e-8e22-49d7-9353-f8ed639b8a6a
# TCGA-A6-2682-11A	TCGA-COAD	e5da4acd-0b3a-422f-80f5-4002f19def6f
# TCGA-A6-2683-01A	TCGA-COAD	2331c1a0-336b-45b4-8933-f7975f90dc12
# TCGA-A6-2683-10A	TCGA-COAD	656714d1-f7ca-4685-a883-2386653d4b62
# TCGA-A6-2683-11A	TCGA-COAD	edf9a91e-bb7a-46d1-9da5-5f4a3d59aacc
# TCGA-A6-2684-01A	TCGA-COAD	75bcf2f8-f9a1-425c-b42f-12753de916ef
# TCGA-A6-2684-01C	TCGA-COAD	f0183566-da57-4cbd-b89b-7388fecffbc5
# TCGA-A6-2684-10A	TCGA-COAD	672d4d03-94b2-4ec4-8193-883a51313fcb
# TCGA-A6-2684-10Ab	TCGA-COAD	f48f0411-f1dc-41c3-a366-8aa05ebacb6c
# TCGA-A6-2684-11A	TCGA-COAD	89561e80-9ad3-4cc9-9965-f273e207e8fe
# TCGA-A6-2685-01A	TCGA-COAD	e38da823-b4c0-49f7-bc9c-928499f1a7b8
# TCGA-A6-2685-10A	TCGA-COAD	95445544-6109-425f-99dd-b890d48504b1
# TCGA-A6-2685-11A	TCGA-COAD	68098509-152b-41e3-bea4-78c2bcc03a89
# TCGA-A6-2686-01A	TCGA-COAD	fd7f1a4e-af37-4c9a-9f75-b84da1645f87
# TCGA-A6-2686-10A	TCGA-COAD	8315de30-6a18-4248-a87d-af7f0f23fe50
# TCGA-A6-2686-11A	TCGA-COAD	f5f0b131-5382-42bd-8d93-9c4021d9db61
# TCGA-A6-3807-01A	TCGA-COAD	b48b5c2a-ac23-4ae7-9091-82824610c407
# TCGA-A6-3807-10A	TCGA-COAD	b3cecfc2-7d45-4bb6-996e-7265f6668d66
# TCGA-A6-3807-11A	TCGA-COAD	c7d84f43-f8e3-4267-8878-acc01160a232
# TCGA-A6-3808-01A	TCGA-COAD	1da80f23-c59f-4ace-ba93-a884e49a0ca5
# TCGA-A6-3808-10A	TCGA-COAD	b75e576b-5338-49b1-8f5b-281f5c30ebc9
# TCGA-A6-3808-11A	TCGA-COAD	ce815d1c-d651-43a6-9c5f-51f9d7dface2
# TCGA-A6-3809-01A	TCGA-COAD	76e9de45-af12-484c-895a-4b7e4327ca26
# TCGA-A6-3809-01B	TCGA-COAD	7f84f3c8-f6ed-4a21-b429-fd433a0ba100
# TCGA-A6-3809-10A	TCGA-COAD	bf6984c6-ca7a-41ff-b733-d03a0f294a59
# TCGA-A6-3809-10Ab	TCGA-COAD	57b6590c-f9ab-42cd-9739-124828001116
# TCGA-A6-3810-01A	TCGA-COAD	1141666a-34ca-4326-82ba-2fd38eae2450
# TCGA-A6-3810-01B	TCGA-COAD	a743cc2c-477d-44b7-b749-842a8de022bf
# TCGA-A6-3810-10A	TCGA-COAD	bde37792-d40f-434d-8369-9c8a1cd5e823
# TCGA-A6-3810-10Ab	TCGA-COAD	c0434a5a-7463-47a9-955d-69625f69ec9b
# TCGA-A6-3810-11A	TCGA-COAD	d9733444-4c49-44bb-8374-48120f2a7dd1
# TCGA-A6-4105-01A	TCGA-COAD	a4a8afbe-8634-4dd6-99c7-44a2caf4ea27
# TCGA-A6-4105-10A	TCGA-COAD	abd27d77-0396-4151-a551-0cc89e61a9e2
# TCGA-A6-4107-01A	TCGA-COAD	d0a2ae31-6894-4cf9-a78c-771d63f0a296
# TCGA-A6-4107-10A	TCGA-COAD	8c42abcb-73b2-403a-ba83-b26b36f43696
# TCGA-A6-4107-11A	TCGA-COAD	77b3b571-3e03-4445-8b1b-a54b6687dc6e
# TCGA-A6-5656-01A	TCGA-COAD	a72cb025-2ece-4ec0-a410-92b51ea6be57
# TCGA-A6-5656-01Ab	TCGA-COAD	012fc920-2c94-4596-a937-9e6f6a3fffd8
# TCGA-A6-5656-01B	TCGA-COAD	4ed6d3ba-92e2-40b5-8074-0d46617eea4c
# TCGA-A6-5656-10A	TCGA-COAD	2f89827c-5ff3-4b95-a7b7-577af52526ff
# TCGA-A6-5656-10Ab	TCGA-COAD	931fb73c-a61e-4bcb-ac34-0aa912695894
# TCGA-A6-5657-01A	TCGA-COAD	fda75d52-0a00-43d9-b41c-7317cb507329
# TCGA-A6-5657-10A	TCGA-COAD	d19db856-c9bf-4b6e-bdbf-bc60c1f7d865
# TCGA-A6-5657-11A	TCGA-COAD	b14120b3-bfd9-4d4c-b2f7-66b69270384e
# TCGA-A6-5659-01A	TCGA-COAD	55850db0-5e63-4683-9ce1-3993bdea3e57
# TCGA-A6-5659-01Ab	TCGA-COAD	b995ca5b-cca3-4819-bb0b-cd087e2d7722
# TCGA-A6-5659-01B	TCGA-COAD	b3b8daa2-d714-40b6-a6e5-3b37eeeace5c
# TCGA-A6-5659-10A	TCGA-COAD	f8d25880-1498-4583-9a89-4c09ce7087c9
# TCGA-A6-5659-10Ab	TCGA-COAD	415f7b4a-2456-4418-a335-cb99ab3727a4
# TCGA-A6-5659-11A	TCGA-COAD	61469e45-25e3-43c5-b58c-1c6d6fdd0bb0
# TCGA-A6-5660-01A	TCGA-COAD	d15a8749-e497-495d-a0a5-d21e79f4e172
# TCGA-A6-5660-10A	TCGA-COAD	b3d797d6-6505-487e-b99a-729941480be2
# TCGA-A6-5660-11A	TCGA-COAD	24ea8f0c-81cb-4083-afd1-72b85f0e8a2d
# TCGA-A6-5661-01A	TCGA-COAD	9878a06f-05d5-40c8-96fb-abcbe25f9f82
# TCGA-A6-5661-10A	TCGA-COAD	2de754c2-ec19-4a16-a6bf-3f3844abbb70
# TCGA-A6-5661-11A	TCGA-COAD	02821c27-c53f-495a-8043-fce0359c75ed
# TCGA-A6-5662-01A	TCGA-COAD	510f1a26-72b9-4740-a384-0140c097ab55
# TCGA-A6-5662-10A	TCGA-COAD	b69223e6-4f38-435b-a795-272950f23333
# TCGA-A6-5662-11A	TCGA-COAD	67941aa9-14de-4e05-b7c8-3e079fd32ba7
# TCGA-A6-5664-01A	TCGA-COAD	308be819-2bdf-4fe5-93ba-dab8fd616ce8
# TCGA-A6-5664-10A	TCGA-COAD	aedb0221-b582-4c31-aa63-dc3666cf08e7
# TCGA-A6-5665-01A	TCGA-COAD	4bd3a26d-faa4-4d15-a71d-81fd4cc5c22d
# TCGA-A6-5665-01B	TCGA-COAD	4e12defd-63cd-4025-8e42-75d7fb737432
# TCGA-A6-5665-10A	TCGA-COAD	a03d8ee9-c8b7-4a0c-9537-24ba0d952b39
# TCGA-A6-5665-11A	TCGA-COAD	24edfbe5-7862-41fe-b456-5efd06b7e3ac
# TCGA-A6-5666-01A	TCGA-COAD	55496b67-7d45-44c0-ac8f-f3da47aae72b
# TCGA-A6-5666-10A	TCGA-COAD	f3baa4da-4b45-434a-9ef2-dff37b2dd85c
# TCGA-A6-5666-11A	TCGA-COAD	6bda5b10-a09a-42d0-bd52-f93c2b532423
# TCGA-A6-5667-01A	TCGA-COAD	7ab5db41-ec04-45aa-bf1a-8de9303a0bd3
# TCGA-A6-5667-10A	TCGA-COAD	c3df8407-2ace-475a-849d-50f67388445e
# TCGA-A6-5667-11A	TCGA-COAD	3452da56-5668-4cc7-9943-0f89899536e1
# TCGA-A6-6137-01A	TCGA-COAD	1e20b5e9-6213-46bd-bac8-9a7eba0b0fb7
# TCGA-A6-6137-10A	TCGA-COAD	e840a12f-8419-49cd-8213-9961754d8250
# TCGA-A6-6138-01A	TCGA-COAD	27fefd11-a729-45e0-a530-5e1b74dfcaab
# TCGA-A6-6138-10A	TCGA-COAD	68ea65f3-5ebb-4921-ae2b-0bc8706f13fc
# TCGA-A6-6140-01A	TCGA-COAD	997a60b1-c61e-4f70-9356-8357316f8fa9
# TCGA-A6-6140-10A	TCGA-COAD	a35ff3f9-30a1-4b71-93a9-bd9231080bd9
# TCGA-A6-6141-01A	TCGA-COAD	f3e69daf-130f-4b90-999a-ac67f460000e
# TCGA-A6-6141-10A	TCGA-COAD	b16ecabe-6c32-48ae-94ab-5b308b349506
# TCGA-A6-6142-01A	TCGA-COAD	f4b5a59a-b416-4768-a34d-629c6730330a
# TCGA-A6-6142-10A	TCGA-COAD	3d8af6b3-ce33-4792-8c65-6e7c00bc994b
# TCGA-A6-6648-01A	TCGA-COAD	f3089889-cb30-4581-821b-00d08dac1bdc
# TCGA-A6-6648-10A	TCGA-COAD	d0c20d06-66f6-4f90-906a-0c1b33dfa28c
# TCGA-A6-6649-01A	TCGA-COAD	2e3bd398-1ec5-4ebc-b883-19dd33bbddf0
# TCGA-A6-6649-10A	TCGA-COAD	67412d6d-ecb8-4000-a951-fe8fbe4bc089
# TCGA-A6-6650-01A	TCGA-COAD	5bb6d119-f6c6-4853-b015-ce219e0d26cd
# TCGA-A6-6650-01Ab	TCGA-COAD	7b2462e0-38ff-4ff9-ba9e-7955aa3e986c
# TCGA-A6-6650-01B	TCGA-COAD	e4890fe4-f5d6-4af4-9381-13a4e92b39f8
# TCGA-A6-6650-10A	TCGA-COAD	1b8e8868-a6c0-41fe-abd9-ded9a8707fab
# TCGA-A6-6650-10Ab	TCGA-COAD	47219546-568c-45d7-a765-2317bab54dbb
# TCGA-A6-6651-01A	TCGA-COAD	914126a3-28f3-4dd2-b8e1-2d4a35ccb484
# TCGA-A6-6651-10A	TCGA-COAD	3d4ea84b-c177-4b21-8891-88b301eea4e3
# TCGA-A6-6652-01A	TCGA-COAD	44ea3207-53bf-46be-ad74-17ae52c9d08c
# TCGA-A6-6652-10A	TCGA-COAD	b2efd74b-49b5-4c36-a105-172dcc7faef1
# TCGA-A6-6653-01A	TCGA-COAD	972eaabf-a7a6-46bf-bc6b-20d010aba9af
# TCGA-A6-6653-10A	TCGA-COAD	f331377f-dfb3-4ff7-b4d3-89c32c570b47
# TCGA-A6-6654-01A	TCGA-COAD	8f713761-662d-460c-b8ed-04404b3dd08a
# TCGA-A6-6654-10A	TCGA-COAD	846dbc88-57fb-44c9-8881-d0a6737c21af
# TCGA-A6-6780-01A	TCGA-COAD	fd872be2-0390-4767-b17b-42ac977409d3
# TCGA-A6-6780-01Ab	TCGA-COAD	5da6303d-6cb1-4ff4-9f88-76b006735953
# TCGA-A6-6780-01B	TCGA-COAD	40dca687-f4c4-4db1-964f-e33b6de1d388
# TCGA-A6-6780-10A	TCGA-COAD	834ca2d6-a534-42a2-9723-d8133ba5127a
# TCGA-A6-6780-10Ab	TCGA-COAD	a3ed2b57-94e2-477d-aad6-dce2f39e8c66
# TCGA-A6-6781-01A	TCGA-COAD	b8f0507f-42af-4e76-94b4-a073fa9f9271
# TCGA-A6-6781-01Ab	TCGA-COAD	2933c9bc-ed28-476a-8721-ca06f72efc2f
# TCGA-A6-6781-01B	TCGA-COAD	2a29661f-c4e6-41d7-9135-1cbd0eafef97
# TCGA-A6-6781-10A	TCGA-COAD	fd361f85-8843-4ede-bf09-e9026b4cd815
# TCGA-A6-6781-10Ab	TCGA-COAD	80661419-c566-47ae-bd6b-5ddd33c90df6
# TCGA-A6-6782-01A	TCGA-COAD	88a42334-717f-44ff-862f-4e86b476230c
# TCGA-A6-6782-10A	TCGA-COAD	ff6cc782-22bc-401d-a22d-89ac77b3b824
# TCGA-A6-A565-01A	TCGA-COAD	a6c41722-7754-4a0d-bef5-62ba0feabb61
# TCGA-A6-A565-10A	TCGA-COAD	f1fe910d-0e8d-402b-9b1c-dbef348d8fd7
# TCGA-A6-A566-01A	TCGA-COAD	b703d69b-0ee0-40ea-9f54-00b9e5185e56
# TCGA-A6-A566-10A	TCGA-COAD	3001d98f-4021-4d39-aab5-e1ec0f3c147c
# TCGA-A6-A567-01A	TCGA-COAD	1795ac47-0e3c-4875-841e-7f5dd780e10f
# TCGA-A6-A567-10A	TCGA-COAD	926cc010-e4c9-4d76-bbe4-edb38d59ac2f
# TCGA-A6-A56B-01A	TCGA-COAD	8ced3acb-21ac-4295-891b-043802598726
# TCGA-A6-A56B-10A	TCGA-COAD	22e5b3d0-2670-4935-a6dd-18b581a5a3c5
# TCGA-A6-A5ZU-10A	TCGA-COAD	7a71b043-a39e-4d55-9ca2-73703e419a7c
# TCGA-AA-3488-01A	TCGA-COAD	ea89f412-143e-4938-a1a9-ee4d3a3a11cf
# TCGA-AA-3488-11A	TCGA-COAD	29c01da8-879d-4ffa-a50f-5a26e89f98e0
# TCGA-AA-3489-01A	TCGA-COAD	dc87e514-2c34-4fb2-9eea-69210de60fb3
# TCGA-AA-3489-11A	TCGA-COAD	8b356214-31f4-4849-a3b1-60e6841d75d2
# TCGA-AA-3492-01A	TCGA-COAD	73c41bab-a238-410a-b7cf-f073a70b9a7a
# TCGA-AA-3492-11A	TCGA-COAD	cb0b171b-f242-4c72-902a-2bf79fd1f7c3
# TCGA-AA-3494-01A	TCGA-COAD	995a8c99-1b7d-4617-9f21-25de7de0796f
# TCGA-AA-3494-11A	TCGA-COAD	ea3ab57b-9b07-452b-9fd7-1a1c144b33b0
# TCGA-AA-3495-01A	TCGA-COAD	51bc66a3-801e-4ce6-99f9-2a542a4cd645
# TCGA-AA-3495-11A	TCGA-COAD	46c73be3-b3a0-47b6-ae4b-b81616b22a07
# TCGA-AA-3496-01A	TCGA-COAD	d7d6fae8-bbf6-46ec-a7cd-fa715d615832
# TCGA-AA-3496-11A	TCGA-COAD	8d1026f0-8846-49a9-840b-fd8ccfda5c80
# TCGA-AA-3502-01A	TCGA-COAD	3c5025a1-a6ce-4874-aab8-5f61281bc1a4
# TCGA-AA-3502-11A	TCGA-COAD	580d6c90-7e49-4143-bb89-f019bb41654d
# TCGA-AA-3506-01A	TCGA-COAD	bdfbb770-adab-4bf7-b7ff-a90baba0b67b
# TCGA-AA-3506-11A	TCGA-COAD	87b516b0-9225-4d18-bbf0-4fc71717d307
# TCGA-AA-3509-01A	TCGA-COAD	ac028845-0434-4544-a61f-614067952551
# TCGA-AA-3509-11A	TCGA-COAD	171a9bde-c390-47d1-8151-6baed9e546c3
# TCGA-AA-3510-01A	TCGA-COAD	61d2325e-f51a-4e41-9c54-e9414269d872
# TCGA-AA-3510-11A	TCGA-COAD	bc9c0463-2cc3-4210-968f-595737f6dd9f
# TCGA-AA-3511-01A	TCGA-COAD	97ab2c54-7daa-4249-88c2-516adf6885a0
# TCGA-AA-3511-11A	TCGA-COAD	df5674b5-f0a1-433d-b257-fad48f212e0e
# TCGA-AA-3514-01A	TCGA-COAD	b6adec92-0ec1-4dec-87f1-d10798d3b64f
# TCGA-AA-3514-10A	TCGA-COAD	4c7204ee-8b43-4015-834a-9c7f302e2115
# TCGA-AA-3514-11A	TCGA-COAD	c8769c35-0581-4323-9175-c7d656760e35
# TCGA-AA-3516-11A	TCGA-COAD	059b364e-8dd3-40ad-b9ce-f4710041e0a2
# TCGA-AA-3517-01A	TCGA-COAD	115b9c5a-ea3e-421e-8fe2-f4dd5e682ce5
# TCGA-AA-3517-10A	TCGA-COAD	73830550-801f-444a-a03a-bdd06b6d62e0
# TCGA-AA-3517-11A	TCGA-COAD	73428073-0747-49af-a1dd-6500a261795f
# TCGA-AA-3519-01A	TCGA-COAD	fc00f11e-6e05-40c8-b1fa-02c18a1cd8a1
# TCGA-AA-3519-10A	TCGA-COAD	f2c20a17-c760-49cf-808a-732ce583ccf9
# TCGA-AA-3519-11A	TCGA-COAD	37579f2d-2f83-4375-b357-5bced7d4b9d6
# TCGA-AA-3520-01A	TCGA-COAD	facb0520-e3f6-4acb-9f14-526c7ec69d9b
# TCGA-AA-3520-11A	TCGA-COAD	18456a0a-7b73-4900-ab57-6de44704693b
# TCGA-AA-3521-01A	TCGA-COAD	991b900a-d6dc-49b2-abb6-517e1f0249a2
# TCGA-AA-3521-11A	TCGA-COAD	815a8302-e758-4c72-84ad-c9693d4b401a
# TCGA-AA-3522-01A	TCGA-COAD	b3536a1a-2965-4ace-948c-a8705e72c48a
# TCGA-AA-3522-10A	TCGA-COAD	31a5ded3-238d-4b46-8b5c-5d0bcfcdd9e7
# TCGA-AA-3522-11A	TCGA-COAD	9a498ae7-0ff5-48c5-8a94-90a2227d0dfa
# TCGA-AA-3524-01A	TCGA-COAD	68bef0ef-e3c3-470b-a08d-d3b1ca39cb11
# TCGA-AA-3524-10A	TCGA-COAD	4d59b410-2b86-4ce7-8241-8c13e9ee30d0
# TCGA-AA-3524-11A	TCGA-COAD	7bc10cae-903b-479b-934c-13fa89385153
# TCGA-AA-3525-11A	TCGA-COAD	b525af05-35b5-4ff0-a387-748bb184d79b
# TCGA-AA-3526-01A	TCGA-COAD	cb7d084e-81bc-408a-83c2-5d8a8bcfbfba
# TCGA-AA-3526-10A	TCGA-COAD	1c515e50-c51c-411e-9197-2dc556ffc9fa
# TCGA-AA-3526-11A	TCGA-COAD	41e9471d-28d6-4919-ab4b-fe47d68f1277
# TCGA-AA-3527-01A	TCGA-COAD	82c191ac-5de3-49cf-9632-5d9e60edb662
# TCGA-AA-3527-10A	TCGA-COAD	04d12aa0-e449-4ae1-8425-2d0bcf827204
# TCGA-AA-3527-11A	TCGA-COAD	3710fd20-4591-4f36-937a-afcd26e53777
# TCGA-AA-3529-01A	TCGA-COAD	adb06796-2f05-493e-9620-4b30820bb6e5
# TCGA-AA-3529-10A	TCGA-COAD	31fd8960-d28a-4906-aba7-44d1ac7e8073
# TCGA-AA-3529-11A	TCGA-COAD	14ab5607-db83-48cf-ad04-003b49d0cc71
# TCGA-AA-3530-01A	TCGA-COAD	3820ce7e-5543-4831-998e-75a6e903cfd2
# TCGA-AA-3530-10A	TCGA-COAD	0feab601-cd75-4826-8cfc-9accc3eba859
# TCGA-AA-3530-11A	TCGA-COAD	8df61da3-4989-428f-861f-c0d4113fa794
# TCGA-AA-3531-01A	TCGA-COAD	5076b623-bd92-40c0-97d1-d451ddb8a9ae
# TCGA-AA-3531-10A	TCGA-COAD	561acf76-e365-4237-a507-64d82a5fea72
# TCGA-AA-3531-11A	TCGA-COAD	97343b6a-15e4-4a69-98a3-ae8d81a07931
# TCGA-AA-3532-01A	TCGA-COAD	3061d2ed-d909-4420-8c17-ccf9a7cfe9c3
# TCGA-AA-3532-10A	TCGA-COAD	e23b9467-8d25-4171-8587-4cbc5f12598d
# TCGA-AA-3532-11A	TCGA-COAD	49ddb664-496e-4938-8ff1-35c90609c523
# TCGA-AA-3534-01A	TCGA-COAD	21a29948-1163-4724-a95e-7c8f5f4e13a2
# TCGA-AA-3534-10A	TCGA-COAD	af5de507-6833-40cf-ae97-90852ae9a12f
# TCGA-AA-3534-11A	TCGA-COAD	11f4cecc-e8f8-47da-8746-267672d28573
# TCGA-AA-3538-01A	TCGA-COAD	585fde16-6d71-469c-bf70-56e6af737d72
# TCGA-AA-3538-10A	TCGA-COAD	9ceb7044-a923-4546-9f04-f95fa37d800b
# TCGA-AA-3544-01A	TCGA-COAD	83fb3e42-17dc-4777-a00f-0a81c470906b
# TCGA-AA-3544-10A	TCGA-COAD	eaeebb9f-192c-4fa5-8231-479d37d387ab
# TCGA-AA-3548-01A	TCGA-COAD	153073b9-ef18-4a83-9fb3-26d01fe11b80
# TCGA-AA-3548-10A	TCGA-COAD	3d843b5e-d6aa-428e-bbe3-db1a92dd353c
# TCGA-AA-3549-01A	TCGA-COAD	2cc97c1b-e6b7-4961-9232-017eba67e77a
# TCGA-AA-3549-10A	TCGA-COAD	990c027a-bb27-45b4-a4a7-add13a428cbf
# TCGA-AA-3552-01A	TCGA-COAD	a2147c9d-45bd-448b-98ec-6e072ec8db9b
# TCGA-AA-3553-01A	TCGA-COAD	ecd4fb95-6f88-4a1a-a258-8ec5299e9efd
# TCGA-AA-3556-01A	TCGA-COAD	c4ca9d89-40d1-4deb-9194-8b1fc93f77ed
# TCGA-AA-3556-10A	TCGA-COAD	5ac259bb-21d1-4dc2-bc46-a08ef8b9e9f1
# TCGA-AA-3558-01A	TCGA-COAD	05b9ad95-bde4-4168-bd18-b9f058f7575a
# TCGA-AA-3558-10A	TCGA-COAD	d025ba1f-b2e3-4802-9ae8-25ec0a34960c
# TCGA-AA-3560-01A	TCGA-COAD	6dcd4b55-4927-40df-ba77-649bc3525486
# TCGA-AA-3560-10A	TCGA-COAD	db89c846-0f6c-4a77-ae03-761aac87ecbc
# TCGA-AA-3561-01A	TCGA-COAD	b17153a4-2b03-4ce6-897f-9dffc1d7bf4d
# TCGA-AA-3561-10A	TCGA-COAD	ee680f01-2e85-4146-8a37-31e97128b3b8
# TCGA-AA-3562-10A	TCGA-COAD	b65d5780-cec1-4566-b421-aa536c01482f
# TCGA-AA-3655-01A	TCGA-COAD	c9f34fad-e048-41cf-b324-cea62036ba3b
# TCGA-AA-3655-11A	TCGA-COAD	4f35ba22-c1d2-440e-8164-684275820594
# TCGA-AA-3660-01A	TCGA-COAD	45c00e89-85d1-43a8-b8d4-aedc807f8422
# TCGA-AA-3660-11A	TCGA-COAD	b54d2c36-57fa-480a-b237-109e239fb736
# TCGA-AA-3662-01A	TCGA-COAD	c85ee270-868d-4522-8bf0-f15fbf7c237e
# TCGA-AA-3662-11A	TCGA-COAD	881a71c9-57c4-4c7c-9fa7-b799dc14f9ca
# TCGA-AA-3663-01A	TCGA-COAD	47fd7e73-bbb5-4cf3-931c-72e6c31578cb
# TCGA-AA-3663-11A	TCGA-COAD	8ab784dc-3120-42f6-b2f2-305d2a665a06
# TCGA-AA-3664-01A	TCGA-COAD	4748dcd9-15ce-4c16-b068-a5454d8d6530
# TCGA-AA-3664-10A	TCGA-COAD	ad213939-379e-4ac6-8fcd-ce010c671c66
# TCGA-AA-3666-01A	TCGA-COAD	b3aaad19-0700-47e6-a2e5-e7d491de42ea
# TCGA-AA-3666-10A	TCGA-COAD	a6a2cbaa-b3a5-43e7-ab67-056d9d5adbe9
# TCGA-AA-3667-01A	TCGA-COAD	08fa625f-4793-4d85-9032-e8f25161ed93
# TCGA-AA-3667-10A	TCGA-COAD	6f346e74-7317-4873-bafe-5db68934a1a6
# TCGA-AA-3672-01A	TCGA-COAD	6fb1db2f-7e6f-4aaa-bdaf-a59fb9e89275
# TCGA-AA-3672-10A	TCGA-COAD	abc42324-006c-490a-a975-80238b8063e9
# TCGA-AA-3673-01A	TCGA-COAD	0d9056ab-c489-46ea-9953-4e0455ebc071
# TCGA-AA-3673-10A	TCGA-COAD	96710d8a-3d8f-4c0b-af6a-790848436017
# TCGA-AA-3675-01A	TCGA-COAD	99368351-2118-40b3-881e-7ec75241a971
# TCGA-AA-3675-10A	TCGA-COAD	ae62c8de-bc13-4865-b21b-205fddbf8d95
# TCGA-AA-3678-01A	TCGA-COAD	69e472be-cb77-4971-aa78-00f57b4be067
# TCGA-AA-3678-10A	TCGA-COAD	d0996cd7-bf75-4e23-ac1f-811b041fe299
# TCGA-AA-3679-01A	TCGA-COAD	bfdf4325-49e5-4f66-b869-a17f4d40039a
# TCGA-AA-3679-10A	TCGA-COAD	23b51647-90ec-4655-8a38-e864eedb3e63
# TCGA-AA-3680-01A	TCGA-COAD	8aaa8a17-f1fc-4b25-b1a8-9fcf25a0494b
# TCGA-AA-3680-10A	TCGA-COAD	488019a6-2fc9-4ded-8210-69d114f65b01
# TCGA-AA-3681-01A	TCGA-COAD	68fd38fd-654b-4b7e-a89d-1a6de5db05db
# TCGA-AA-3681-10A	TCGA-COAD	86698d19-8a95-4a32-b73c-69bfb4c22dd5
# TCGA-AA-3684-01A	TCGA-COAD	40a6f612-1426-4e0b-bdc9-8175a01117dc
# TCGA-AA-3684-10A	TCGA-COAD	5fc4714f-8f78-4868-8321-537cea3b0ce1
# TCGA-AA-3685-01A	TCGA-COAD	d298683f-6e7e-4aa7-8606-1873b393e89d
# TCGA-AA-3685-10A	TCGA-COAD	f271d9dc-4ee2-46ad-a827-b96bf806bc5e
# TCGA-AA-3688-01A	TCGA-COAD	2c4417cc-f580-4cef-90ca-d5f28145308c
# TCGA-AA-3688-10A	TCGA-COAD	96cd922b-c173-458d-a70c-e4a699cad9d1
# TCGA-AA-3692-01A	TCGA-COAD	90d6dd72-7174-464b-a6f1-9f4118756618
# TCGA-AA-3692-10A	TCGA-COAD	77d3cf0d-d5a3-4fe3-b0aa-b0e536a184bf
# TCGA-AA-3693-01A	TCGA-COAD	cc1adff1-d05b-407c-8a90-e4325d4b4f7b
# TCGA-AA-3693-10A	TCGA-COAD	e8bd3768-07fb-4a31-bbed-183506993d0f
# TCGA-AA-3695-01A	TCGA-COAD	94cba853-5817-467f-8228-92abefb00ee5
# TCGA-AA-3695-10A	TCGA-COAD	19c9a5f9-9ac6-4f81-b9c7-d980858fd708
# TCGA-AA-3696-01A	TCGA-COAD	d6f8f925-2bbb-418c-9554-cc888c80f87f
# TCGA-AA-3696-10A	TCGA-COAD	520100c3-b1db-462d-a709-70413c6b797a
# TCGA-AA-3697-01A	TCGA-COAD	cb1acb37-af2a-4a47-9764-46187c9192bc
# TCGA-AA-3697-11A	TCGA-COAD	93fb0229-497a-464b-8143-f560320dbf20
# TCGA-AA-3710-01A	TCGA-COAD	135f1536-8f9c-4e8b-9dc9-e0da6e984104
# TCGA-AA-3710-10A	TCGA-COAD	6b5b0649-f66d-4f69-b758-d2c24812d5a4
# TCGA-AA-3710-10Ab	TCGA-COAD	b0892837-0cf3-48eb-91f2-7fb652fa1924
# TCGA-AA-3712-01A	TCGA-COAD	4f727057-2c2d-4a3f-9da1-306ec46e30ef
# TCGA-AA-3712-11A	TCGA-COAD	858d4731-40b9-4d25-b84e-c0b8a17fd96d
# TCGA-AA-3713-01A	TCGA-COAD	6e4fce52-741f-4e82-a7b4-198edf4d9c73
# TCGA-AA-3713-11A	TCGA-COAD	cf17a36a-8bd5-44d4-b92e-4f0ab414a22e
# TCGA-AA-3715-01A	TCGA-COAD	effb34d0-07a1-4fc1-8a87-074f49519306
# TCGA-AA-3715-10A	TCGA-COAD	515e3373-495c-4001-b693-38c0c0ec2ede
# TCGA-AA-3811-01A	TCGA-COAD	04a38123-6191-4848-8b0e-3a6b1749e2a7
# TCGA-AA-3811-01Ab	TCGA-COAD	dee86960-536d-4966-8996-04e78e937205
# TCGA-AA-3811-10A	TCGA-COAD	3711290f-0352-4983-a0a2-e4fc82e35591
# TCGA-AA-3812-01A	TCGA-COAD	7a830631-dfe6-4540-9467-aaf8d004aebc
# TCGA-AA-3812-10A	TCGA-COAD	ad944027-382b-4031-918d-92b77f5e1ccf
# TCGA-AA-3814-01A	TCGA-COAD	22a90027-dcc7-441e-ac0f-7ab4698b177f
# TCGA-AA-3814-10A	TCGA-COAD	dc406a98-c022-406e-9e76-489e97cba1e2
# TCGA-AA-3815-01A	TCGA-COAD	126ef3be-b380-4fe8-a8bd-dcbc905c6375
# TCGA-AA-3815-10A	TCGA-COAD	7818958e-c035-471c-8ee8-bf371afdd72d
# TCGA-AA-3818-01A	TCGA-COAD	5db815a8-839b-4833-99e1-9388841c1ec7
# TCGA-AA-3818-10A	TCGA-COAD	39abc166-acfb-47ab-a953-6838aac9ddf2
# TCGA-AA-3819-01A	TCGA-COAD	457452b7-f79d-4356-86a6-b70bd03bf2e5
# TCGA-AA-3819-10A	TCGA-COAD	1066f338-68d1-4457-bf67-f7c7e523a9de
# TCGA-AA-3821-01A	TCGA-COAD	18d79db5-187d-4c9f-99ad-f07ef7814e65
# TCGA-AA-3821-10A	TCGA-COAD	1b4cb7ae-1d83-46c6-9c22-61d5b913699c
# TCGA-AA-3831-01A	TCGA-COAD	ea75e0c0-48b1-4e7f-8c25-6954dec350f3
# TCGA-AA-3831-10A	TCGA-COAD	6162e907-cd00-4d2c-9ef8-c9c8d57ee846
# TCGA-AA-3833-01A	TCGA-COAD	d6e178d7-07fd-4e60-9309-16d3e8047635
# TCGA-AA-3833-01Ab	TCGA-COAD	31e0687d-cd31-4844-8e82-759a472308f4
# TCGA-AA-3833-10A	TCGA-COAD	8ffc17e0-e1ff-499f-bfb1-7c1c54c46f41
# TCGA-AA-3833-10Ab	TCGA-COAD	a30ca210-69cd-4f5d-a6a6-e7bcc78253c5
# TCGA-AA-3837-01A	TCGA-COAD	3c13d5fd-2f30-455b-9812-5819fe7c8d3f
# TCGA-AA-3837-10A	TCGA-COAD	6910f8b1-3f7e-4c99-8830-88d714f54e9d
# TCGA-AA-3841-01A	TCGA-COAD	f02218c5-f79c-496c-8b3e-2e409b005726
# TCGA-AA-3841-10A	TCGA-COAD	8b3070a2-514c-4763-aa9b-760fef0c157b
# TCGA-AA-3842-01A	TCGA-COAD	11e7de74-bf14-43d4-b641-be4465ea95f4
# TCGA-AA-3842-10A	TCGA-COAD	94a9f39a-e180-48dc-9eb5-5228f1873711
# TCGA-AA-3844-01A	TCGA-COAD	30ee32c4-ab35-4675-8b72-38c3eb80f2a0
# TCGA-AA-3844-10A	TCGA-COAD	a7e24d22-7aa8-4b4e-8a8d-0719f9bcca2b
# TCGA-AA-3845-01A	TCGA-COAD	ec2c9ba3-d8a8-4a78-89ed-fc3ad5a8daf8
# TCGA-AA-3845-01Ab	TCGA-COAD	82805a58-0e0c-4b29-bfae-e121236203a7
# TCGA-AA-3845-10A	TCGA-COAD	de95a607-279d-4fe0-8f7f-521d4364ef3b
# TCGA-AA-3846-01A	TCGA-COAD	b1131d86-f5f5-467c-bb04-639b94bca574
# TCGA-AA-3846-10A	TCGA-COAD	5746c62c-9239-4479-a725-6971447b4923
# TCGA-AA-3848-01A	TCGA-COAD	b95a641c-32cb-4af0-95bb-cb70b89425cb
# TCGA-AA-3848-10A	TCGA-COAD	91671616-6642-4f28-9163-21486cabc280
# TCGA-AA-3850-01A	TCGA-COAD	7f29c49c-1bf8-43ef-82ae-da5b07220fa8
# TCGA-AA-3850-10A	TCGA-COAD	a0284a93-7497-4003-ac85-7afdd911fb5f
# TCGA-AA-3851-01A	TCGA-COAD	3362c2e9-6fb5-43ce-8c44-7fe9901ff78e
# TCGA-AA-3851-10A	TCGA-COAD	36e102cb-f819-40b4-bec6-946dddecc27d
# TCGA-AA-3852-01A	TCGA-COAD	bd7b32e3-6ac1-482a-b975-2475ad4bac75
# TCGA-AA-3852-10A	TCGA-COAD	697b2d7b-27e3-48af-bb09-7232bb9cc657
# TCGA-AA-3854-01A	TCGA-COAD	aee59722-d4e8-44a7-ac89-bdedf53f7d14
# TCGA-AA-3854-10A	TCGA-COAD	2c27830f-7caf-43bf-bc5d-d0424bab5341
# TCGA-AA-3855-01A	TCGA-COAD	46d34cb0-b02e-45f3-a3fe-7d7dd45ca012
# TCGA-AA-3855-10A	TCGA-COAD	ed83f1b1-52e9-47cc-9479-0601429c5bd2
# TCGA-AA-3856-01A	TCGA-COAD	5491b9dc-1659-45e1-bad1-43778ac8da65
# TCGA-AA-3856-10A	TCGA-COAD	653f61c4-b5ae-402b-a1b6-ce46d7bc2c11
# TCGA-AA-3858-01A	TCGA-COAD	82045f06-fbbe-4a7e-bdca-e598ca68aa10
# TCGA-AA-3858-10A	TCGA-COAD	688ea4f7-fa22-42a8-9cf0-c31fa25e2095
# TCGA-AA-3860-01A	TCGA-COAD	70d0755b-1415-46c9-a63f-1913f11575a2
# TCGA-AA-3860-10A	TCGA-COAD	8387c95c-2f1f-405a-bbce-419c14e3f43e
# TCGA-AA-3861-01A	TCGA-COAD	3b7d7dd1-3dd0-4cdd-b34d-5df839eb8447
# TCGA-AA-3861-10A	TCGA-COAD	48be5e8d-6650-4dfb-bd76-ebb17f97bb5e
# TCGA-AA-3862-01A	TCGA-COAD	92147064-5421-421e-9ac1-c076e0d8782a
# TCGA-AA-3862-10A	TCGA-COAD	1be50877-f509-4751-bb9e-f5ed8be7427a
# TCGA-AA-3864-01A	TCGA-COAD	33790251-91f3-44ab-96b9-69e661d0f582
# TCGA-AA-3864-10A	TCGA-COAD	ddd32e12-1107-4fb8-8fb3-e82e94db2eb3
# TCGA-AA-3866-01A	TCGA-COAD	afd08843-c655-45d4-873d-a31c826b1727
# TCGA-AA-3866-10A	TCGA-COAD	97401027-5a1a-498f-b256-004b28b9db44
# TCGA-AA-3867-01A	TCGA-COAD	fd4f8a04-6e5a-41fd-a247-9762ce693717
# TCGA-AA-3867-10A	TCGA-COAD	c5cc539f-3606-4398-8004-b5d7334f8a8e
# TCGA-AA-3869-01A	TCGA-COAD	23fd173e-7980-4e89-9ab4-6d03d3c261ab
# TCGA-AA-3869-10A	TCGA-COAD	31c3d889-9960-496a-8eda-853b998bba5f
# TCGA-AA-3870-01A	TCGA-COAD	c27bf95f-f9a9-4dfd-9003-fbf1a43f24d2
# TCGA-AA-3870-10A	TCGA-COAD	6d7bc15b-c2e9-42d9-9fd1-004ad3a13e17
# TCGA-AA-3872-01A	TCGA-COAD	af194ef2-4013-4f59-92de-e15c8a85bd19
# TCGA-AA-3872-10A	TCGA-COAD	f5529875-cf5f-4cde-80de-3ebb6191dfb6
# TCGA-AA-3875-01A	TCGA-COAD	1b809beb-f87d-42b3-a409-4cdd4b22b306
# TCGA-AA-3875-10A	TCGA-COAD	e5f511df-d3c6-4b9f-8a4a-41b0117a7ad6
# TCGA-AA-3877-01A	TCGA-COAD	eeba1455-d5b0-4af4-9979-0b62592b82cb
# TCGA-AA-3877-10A	TCGA-COAD	9d5005b5-e663-483d-95d4-be5a8f33d9a6
# TCGA-AA-3877-10Ab	TCGA-COAD	3e4d30ea-b37e-40e4-b729-0a7bce998e08
# TCGA-AA-3930-01A	TCGA-COAD	6311e524-e21c-4a77-94ed-70a8e15be6af
# TCGA-AA-3930-10A	TCGA-COAD	25f7e41a-a33c-43d9-a242-a80c921bb53b
# TCGA-AA-3939-01A	TCGA-COAD	f4c1a9ec-eade-46db-a375-afa93dd5aac6
# TCGA-AA-3939-10A	TCGA-COAD	60da9169-68be-4cd8-8b9e-b747ecfdacf4
# TCGA-AA-3941-01A	TCGA-COAD	212ad93c-7bc9-4c8e-b11d-d905131c1152
# TCGA-AA-3941-10A	TCGA-COAD	b4ea2516-aa5f-45ae-b8be-23a2e8155ab5
# TCGA-AA-3947-01A	TCGA-COAD	19f578f5-c6a2-4d89-bdfe-0a98c2410ba8
# TCGA-AA-3947-10A	TCGA-COAD	19b14fc5-4320-4ad8-bf40-de83580f1dac
# TCGA-AA-3947-10Ab	TCGA-COAD	bc6a27bb-88ae-4642-a8e7-53b56761a0a4
# TCGA-AA-3949-01A	TCGA-COAD	408b083d-baf6-468c-80d8-7147e6c8f800
# TCGA-AA-3949-10A	TCGA-COAD	6af9aa14-f183-4dd5-9fa1-db8d07e700ff
# TCGA-AA-3949-10Ab	TCGA-COAD	1b76648b-375a-4fab-ab2e-f9b81c39aa52
# TCGA-AA-3950-01A	TCGA-COAD	9bb17b10-d070-4e8a-9555-26ebd060d795
# TCGA-AA-3950-10A	TCGA-COAD	f78e1876-ab07-49c4-9912-ef3f3ce3963a
# TCGA-AA-3952-01A	TCGA-COAD	c42514ce-68ed-43a5-a26d-5a30af531df0
# TCGA-AA-3952-10A	TCGA-COAD	7179b17c-9573-4793-9506-23ea4983f9a1
# TCGA-AA-3955-01A	TCGA-COAD	9ac51f2c-9ad5-4149-9371-253a3e9ec6c7
# TCGA-AA-3955-10A	TCGA-COAD	88377de4-ffd7-4d0c-bc4e-9ffdb42ea1fb
# TCGA-AA-3956-01A	TCGA-COAD	1aeaa2fd-2748-4d3d-8a5d-776210cdd6b7
# TCGA-AA-3956-10A	TCGA-COAD	d1fd6cab-2eda-4408-a75e-99fc3ae08dba
# TCGA-AA-3966-01A	TCGA-COAD	d144e464-1809-4d3f-a785-f7ef7090d869
# TCGA-AA-3966-01Ab	TCGA-COAD	05d73da9-f655-4b92-840e-fca14bfd1ad7
# TCGA-AA-3966-10A	TCGA-COAD	ad8c4921-7b03-4fcf-98f3-e151d4d6a54b
# TCGA-AA-3967-01A	TCGA-COAD	889ecef7-f701-4b3c-898e-f43116fa9f48
# TCGA-AA-3967-10A	TCGA-COAD	358b265e-09f1-47aa-bbe9-93230ca9462f
# TCGA-AA-3968-01A	TCGA-COAD	adeba039-da80-4ca1-873b-7cc16ea50778
# TCGA-AA-3968-10A	TCGA-COAD	ce4451b5-f6e7-4af9-b56c-c4f652f0f85f
# TCGA-AA-3971-01A	TCGA-COAD	39c50f2f-ae9b-4036-956e-3e0641d87ce6
# TCGA-AA-3971-10A	TCGA-COAD	fd762f72-5881-4e5f-9910-33dda0317d03
# TCGA-AA-3972-01A	TCGA-COAD	d970bbb0-cda4-42e3-a20c-fbb47aeda143
# TCGA-AA-3972-10A	TCGA-COAD	57ad0e1b-cd7f-447a-a89d-5633928d6b89
# TCGA-AA-3973-01A	TCGA-COAD	2943cb64-ffd2-44ec-9764-8aed4dab10fe
# TCGA-AA-3973-10A	TCGA-COAD	b24c4b20-2bbf-4ba3-9d17-bf1a1ee5fe2c
# TCGA-AA-3975-01A	TCGA-COAD	62f0f35c-8175-4323-9bc5-a7b26b0cf1ae
# TCGA-AA-3975-10A	TCGA-COAD	d38819a4-d663-4a78-bdc9-cddc80c613b3
# TCGA-AA-3976-01A	TCGA-COAD	0ec40c23-5513-42bf-ba45-406a7bd7874f
# TCGA-AA-3976-10A	TCGA-COAD	6ed50881-9d56-45ce-b486-add44af0df9c
# TCGA-AA-3977-01A	TCGA-COAD	c8aba083-0e90-46ff-89a3-f0c45efc0755
# TCGA-AA-3977-01Ab	TCGA-COAD	eab2f06c-1af0-4f46-9656-37d4b04ca771
# TCGA-AA-3977-10A	TCGA-COAD	2ecfd35e-b50d-427c-ac7a-6c4554136d13
# TCGA-AA-3977-10Ab	TCGA-COAD	265383ad-9599-4671-9309-609aa226e982
# TCGA-AA-3979-01A	TCGA-COAD	9369b111-be09-46dc-8879-3e0003ac0257
# TCGA-AA-3979-10A	TCGA-COAD	136842b0-5db1-4ce6-ac00-6f789e1178a8
# TCGA-AA-3980-01A	TCGA-COAD	050a26dc-7ee4-4c5b-be2a-2a315a5d1182
# TCGA-AA-3980-10A	TCGA-COAD	13fe8eb3-fcbc-4ab7-8ad7-a1c72ee8bba3
# TCGA-AA-3982-01A	TCGA-COAD	156022d7-e823-4db8-9902-639c5fa33fff
# TCGA-AA-3982-10A	TCGA-COAD	29ded859-2ba7-4df5-afcb-f6e17340a419
# TCGA-AA-3984-01A	TCGA-COAD	c7b25533-698d-4f4d-bf1c-ed7521d8cd84
# TCGA-AA-3984-01Ab	TCGA-COAD	15a92d37-2fb7-489d-9559-3c6297d61b71
# TCGA-AA-3984-10A	TCGA-COAD	1a16d1f2-a8a2-4256-b063-4863b9a17906
# TCGA-AA-3984-10Ab	TCGA-COAD	fd0d00dc-faff-4454-a35a-d34d7aa12eb4
# TCGA-AA-3986-01A	TCGA-COAD	b95deaeb-5e85-49c3-a3a5-1bc88f53222d
# TCGA-AA-3986-10A	TCGA-COAD	52b105ba-adaa-4e2d-9737-3b0056fe9452
# TCGA-AA-3989-01A	TCGA-COAD	e0e00920-58c9-4c25-b9f5-ae26e49a2e01
# TCGA-AA-3989-10A	TCGA-COAD	7f385075-01c7-4ecb-9d16-abe74f7924f1
# TCGA-AA-3994-01A	TCGA-COAD	92358f23-f4d0-443e-ad2a-ca11657b5859
# TCGA-AA-3994-10A	TCGA-COAD	1f4a7db4-388b-4286-9425-2fe80e7199a9
# TCGA-AA-A004-01A	TCGA-COAD	6908d4f6-5ad9-4855-96a8-cb320d07d7f6
# TCGA-AA-A004-10A	TCGA-COAD	c8e8884a-96b3-4130-a27b-cfde7fa5606b
# TCGA-AA-A00N-01A	TCGA-COAD	22aa4ead-ca08-4db7-b43c-b590dd16e09f
# TCGA-AA-A00N-01Ab	TCGA-COAD	dd3c12f5-cdb6-4419-b400-f8ddd374bf33
# TCGA-AA-A00N-10A	TCGA-COAD	7f1d4c5d-81a9-46af-a487-46ae599cd766
# TCGA-AA-A00N-10Ab	TCGA-COAD	7cffb8e7-0511-4609-9df6-c15a1f25b25a
# TCGA-AA-A00O-01A	TCGA-COAD	a1e907be-162d-4cfa-8872-45d367fdff12
# TCGA-AA-A00O-10A	TCGA-COAD	ee492a12-bb68-4c28-b0a7-09c72fa2c156
# TCGA-AA-A00U-01A	TCGA-COAD	6567c623-dd7a-49c7-b0b4-b7d1c2277d3d
# TCGA-AA-A00W-01A	TCGA-COAD	97871da8-692c-4183-9b7e-5e38e7e109e2
# TCGA-AA-A00Z-01A	TCGA-COAD	6642c991-008b-4f87-bbfd-e1d2b125291b
# TCGA-AA-A00Z-10A	TCGA-COAD	6a5fdb29-ea7d-4e8d-ba81-d99d6648f4e7
# TCGA-AA-A010-01A	TCGA-COAD	53665804-6bbe-4d2e-8edb-6ed744c12a5b
# TCGA-AA-A010-01Ab	TCGA-COAD	56b34c63-080a-4e7b-873e-72f50abbb349
# TCGA-AA-A010-10A	TCGA-COAD	5d07253e-7bce-4853-b05b-c850384a851c
# TCGA-AA-A010-10Ab	TCGA-COAD	f0bfa4be-83f7-43a6-bace-f2c93075b8f2
# TCGA-AA-A017-01A	TCGA-COAD	14be6bb2-f213-4820-939c-6a1dce518004
# TCGA-AA-A017-10A	TCGA-COAD	4aa80dd2-e22c-4573-acd8-0846a39cfd1d
# TCGA-AA-A01C-01A	TCGA-COAD	91248600-c2fe-4ede-a51c-92fd15c9ea18
# TCGA-AA-A01C-10A	TCGA-COAD	4b6ac708-f0da-41f7-b01e-abed693177de
# TCGA-AA-A01D-01A	TCGA-COAD	1459a6d4-bf66-4171-8824-8d1e1783a7aa
# TCGA-AA-A01D-10A	TCGA-COAD	5e54f52a-0cf5-4550-80bd-218277caef04
# TCGA-AA-A01G-01A	TCGA-COAD	e88857f3-3f1e-495f-b519-d8221ba6298a
# TCGA-AA-A01I-01A	TCGA-COAD	0efd5393-170d-4da8-9647-10f70d82dd43
# TCGA-AA-A01I-10A	TCGA-COAD	7cba271c-5844-4eba-be54-b9559335da9b
# TCGA-AA-A01K-01A	TCGA-COAD	bccfe508-a935-480a-8b9b-da4da3f7bad0
# TCGA-AA-A01K-10A	TCGA-COAD	0ad881c3-71ad-46f1-82e8-12a2b5958f9a
# TCGA-AA-A01P-01A	TCGA-COAD	8a96b9bf-fc29-4cb0-8bf7-fc2abcaa337d
# TCGA-AA-A01P-01Ab	TCGA-COAD	c4110499-171e-4311-bdbb-4fd4a945f33e
# TCGA-AA-A01P-11A	TCGA-COAD	7544ff4c-524e-49f3-83e3-6d7cd333c7ef
# TCGA-AA-A01P-11Ab	TCGA-COAD	f2232238-8ecf-4cab-a9b9-b6665fd01d53
# TCGA-AA-A01R-01A	TCGA-COAD	8b6add12-5374-476e-aa4d-81afdbb7d48a
# TCGA-AA-A01R-01Ab	TCGA-COAD	daff02e1-0898-44f9-9584-8ad6e0c81c7c
# TCGA-AA-A01R-11A	TCGA-COAD	701e107a-4068-42ea-a7ef-f6c78b94a178
# TCGA-AA-A01R-11Ab	TCGA-COAD	4fc62244-355a-404a-95e6-362a6c84922c
# TCGA-AA-A01S-01A	TCGA-COAD	8e8e17fc-a483-452b-829b-d4776a2bfad3
# TCGA-AA-A01S-11A	TCGA-COAD	b971be3c-0872-4116-b57f-a33ad4536317
# TCGA-AA-A01T-01A	TCGA-COAD	d5c1a2d0-9e5e-4b05-a690-8f8f7723be74
# TCGA-AA-A01T-11A	TCGA-COAD	248b1738-bab4-49af-982d-f6c815fab313
# TCGA-AA-A01V-01A	TCGA-COAD	9cd6db8c-c131-4e22-884e-6366b6bb98aa
# TCGA-AA-A01V-11A	TCGA-COAD	2da2816d-5a8f-43cf-8e34-b4a954c9c2b1
# TCGA-AA-A01X-01A	TCGA-COAD	6f8c7c83-cd5b-4235-9da8-ea7a376b2aaf
# TCGA-AA-A01X-11A	TCGA-COAD	1b35da6b-fb99-450f-be46-e1a67c5e9132
# TCGA-AA-A01Z-01A	TCGA-COAD	c3c7dcbe-4348-45d5-ab8e-41e4387a3aa2
# TCGA-AA-A01Z-11A	TCGA-COAD	9656d49b-bbc9-4a40-b239-0232630a3ce6
# TCGA-AA-A022-01A	TCGA-COAD	6925bdbd-f9cc-4222-bece-8b17796e3708
# TCGA-AA-A022-01Ab	TCGA-COAD	56cd3fff-7bc1-405e-8c82-d9e853f662d9
# TCGA-AA-A022-11A	TCGA-COAD	f302d2f3-027a-4371-b263-550130d4f09e
# TCGA-AA-A022-11Ab	TCGA-COAD	e8300e1b-4b4b-43ea-a4a7-f094697b3bb5
# TCGA-AA-A024-01A	TCGA-COAD	8ddf2895-a389-4fa4-9c3f-0b717c55a532
# TCGA-AA-A024-10A	TCGA-COAD	572eb4a0-2d3f-461a-a087-cbc664fa9b26
# TCGA-AA-A029-01A	TCGA-COAD	77358d42-f3fb-4fa5-8d21-9071f0b96660
# TCGA-AA-A029-10A	TCGA-COAD	81434c53-458d-4f4c-a595-f6070cea1f2c
# TCGA-AA-A02E-01A	TCGA-COAD	b28eeced-a0bc-499d-9aa3-518ff61d201e
# TCGA-AA-A02E-10A	TCGA-COAD	8c2c9a58-2014-43d9-af4f-e4eb942fd276
# TCGA-AA-A02F-01A	TCGA-COAD	21c13bb6-06fc-4705-969f-21725acc9d9b
# TCGA-AA-A02F-10A	TCGA-COAD	b9693fa8-6f85-41d3-ac57-aa06b43d2d06
# TCGA-AA-A02H-01A	TCGA-COAD	5a070995-4d84-432f-b614-faf561823db6
# TCGA-AA-A02H-10A	TCGA-COAD	04c5cb10-7511-45fb-9e96-df05a8a06e94
# TCGA-AA-A02J-01A	TCGA-COAD	9181af50-4109-4623-a3a6-997956c2c637
# TCGA-AA-A02J-10A	TCGA-COAD	85db4f9e-9efc-4464-974d-d7eb2e072e40
# TCGA-AA-A02K-01A	TCGA-COAD	971c7d88-323c-460c-9143-c4e0c5e9aad8
# TCGA-AA-A02K-10A	TCGA-COAD	6eac66fb-3e27-46f5-91f0-4f71abdd0e53
# TCGA-AA-A02O-01A	TCGA-COAD	fe7e03bd-38eb-41fb-9157-b066d2a6c394
# TCGA-AA-A02O-11A	TCGA-COAD	a9677c47-cef3-4ebb-9c1b-44d50ad32bc8
# TCGA-AA-A02R-01A	TCGA-COAD	71ddb2c1-1159-456b-945b-aba0ae88037c
# TCGA-AA-A02R-10A	TCGA-COAD	122d5602-e616-45b7-accb-40d9052d7e2d
# TCGA-AA-A02W-01A	TCGA-COAD	f5b1bdf7-1a48-4265-bd3d-fd9f9473fdab
# TCGA-AA-A02W-10A	TCGA-COAD	34f13d80-63ce-4a27-b524-1f6bb7c94e74
# TCGA-AA-A02Y-01A	TCGA-COAD	ce36d465-cf2c-4d32-be3b-bb49a91eca61
# TCGA-AA-A02Y-10A	TCGA-COAD	13299b92-ce09-4fb6-99b4-af06ae36a54d
# TCGA-AA-A03F-01A	TCGA-COAD	559d18cd-bfa7-48d6-b92a-4d65d3f0570b
# TCGA-AA-A03F-11A	TCGA-COAD	97560f5c-88b2-4c03-af70-668618ff8023
# TCGA-AA-A03J-01A	TCGA-COAD	d4eb3c7d-76f4-469d-bc4e-82a12b632877
# TCGA-AA-A03J-11A	TCGA-COAD	b52c00c2-dea7-4111-ba25-c23befd97956
# TCGA-AD-5900-01A	TCGA-COAD	83f05058-7d13-4501-9e23-ec29a41b508d
# TCGA-AD-5900-10A	TCGA-COAD	d7fc26f9-7630-404f-9c86-294d47e91fbf
# TCGA-AD-6548-01A	TCGA-COAD	1dc1aa02-998b-46c6-bb83-2a5ff1e52d33
# TCGA-AD-6548-10A	TCGA-COAD	71b069ba-0e2e-410d-aaec-2a307ccb9ade
# TCGA-AD-6888-01A	TCGA-COAD	35cf7197-2b19-47d1-b6b4-e38a20506fd0
# TCGA-AD-6888-10A	TCGA-COAD	95127005-04a8-4caf-b729-7a39db53c13b
# TCGA-AD-6889-01A	TCGA-COAD	d87b2703-0058-4aa6-8c32-8b8967ec3e5a
# TCGA-AD-6889-10A	TCGA-COAD	df68bae2-97d4-48a1-8244-caa1588de2dc
# TCGA-AD-6890-01A	TCGA-COAD	916a1406-c303-46a3-aa6d-fa24fc5ea96c
# TCGA-AD-6890-10A	TCGA-COAD	26488eff-a8b3-422f-af1f-1fba07e1ce2b
# TCGA-AD-6895-01A	TCGA-COAD	37167072-be85-4048-834b-6cc5aeb5fa0b
# TCGA-AD-6895-10A	TCGA-COAD	87336035-6cc3-4de2-94d5-994f47d97706
# TCGA-AD-6899-01A	TCGA-COAD	6c692806-89d6-4091-ad20-fc94511e63ee
# TCGA-AD-6899-10A	TCGA-COAD	d7742302-a971-46b0-92a6-7c8f10e3a452
# TCGA-AD-6901-01A	TCGA-COAD	6fcbc1e1-f835-42d8-a8a3-09a8216a6a9f
# TCGA-AD-6901-10A	TCGA-COAD	6076ea32-50d9-4d9c-bf67-f03d38d3d31e
# TCGA-AD-6963-01A	TCGA-COAD	6d832c2c-d4f0-4fc4-9f6b-47df85f506a3
# TCGA-AD-6963-10A	TCGA-COAD	ee1fc13a-5449-439f-b923-6b31ce37b729
# TCGA-AD-6964-01A	TCGA-COAD	3e4105fa-2dc8-4370-9b39-ccfb6bc73d2f
# TCGA-AD-6964-10A	TCGA-COAD	e748bad2-9436-40a6-9f76-df3999ec72aa
# TCGA-AD-6965-01A	TCGA-COAD	34005f0e-8cdd-4b02-acd1-778b2fb683f3
# TCGA-AD-6965-10A	TCGA-COAD	bb466fb1-a60d-4252-8d82-febab0bdf463
# TCGA-AD-A5EJ-01A	TCGA-COAD	4faee7cd-084f-46a4-a686-b02ae5729adc
# TCGA-AD-A5EJ-10A	TCGA-COAD	f6132347-80fe-4866-81ea-9e943bba6d5b
# TCGA-AD-A5EK-01A	TCGA-COAD	801a2cac-3015-4f91-be09-d0f1ce6536bc
# TCGA-AD-A5EK-10A	TCGA-COAD	8530b067-006a-461e-8ef4-8e5dd0560eea
# TCGA-AM-5820-01A	TCGA-COAD	176159c8-42a8-4ca4-b0ec-5a59630426c3
# TCGA-AM-5820-10A	TCGA-COAD	af9aca82-550f-4835-a099-ba99f644c4be
# TCGA-AM-5821-01A	TCGA-COAD	734ea9e5-e654-4d5b-ac5e-8ae0ed3c8c17
# TCGA-AM-5821-10A	TCGA-COAD	7a6c2b8e-ee14-41c5-85d4-355b8ab302dd
# TCGA-AU-3779-01A	TCGA-COAD	33cf39ee-178a-4a19-b883-6aa1194e7d63
# TCGA-AU-3779-10A	TCGA-COAD	0ea9dce5-7876-46dd-8c14-684186bf7e8c
# TCGA-AU-6004-01A	TCGA-COAD	c76f38ea-046f-45d0-bb49-a59160784356
# TCGA-AU-6004-10A	TCGA-COAD	1df8c24a-85bf-4a17-a8b3-1cabd3cb0e7b
# TCGA-AY-4070-01A	TCGA-COAD	e9d61b07-057d-4a94-bd44-64457273f456
# TCGA-AY-4070-10A	TCGA-COAD	c4bb0ab6-b401-45b3-98ac-f1f788271e89
# TCGA-AY-4071-01A	TCGA-COAD	81fa7707-f413-403a-85c0-a2809996b742
# TCGA-AY-4071-10A	TCGA-COAD	8b7cef91-25cf-4c8e-be3f-1043cba1b817
# TCGA-AY-5543-01A	TCGA-COAD	515ebee7-6476-4a9c-b29a-d3f593420b12
# TCGA-AY-5543-10A	TCGA-COAD	d5b0deb5-4f19-4c87-9ead-c324305a18ca
# TCGA-AY-6196-01A	TCGA-COAD	cb37bfac-da8f-46b7-beea-c81c8c3cb1c2
# TCGA-AY-6196-10A	TCGA-COAD	9fc1632e-15c6-4a0c-85c9-143f5bd0503c
# TCGA-AY-6197-01A	TCGA-COAD	cf6a00b8-6974-452b-a3a1-5987f3cac4f4
# TCGA-AY-6197-10A	TCGA-COAD	1e642489-197f-4039-8570-32e343b78a23
# TCGA-AY-6386-01A	TCGA-COAD	1190a8b3-3e0d-41ce-b6fc-a4411924539d
# TCGA-AY-6386-10A	TCGA-COAD	380dd11c-91d6-4694-9a40-a820ef3e3480
# TCGA-AY-A54L-01A	TCGA-COAD	dddfc4da-ee8e-4e11-8ee8-4be731c4abb7
# TCGA-AY-A54L-10A	TCGA-COAD	75c82da6-715d-42b0-a38f-841623f75d67
# TCGA-AY-A69D-01A	TCGA-COAD	fbbd7e07-2d4d-433e-8fe4-6f5c498f9677
# TCGA-AY-A69D-10A	TCGA-COAD	31bb1574-65ea-4a2a-97c0-9cf7a18dad2e
# TCGA-AY-A71X-01A	TCGA-COAD	543dba31-64d3-4ae9-ab9a-394db919f5f0
# TCGA-AY-A71X-10A	TCGA-COAD	1e40e8e6-7e41-4bb1-8068-d60c8f6019df
# TCGA-AY-A8YK-01A	TCGA-COAD	28e76f2c-b3d7-4de6-a7b3-86d898e0ad9c
# TCGA-AY-A8YK-10A	TCGA-COAD	72d96bf3-6a03-4eda-8f4d-4f06d06fb9db
# TCGA-AZ-4308-01A	TCGA-COAD	6fb6f32e-4ef1-40f0-9361-bab2d02abf00
# TCGA-AZ-4308-10A	TCGA-COAD	3f2f400f-598d-426b-a133-9d61b178c6d7
# TCGA-AZ-4313-01A	TCGA-COAD	ba522507-7484-4bd9-8f2f-5c668cc7008b
# TCGA-AZ-4313-10A	TCGA-COAD	878a81ce-50fa-44a9-8acd-29eedc63c68e
# TCGA-AZ-4315-01A	TCGA-COAD	014560ce-4236-4fbe-8f1c-ac5c67bc1517
# TCGA-AZ-4315-10A	TCGA-COAD	cda596df-a4f7-40f9-b961-df456c72ce18
# TCGA-AZ-4323-01A	TCGA-COAD	185abeb8-2fef-4397-834f-5fa62e6bdbdb
# TCGA-AZ-4323-10A	TCGA-COAD	728b052a-54a6-4230-a330-f52d1f80888d
# TCGA-AZ-4614-01A	TCGA-COAD	fabbf2a1-72d9-421e-a0bc-5a4b9a14b613
# TCGA-AZ-4614-10A	TCGA-COAD	c7f264f3-a1c0-419f-ade2-edd9f7e99c81
# TCGA-AZ-4615-01A	TCGA-COAD	0f0b7f1f-f93d-40ba-965b-a1cf60d973ee
# TCGA-AZ-4615-10A	TCGA-COAD	0d6ed291-c3fb-4cec-bad6-827d1ac92608
# TCGA-AZ-4615-10Ab	TCGA-COAD	53483841-1f2e-418a-b3d6-317e2ccb95d4
# TCGA-AZ-4616-01A	TCGA-COAD	c1ec4e56-d73c-4807-ab48-b5fc06b899d0
# TCGA-AZ-4616-10A	TCGA-COAD	a4dc2837-550d-4a21-8ff2-094c1a8eac4f
# TCGA-AZ-4681-01A	TCGA-COAD	0e06cb62-1a60-4804-8da5-b331354a3bfb
# TCGA-AZ-4681-10A	TCGA-COAD	2ef43a3c-c4a5-4a88-9ee2-8c89cc4eea94
# TCGA-AZ-4682-01B	TCGA-COAD	f6de3c07-3f8a-40f8-a6d1-9a1c5a2cb10f
# TCGA-AZ-4682-10A	TCGA-COAD	78434595-9a2c-4495-866b-08f4357ae1a5
# TCGA-AZ-4684-01A	TCGA-COAD	03d31c4a-bf43-4ae5-b4a3-588b16e9ed71
# TCGA-AZ-4684-10A	TCGA-COAD	47aba8b6-122f-4e61-82b9-5c27ad89be49
# TCGA-AZ-5403-01A	TCGA-COAD	f321d722-eb4e-44a0-a1cc-0317d435f8fa
# TCGA-AZ-5403-10A	TCGA-COAD	11c41203-7dd4-4999-a847-f64f248e5e1b
# TCGA-AZ-5407-01A	TCGA-COAD	fcee6505-2471-4ec0-9c26-7570dd8d61a5
# TCGA-AZ-5407-10A	TCGA-COAD	b9d824c2-b127-4ab0-85a7-21703b552574
# TCGA-AZ-6598-01A	TCGA-COAD	64cece7f-63e8-43ce-91dc-b63477b858fe
# TCGA-AZ-6598-11A	TCGA-COAD	85ec8046-cf62-4da7-a8e0-385e4a6e7a58
# TCGA-AZ-6599-01A	TCGA-COAD	9b30a498-d307-4635-9b95-2f3b089a85f8
# TCGA-AZ-6599-11A	TCGA-COAD	594bcd94-a016-49aa-b25f-ffce734dd558
# TCGA-AZ-6600-01A	TCGA-COAD	0ce1cfa1-b577-4d05-972e-bad94c318243
# TCGA-AZ-6600-11A	TCGA-COAD	c4a157ab-fb5a-498f-8722-6467d643d574
# TCGA-AZ-6601-01A	TCGA-COAD	61458725-4a95-4634-bfbe-96daf6900e92
# TCGA-AZ-6601-11A	TCGA-COAD	00f789a0-bc97-48a3-abff-51d0acaff845
# TCGA-AZ-6603-01A	TCGA-COAD	d9d5d79b-a573-4522-8e84-079cf39327a3
# TCGA-AZ-6603-11A	TCGA-COAD	94117086-ccb7-45f3-8cb1-2d7386300e00
# TCGA-AZ-6605-01A	TCGA-COAD	4c6ae6f3-f3b4-4379-a44c-ce2a6f92f5fe
# TCGA-AZ-6605-11A	TCGA-COAD	ec5c0770-15da-4b0c-9f65-14c84883efc4
# TCGA-AZ-6606-01A	TCGA-COAD	157bf479-62ef-4226-9f21-5b140237e57c
# TCGA-AZ-6606-11A	TCGA-COAD	2af4749d-9cf1-4a66-a27a-768a6b3606b2
# TCGA-AZ-6607-01A	TCGA-COAD	f51d0783-e669-4bd9-9aff-66dea154b7ac
# TCGA-AZ-6607-11A	TCGA-COAD	42af3b52-63be-401e-8253-6bc687a83f13
# TCGA-AZ-6608-01A	TCGA-COAD	abec8d73-05fb-4d16-b462-728993dca9ba
# TCGA-AZ-6608-11A	TCGA-COAD	a3905f9c-e88d-466f-877a-dc39a1bce64b
# TCGA-CA-5254-01A	TCGA-COAD	815f9774-d278-46c5-884e-b5545c8db6eb
# TCGA-CA-5254-10A	TCGA-COAD	33823cb8-73c3-4aaa-9f02-15b7018a1046
# TCGA-CA-5255-01A	TCGA-COAD	830abdb4-24f1-4f54-a7ac-5e2f4aa56872
# TCGA-CA-5255-10A	TCGA-COAD	e12ecdf8-a0b5-47c9-a981-0250919870e7
# TCGA-CA-5256-01A	TCGA-COAD	82e658b8-da41-4835-8e3b-919ff88e4add
# TCGA-CA-5256-10A	TCGA-COAD	87f36dda-6c30-44ac-b577-1b681b10e65e
# TCGA-CA-5796-01A	TCGA-COAD	2845e5ad-be33-4da6-9bd2-bbfdec8f2e64
# TCGA-CA-5796-10A	TCGA-COAD	7fa77f8b-e30a-4b89-a60d-7c9b6e8478c1
# TCGA-CA-5797-01A	TCGA-COAD	915a775e-8fc2-48e6-a832-60f4bbf78d20
# TCGA-CA-5797-10A	TCGA-COAD	3d1c3016-17e2-4679-908d-9166943d4e99
# TCGA-CA-6715-01A	TCGA-COAD	5151ae3c-9bcd-496c-a678-e8d0d8cb82f9
# TCGA-CA-6715-10A	TCGA-COAD	632843f4-e83a-4096-b3fc-e8d6dcad3c8a
# TCGA-CA-6716-01A	TCGA-COAD	61f18e53-0f98-4f6c-a1fe-6f6016d9ffe4
# TCGA-CA-6716-10A	TCGA-COAD	e4b393b7-179a-426d-b44f-ce4ff7aa1a4c
# TCGA-CA-6717-01A	TCGA-COAD	df9b7cf9-e798-4946-ac52-451eca278708
# TCGA-CA-6717-10A	TCGA-COAD	e829af3c-f447-4a06-9fd4-d9b3de714d93
# TCGA-CA-6718-01A	TCGA-COAD	2787438b-a809-461f-9dc7-223553a90e4d
# TCGA-CA-6718-10A	TCGA-COAD	d00ada4a-1660-410e-a448-58226aba6a96
# TCGA-CA-6719-01A	TCGA-COAD	98fa11ac-1c7a-4e9b-8176-5746a1cd1d85
# TCGA-CA-6719-10A	TCGA-COAD	1a34f2c0-af8a-4704-958c-a2fb922a3302
# TCGA-CK-4947-01B	TCGA-COAD	4b056ffd-d3c6-488f-b028-6097a7490304
# TCGA-CK-4947-10A	TCGA-COAD	c946e6b7-f0c1-4a4a-959d-5c3c287d8012
# TCGA-CK-4948-01B	TCGA-COAD	19daaf67-de70-47ba-88f6-6d263cc01653
# TCGA-CK-4948-10A	TCGA-COAD	1db7abf8-0726-4651-a7cb-56eb4e27e606
# TCGA-CK-4950-01A	TCGA-COAD	8b91371d-1886-4a92-8add-12702ed68558
# TCGA-CK-4950-10A	TCGA-COAD	167689b8-5e19-41f5-aedf-704e8a6f8812
# TCGA-CK-4951-01A	TCGA-COAD	fde60dfa-405c-457f-a9e0-eff346361ae3
# TCGA-CK-4951-10A	TCGA-COAD	7b46b911-9e7f-451f-8c2f-1191b737d9a4
# TCGA-CK-4952-01A	TCGA-COAD	00b7ee04-b97b-49ee-b27b-13f6fb981fec
# TCGA-CK-4952-10A	TCGA-COAD	288e933e-1b99-46c4-9d58-de3fe9306a2d
# TCGA-CK-5912-01A	TCGA-COAD	392a1c87-de1d-4f20-8096-5924d2894e4a
# TCGA-CK-5912-10A	TCGA-COAD	9ca38767-1a54-485d-9d93-01a3e712a670
# TCGA-CK-5913-01A	TCGA-COAD	f7ba03d5-0d23-49e7-a29a-e8ad57c4eee5
# TCGA-CK-5913-10A	TCGA-COAD	384e57e3-2e91-477c-8fff-573fd98afc19
# TCGA-CK-5914-01A	TCGA-COAD	f9069699-2446-435b-b004-76666c21e0c2
# TCGA-CK-5914-10A	TCGA-COAD	e7f84c66-3f13-493b-a544-e3b78fd3de86
# TCGA-CK-5915-01A	TCGA-COAD	eb43e348-99bc-495b-98f9-6cf7435e7f9a
# TCGA-CK-5915-10A	TCGA-COAD	6f8d6504-5a6c-439a-a32d-de18ff9a6424
# TCGA-CK-5916-01A	TCGA-COAD	8e9b832d-9b6f-40f5-abed-ffe4e1e7c468
# TCGA-CK-5916-10A	TCGA-COAD	248ad8df-6bba-4a30-a642-c2d27bdb4b15
# TCGA-CK-6746-01A	TCGA-COAD	678b7c15-1f96-4620-92ae-d2dc402aa541
# TCGA-CK-6746-10A	TCGA-COAD	a688a42e-47b7-47a3-a805-f14ce49af9af
# TCGA-CK-6747-01A	TCGA-COAD	683088bc-cc1f-4213-a840-a00b3621e7de
# TCGA-CK-6747-10A	TCGA-COAD	da9800b6-0daf-4262-9ea5-e9db5e26fa65
# TCGA-CK-6748-01A	TCGA-COAD	db0b82e3-a1ac-4e69-834e-330b20f8a20b
# TCGA-CK-6748-10A	TCGA-COAD	033b5b49-14dd-42e3-bd44-f304f4c8d08d
# TCGA-CK-6751-01A	TCGA-COAD	7de9d9e2-c4a4-4311-826f-973cb7987c66
# TCGA-CK-6751-10A	TCGA-COAD	861ad835-790a-47ad-8c03-06f7eb7b5710
# TCGA-CM-4743-01A	TCGA-COAD	54e51c31-0690-4a11-964a-45c2d220d04a
# TCGA-CM-4743-10A	TCGA-COAD	ede76f06-58d7-4bd3-ae30-d6e4ee649d78
# TCGA-CM-4744-01A	TCGA-COAD	f2c2ad06-0d7e-4c54-b87a-81de283649d0
# TCGA-CM-4744-10A	TCGA-COAD	c38fb219-ea20-40dd-839f-12c43a6ec311
# TCGA-CM-4746-01A	TCGA-COAD	2ac0c105-ee78-4885-b343-ae06c9112b8d
# TCGA-CM-4746-10A	TCGA-COAD	4ffb08a7-f0ac-4744-b205-bc848ae107c5
# TCGA-CM-4747-01A	TCGA-COAD	1a64b672-7262-4a2a-935a-ec96693898ef
# TCGA-CM-4747-10A	TCGA-COAD	3247d1c9-a15b-4cf8-a186-315ea5a43619
# TCGA-CM-4748-01A	TCGA-COAD	07fe1566-0485-4da5-8d00-00b5cc481264
# TCGA-CM-4748-10A	TCGA-COAD	0fbc46d3-9abb-4372-a793-092b610ba734
# TCGA-CM-4750-01A	TCGA-COAD	3e5be02b-b72d-43d0-9cea-0a7fc8188d71
# TCGA-CM-4750-10A	TCGA-COAD	7a51c223-c154-4a29-83d9-95207c001a97
# TCGA-CM-4751-01A	TCGA-COAD	24d4c51e-9a2f-477f-a06d-95bd850e28d1
# TCGA-CM-4751-10A	TCGA-COAD	ff3b81fc-1e16-4514-b866-7447bbb31361
# TCGA-CM-4752-01A	TCGA-COAD	121fd14d-3d67-4493-ab71-be6f086cea89
# TCGA-CM-4752-10A	TCGA-COAD	c540f988-bac5-4850-894b-1f2804452b24
# TCGA-CM-5341-01A	TCGA-COAD	bc546b8e-4577-4226-9dff-44cebb4dcfd5
# TCGA-CM-5341-10A	TCGA-COAD	387ba682-5c5b-4667-8811-d355f0e97f6d
# TCGA-CM-5344-01A	TCGA-COAD	db3c864d-7dfb-4bd8-9628-c303d5f7365e
# TCGA-CM-5344-10A	TCGA-COAD	fe4f956f-846a-458f-9e5b-d23499d202d9
# TCGA-CM-5348-01A	TCGA-COAD	f16d7575-f1b6-45a5-ae93-e604aec6ac4e
# TCGA-CM-5348-10A	TCGA-COAD	21afdd3e-bb4f-41df-902c-582ee8cf745e
# TCGA-CM-5349-01A	TCGA-COAD	d45dd851-42f3-455a-a3db-4ac2fc6b7832
# TCGA-CM-5349-10A	TCGA-COAD	de9f5a6b-5c2d-40eb-af8f-bd69c96639ce
# TCGA-CM-5860-01A	TCGA-COAD	4137fd71-6dac-4da9-bf39-c1a60a919770
# TCGA-CM-5860-10A	TCGA-COAD	9ded1559-d7f2-4e39-bc58-e8997247f19d
# TCGA-CM-5861-01A	TCGA-COAD	bef7ded4-53c4-4230-877d-7698f1a85234
# TCGA-CM-5861-10A	TCGA-COAD	0b05fe9b-3a7a-49bb-9ffc-8ae6c5434512
# TCGA-CM-5862-01A	TCGA-COAD	c7bb9dd2-84a9-4508-9d5f-067946b74589
# TCGA-CM-5862-10A	TCGA-COAD	8853efa1-27c2-4791-a7bb-d0c5793f2ce4
# TCGA-CM-5863-01A	TCGA-COAD	e2a983a8-f492-4f30-869d-7c5ab3dd98b8
# TCGA-CM-5863-10A	TCGA-COAD	ce01fef0-26e2-4471-a7d7-775d3049e19b
# TCGA-CM-5864-01A	TCGA-COAD	8e822e0e-7a7d-40c2-85f7-80087e441335
# TCGA-CM-5864-10A	TCGA-COAD	0a2d0a0d-fc75-4a46-bf2c-8d76b099c916
# TCGA-CM-5868-01A	TCGA-COAD	a9d7d6a5-1bdc-4ef5-917b-1bfc781f4235
# TCGA-CM-5868-10A	TCGA-COAD	3c33186b-0218-4ba3-9e3f-a347e7080243
# TCGA-CM-6161-01A	TCGA-COAD	bcf9d196-dbf8-4ef4-940c-bceb8c88a035
# TCGA-CM-6161-10A	TCGA-COAD	8d0f5abd-0806-4a31-8a62-2e0958b348f9
# TCGA-CM-6162-01A	TCGA-COAD	97208f4c-07cc-4580-8c49-5514a775a1fe
# TCGA-CM-6162-10A	TCGA-COAD	38f224e0-6ef0-4320-a755-6aa2c8b39a7e
# TCGA-CM-6163-01A	TCGA-COAD	552a3607-cc5f-4753-a6f3-268978d6ba90
# TCGA-CM-6163-10A	TCGA-COAD	bd181996-111d-4579-9d53-8867522b20e7
# TCGA-CM-6164-01A	TCGA-COAD	65290b70-233d-4185-a052-4befb08aa12f
# TCGA-CM-6164-10A	TCGA-COAD	540aeb75-cac1-44df-8243-42d9db80cb3c
# TCGA-CM-6165-01A	TCGA-COAD	e6663ed0-dd57-4da3-a110-17a5fdf20827
# TCGA-CM-6165-10A	TCGA-COAD	6ce2b1e5-3e18-433f-9d33-86ea0bd1ee7a
# TCGA-CM-6166-01A	TCGA-COAD	8a2bd45c-5400-4931-8638-6923239fee06
# TCGA-CM-6166-10A	TCGA-COAD	e64e0476-c1ef-4b70-bf42-f181edc64179
# TCGA-CM-6167-01A	TCGA-COAD	3640fe3d-e81e-44f9-b18e-60643ed6b3dc
# TCGA-CM-6167-10A	TCGA-COAD	c892c83c-adfa-44c3-a0db-570379ca1be7
# TCGA-CM-6168-01A	TCGA-COAD	079c518c-5452-4d78-8d96-c49d6ae5a05b
# TCGA-CM-6168-10A	TCGA-COAD	b4ac293d-c46c-463d-bfb6-9fabcae64d64
# TCGA-CM-6169-01A	TCGA-COAD	74e1d4b4-b1a1-4d1e-a448-285670397e56
# TCGA-CM-6169-10A	TCGA-COAD	bbab120e-1f41-4c7f-8928-73055ae5a2fe
# TCGA-CM-6170-01A	TCGA-COAD	ced693a0-6e5d-467a-a84f-6e9c6e6541a7
# TCGA-CM-6170-10A	TCGA-COAD	b44d6434-5534-46b9-95b2-88089372a38f
# TCGA-CM-6171-01A	TCGA-COAD	f60024bf-b1ff-48d2-82a7-9386f78b87a5
# TCGA-CM-6171-10A	TCGA-COAD	afc1678e-f6fa-4c2a-9365-71f187e0ee70
# TCGA-CM-6172-01A	TCGA-COAD	f75eb1e3-e808-4a41-9819-96908b76ddd4
# TCGA-CM-6172-10A	TCGA-COAD	45654d46-56f0-4d32-b3c8-389e34060930
# TCGA-CM-6674-01A	TCGA-COAD	41273679-1683-4686-83dc-e8e1cf7806d3
# TCGA-CM-6674-10A	TCGA-COAD	19a112b9-4526-484a-912f-93138947e7a4
# TCGA-CM-6675-01A	TCGA-COAD	eab7611b-34e9-4ef8-a43b-9d29ef3f415b
# TCGA-CM-6675-10A	TCGA-COAD	431ccf65-bdea-4b79-ad7b-c8c29357dd68
# TCGA-CM-6676-01A	TCGA-COAD	2174bbc4-4da0-4b2e-96aa-bd55865b6a9a
# TCGA-CM-6676-10A	TCGA-COAD	496d723c-6f3d-42e9-871a-10070889f03f
# TCGA-CM-6677-01A	TCGA-COAD	dd279da3-9d71-450d-8322-40703082dbca
# TCGA-CM-6677-10A	TCGA-COAD	5116ecb7-4536-4d98-8d1f-5a3fb3c6d3e5
# TCGA-CM-6678-01A	TCGA-COAD	e61d7641-b0d5-4373-b803-7e4ecd06464d
# TCGA-CM-6678-10A	TCGA-COAD	3101bd5e-1348-441a-874f-5fc1f8d9b42b
# TCGA-CM-6679-01A	TCGA-COAD	4078caa2-920d-4b52-b76f-b47df698e386
# TCGA-CM-6679-10A	TCGA-COAD	6e184593-713a-4e27-8941-204ab6bc8aa8
# TCGA-CM-6680-01A	TCGA-COAD	c4585ab4-a999-4ec7-b560-2e0517317d64
# TCGA-CM-6680-10A	TCGA-COAD	dd3140b5-5b09-48ac-90bd-efdf0ca080c9
# TCGA-D5-5537-01A	TCGA-COAD	9de03a61-349b-44f7-b947-45315c0cf451
# TCGA-D5-5537-10A	TCGA-COAD	6ee4a0ba-b2f7-4b34-8a38-337a03b3ee17
# TCGA-D5-5538-01A	TCGA-COAD	daa15576-7c33-4acd-b026-ad6eb9e40b79
# TCGA-D5-5538-10A	TCGA-COAD	228722db-49ec-4192-9cbe-370ba924d222
# TCGA-D5-5539-01A	TCGA-COAD	e2704494-84e8-4739-9eb0-02f8a2036f44
# TCGA-D5-5539-10A	TCGA-COAD	e38f18e3-141e-430f-ab93-e31c7015cc01
# TCGA-D5-5540-01A	TCGA-COAD	de519662-a567-47fb-8a7d-6956a6cfe893
# TCGA-D5-5540-10A	TCGA-COAD	a18a0c3a-16f4-4a9d-aa69-ea334f8e7a63
# TCGA-D5-5541-01A	TCGA-COAD	289d8287-c14a-443f-9039-526ca00a72a0
# TCGA-D5-5541-10A	TCGA-COAD	871c055e-2f6c-48b4-98a3-66612ddb32fd
# TCGA-D5-6529-01A	TCGA-COAD	68f85cad-07c5-458d-92f0-d6cb5f9fd275
# TCGA-D5-6529-10A	TCGA-COAD	d69c3097-859f-4418-90ee-cd516085ef8b
# TCGA-D5-6530-01A	TCGA-COAD	275f7eb7-8787-4031-975e-4f5c8c62e201
# TCGA-D5-6530-10A	TCGA-COAD	0940e973-8ad7-4cc8-bacf-35c04271b88f
# TCGA-D5-6531-01A	TCGA-COAD	812373e8-e5c4-43b4-99f6-0ecbeeecbf4e
# TCGA-D5-6531-10A	TCGA-COAD	7db6e03d-1a2e-463d-a156-0068fe1b13d8
# TCGA-D5-6532-01A	TCGA-COAD	7e54c845-9971-48f2-be35-add80194814b
# TCGA-D5-6532-10A	TCGA-COAD	34998c14-ce9d-49c2-bc76-eff94ad206b6
# TCGA-D5-6533-01A	TCGA-COAD	5a94b413-e881-440e-a4ce-046e85ad348e
# TCGA-D5-6533-10A	TCGA-COAD	10ebf44f-3f93-420d-909c-8ffffedca021
# TCGA-D5-6534-01A	TCGA-COAD	d0cdbf35-a727-4711-89d3-cb1438ec92e1
# TCGA-D5-6534-10A	TCGA-COAD	84ee6e7a-cf68-43d6-9ce6-4fd9272292c3
# TCGA-D5-6535-01A	TCGA-COAD	8a04908e-bc1e-42c2-b52d-5024d0ec05eb
# TCGA-D5-6535-10A	TCGA-COAD	dabf7e3f-bb28-45e2-ab4d-b4ed904d9fc7
# TCGA-D5-6536-01A	TCGA-COAD	f220d7fa-6d4e-44e0-ad1b-a13362637ac5
# TCGA-D5-6536-10A	TCGA-COAD	bcc32930-135d-4f1b-8300-1bafce052ec4
# TCGA-D5-6537-01A	TCGA-COAD	f2d0e51d-cbc5-48ab-8b36-ddade2e0aff2
# TCGA-D5-6537-10A	TCGA-COAD	b76a9e82-d195-4f3a-9269-b6e79b4dafaa
# TCGA-D5-6538-01A	TCGA-COAD	a62db962-ca4e-4959-bc4c-0a457daffa38
# TCGA-D5-6538-10A	TCGA-COAD	ccc8742f-1591-46ef-864a-9fc08dca16c8
# TCGA-D5-6539-01A	TCGA-COAD	8fd27cde-54cc-4655-ba3c-04bc119f1fcb
# TCGA-D5-6539-10A	TCGA-COAD	3b97b6b4-4844-41ed-bf07-98fcb4c52a6d
# TCGA-D5-6540-01A	TCGA-COAD	0b0f9b88-124f-451d-aa5d-a3b8c80f5a50
# TCGA-D5-6540-10A	TCGA-COAD	b7eaaa3f-6955-405d-a9a4-eae71477fbba
# TCGA-D5-6541-01A	TCGA-COAD	d626a9bd-ec04-4c42-8da5-ee8821589e28
# TCGA-D5-6541-10A	TCGA-COAD	61eb9b88-8058-4221-9f6f-102d11979f81
# TCGA-D5-6898-01A	TCGA-COAD	64115aff-d522-4bd7-a49a-df74cc5e752c
# TCGA-D5-6898-10A	TCGA-COAD	2810d595-ec40-478e-b3ed-c948f2d878d4
# TCGA-D5-6920-01A	TCGA-COAD	33c14388-7f74-4805-9db5-c3883d24b822
# TCGA-D5-6920-10A	TCGA-COAD	8aa8176c-15da-46e9-8a1c-c4467d2d5432
# TCGA-D5-6922-01A	TCGA-COAD	33f8d2f5-61c7-46ba-82c0-4d01b938b353
# TCGA-D5-6922-10A	TCGA-COAD	592244d8-ab93-4df0-ad95-bc04332371b9
# TCGA-D5-6923-01A	TCGA-COAD	e655cd43-daf8-4330-85db-73563da197b5
# TCGA-D5-6923-10A	TCGA-COAD	25f61e98-825a-4b3f-ab6d-a3eeb793d115
# TCGA-D5-6924-01A	TCGA-COAD	490fc4e1-a13a-4378-9280-7371a687bc6b
# TCGA-D5-6924-10A	TCGA-COAD	dcb27d6d-bd51-429d-a1c1-e84808fb4259
# TCGA-D5-6926-01A	TCGA-COAD	fabbf0e3-ff26-4cba-bb36-f38e3bb7b161
# TCGA-D5-6926-10A	TCGA-COAD	01306a67-e0e9-4b22-807e-4c0a46338415
# TCGA-D5-6927-01A	TCGA-COAD	cc476eac-c0b5-41e0-996d-b4d0269a89d8
# TCGA-D5-6927-10A	TCGA-COAD	bb6475a9-ba13-4d16-8c48-40ca2d2623d4
# TCGA-D5-6928-01A	TCGA-COAD	b11da43e-b657-47ba-b1b5-879b86c84a51
# TCGA-D5-6928-10A	TCGA-COAD	f96f5ae6-96f9-4d33-b572-ba7dddc36842
# TCGA-D5-6929-01A	TCGA-COAD	e5e33e5b-936b-4a1a-bb7e-fed83cc9459d
# TCGA-D5-6929-10A	TCGA-COAD	9aa3287c-4109-43f9-85a1-13905a0a219b
# TCGA-D5-6930-01A	TCGA-COAD	abbe21db-8b12-4a79-8660-496953551adc
# TCGA-D5-6930-10A	TCGA-COAD	eaa70e72-ebf0-4cb7-8538-e6cc6df2da69
# TCGA-D5-6931-01A	TCGA-COAD	3a7e7a9e-0ab7-42f5-96e0-bd63b4281129
# TCGA-D5-6931-10A	TCGA-COAD	6c636efe-36b2-4157-88b4-5efc33d27e34
# TCGA-D5-6932-01A	TCGA-COAD	a4153d58-b776-4068-9690-8cdb9607f569
# TCGA-D5-6932-10A	TCGA-COAD	2232778b-dbf2-4db3-9afb-36b4e8d92407
# TCGA-D5-7000-01A	TCGA-COAD	275eb122-dc11-493d-9d63-64dcb991e48a
# TCGA-D5-7000-10A	TCGA-COAD	b99ef9f4-5bcc-48a9-b74e-47817aff86ba
# TCGA-DM-A0X9-01A	TCGA-COAD	c56d3df7-61b7-4a10-a46b-11ed9e7a468c
# TCGA-DM-A0X9-10A	TCGA-COAD	871ac10e-ec05-43ca-a708-16808f85ce45
# TCGA-DM-A0XD-01A	TCGA-COAD	59207214-79af-41ea-87eb-4ebe6e7fe48d
# TCGA-DM-A0XD-10A	TCGA-COAD	732a6ee1-0a0c-4683-a672-42f933dc0b7f
# TCGA-DM-A0XF-01A	TCGA-COAD	d6e85c52-c133-472c-9c83-8773cdb50c50
# TCGA-DM-A0XF-10A	TCGA-COAD	fcc6525d-5bdf-4a7f-8c71-132a27acbefb
# TCGA-DM-A1D0-01A	TCGA-COAD	a4fddbcb-b140-4531-bf15-22a3f181dcef
# TCGA-DM-A1D0-10A	TCGA-COAD	664ab196-7703-4fa9-ac80-c9277e8dd592
# TCGA-DM-A1D4-01A	TCGA-COAD	2f918aae-f139-4d80-af75-cac61ca7d837
# TCGA-DM-A1D4-10A	TCGA-COAD	cfa69e64-025d-477c-94cd-565ed6e02f6a
# TCGA-DM-A1D6-01A	TCGA-COAD	8062fe44-fbd1-469e-96d9-305b0120357c
# TCGA-DM-A1D6-10A	TCGA-COAD	72481e51-df8c-4455-8515-48573db102e2
# TCGA-DM-A1D7-01A	TCGA-COAD	7bb687b3-90b5-4967-991d-4fe16509168d
# TCGA-DM-A1D7-10A	TCGA-COAD	f6a067c2-6efc-4f92-9abf-0478a0177c8b
# TCGA-DM-A1D8-01A	TCGA-COAD	79f841b2-8286-40cd-9fe9-fe6228048854
# TCGA-DM-A1D8-10A	TCGA-COAD	87aade2c-6d3b-4118-bb90-6315b1a5744c
# TCGA-DM-A1D9-01A	TCGA-COAD	8613db3d-2aad-4345-9852-0a827d4d2100
# TCGA-DM-A1D9-10A	TCGA-COAD	2614e136-aa4a-4542-9221-54a8992a740d
# TCGA-DM-A1DA-01A	TCGA-COAD	938ed93c-9d95-424a-a625-0fe796c7bdb6
# TCGA-DM-A1DA-10A	TCGA-COAD	3c3d44fb-6eda-425f-b470-f989d8fb52ac
# TCGA-DM-A1DB-01A	TCGA-COAD	85a4bf7e-3a89-4c5f-bbcb-c70f0d580b22
# TCGA-DM-A1DB-10A	TCGA-COAD	a16e1797-aeb8-4553-856c-3733e8653095
# TCGA-DM-A1HA-01A	TCGA-COAD	94576652-c4c3-44d7-9732-9a554b285ab9
# TCGA-DM-A1HA-10A	TCGA-COAD	f55a6450-4ab8-4fe6-b74f-e4510f46dc35
# TCGA-DM-A1HB-01A	TCGA-COAD	9a96d52a-cf95-44d7-bd81-a1c9e51b29b3
# TCGA-DM-A1HB-10A	TCGA-COAD	1cb45345-bd7c-4339-88b5-2fc4d91d6445
# TCGA-DM-A280-01A	TCGA-COAD	c19b973e-1937-4b19-9d87-1dc2535754dc
# TCGA-DM-A280-10A	TCGA-COAD	97bc8702-b490-4872-a09e-64652836a237
# TCGA-DM-A282-01A	TCGA-COAD	5041464e-daa3-4db4-a735-8c8af226e979
# TCGA-DM-A282-10A	TCGA-COAD	07ef468b-ac64-4976-a2a6-b98eb912534e
# TCGA-DM-A285-01A	TCGA-COAD	874fc58f-d45d-498a-8641-2e7453ed6494
# TCGA-DM-A285-10A	TCGA-COAD	c8573454-ebd2-48f1-9ba8-f0b575664d3d
# TCGA-DM-A288-01A	TCGA-COAD	5914ee20-502a-4286-8d78-b1251a6e5fab
# TCGA-DM-A288-10A	TCGA-COAD	3c0dd048-bca7-4420-af34-473160e35b45
# TCGA-DM-A28A-01A	TCGA-COAD	3dda6c5d-3851-49a3-a003-02c67e040c5e
# TCGA-DM-A28A-10A	TCGA-COAD	7c5d7535-ba5c-4753-9057-901caf1b00d0
# TCGA-DM-A28C-01A	TCGA-COAD	513501ad-9666-4a58-9b7b-8799d0b84d3e
# TCGA-DM-A28C-10A	TCGA-COAD	2bed1e50-ff22-4373-9ec6-db052a514150
# TCGA-DM-A28E-01A	TCGA-COAD	aa0fa528-37c0-457f-9cd0-5abf17d159a4
# TCGA-DM-A28E-10A	TCGA-COAD	5404637a-a1d8-436c-820e-8369888da88d
# TCGA-DM-A28F-01A	TCGA-COAD	723fc71b-5b87-4123-807c-2ecb4423da36
# TCGA-DM-A28F-10A	TCGA-COAD	8970e5f6-aefb-45b3-b09f-e3a6125afa9c
# TCGA-DM-A28G-01A	TCGA-COAD	1941d226-401e-4b03-8a07-49ac008b6a10
# TCGA-DM-A28G-10A	TCGA-COAD	1647d58b-6858-43c5-953c-ae25d4245feb
# TCGA-DM-A28H-01A	TCGA-COAD	ddd33be2-3d8f-4e63-acb9-c543eee0e5b5
# TCGA-DM-A28H-10A	TCGA-COAD	fa51d25e-4d46-4c3b-af4a-2c635b992ef1
# TCGA-DM-A28K-01A	TCGA-COAD	e1ccb95b-202d-4fd3-a4ca-c7db4b1ed778
# TCGA-DM-A28K-10A	TCGA-COAD	d500e404-f79a-49d0-bd6a-dc1116e5e97f
# TCGA-DM-A28M-01A	TCGA-COAD	89573b9e-9296-4485-bc09-93d315dfa443
# TCGA-DM-A28M-10A	TCGA-COAD	fd6bfb20-892c-431e-a773-735693b1798a
# TCGA-F4-6459-01A	TCGA-COAD	0fa33e5e-60d5-4593-bd3b-7d1dfab99479
# TCGA-F4-6459-10A	TCGA-COAD	340a68a6-c410-4797-9bdc-92a12c79e416
# TCGA-F4-6460-01A	TCGA-COAD	9e0f3fa1-d89b-4e7b-9341-6996f9f25394
# TCGA-F4-6460-10B	TCGA-COAD	34988f38-6eec-46bc-a007-95b768237c5b
# TCGA-F4-6461-01A	TCGA-COAD	1cd69956-6d52-4b40-8e0b-4343ad7f698b
# TCGA-F4-6461-10A	TCGA-COAD	3233b2e6-9ff8-453c-8fe2-e185f30004c8
# TCGA-F4-6463-01A	TCGA-COAD	73a49f66-f86b-43c6-997d-17388c13279c
# TCGA-F4-6463-10A	TCGA-COAD	adb726b4-a04c-4372-b9f4-4346e7cdccfd
# TCGA-F4-6569-01A	TCGA-COAD	059312aa-f536-48f6-92e4-978219e96598
# TCGA-F4-6569-10A	TCGA-COAD	c3830459-472d-4ced-ac02-52b9423b56c3
# TCGA-F4-6570-01A	TCGA-COAD	bef1c396-dca6-4753-9eed-bbdb4637661d
# TCGA-F4-6570-10A	TCGA-COAD	a9ab3bad-85df-472b-a2a6-30d00bd81bd8
# TCGA-F4-6703-01A	TCGA-COAD	76812ae0-961a-4097-84c9-ab694850bc3a
# TCGA-F4-6703-10A	TCGA-COAD	cd16dc90-8e04-4f94-b446-f0cc8cb58912
# TCGA-F4-6704-01A	TCGA-COAD	b2482f3c-283c-4ae2-9b5a-afd9f5d1a1c3
# TCGA-F4-6704-11A	TCGA-COAD	a95d22cc-adff-4269-95c7-8df491f529d2
# TCGA-F4-6805-01A	TCGA-COAD	c38be5b7-10bd-4906-a34f-3b41796dd664
# TCGA-F4-6805-10A	TCGA-COAD	b091d443-9277-4b2d-b065-66698187efcc
# TCGA-F4-6806-01A	TCGA-COAD	540f625e-408a-4e60-ab26-05fe7489fbcf
# TCGA-F4-6806-10A	TCGA-COAD	2a63898b-1c30-49e2-babc-0039b0734894
# TCGA-F4-6807-01A	TCGA-COAD	3b3185d4-0807-46a0-9999-d0e0add1ddb3
# TCGA-F4-6807-10A	TCGA-COAD	35aac059-2ca4-4d1d-b377-ac68471309cf
# TCGA-F4-6808-01A	TCGA-COAD	8aefb1d1-58af-4800-ad48-4e3ffc64bb0d
# TCGA-F4-6808-10A	TCGA-COAD	d822785f-99c4-45fc-b0c2-470a2a5dac54
# TCGA-F4-6809-01A	TCGA-COAD	fb0e53a0-5c9f-462d-96e8-7dc13d7afe84
# TCGA-F4-6809-10A	TCGA-COAD	461f1071-0944-4a69-b1af-c59dde08b14f
# TCGA-F4-6854-01A	TCGA-COAD	08c1d8ff-ce77-4add-8c80-6e52f53f4911
# TCGA-F4-6854-10A	TCGA-COAD	dbf4a593-f8f0-41f1-a96b-6f36e4d2e696
# TCGA-F4-6855-01A	TCGA-COAD	09e6c467-e719-40de-8840-4dd11e4dc0f7
# TCGA-F4-6855-10A	TCGA-COAD	88f21d44-a850-479f-947a-250c6dd1dddd
# TCGA-F4-6856-01A	TCGA-COAD	39e462f2-9a9b-4111-b4be-a8c6dff56761
# TCGA-F4-6856-10A	TCGA-COAD	b672acb4-5984-4f8c-86f5-20cdbe1703f0
# TCGA-G4-6293-01A	TCGA-COAD	24b46930-c15e-48dd-a884-a31ebb2a7880
# TCGA-G4-6293-10A	TCGA-COAD	ceb64ce8-724e-45bd-956f-a2d9548ec534
# TCGA-G4-6294-01A	TCGA-COAD	f3218e1d-6f0c-4875-9743-75390008571c
# TCGA-G4-6294-10A	TCGA-COAD	cbf3b24b-1335-41c7-8a7f-222d738ab4a8
# TCGA-G4-6295-01A	TCGA-COAD	dbff7cdd-80a0-4570-86be-dbb6a6e988e9
# TCGA-G4-6295-10A	TCGA-COAD	03ad1c7a-fe84-4d6f-b24c-103f0c96000c
# TCGA-G4-6295-11A	TCGA-COAD	be043395-6296-4df8-831e-2c87be91161c
# TCGA-G4-6297-01A	TCGA-COAD	7d420cfb-3c0e-49c0-b880-a8c8d612db0b
# TCGA-G4-6297-10A	TCGA-COAD	756a00db-66d4-453c-8353-19af38b2ede5
# TCGA-G4-6297-11A	TCGA-COAD	3bf94eef-e039-4327-aff1-e5e0011b00cb
# TCGA-G4-6298-01A	TCGA-COAD	c750908b-6916-4e32-a856-f31d7c1f3724
# TCGA-G4-6298-10A	TCGA-COAD	3770dcec-e581-49cc-a63e-18065084a27d
# TCGA-G4-6298-11A	TCGA-COAD	32819740-c892-477e-ace1-5ebc7c9031fe
# TCGA-G4-6299-01A	TCGA-COAD	bfc7527f-93bf-4b56-9586-11608c8593ce
# TCGA-G4-6299-10A	TCGA-COAD	6d4d1a93-d078-4f87-b07c-dd3d8a134a8e
# TCGA-G4-6302-01A	TCGA-COAD	dbe61972-56bd-47e4-9b62-fac4730114a4
# TCGA-G4-6302-10A	TCGA-COAD	a11c11e1-a787-4e8a-8408-6f7829970b5b
# TCGA-G4-6302-11A	TCGA-COAD	8d45e62d-4f3b-4284-b1f0-98194d902fef
# TCGA-G4-6303-01A	TCGA-COAD	7bc68281-9173-43c3-97bc-a0bbb0f23e8a
# TCGA-G4-6303-10A	TCGA-COAD	21c4a357-da72-47c6-b9c4-1111d90ad7dc
# TCGA-G4-6304-01A	TCGA-COAD	4ae7cc99-c33b-47d3-9030-a756d2acca6b
# TCGA-G4-6304-10A	TCGA-COAD	a282a5c6-0f67-4850-b888-04f049a7562e
# TCGA-G4-6306-01A	TCGA-COAD	7d658ae8-b10c-4e3b-aad8-c08bfe5018d8
# TCGA-G4-6306-10A	TCGA-COAD	62f5d6ba-d002-46cb-9e97-a2684c47c17e
# TCGA-G4-6307-01A	TCGA-COAD	1780007b-1612-45ac-aacd-7fe7de7dd885
# TCGA-G4-6307-10A	TCGA-COAD	ef498a82-e2fa-4b06-a9ad-821d47e19f42
# TCGA-G4-6309-01A	TCGA-COAD	bcf6331d-c70d-41ae-bb02-92989bfdd5f0
# TCGA-G4-6309-10A	TCGA-COAD	2778fd23-6fd4-4372-90db-8b15c5b880a4
# TCGA-G4-6310-01A	TCGA-COAD	11b879fb-84fb-403e-a065-097ecff03626
# TCGA-G4-6310-10A	TCGA-COAD	e10a3587-7ba7-4847-9f9d-5db55ef97a4f
# TCGA-G4-6311-01A	TCGA-COAD	2a6519f8-6d4d-46ef-9ff7-195bf2945d84
# TCGA-G4-6311-10A	TCGA-COAD	7017fa31-4878-43d5-b5c1-0c29a0edbc3b
# TCGA-G4-6311-11A	TCGA-COAD	a079d49a-0d9f-4793-89cb-fe914c74d626
# TCGA-G4-6314-01A	TCGA-COAD	e728fde5-352c-486e-ab2a-dd73b5ad41a6
# TCGA-G4-6314-10A	TCGA-COAD	c27ae7ca-a798-42cd-88cf-a879b0fff64e
# TCGA-G4-6314-11A	TCGA-COAD	3393c7e0-f452-4ed8-b592-2c820bb9f9f1
# TCGA-G4-6315-01A	TCGA-COAD	aabaf556-e53e-4f68-b946-579d89458e88
# TCGA-G4-6315-10A	TCGA-COAD	b8403dbc-7c34-4411-9c42-e1903cd5a9a8
# TCGA-G4-6317-01A	TCGA-COAD	6261c436-0d6f-4598-9b07-35d82e2119d7
# TCGA-G4-6317-02A	TCGA-COAD	eeae0b7b-8448-4772-842f-fe7ef7ee466a
# TCGA-G4-6317-10A	TCGA-COAD	9f0cd882-9ed3-4287-b86f-8544f668bfff
# TCGA-G4-6320-01A	TCGA-COAD	f7c4f460-6ec6-4f59-90fc-45abda07e7b1
# TCGA-G4-6320-10A	TCGA-COAD	36b29d7f-1605-46a8-bf9c-041fbf8eb357
# TCGA-G4-6320-11A	TCGA-COAD	09d399af-60fb-4aa7-899b-75578a291984
# TCGA-G4-6321-01A	TCGA-COAD	29537875-c763-424a-abcf-dece69a348af
# TCGA-G4-6321-10A	TCGA-COAD	42eeb75b-0bbc-4b9a-8093-f6d0ff19665a
# TCGA-G4-6322-01A	TCGA-COAD	1986a60d-4ca2-4c18-9b58-27b3c0fa5307
# TCGA-G4-6322-10A	TCGA-COAD	5377eed7-168a-4d2f-b84e-39e9f4463887
# TCGA-G4-6322-11A	TCGA-COAD	44af7455-f0c2-4adf-a498-f1585612568e
# TCGA-G4-6323-01A	TCGA-COAD	0cf81f39-07cb-4687-a709-51d6e9009ca1
# TCGA-G4-6323-10A	TCGA-COAD	21c5e08b-abe8-423f-8c38-efe366301cbd
# TCGA-G4-6586-01A	TCGA-COAD	2f5e1304-2704-4653-9b1d-6069579a8e8d
# TCGA-G4-6586-10A	TCGA-COAD	69ea4d18-50f7-4c9c-b811-95c0352efde1
# TCGA-G4-6588-01A	TCGA-COAD	1a571e3b-84e0-430f-8060-176e6f9170b9
# TCGA-G4-6588-10A	TCGA-COAD	b9527ea0-a421-41d2-88ee-e194f603f922
# TCGA-G4-6625-01A	TCGA-COAD	6f0c53eb-bb99-4dcb-ae02-dc79b19ec3a9
# TCGA-G4-6625-11A	TCGA-COAD	77c717b7-0d87-41e8-86eb-e4d2d11f0328
# TCGA-G4-6626-01A	TCGA-COAD	3615048a-5bb5-4071-a1cd-116f6fa1b35f
# TCGA-G4-6626-10A	TCGA-COAD	cb9550a2-377d-4b05-81d1-cdcb57c6b64b
# TCGA-G4-6627-01A	TCGA-COAD	3089b828-442d-4712-b2da-e30d48375bda
# TCGA-G4-6627-10A	TCGA-COAD	7b09b1db-07c0-4335-8b23-79852920151a
# TCGA-G4-6628-01A	TCGA-COAD	b177fc6b-ef17-4ce2-ae44-71eb500543d9
# TCGA-G4-6628-10A	TCGA-COAD	adab89b5-21b2-4df4-87c1-bb0e145599a6
# TCGA-NH-A50T-01A	TCGA-COAD	ce595cc1-52b3-411a-9359-aea68691acbe
# TCGA-NH-A50T-10A	TCGA-COAD	d22d500e-fbf7-48b3-9fbd-33ae0d1a6197
# TCGA-NH-A50U-01A	TCGA-COAD	5ce75def-e1d0-469d-93d4-ab1a01335d7c
# TCGA-NH-A50U-10A	TCGA-COAD	b41cc642-7781-401a-a948-c33aaea49b62
# TCGA-NH-A50V-01A	TCGA-COAD	aeafe2c1-bc94-474d-b303-94dd9939309c
# TCGA-NH-A50V-10A	TCGA-COAD	fdd4cb0a-8eac-4e82-a3d7-4f99793c98b0
# TCGA-NH-A5IV-01A	TCGA-COAD	3337994f-9b88-483b-8f61-85fe97ea6cbc
# TCGA-NH-A5IV-10A	TCGA-COAD	3beebb81-b6b8-4def-bc05-f3a2409f5d1d
# TCGA-NH-A6GA-01A	TCGA-COAD	2463e0fd-6316-461e-b6f8-22e6a0b01e06
# TCGA-NH-A6GA-10A	TCGA-COAD	af53d446-f416-4b8e-9580-06a3c2c75b41
# TCGA-NH-A6GB-01A	TCGA-COAD	6e257d17-6f1a-4043-9960-c59afc8670c9
# TCGA-NH-A6GB-10A	TCGA-COAD	3e4f7ad4-32ab-43dc-b62d-6c7344d8f939
# TCGA-NH-A6GC-01A	TCGA-COAD	0e94d500-50c0-4c52-b874-90f2654564f4
# TCGA-NH-A6GC-10A	TCGA-COAD	68073eef-f640-4804-8e0f-a55be15c2e3f
# TCGA-NH-A8F7-01A	TCGA-COAD	13510e39-3120-4dc1-8d17-65c9538e13db
# TCGA-NH-A8F7-06A	TCGA-COAD	0154afa8-454b-4ba4-8386-b27b222a6a3c
# TCGA-NH-A8F7-10A	TCGA-COAD	d8cd8cdd-8d7f-460d-8b45-f9be71411a5c
# TCGA-NH-A8F8-01A	TCGA-COAD	605525cb-a0b2-49e4-a4b2-d5ed74c66cd6
# TCGA-NH-A8F8-10A	TCGA-COAD	65156c95-173a-4c4e-a3ed-57b5b32daa2e
# TCGA-QG-A5YV-01A	TCGA-COAD	d645abc6-c91d-4fee-a8c3-dd58b7e7e848
# TCGA-QG-A5YV-10A	TCGA-COAD	ccca4ac8-b3df-4ac5-8c72-87d01f395abc
# TCGA-QG-A5YW-01A	TCGA-COAD	ca173bc7-cf0e-4123-b4d6-6b8d22b7dd28
# TCGA-QG-A5YW-10A	TCGA-COAD	5482aac3-cf27-4be5-bdab-16c3276c6eb0
# TCGA-QG-A5YX-01A	TCGA-COAD	bf62f5c9-cc5b-4419-98ca-7ede0b55c426
# TCGA-QG-A5YX-10A	TCGA-COAD	11423fa7-1434-4525-97f0-04e4a76c0e39
# TCGA-QG-A5Z1-01A	TCGA-COAD	0d40f4cd-cc31-490f-aef6-9cbe8b0dad12
# TCGA-QG-A5Z1-10A	TCGA-COAD	a0b5745b-4658-452c-ac07-f7b585ef7b7c
# TCGA-QG-A5Z2-01A	TCGA-COAD	6c9ae89a-13d3-45de-8932-413b449a18e9
# TCGA-QG-A5Z2-10A	TCGA-COAD	952dc891-fca9-4149-a6ac-41e9d657642a
# TCGA-QL-A97D-01A	TCGA-COAD	379eaec5-9376-4bec-9dea-d997ea5758c2
# TCGA-QL-A97D-10A	TCGA-COAD	19de15f7-430a-4dfb-a64d-3f13968b63cc
# TCGA-RU-A8FL-01A	TCGA-COAD	98f5b862-6a36-4cbe-bc21-d44614cbe30e
# TCGA-RU-A8FL-10A	TCGA-COAD	e0bc9fb8-e238-485a-8151-0869eb0af655
# TCGA-SS-A7HO-01A	TCGA-COAD	a9d64ba4-fdfe-4c94-99e3-1b9ef2e424ef
# TCGA-SS-A7HO-10A	TCGA-COAD	0f5c5b9e-1d23-4824-be8c-675f449c8c84
# TCGA-T9-A92H-01A	TCGA-COAD	026ac354-163a-44c3-8b8e-25365c0998be
# TCGA-T9-A92H-10A	TCGA-COAD	2ce5f527-04f4-41da-9a75-e302bc409031
# TCGA-WS-AB45-01A	TCGA-COAD	d5c99685-0254-4f7e-aa8c-f753337c6c29
# TCGA-WS-AB45-10A	TCGA-COAD	af4612fb-3c3f-43d6-95a2-ef4a33395e8e

# %%
# Local Folder Operations -----------------------------
# LOCAL:
cd $WORKDIR

#NOTE For pilot run, AWS s3 shutdown commented out. Re-upload hgr1 script upon full run

aws s3 cp queenB.sh $S3URL/scripts/
aws s3 cp droneB.sh $S3URL/scripts/
aws s3 cp hgr1_align_v5.wxs.sh $S3URL/scripts/
aws s3 cp $INPUT $S3URL/scripts/
aws s3 cp ../../gdc.token.txt $S3URL/scripts/gdc.token
# Out:
# upload: ./queenB.sh to s3://crownproject/tcga_wxs/scripts/queenB.sh
# upload: ./droneB.sh to s3://crownproject/tcga_wxs/scripts/droneB.sh
# upload: ./hgr1_align_v5.wxs.sh to s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh
# upload: ./tcga_wxs.input to s3://crownproject/tcga_wxs/scripts/tcga_wxs.input
# upload: ../../gdc.token.txt to s3://crownproject/tcga_wxs/scripts/gdc.token

# %%
# Remote EC2 Instance Operations ----------------------
# bash queenB.sh tcga_wxs.input
#
# aws s3 cp screenlog.0 s3://crownproject/tcga_wxs/logs/tcga_wxs.input.log

aws s3 cp s3://crownproject/tcga_wxs/logs/tcga_wxs_input.log ./
cat tcga_wxs.input.log

# %% [markdown]
# ### Error List
#
# - TCGA-A6-2679-10A
# ```
# Aligning
# Error: Read HWI-ST807:232:D0VM5ACXX:5:1201:13180:439981/1 has more quality values than read characters.
# ```
# - TCGA-A6-2681-10A `Read HWI-ST807:232:D0VM5ACXX:2:2210:16628:606201/1`
# - TCGA-A6-2682-10A `Read HWI-ST807:232:D0VM5ACXX:2:2107:12164:573701/1`
# - TCGA-A6-2684-10Ab `Read HWI-ST807:232:D0VM5ACXX:2:1309:16259:665651/1`
# - TCGA-A6-4107-10A `Read HWI-ST807:232:D0VM5ACXX:4:2311:15608:577101/1`
# - TCGA-A6-5665-01B `Read C0YRNACXX120905:4:1210:3297:319811/1`
# - TCGA-AA-3494-11A
# - TCGA-AA-3495-11A
# - TCGA-AA-3506-11A
# - TCGA-AA-3509-11A
#
# ```
# # Temporary save command
# aws s3 cp . s3://crownproject/tcga_wxs/error/ \
#   --recursive --exclude "*" --include "*region.fq"
# ```
#
# The Error is arising when quality of a line begins with `@` a /1 is being added by the sed command to the end. Need to make the regex more FASTQ sensitive.q
#
# ### Restart Run
#
# After sample `TCGA-AA-3678-10A` will reboot the head node (ssh error also arose by changing permission of `.ssh` away from 700 accidently). I will fix the regex as well to prevent the above error.
#
# ```
# ssh -i "~/.ssh/CrownKey.pem" ec2-user@ec2-35-167-240-253.us-west-2.compute.amazonaws.com
# ```
#
# Changed sed command to:
# ```
#   # Append \1 and \2 to each read name in fq files
#   # Every 4th line in file
#   sed -i '1~4 s/$/\/1/g' $FQ1
#   sed -i '1~4 s/$/\/2/g' $FQ2
# ```

# %%
# Local Folder Operations -----------------------------
# LOCAL:
cd $WORKDIR

INPUT="tcga_wxs_errors.input"
cat $INPUT
echo ''
echo ''

aws s3 cp queenB.sh $S3URL/scripts/
aws s3 cp droneB.sh $S3URL/scripts/
aws s3 cp hgr1_align_v5.wxs.sh $S3URL/scripts/
aws s3 cp $INPUT $S3URL/scripts/
aws s3 cp ../../gdc.token.txt $S3URL/scripts/gdc.token
# Out:
# TCGA-A6-2681-10A	TCGA-COAD	e52fa5db-671e-4f0f-8279-01b66bd71069
# TCGA-A6-2682-10A	TCGA-COAD	c6980d7e-8e22-49d7-9353-f8ed639b8a6a
# TCGA-A6-2684-10Ab	TCGA-COAD	f48f0411-f1dc-41c3-a366-8aa05ebacb6c
# TCGA-A6-4107-10A	TCGA-COAD	8c42abcb-73b2-403a-ba83-b26b36f43696
# TCGA-A6-5665-01B	TCGA-COAD	4e12defd-63cd-4025-8e42-75d7fb737432
# TCGA-AA-3494-11A	TCGA-COAD	ea3ab57b-9b07-452b-9fd7-1a1c144b33b0
# TCGA-AA-3495-11A	TCGA-COAD	46c73be3-b3a0-47b6-ae4b-b81616b22a07
# TCGA-AA-3506-11A	TCGA-COAD	87b516b0-9225-4d18-bbf0-4fc71717d307
# TCGA-AA-3509-11A	TCGA-COAD	171a9bde-c390-47d1-8151-6baed9e546c3
#
#
# upload: ./queenB.sh to s3://crownproject/tcga_wxs/scripts/queenB.sh
# upload: ./droneB.sh to s3://crownproject/tcga_wxs/scripts/droneB.sh
# upload: ./hgr1_align_v5.wxs.sh to s3://crownproject/tcga_wxs/scripts/hgr1_align_v5.wxs.sh
# upload: ./tcga_wxs_errors.input to s3://crownproject/tcga_wxs/scripts/tcga_wxs_errors.input
# upload: ../../gdc.token.txt to s3://crownproject/tcga_wxs/scripts/gdc.token

# %%
# REMOTE:
# aws s3 cp --recursive s3://crownproject/tcga_wxs/scripts/ ./
#
# mv <KEY>.pem ~/.ssh/
# chmod 400 ~/.ssh/<KEY>.pem

# REMOTE:
# Open logging screen and being launchign EC2 instances
# screen -L
# 
# bash queenB.sh tcga_wxs_pilot.input
#
# aws s3 cp screenlog.0 s3://crownproject/tcga_wxs/logs/tcga_wxs_pilot.input.log

# %%
# Local Folder Operations -----------------------------
# LOCAL:
# Split up remaining files into 3 inputs, run each
# in parallel
aws s3 cp tcga_wxs_2.input $S3URL/scripts/
aws s3 cp tcga_wxs_3.input $S3URL/scripts/
aws s3 cp tcga_wxs_4.input $S3URL/scripts/
# Out:
# upload: ./tcga_wxs_2.input to s3://crownproject/tcga_wxs/scripts/tcga_wxs_2.input
# upload: ./tcga_wxs_3.input to s3://crownproject/tcga_wxs/scripts/tcga_wxs_3.input
# upload: ./tcga_wxs_4.input to s3://crownproject/tcga_wxs/scripts/tcga_wxs_4.input

# %%
# All runs completed successfully, (non-zero bam file present)
# downloaded log files to S3 then to local

# One file was missed
# `TCGA-A6-2679-10A	TCGA-COAD	4b4502d4-27c3-4bd6-9f37-229efd347756`
# will run that one as a 'cleanup'
#

WORKDIR='/home/artem/Crown/data2/tcga_wxs'
cd $WORKDIR
ls logs
# Out:
# tcga_wxs_2.input.log  tcga_wxs_4.input.log  tcga_wxs_pilot.input1.log
# tcga_wxs_3.input.log  tcga_wxs_error.log    tcga_wxs_pilot.input2.log

# %%
# Amazon AWS S3 file manifest
aws s3 ls s3://crownproject/tcga_wxs/TCGA-COAD/ > tcga_wxs.filelist
grep 'bam$' tcga_wxs.filelist > tcga_wxs.bamlist
wc -l tcga_wxs.bamlist
# Out:
# 973 tcga_wxs.bamlist

# %% [markdown]
# ## GVCF File for WXS
#
# Use the `ADCalc.sh` script to generate GVCF files for rDNA based on WXS leakthrough bam files.

# %%
# DNS:ec2-54-149-215-86.us-west-2.compute.amazonaws.com
# AMI: ami-0b375c9c58cb4a7a2 (TCGA aligner)
# Instance: m4.4xlarge
# Storage: 400 Gb

# ON REMOTE:

## Copy WXS files (1.8 Gb) into it's dir
#mkdir -p ~/wxs; cd wxs
#aws s3 cp --recursive s3://crownproject/tcga_wxs/TCGA-COAD ./

## PATHS:
## ~/wxs

## Run ADcalc script.sh
# screen -L
# bash ADcalc_tcga.sh

# aws s3 cp screenlog.0 s3://crownproject/ccle/logs/ccle.gvcf.log

aws s3 cp s3://crownproject/ccle/logs/ccle.gvcf.log ./
cat ccle.gvcf.log

## DONE

# %%
#!/bin/bash
# ADcalc_wxs.sh
# Allelic Depth Calculator
# for a position
#

# Controls -----------------
DEPTH='100000' #Max per file DP

# Regions in hgr1.fa reference genome
REGIONS=('chr13:1003660-1005529' 'chr13:1005529-1005629' \
        'chr13:10219-10340' 'chr13:1006622-1006779' 'chr13:1007948-1013018')

# Corresponding region/gene names
GENES=('18S' '18SE' '5S' '5.8S' '28S')

# 18S  1870
# 18SE 101
# 5S   122
# 5.8S 158
# 28S  5071

# Terminate instances upon completion (for debugging)
TERMINATE='FALSE'

# S3 Output directory
S3DIR='s3://crownproject/tcga_wxs/gvcf/'

BAMLIST='bam.list.tmp'
TYPE='TCGA-COAD.WXS' # hardcode run type

# Script ------------------ ------------------------------
cd ~/wxs
mkdir -p ../GVCF #Output Folder

    echo Analyzing $TYPE...
    #cd $TYPE

    ls *.bam > bam.list.tmp
    ls *.bam > ../GVCF/$TYPE.bamlist
          
    for index in ${!GENES[*]}
    do
      printf "Started processing %s\n" ${GENES[$index]}
      OUTPUT="../GVCF/$TYPE.${GENES[$index]}.gvcf"

      # Iterate through every bam file in directory
      # look-up position and return VCF
      bcftools mpileup -f ~/resources/hgr1/hgr1.fa \
        --max-depth $DEPTH -A --min-BQ 30 \
        -a FORMAT/DP,AD \
        -r ${REGIONS[$index]} \
        --ignore-RG \
        -b $BAMLIST | \
        bcftools annotate -x INFO,FORMAT/PL - | \
        bcftools view -O v - \
        >> $OUTPUT

      RESULTS+=("$OUTPUT")
      printf "Done with %s \n" ${GENES[$index]}
      printf "%s\n" ${REGIONS[$index]}

    done

    rm bam.list.tmp

# Copy GVCF output to AWS S3
cd ../GVCF
aws s3 cp --recursive ./ $S3DIR

# %%
mkdir -p gvcf; cd gvcf
aws s3 cp --recursive s3://crownproject/tcga_wxs/gvcf/ ./
# Out:
# download: s3://crownproject/tcga_wxs/gvcf/TCGA-COAD.WXS.5S.gvcf to ./TCGA-COAD.WXS.5S.gvcf
# download: s3://crownproject/tcga_wxs/gvcf/TCGA-COAD.WXS.bamlist to ./TCGA-COAD.WXS.bamlist
# download: s3://crownproject/tcga_wxs/gvcf/TCGA-COAD.WXS.18SE.gvcf to ./TCGA-COAD.WXS.18SE.gvcf
# download: s3://crownproject/tcga_wxs/gvcf/TCGA-COAD.WXS.5.8S.gvcf to ./TCGA-COAD.WXS.5.8S.gvcf
# download: s3://crownproject/tcga_wxs/gvcf/TCGA-COAD.WXS.18S.gvcf to ./TCGA-COAD.WXS.18S.gvcf
# download: s3://crownproject/tcga_wxs/gvcf/TCGA-COAD.WXS.28S.gvcf to ./TCGA-COAD.WXS.28S.gvcf

# %% [markdown]
# ## Discussion
#
# Notes about run.

# %% [markdown]
# ### Errors / Debugging
