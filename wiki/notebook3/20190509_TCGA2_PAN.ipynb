# %% [markdown]
# # TCGA2 - Pan
# ```
# pi:ababaian
# files: ~/Crown/data2/tcga2_3_Pan/
# start: 2019 05 10
# complete : 2019 05 19
# ```
# ## Introduction
#
# Looks like we're in the pipe five-by-five.
#
# Opening up to 90 nodes and running all remaining cancer types.

# %% [markdown]
# | TCGA Project Code | Cancer Type                                                      | This_Run |
# |-------------------|------------------------------------------------------------------|----------|
# | LAML              | Acute Myeloid Leukemia                                           | X        |
# | ACC               | Adrenocortical carcinoma                                         | X        |
# | BLCA              | Bladder Urothelial Carcinoma                                     | X        |
# | LGG               | Brain Lower Grade Glioma                                         | X        |
# | BRCA              | Breast invasive carcinoma                                        | Complete |
# | CESC              | Cervical squamous cell carcinoma and endocervical adenocarcinoma | X        |
# | CHOL              | Cholangiocarcinoma                                               | X        |
# | LCML              | Chronic Myelogenous Leukemia                                     | N/A      |
# | COAD              | Colon adenocarcinoma                                             | Complete |
# | CNTL              | Controls                                                         | N/A      |
# | ESCA              | Esophageal carcinoma                                             | X        |
# | FPPP              | FFPE Pilot Phase II                                              | -        |
# | GBM               | Glioblastoma multiforme                                          | -        |
# | HNSC              | Head and Neck squamous cell carcinoma                            | X        |
# | KICH              | Kidney Chromophobe                                               | X        |
# | KIRC              | Kidney renal clear cell carcinoma                                | X        |
# | KIRP              | Kidney renal papillary cell carcinoma                            | X        |
# | LIHC              | Liver hepatocellular carcinoma                                   | X        |
# | LUAD              | Lung adenocarcinoma                                              | X        |
# | LUSC              | Lung squamous cell carcinoma                                     | X        |
# | DLBC              | Lymphoid Neoplasm Diffuse Large B-cell Lymphoma                  | X        |
# | MESO              | Mesothelioma                                                     | X        |
# | MISC              | Miscellaneous                                                    | -        |
# | OV                | Ovarian serous cystadenocarcinoma                                | X        |
# | PAAD              | Pancreatic adenocarcinoma                                        | X        |
# | PCPG              | Pheochromocytoma and Paraganglioma                               | X        |
# | PRAD              | Prostate adenocarcinoma                                          | X        |
# | READ              | Rectum adenocarcinoma                                            | X        |
# | SARC              | Sarcoma                                                          | X        |
# | SKCM              | Skin Cutaneous Melanoma                                          | X        |
# | STAD              | Stomach adenocarcinoma                                           | X        |
# | TGCT              | Testicular Germ Cell Tumors                                      | X        |
# | THYM              | Thymoma                                                          | X        |
# | THCA              | Thyroid carcinoma                                                | X        |
# | UCS               | Uterine Carcinosarcoma                                           | X        |
# | UCEC              | Uterine Corpus Endometrial Carcinoma                             | X        |
# | UVM               | Uveal Melanoma                                                   | X        |

# %% [markdown]
# ## Objective
#
# 1. Align this set of TCGA seq data to the `hgr1` reference sequence for further analysis

# %% [markdown]
# ## Matererials and Methods

# %% [markdown]
# ### Data Initialization

# %% [markdown]
# From the GDC/TCGA website, this cohort of data was selected with the following filter command.
#
# ```
# cases.project.project_id in ["TCGA-LAML","TCGA-DLBC","TCGA-ACC","TCGA-BLCA","TCGA-CESC","TCGA-CHOL","TCGA-ESCA","TCGA-GBM","TCGA-HNSC","TCGA-KICH","TCGA-KIRC","TCGA-KIRP","TCGA-LIHC","TCGA-LGG","TCGA-LUAD","TCGA-LUSC","TCGA-MESO","TCGA-OV","TCGA-PAAD","TCGA-PCPG","TCGA-PRAD","TCGA-READ","TCGA-SARC","TCGA-SKCM","TCGA-STAD","TCGA-TGCT","TCGA-THYM","TCGA-THCA","TCGA-UCS","TCGA-UCEC","TCGA-UVM"] and files.data_format in ["BAM"] and files.data_type in ["Aligned Reads"] and files.experimental_strategy in ["RNA-Seq"] and cases.samples.is_ffpe in [false]
# ```
#
# This yields a total of `9326` files in `8691` cases. (82.09 TB!)
#
# The `Sample Sheet`, `File Manifest`, and `Biospecimen` data for this selection was downloaded. This is stored in `$PWD\metadata`
#
# In the `TCGA_File_Selection_PAN.xlsx` spreadsheet, this set of files was filtered/parsed to `8114` files
#
# 1. Remove files already aligned in the `tcga1` set, as defined in `~/Crown/data2/tcga2_pilot/tcga1_filelist.bamlist`
#
# 2. If there is a technical replicate of the same sample, they will share a SampleID (`TCGA-XX-####-01A`), add a replicate suffix to make naming unique downstream (`TCGA-XX-####-01Ax`) where x = {a,b,c...}
#
#
# The output of this parsing was copied to two input files: `tcga2_pan_input1.txt` for files 1-4100, and and `tcga2_pan_input2.txt` for files 4101-8114.

# %% [markdown]
# ### Scripts and Localization

# %% [markdown]
# #### 1 - Localization

# %%
WORKDIR='/home/artem/Crown/data2/tcga2_3_pan'
cd $WORKDIR
ls

# Amazon AWS S3 Home URL
S3URL='s3://crownproject/tcga2'
# Out:
# droneB.sh              queenB.sh             TCGA_File_Selection_PAN.xlsx
# hgr1_align_v3.tcga.sh  tcga2_pan_input1.txt
# metadata               tcga2_pan_input2.txt

# %%
INPUT='tcga2_pan_input1.txt'

cat $INPUT
# Out:
# TCGA-OR-A5J1-01A	TCGA-ACC	ca8350f6-113c-407f-8df4-bfe25cc11df8
# TCGA-OR-A5J2-01A	TCGA-ACC	ee0cc0fc-d7eb-436e-99b5-8fc2965cd970
# TCGA-OR-A5J3-01A	TCGA-ACC	ce4236e2-9d9a-4b69-a03d-5ecff849483f
# TCGA-OR-A5J5-01A	TCGA-ACC	1005028e-b7de-40c8-9e21-dbf16479754f
# TCGA-OR-A5J6-01A	TCGA-ACC	5062e501-4772-4af0-bef2-750e099b0e78
# TCGA-OR-A5J7-01A	TCGA-ACC	2adc136b-0500-4abe-b5e5-611d2bb28e38
# TCGA-OR-A5J8-01A	TCGA-ACC	bd2004e3-31de-483f-b26f-bd9c718e2e3b
# TCGA-OR-A5J9-01A	TCGA-ACC	d30db9ca-b2f0-472b-8985-661175b9d389
# TCGA-OR-A5JA-01A	TCGA-ACC	fab484b9-2ceb-42f8-a8d4-4308c674966e
# TCGA-OR-A5JB-01A	TCGA-ACC	eacd3a48-8056-479a-833f-3e9eaa7b2817
# TCGA-OR-A5JC-01A	TCGA-ACC	2adc7705-30d5-4871-a632-80d679670a1a
# TCGA-OR-A5JD-01A	TCGA-ACC	c797897c-a0df-475d-ba53-3327876e3a50
# TCGA-OR-A5JE-01A	TCGA-ACC	e855451a-901f-4916-90d6-e4b2d50cbf70
# TCGA-OR-A5JF-01A	TCGA-ACC	93bb0dca-ccb2-40ff-88aa-c4d74d1006eb
# TCGA-OR-A5JG-01A	TCGA-ACC	eecc212f-f502-4247-9230-93359af3a32e
# ...

# %%
INPUT2='tcga2_pan_input2.txt'

cat $INPUT2
# Out:
# TCGA-98-A53H-01A	TCGA-LUSC	e5dc1187-5622-443a-a70d-2de4e610dc6c
# TCGA-98-A53I-01A	TCGA-LUSC	36ce07c5-a22b-4d3c-af6f-91f70fb79705
# TCGA-98-A53J-01A	TCGA-LUSC	789ac3c2-411e-411d-888d-6934dd9d7c66
# TCGA-J1-A4AH-01A	TCGA-LUSC	e8c8e0d5-3b7a-4936-a06d-78fa1c9ebaf9
# TCGA-L3-A4E7-01A	TCGA-LUSC	430ab06d-aedc-41ba-a727-6667884bac56
# TCGA-L3-A524-01A	TCGA-LUSC	0b8bbd70-0f45-4d64-9db5-f1a3a6fcafdb
# TCGA-LA-A446-01A	TCGA-LUSC	f80de23f-8df9-4de1-b2c0-cbab7c579b51
# TCGA-LA-A7SW-01A	TCGA-LUSC	031c5b9b-9dcd-4d08-9291-5f1680558214
# TCGA-MF-A522-01A	TCGA-LUSC	3326ca7f-8518-4c81-b861-cc1a8fe461e4
# TCGA-NC-A5HD-01A	TCGA-LUSC	67d7c574-a3e8-47c7-885b-6fed92d0fcac
# TCGA-NC-A5HE-01A	TCGA-LUSC	66b757f5-36d4-48d2-a37b-a522423126e7
# TCGA-NC-A5HF-01A	TCGA-LUSC	b3ae5407-d5d4-4192-addb-b452b7b52842
# TCGA-NC-A5HG-01A	TCGA-LUSC	9f953a61-edc0-44f3-9881-fc4e016b7050
# TCGA-NC-A5HH-01A	TCGA-LUSC	0a8c5aba-01af-4ab2-85c8-4a6163b58f39
# TCGA-NC-A5HI-01A	TCGA-LUSC	ed63448c-0fa2-4377-9802-f10665d50766
# ...

# %% [markdown]
# #### 2 - Script Versions

# %%
cd $WORKDIR
# Echo scripts to be used for this analysis for version control.
# Note these need to be manually copied to the $WORKDIR

cat hgr1_align_v3.tcga.sh
echo 
echo
cat queenB.sh
echo 
echo
cat droneB.sh
echo 
echo
# Out:
# #!/bin/bash
# # hgr1_align_v3.tcga.sh
# # rDNA alignment pipeline
# PIPE_VERSION='190506 build -- TCGA'
# AMI_VERSION='crown-180813 - ami-0031fd61f932bdef9'
# # EC2: c4.2xlarge (8cpu / 15 gb)
# # EC2: c4.xlarge  (4cpu / 8  gb)
# # Storage: 200 Gb
# #
#
# # Input Requirements --------------------------
#
# # $1 : Library name and file-output name (unique)
# # $2 : Library population/analysis set
# # $3 : Library UUID
#
# # Control Panel -------------------------------
# # Amazon AWS S3 Home URL
#   S3URL='s3://crownproject/tcga2'
#
# # CPU
# 	THREADS='3'
#
# # Terminate instances upon completion (for debuggin)
#   TERMINATE='TRUE'
#
# # Sequencing Data
# 	LIBRARY=$1 # Library/ File name
#
# # TCGA FILE UUID
#   UUID=$3
#
#  # FastQ File-names
#     FQ0="$LIBRARY.tmp.sort.0.fq"
#     FQ1="$LIBRARY.tmp.sort.1.fq"
#     FQ2="$LIBRARY.tmp.sort.2.fq"
#
# # Read Group Data
# # Extract from downloaded BAM file / input
# 	RGPO=$2 # Patient Population
#
# 	#RGSM= # Sample. Patient Identifer
# ...

# %% [markdown]
# ## Results - TCGA2 Pilot Run

# %% [markdown]
# #### 3 - Copy local to S3

# %%
# Local Folder Operations -----------------------------
# LOCAL:
cd $WORKDIR

#NOTE For pilot run, AWS s3 shutdown commented out. Re-upload hgr1 script upon full run

aws s3 cp queenB.sh $S3URL/scripts/
aws s3 cp droneB.sh $S3URL/scripts/
aws s3 cp hgr1_align_v3.tcga.sh $S3URL/scripts/
aws s3 cp $INPUT $S3URL/scripts/
aws s3 cp $INPUT2 $S3URL/scripts/
aws s3 cp ../../gdc.token.txt $S3URL/scripts/gdc.token
# Out:
# upload: ./queenB.sh to s3://crownproject/tcga2/scripts/queenB.sh
# upload: ./droneB.sh to s3://crownproject/tcga2/scripts/droneB.sh
# upload: ./hgr1_align_v3.tcga.sh to s3://crownproject/tcga2/scripts/hgr1_align_v3.tcga.sh
# upload: ./tcga2_pan_input1.txt to s3://crownproject/tcga2/scripts/tcga2_pan_input1.txt
# upload: ./tcga2_pan_input2.txt to s3://crownproject/tcga2/scripts/tcga2_pan_input2.txt
# upload: ../../gdc.token.txt to s3://crownproject/tcga2/scripts/gdc.token

# %% [markdown]
# #### 4 - Launch and run master EC2 node

# %%
# Remote EC2 Instance Operations ----------------------

# QUEEN BEE 1
# Instance ID: i-0f74a2d0a41c64e45
# ec2-user@ec2-34-217-67-161.us-west-2.compute.amazonaws.com
# input 1

# Remote:
# Manually open an Amazon Linux 2 AMI
# ami-061392db613a6357b
# t2.micro
#
# ssh login:
# ssh -i "crown.pem" ec2-user@PUBLICDNS
#

# Commands on EC2 machine to set-up AWS
# enter personal login info:

# REMOTE:
#aws configure
  # AWS Key ID
  # AWS Secret Key ID
  # Region: us-west-2
  
# Copy local run files to S3 and download them on EC2

# REMOTE:
# aws s3 cp --recursive s3://crownproject/tcga2/scripts/ ./
#
# mv <KEY>.pem ~/.ssh/
# chmod 400 ~/.ssh/<KEY>.pem

# REMOTE:
# Open logging screen and being launchign EC2 instances
# screen -L
# 
# bash queenB.sh tcga2_pan_input1.txt
#
# aws s3 cp screenlog.0 s3://crownproject/tcga2/logs/tcga2_pan_1.log
#

aws s3 cp s3://crownproject/tcga2/logs/tcga2_pan_1.log ./
head -n100 tcga2_pan_1.log #cannot load entire file to jupyter
# Out:
# download: s3://crownproject/tcga2/logs/tcga2_pan_1.log to ./tcga2_pan_1.log
# kec2-user@ip-172-31-31-231:~\[ec2-user@ip-172-31-31-231 ~]$ ls
# CrownKey.pem  gdc.token		     queenB.sh	  tcga2_pan_input1.txt
# droneB.sh     hgr1_align_v3.tcga.sh  screenlog.0
# kec2-user@ip-172-31-31-231:~\[ec2-user@ip-172-31-31-231 ~]$ bash queenB.sh tcga2_pan_input1.txt
# Launch instance # 1
# Fri May 10 16:07:08 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga2/scripts/hgr1_align_v3.tcga.sh
# Parameters: TCGA-OR-A5J1-01A TCGA-ACC ca8350f6-113c-407f-8df4-bfe25cc11df8
# Instance ID: i-021bca53556fc1600
# Public DNS: ec2-34-218-226-241.us-west-2.compute.amazonaws.com
# ...
# download: s3://crownproject/tcga2/scripts/hgr1_align_v3.tcga.sh to ./hgr1_align_v3.tcga.sh
#
#
# Launch instance # 2
# Fri May 10 16:10:18 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga2/scripts/hgr1_align_v3.tcga.sh
# ...

# %%
# Remote EC2 Instance Operations ----------------------

# QUEEN BEE 2
# Instance ID: i-05fc4b0d63f87157d
# ec2-user@ec2-34-209-196-15.us-west-2.compute.amazonaws.com
# input 2

# Remote:
# Manually open an Amazon Linux 2 AMI
# ami-061392db613a6357b
# t2.micro
#
# ssh login:
# ssh -i "crown.pem" ec2-user@PUBLICDNS
#

# Commands on EC2 machine to set-up AWS
# enter personal login info:

# REMOTE:
#aws configure
  # AWS Key ID
  # AWS Secret Key ID
  # Region: us-west-2
  
# Copy local run files to S3 and download them on EC2

# REMOTE:
# aws s3 cp --recursive s3://crownproject/tcga2/scripts/ ./
#
# mv <KEY>.pem ~/.ssh/
# chmod 400 ~/.ssh/<KEY>.pem

# REMOTE:
# Open logging screen and being launchign EC2 instances
# screen -L
# 
# bash queenB.sh tcga2_pan_input2.txt
#
# aws s3 cp screenlog.0 s3://crownproject/tcga2/logs/tcga2_pan_2.log
#

aws s3 cp s3://crownproject/tcga2/logs/tcga2_pan_2.log ./
head -n100 tcga2_pan_2.log
# Out:
# download: s3://crownproject/tcga2/logs/tcga2_pan_2.log to ./tcga2_pan_2.log
# kec2-user@ip-172-31-17-64:~\[ec2-user@ip-172-31-17-64 ~]$ ls
# CrownKey.pem  gdc.token		     queenB.sh	  tcga2_pan_input2.txt
# droneB.sh     hgr1_align_v3.tcga.sh  screenlog.0
# 2.txt
# Launch instance # 1
# Fri May 10 16:07:36 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga2/scripts/hgr1_align_v3.tcga.sh
# Parameters: TCGA-98-A53H-01A TCGA-LUSC e5dc1187-5622-443a-a70d-2de4e610dc6c
# Instance ID: i-000e343ad2b6b89a5
# Public DNS: ec2-35-166-34-32.us-west-2.compute.amazonaws.com
# ...
# download: s3://crownproject/tcga2/scripts/hgr1_align_v3.tcga.sh to ./hgr1_align_v3.tcga.sh
#
#
# Launch instance # 2
# Fri May 10 16:10:42 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga2/scripts/hgr1_align_v3.tcga.sh
# Parameters: TCGA-98-A53I-01A TCGA-LUSC 36ce07c5-a22b-4d3c-af6f-91f70fb79705
# ...

# %% [markdown]
# ## Discussion

# %% [markdown]
# ### Time Logs

# %% [markdown]
# **Start time** (EC2 Local): `Fri May 10 16:07:08 UTC 2019`
#
# ```
# Launch instance # 100
# Fri May 10 21:22:33 UTC 2019
# ```
# **5h 15m** or 200 samples into the run the total number of instances is reaching an equilibrium at ~45 concurrent runs. Could probably have used 3 or 4 head nodes to reach 95 node peak. Estimate is 9.5 days to complete alignments. GG
#
# ```
# Launch instance # 149
# Fri May 10 23:55:21 UTC 2019
# ```
# **7h 45m**. 58 instances running. 3.7% Complete. ETA: 201h
#
# ```
# Launch instance # 1370
# Mon May 13 16:45:45 UTC 2019
# ...
# Parameters: TCGA-CV-6935-01A TCGA-HNSC 9913f41d-5376-4f18-97f9-909f4b3a90da
# ```
# **72 hours** in. 1370/4000 runs launched. 34.3% complete. ETA: 153h
#
# ```
# Launch instance # 1483
# Mon May 13 22:37:57 UTC 2019
# ...
# Parameters: TCGA-F7-A50J-01A TCGA-HNSC a44e03d6-5798-427f-a7e2-40bcc1424a7b
# ```
# **76 hours**
#
# ```
# Launch instance # 1832
# Tue May 14 16:58:43 UTC 2019
# Parameters: TCGA-B8-4148-01A TCGA-KIRC 9abaf062-b5cd-41b1-bd3e-01fd002c5b8b
# ```
# **96 hours** in. 1832/4000 launched. Cohorts complete: COAD, BRCA, and ACC, BLCA, CESC, CHOL, ESCA, GBM, HNSC, and MESO, OV, PAAD, PCPG, PRAD, READ, SARC.
#
# ```
# Launch instance # 2254
# Wed May 15 15:13:04 UTC 2019
# Parameters: TCGA-G7-6789-01A TCGA-KIRP fba2dd37-f1ca-44e1-8405-a3696d72b25f
# ```
# **119 hours** in. 2254/4000. approx 1,971 in computing credits.
#
# ```
# Launch instance # 2711
# Thu May 16 15:57:26 UTC 2019
# Parameters: TCGA-HW-7491-01A TCGA-LGG deb7d0a3-9ace-46fb-a421-155c03311efd
# ```
# **144 hours** in. 2711/4000. KICH, KIRK, KIRP and SKCM, STAD, TGCT cohorts complete.
#
# ```
# Launch instance # 3158
# Fri May 17 15:29:56 UTC 2019
# Parameters: TCGA-KR-A7K7-01A TCGA-LIHC ccd7cefc-e15e-4cf5-880b-816e28728a44
# ```
# **168 hours** in. 3158/4000 or 78.95% complete. 3,093 credits.
#
# ```
# Launch instance # 3667
# Sat May 18 18:11:26 UTC 2019
# Parameters: TCGA-MP-A4T9-01A TCGA-LUAD 466eace8-ca6f-4eb9-919f-94858c2fe700
# ```
# **192 hours** in. Probably one more day for this.
# ```
# Launch instance # 4066
# Sun May 19 15:12:19 UTC 2019
# Parameters: TCGA-90-7769-01A TCGA-LUSC 81b0690e-a797-4210-83c9-99ca2a9d20bf
# ```
# **215 hours** in. 4066/4100 to be exact (4114 on node 2). It's happening!!
#
# ```
# Launch instance # 4100
# Sun May 19 16:58:18 UTC 2019
# Parameters: TCGA-98-A53D-01A TCGA-LUSC 0ca15ae4-f70a-4af2-b201-0719b708b4b8
# ```
# **217 hours** or 9 days 1 hour in. Final instance was launched on node-set 1.
# ```
# Launch instance # 4114
# Sun May 19 17:38:47 UTC 2019
# Parameters: TCGA-YZ-A985-01A TCGA-UVM 6cdc52fd-37b5-4447-9b1f-5badd4ea4d0f
# ```
#
# ** RUN COMPLETE **

# %% [markdown]
# ### Errors / Debugging

# %% [markdown]
# #### EC2 instance error
#
# Following node did not pass 'status check on ec2'. I cannot SSH into the node manually. Will cancel and re-run. Modified `queenB.sh` script (`:%s/\.tmp/\.tmp2/g`) to make `.tmp2` temp files (no collision).
#
# ERROR INSTANCE:
# ```
# Launch instance # 42
# Fri May 10 18:24:32 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga2/scripts/hgr1_align_v3.tcga.sh
# Parameters: TCGA-3H-AB3S-01A TCGA-MESO 87bfb031-132a-4598-a32b-f4ea7fe4d14a
# Instance ID: i-03e5cda2edc65c447
# Public DNS: ec2-34-211-200-201.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-211-200-201.us-west-2.compute.amazonaws.com,172.31.23.219' (ECDSA) to the list of known hosts.^M
# download: s3://crownproject/tcga2/scripts/hgr1_align_v3.tcga.sh to ./hgr1_align_v3.tcga.sh
# ```
# RERUN OUTPUT:
# ```
# Launch instance # 1
# Sat May 11 00:11:41 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga2/scripts/hgr1_align_v3.tcga.sh
# Parameters: TCGA-3H-AB3S-01A TCGA-MESO 87bfb031-132a-4598-a32b-f4ea7fe4d14a
# Instance ID: i-0d82fd9ed4e763a69
# Public DNS: ec2-54-188-26-126.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-188-26-126.us-west-2.compute.amazonaws.com,172.31.24.109' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga2/scripts/hgr1_align_v3.tcga.sh to ./hgr1_align_v3.tcga.sh
# ```
#
# #### Error Download
# One node which was up for 12 hours was checked out manually. Pipeline froze on GDC download.
# On the same node I'm re-starting the script. Node: `ec2-52-12-77-174.us-west-2.compute.amazonaws.com`
#
# Error:
# ```
# -- hgr1 Alignment Pipeline --
#  version: 190506 build -- TCGA
#  ami:     crown-180813 - ami-0031fd61f932bdef9
#  s3:      s3://crownproject/tcga2
#  library: TCGA-BK-A6W3-01A
#  date:    Sat May 18 21:39:46 UTC 2019
#
# Initializing ...
# download: s3://crownproject/tcga2/scripts/gdc.token to ./gdc.token
# Download BAM file: 049d66a0-8e21-4ef1-a861-1c17fba9bf59
#  92% [##########################################    ] ETA:  0ERROR: Max retries exceeded.
# ```
#
# Restart script:
# ```
# screen -L
# bash hgr1_align_v3.tcga.sh TCGA-BK-A6W3-01A TCGA-UCEC 049d66a0-8e21-4ef1-a861-1c17fba9bf59
# ```
#
#
# #### Local backup
#
# On a CRC computer, I am downloading all of `s3://crownproject/tcga` and `s3://crownproject/tcga2/` to a local hard drive for accessing the bam files in IGV more quickly.

# %% [markdown]
# ### TCGA2 Filelist
#
# Upon last instance completion, download a file inventory of TCGA2 folder.

# %%
cd $WORKDIR
aws s3 ls --summarize --human-readable --recursive s3://crownproject/tcga2/ > tcga2.filelist

# %%
grep -e '.bam$' tcga2.filelist | wc -l -
# Out:
# 9637 -

# %% [markdown]
# #### Missing BAM Files from this analysis
#
# ```
# TCGA-CV-6956-01A	TCGA-HNSC	eb068595-b56a-4bff-a6fd-0027caa5c44b
# TCGA-24-2262-01A	TCGA-OV	397df160-9ae2-4311-a58f-f2e7327d9856
# ```
#
# Make a `tcga2.cleanup.input` file on node 1 and re-launch these two files. REMOTE: `bash queenB.sh tcga2.cleanup.input`.

# %%
cd $WORKDIR

aws s3 cp s3://crownproject/tcga2/logs/TCGA-CV-6956-01A.screenlog ./
cat TCGA-CV-6956-01A.screenlog
echo =================================================
aws s3 cp s3://crownproject/tcga2/logs/TCGA-24-2262-01A.screenlog ./
cat TCGA-CV-6956-01A.screenlog
# Out:
# download: s3://crownproject/tcga2/logs/TCGA-CV-6956-01A.screenlog to ./TCGA-CV-6956-01A.screenlog
#  -- hgr1 Alignment Pipeline --
#  version: 190506 build -- TCGA
#  ami:     crown-180813 - ami-0031fd61f932bdef9
#  s3:      s3://crownproject/tcga2
#  library: TCGA-CV-6956-01A
#  date:    Mon May 13 17:29:19 UTC 2019
#
# Initializing ...
# download: s3://crownproject/tcga2/scripts/gdc.token to ./gdc.token
# Download BAM file: eb068595-b56a-4bff-a6fd-0027caa5c44b
# 100% [##############################################] Time: 0:04:37  27.27 MB/s
# 100% [##############################################] Time: 0:00:01   3.90 MB/s
# Successfully downloaded: 1
#  Convert BAM file to fastq file
# ...
# download: s3://crownproject/tcga2/logs/TCGA-24-2262-01A.screenlog to ./TCGA-24-2262-01A.screenlog
#  -- hgr1 Alignment Pipeline --
#  version: 190506 build -- TCGA
#  ami:     crown-180813 - ami-0031fd61f932bdef9
#  s3:      s3://crownproject/tcga2
#  library: TCGA-CV-6956-01A
# ...

# %% [markdown]
# ```
# [ec2-user@ip-172-31-31-231 ~] bash queenB.sh tcga2.cleanup.input
# Launch instance # 1
# Sun May 19 20:41:10 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga2/scripts/hgr1_align_v3.tcga.sh
# Parameters: TCGA-CV-6956-01A TCGA-HNSC eb068595-b56a-4bff-a6fd-0027caa5c44b
# Instance ID: i-02d3fd18df314a79c
# Public DNS: ec2-34-222-152-34.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-222-152-34.us-west-2.compute.amazonaws.com' (ECDSA) to the list of known hosts.
# Warning: the ECDSA host key for 'ec2-34-222-152-34.us-west-2.compute.amazonaws.com' differs from the key for the IP address '172.31.21.90'
# Offending key for IP in /home/ec2-user/.ssh/known_hosts:1445
# download: s3://crownproject/tcga2/scripts/hgr1_align_v3.tcga.sh to ./hgr1_align_v3.tcga.sh
#
#
# Launch instance # 2
# Sun May 19 20:44:18 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga2/scripts/hgr1_align_v3.tcga.sh
# Parameters: TCGA-24-2262-01A TCGA-OV 397df160-9ae2-4311-a58f-f2e7327d9856
# Instance ID: i-01c39ab3c539de958
# Public DNS: ec2-35-162-166-198.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-162-166-198.us-west-2.compute.amazonaws.com' (ECDSA) to the list of known hosts.
# Warning: the ECDSA host key for 'ec2-35-162-166-198.us-west-2.compute.amazonaws.com' differs from the key for the IP address '172.31.19.202'
# Offending key for IP in /home/ec2-user/.ssh/known_hosts:466
# download: s3://crownproject/tcga2/scripts/hgr1_align_v3.tcga.sh to ./hgr1_align_v3.tcga.sh
#
# ```
#
# Upon completion, re-download TCGA2 filelist (overwrite).
#
# ... didn't work. Just drop these two libraries.

# %%
cd $WORKDIR

aws s3 cp s3://crownproject/tcga2/logs/TCGA-CV-6956-01A.screenlog ./
cat TCGA-CV-6956-01A.screenlog
echo =================================================
aws s3 cp s3://crownproject/tcga2/logs/TCGA-24-2262-01A.screenlog ./
cat TCGA-CV-6956-01A.screenlog
# Out:
# download: s3://crownproject/tcga2/logs/TCGA-CV-6956-01A.screenlog to ./TCGA-CV-6956-01A.screenlog
#  -- hgr1 Alignment Pipeline --
#  version: 190506 build -- TCGA
#  ami:     crown-180813 - ami-0031fd61f932bdef9
#  s3:      s3://crownproject/tcga2
#  library: TCGA-CV-6956-01A
#  date:    Sun May 19 20:44:17 UTC 2019
#
# Initializing ...
# download: s3://crownproject/tcga2/scripts/gdc.token to ./gdc.token
# Download BAM file: eb068595-b56a-4bff-a6fd-0027caa5c44b
# 100% [##################################################################] Time: 0:06:14  20.22 MB/s
# 100% [##################################################################] Time: 0:00:01   4.17 MB/s
# Successfully downloaded: 1
#  Convert BAM file to fastq file
# ...
# download: s3://crownproject/tcga2/logs/TCGA-24-2262-01A.screenlog to ./TCGA-24-2262-01A.screenlog
#  -- hgr1 Alignment Pipeline --
#  version: 190506 build -- TCGA
#  ami:     crown-180813 - ami-0031fd61f932bdef9
#  s3:      s3://crownproject/tcga2
# ...
