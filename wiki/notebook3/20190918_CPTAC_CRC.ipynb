# %% [markdown]
# # CPTAC - CRC Cohort 5 2019
# ```
# pi:ababaian
# files: ~/Crown/data2/crc_cptac/
# start: 2019 05 28
# complete : 2019 06 02
# ```
# ## Introduction
#
# This year a new CRC cohort of ~110 patients was released, there is matched RNA-seq, Exome-seq and Proteomics for this cohort. Unfortunately there is no normal control RNA-seq but if we take a leap of faith that the other 30+ cohorts are representative, then we can allow for the assumption that the normals are normal here too.
#
# I've also recieved $$ from AWS again so it's time to spool up this analysis.
#
# ## Addendum -- remainder of CPTAC
#
# After completing this experiment (only 66 CRC were available) there are an additional 168 tumour RNA-seq available in CPTAC from breast, lung and ovarian cancers. Run them for completion.

# %%
# Initialize
WORKDIR='/home/artem/Crown/data2/crc_cptac'
mkdir -p $WORKDIR; cd $WORKDIR

# %% [markdown]
# ## Objective
#
# 1. Pilot: Align 5x CRC5 RNA-seq libraries to hgr1. Confirm OK.
# 2. Full : Align remaining 105x CRC5 libraries to hgr1

# %% [markdown]
# ## Materials and Methods

# %% [markdown]
# ### Data Initialization

# %% [markdown]
# From the SRA website, the CPTAC Confirmatory Study project was found (not referenced in paper!) [BioProject:
# PRJNA279695](https://www.ncbi.nlm.nih.gov/bioproject/PRJNA279695/), this includes breast, ovarian and colorectal cancer samples. Loaded all data into SRA table viewer, downloaded accession files. Filtered for RNA-seq and CRC yielding 110 samples.
#
# The output of this parsing is copied to the input file: `cptac_pilot.input`
#
# Input columns are (see below):
#
# 1. Library Name
# 2. Data Type
# 3. Sample ID
# 4. SRA Accesion
# 5. Experiment Accession

# %% [markdown]
# ### Scripts and Localization

# %% [markdown]
# #### 1 - Localization

# %%
WORKDIR='/home/artem/Crown/data2/crc_cptac'
cd $WORKDIR
ls

# Amazon AWS S3 Home URL
S3URL='s3://crownproject/cptac'
# Out:
# CPTAC_conf_study_SraRunTable.xlsx
# cptac_pilot0.input
# cptac_pilot2.input
# dbgap.key
# droneB.sh
# hgr1_align_v4.cptac.sh
# Human__CPTAC_COAD__PNNL__Proteome__TMT__03_01_2017__BCM__Gene__PNNL_Tumor_TMT_UnsharedLogRatio.cct
# input
# meta
# paper
# queenB.sh
# tcga_proteomics

# %%
INPUT='cptac_pilot0.input'
# Note the different column requirements from CCLE

cat $INPUT
# Out:
# 01CO001	crc5	SAMN03453626	SRR1999563	SRX1011590
# 01CO005	crc5	SAMN03453627	SRR1999549	SRX1011576

# %% [markdown]
# #### 2 - Script Versions

# %%
cd $WORKDIR
# Echo scripts to be used for this analysis for version control.
# Note these need to be manually copied to the $WORKDIR

cat hgr1_align_v4.cptac.sh
echo 
echo
cat queenB.sh
echo 
echo
cat droneB.sh
echo 
echo
# Out:
# #!/bin/bash
# # hgr1_align_v4.ccle.sh
# # rDNA alignment pipeline - SRA version
# PIPE_VERSION='191003 build -- CPTAC'
# AMI_VERSION='crown-190601 - ami-0b375c9c58cb4a7a2'
# # EC2: c4.2xlarge (8cpu / 15 gb)
# # EC2: c4.xlarge  (4cpu / 8  gb)
# # Storage: 200 Gb
# #
#
# # Input Requirements --------------------------
#
# # $1 : Library name + Output name(unique)
# # $2 : Seq-read type (wgs|rna)
# # $3 : BioSample ID
# # $4 : Library SRA Accession
#
# # Control Panel -------------------------------
# # Amazon AWS S3 Home URL
#   S3URL='s3://crownproject/cptac'
#
# # CPU
# 	THREADS='3'
#
# # Terminate instances upon completion (for debuggin)
#   TERMINATE='FALSE'
#
# # Read Group Data
#   LIBRARY=$1    # Library Name / File prefix / patient ID
#   TYPE=$2       # wgs OR rna data-type (using crc5 here)
# 	RGPO='cptac-crc'  # Patient Population - CPTAC
# 	RGSM=$3       # Sample ID
# 	RGID=$4       # Read Group ID. SRA Accession Number
#   RGLB=$LIBRARY # Library Name. Accession Number
#   RGPL='ILLUMINA'   # Seq Platform
#   RGPU=$5       # Read Group. Platform Unit (SRA Experiment)
#
#   SRA=$4
#   OUTPUT="$LIBRARY.$TYPE" # Output filename
#
#   # Fastq files from fastq-dump
#   # FQ1=<SRR>_1.fastq.gz
#   # FQ2=<SRR>_2.fastq.gz
#
# echo " -- hgr1 Alignment Pipeline -- "
# echo " version: $PIPE_VERSION "
# echo " ami:     $AMI_VERSION  "
# echo " s3:      $S3URL  "
# echo " library: $LIBRARY -- $TYPE"
# echo " date:    $(date)"
# echo ''
#
# # Initialize wordir ---------------------------
# echo 'Initializing ...'
#
# # Make working directory
# mkdir -p align; cd align
#
# # Copy hgrX genome and create bowtie2 index
# cp ~/resources/hgr1/* ./
#
# # GDC --- Load updated GDC token to instance
# #  aws s3 cp $S3URL/scripts/gdc.token gdc.token
# #  chmod 600 gdc.token
#
# # dbGAP --- Download dbGAP access key to instance
#   cd ~/ncbi/
#   aws s3 cp $S3URL/scripts/dbgap.key dbgap.key
#   $HOME/bin/vdb-config --import dbgap.key
#   cd dbGaP*
#
#   echo "Download SRA file: $SRA"
#   echo "  cmd: prefetch -X 200G --ascp-path <PATH> $SRA"
#
#   $HOME/bin/prefetch -X 200G --ascp-path \
#     "$HOME/.aspera/connect/bin/ascp|$HOME/.aspera/connect/etc/asperaweb_id_dsa.openssh"\
#     $SRA
#
#   $HOME/bin/fastq-dump --split-3 --gzip $SRA
#
#   FQ1=$(ls *_1*)
#   FQ2=$(ls *_2*)
#
#   mv *.gz ~/align/
#   cd ~/align
#
# # SRA -- no additional resources needed
#
# # SRA INPUT ====================================================
# cd ~/align
#
# #if [ -s $FQ1 ]
# #then
#     echo "SRA Input Pipe"
#     echo ''
#     echo "Starting hgr1 alignment"
#     # Paired-End Extracted Reads Alignment
#
#     echo "~/bin/bowtie2 --very-sensitive-local -p $THREADS \
#       --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \
#       --rg PL:$RGPL --rg PU:$RGPU \
#       -x hgr1 --sra-acc $SRA | \
#       ~/bin/samtools view -bS - > aligned_unsorted.bam"
#
#     # Bowtie2: align to genome
#     ~/bin/bowtie2 --very-sensitive-local -p $THREADS \
#       --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \
#       --rg PL:$RGPL --rg PU:$RGPU \
#       -x hgr1 -1 $FQ1 -2 $FQ2 | \
#       ~/bin/samtools view -bS - > aligned_unsorted.bam
#
#     echo "Alignment complete."
#     echo "Calculate flagstats."
#
#     # Calcualte library flagstats
#       ~/bin/samtools flagstat aligned_unsorted.bam > aligned_unsorted.flagstat
#
#     # Read Subset ------------------------------
#     echo "Subset reads (retain mapped & their pairs, remove unmapped)."
#
#     # Extract mapped reads, and their unmapped pairs
#
#       # Extract Header
#       ~/bin/samtools view -H aligned_unsorted.bam > align.header.tmp
#
#       # Unmapped reads with mapped pairs
#       # Extract Mapped Reads
#       # and their unmapped pairs
#       ~/bin/samtools view -b -F 4 aligned_unsorted.bam > align.F4.bam #mapped
#       ~/bin/samtools view -b -f 4 -F 8 aligned_unsorted.bam > align.f4F8.bam #unmapped pairs
#
#       echo "Recompiling mapped bam file."
#
#       # Re-compile bam file
#       ~/bin/samtools cat -h align.header.tmp -o align.hgr1.tmp.bam align.F4.bam align.f4F8.bam
#         ~/bin/samtools sort -@ $THREADS -O BAM align.hgr1.tmp.bam > align.hgr1.bam
#         ~/bin/samtools index align.hgr1.bam
#         ~/bin/samtools flagstat align.hgr1.bam > align.hgr1.flagstat
#
#       # Clean up
#       rm *tmp* align.F4.bam align.f4F8.bam
#
#     echo "Processing complete. Copy files to S3"
#     # Rename the total Bam Files
#       mv aligned_unsorted.bam $OUTPUT.bam
#       #mv aligned_unsorted.bam.bai $OUTPUT.bam.bai
#       mv aligned_unsorted.flagstat $OUTPUT.flagstat
#
#     # Rename the hgr-aligned Bam files
#       mv align.hgr1.bam $OUTPUT.hgr1.bam
#       mv align.hgr1.bam.bai $OUTPUT.hgr1.bam.bai
#       mv align.hgr1.flagstat $OUTPUT.hgr1.flagstat
#
#     # Copy output to AWS S3
#     # Alignments (Full)
#       aws s3 cp $OUTPUT.flagstat $S3URL/hgr1/
#
#     # Alignments (Aligned)
#       aws s3 cp $OUTPUT.hgr1.bam $S3URL/hgr1/
#       aws s3 cp $OUTPUT.hgr1.bam.bai $S3URL/hgr1/
#       aws s3 cp $OUTPUT.hgr1.flagstat $S3URL/hgr1/
#
# #fi
#
# echo "Create log files and copy to S3"
# # Copy screen log file to AWS S3
# cp ~/screenlog.0 ./$OUTPUT.screenlog
# aws s3 cp $OUTPUT.screenlog $S3URL/logs/
#
# # Shutdown and Terminate instance
# EC2ID=$(ec2metadata --instance-id)
# sleep 20s # to catch errors
#
# if [ "$TERMINATE" = TRUE ]
# then
#   echo "Run Complete -- Shutting down instance."
#   aws ec2 terminate-instances --instance-ids $EC2ID
# else
#   echo "Run Complete -- Instance is online."
# fi
#
# # Script complete
#
#
# #!/bin/bash
# # queenB.sh
# # 20180814 build
# # EC2 Launch / Control Script
# #
#
# # 1. queenB script is initialized locally and input files
# #    are parsed ready for cluster analaysis
# # 2. queenB launches instances, logs in to it and runs the
# #    droneB.sh script remotely.
# # 3. The droneB script is executed on the instance and it
# #    launches a `screen` on the instance and loads and
# #    starts to perform the $TASK (gather.sh) script.
# # 4. TASK script should include a instance shut-down
# #    command to close instance upon completion.
# #
#
# # Control Panel =========================
# # Amazon AWS S3 Home URL
# S3URL='s3://crownproject/cptac'
#
# # EC2 TASK Script - script for droneB to execute
# TASK="$S3URL/scripts/hgr1_align_v4.cptac.sh"
#
# # Parameter file:
# # Each line of PARAMETERS will be input to STDIN of
# # the droneB script which can then be used to run the
# # TASK script.
# # i.e. bash droneB.sh <line_N_of_PARAMETERS>
# # PARAMETERS="tcga0_input.txt"
# PARAMETERS=$1
#
# # EC2 Set-up
# instanceTYPE='c4.xlarge'
# imageID='ami-0b375c9c58cb4a7a2' #AMI Crown CCLE/SRA
#
# devNAME='/dev/sda1' # /dev/sda1 for Crown-AMI
# volSIZE='300' # in Gb
#
# # Maximum number of EC2 instances to run simultaniously
# MAX_INSTANCE='45'
#
# # Number of instances to launch
# #COUNT=2 # predetermined number
# COUNT=$(awk 'END{print NR}' $PARAMETERS) # for each input argument
#
# # Security
# keyNAME='CrownKey'
# keyPATH="/home/ec2-user/.ssh/CrownKey.pem"
# secGROUP='crown-group'
#
# # Input Validation ======================
# # Test input file for duplicate sample ID (which will cause file collisions downstream)
# # exit with error 1 if collision exists
#
# SAMPLEIDS=$(cut -f1 $1 | uniq -d )
#
# if [ -n "$SAMPLEIDS" ]
# then
#   # If there are duplicate sample IDs exit
#   echo "Error 02 - Duplicate Sample ID detected in input"
#   echo " I hope you know what you're doing"
#   echo " script will not exit in this version"
#   echo " re-run with unique ID or outputs will overwrite"
#   echo ""
#   #echo "$SAMPLEIDS"
#   #exit 2
# fi
#
# # Script Core ===========================
#
# for ITER in $(seq 1 $COUNT)
# do
#
#   # Count the total number of instances
#   running_instance=$(aws ec2 describe-instances |\
#     grep '"Name": "running"' - |\
#     wc -l - | cut -f1 -d' ' - )
#
#   while [ $running_instance -ge $MAX_INSTANCE ];
#   do
#
#   	echo "Reached max of $running_instance, wait."
#   	echo ''
#
#   	# If there are greater then 25 instances
#   	# wait for instance to close
#   	sleep 5m
#
#   	running_instance=$(aws ec2 describe-instances |\
#     grep '"Name": "running"' - |\
#     wc -l - | cut -f1 -d' ' - )
#   done
#
#   # Extract Parameters/Arguments ----------
#
#   ARGS=$(sed -n "$ITER"p $PARAMETERS | sed 's/\t/ /g' - )
#
#   echo "Launch instance # $ITER"
#   date
#   echo "Instance Type: $instanceTYPE"
#   echo "AMI Image: $imageID"
#   echo "Run Script: $TASK"
#   echo "Parameters: $ARGS"
#
#   # Launch an instance --------------------
#   # NOTE: each iteration of the for loop launches one instance
#   # therefore each loop launches only one instance
#   aws ec2 run-instances --image-id $imageID --count 1 \
#    --instance-type $instanceTYPE --key-name $keyNAME \
#    --block-device-mappings DeviceName=$devNAME,Ebs={VolumeSize=$volSIZE} \
#    --security-groups $secGROUP > launch.tmp
#
#   # Another alternative is to use --user-data droneB.sh
#   # which will run at instance boot-up
#   # passing arguments to it may be challenging
#
#   # Retrieve instance ID
#   instanceID=$(cat launch.tmp | \
#     egrep -o -e 'InstanceId[":/A-Za-z0-9_ \\-]*' - |\
#     cut -f2 -d' ' - | xargs)
#
#   echo "Instance ID: $instanceID"
#
#
#   # Add a few minute wait here to allow for Public DNS to be assigned
#   # otherwise ssh doesn't work
#   # CURRENT BOTTLENECK
#   sleep 180s
#
#   # Check that the instance is 'running' and not pending
#   pending_instance=$(aws ec2 describe-instances |\
#    grep '"Name": "pending"' - |\
#    wc -l - | cut -f1 -d' ' - )
#
#   while [ $pending_instance -gt 0 ];
#   do
#
#   	echo "Launchign instance not ready yet, chill"
#   	# Instance still pending
#   	sleep 180s
#
#     pending_instance=$(aws ec2 describe-instances |\
#      grep '"Name": "pending"' - |\
#      wc -l - | cut -f1 -d' ' - )
#   done
#
#
#   # Retrieve public DNS
#   aws ec2 describe-instances --instance-ids $instanceID > launch2.tmp
#
#   pubDNS=$(cat launch2.tmp | \
#     egrep -o -m 1 -e 'PublicDnsName[.":/A-Za-z0-9_ \\-]*' - |\
#     cut -f2 -d' ' - | xargs)
#
#   echo "Public DNS: $pubDNS"
#
#   # Access the instance -------------------
#
#   LOGIN="ubuntu@$pubDNS"
#
#   ssh -i $keyPATH \
#     -o StrictHostKeyChecking=no \
#     $LOGIN 'bash -s' < droneB.sh $TASK $(echo $ARGS)
#
#   # Cleanup
#   rm *.tmp
#
#   echo ''
#   echo ''
#
# done
#
# # end of script
#
# #!/bin/bash
# # droneB.sh
# #
#
# # This script-layer is neccesary to launch a screen session
# # on each ec2-machine. The pipeline is run within that session
# # and the output is logged. This allows 'looking in' on sessions
# # as they are running.
#
# # Commands to run on server-side
# # ===============================================================
#
# SCRIPTPATH=$1
#
# SCRIPT=$(basename $1)
#
# shift # drop first (TASK or SCRIPT variable)
#
# # Download pipeline / droneB's function
#   aws s3 cp $SCRIPTPATH ./
#
#   chmod 777 *.sh
#
# # open screen; run gather.sh function. -L logged
#   screen -Ldmt sh ~/$SCRIPT $@
#
#
# # ===============================================================

# %% [markdown]
# ## Results - CCLE Pilot Run I

# %% [markdown]
# #### 3 - Copy local to S3

# %%
# Local Folder Operations -----------------------------
# LOCAL:
cd $WORKDIR

#NOTE For pilot run, AWS s3 shutdown commented out. Re-upload hgr1 script upon full run

aws s3 cp queenB.sh $S3URL/scripts/
aws s3 cp droneB.sh $S3URL/scripts/
aws s3 cp hgr1_align_v4.cptac.sh $S3URL/scripts/
aws s3 cp $INPUT $S3URL/scripts/
aws s3 cp dbgap.key $S3URL/scripts/
# Out:
# upload: ./queenB.sh to s3://crownproject/cptac/scripts/queenB.sh
# upload: ./droneB.sh to s3://crownproject/cptac/scripts/droneB.sh
# upload: ./hgr1_align_v4.cptac.sh to s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# upload: ./cptac_pilot0.input to s3://crownproject/cptac/scripts/cptac_pilot0.input
# upload: ./dbgap.key to s3://crownproject/cptac/scripts/dbgap.key

# %%
# start
date
date -u
# Out:
# Thu Oct  3 09:47:47 PDT 2019
# Thu Oct  3 16:47:47 UTC 2019

# %% [markdown]
# #### 4 - Launch and run master EC2 node

# %% [markdown]
# ### Note: 20190919
#
# There is an error in running this analysis. 1) This data is restricted in dbGAP, and while we have access to one CPTAC data set (which looks to be consent forms), I didn't request acess to this cohort (phs000892.v6.p1).
#
# : / fuck
#
# By 20191003 I have access sorted out. Resume

# %%
# Remote EC2 Instance Operations ----------------------

# Remote:
# Manually open an Amazon Linux 2 AMI
# ami-061392db613a6357b
# t2.micro
#
# ssh login:
# ssh -i "crown.pem" ec2-user@PUBLICDNS
#

# Commands on EC2 machine to set-up AWS
# enter personal login info:

# REMOTE:
#aws configure
  # AWS Key ID
  # AWS Secret Key ID
  # Region: us-west-2
  
# Copy local run files to S3 and download them on EC2

# REMOTE:
# aws s3 cp --recursive s3://crownproject/cptac/scripts/ ./
#
# mv <KEY>.pem ~/.ssh/
# chmod 400 ~/.ssh/<KEY>.pem

# REMOTE:
# Open logging screen and being launchign EC2 instances
# screen -L
# 
# bash queenB.sh cptac_pilot0.input
#
# aws s3 cp screenlog.0 s3://crownproject/cptac/logs/cptac_pilot0.log

aws s3 cp s3://crownproject/cptac/logs/cptac_pilot0.log ./
cat cptac_pilot0.log
date -u

# Run completed successfully!
# Out:
# download: s3://crownproject/cptac/logs/cptac_pilot0.log to ./cptac_pilot0.log
# kec2-user@ip-172-31-40-172:~\[ec2-user@ip-172-31-40-172 ~]$ ls
# ADcalc_ccle2.sh     CrownKey.pem  droneB.sh		  queenB.sh
# cptac_pilot0.input  dbgap.key	  hgr1_align_v4.cptac.sh  screenlog.0
# bash queenB.sh cptac_pilot0.input
# Launch instance # 1
# Thu Oct  3 16:50:00 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01CO001 crc5 SAMN03453626 SRR1999563 SRX1011590
# Instance ID: i-0e576ba89c5776da1
# Public DNS: ec2-54-185-143-115.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-185-143-115.us-west-2.compute.amazonaws.com,172.31.38.0' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 2
# Thu Oct  3 16:53:07 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01CO005 crc5 SAMN03453627 SRR1999549 SRX1011576
# Instance ID: i-03d13fd048191b399
# Public DNS: ec2-34-210-89-222.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-210-89-222.us-west-2.compute.amazonaws.com,172.31.32.180' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# 11CO027	crc5	SAMN06208659	SRR9861967	SRX6616726
# 11CO031	crc5	SAMN06208531	SRR9861968	SRX6616727
# 11CO032	crc5	SAMN05127251	SRR9861933	SRX6616638
# 11CO042	crc5	SAMN06208715	SRR9861971	SRX6616730
# 11CO044	crc5	SAMN06208767	SRR9861972	SRX6616731
# 11CO047	crc5	SAMN06208501	SRR9861973	SRX6616732
# 11CO053	crc5	SAMN06208800	SRR9861976	SRX6616735
# 11CO057	crc5	SAMN06208831	SRR9861978	SRX6615527
# 11CO058	crc5	SAMN06208731	SRR9861980	SRX6615529
# 11CO059	crc5	SAMN06208756	SRR9862018	SRX6615625
# 11CO072	crc5	SAMN06208458	SRR9861985	SRX6615534
# 11CO077	crc5	SAMN06208654	SRR9861986	SRX6615535
# 11CO079	crc5	SAMN06208545	SRR9861987	SRX6615536
# 14CO002	crc5	SAMN05127427	SRR9861894	SRX6615523
# 14CO003	crc5	SAMN05127272	SRR9861895	SRX6615524
# 15CO001	crc5	SAMN05127128	SRR9861897	SRX6615526
# 16CO012	crc5	SAMN06208455	SRR9862026	SRX6615661
# 20CO001	crc5	SAMN04111332	SRR2518477	SRX1288126
# 20CO003	crc5	SAMN05127329	SRR9861898	SRX6616547
# 20CO004	crc5	SAMN06208698	SRR9861993	SRX6615542
# 20CO007	crc5	SAMN06208628	SRR9861994	SRX6615574
# 22CO006	crc5	SAMN05127402	SRR9861900	SRX6616549

# %%
aws s3 cp queenB.sh $S3URL/scripts/
aws s3 cp droneB.sh $S3URL/scripts/
aws s3 cp hgr1_align_v4.cptac.sh $S3URL/scripts/
aws s3 cp $INPUT $S3URL/scripts/
aws s3 cp dbgap.key $S3URL/scripts/
# Out:
# upload: ./queenB.sh to s3://crownproject/cptac/scripts/queenB.sh
# upload: ./droneB.sh to s3://crownproject/cptac/scripts/droneB.sh
# upload: ./hgr1_align_v4.cptac.sh to s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# upload: ./cptac_crc.input to s3://crownproject/cptac/scripts/cptac_crc.input
# upload: ./dbgap.key to s3://crownproject/cptac/scripts/dbgap.key

# %%
# Remote EC2 Instance Operations ----------------------

# Remote:
# Manually open an Amazon Linux 2 AMI
# ami-061392db613a6357b
# t2.micro
#
# ssh login:
# ssh -i "crown.pem" ec2-user@PUBLICDNS
#

# Commands on EC2 machine to set-up AWS
# enter personal login info:

# REMOTE:
#aws configure
  # AWS Key ID
  # AWS Secret Key ID
  # Region: us-west-2
  
# Copy local run files to S3 and download them on EC2

# REMOTE:
# aws s3 cp --recursive s3://crownproject/cptac/scripts/ ./
#
# mv <KEY>.pem ~/.ssh/
# chmod 400 ~/.ssh/<KEY>.pem

# REMOTE:
# Open logging screen and being launchign EC2 instances
# screen -L
# 
# bash queenB.sh cptac_pilot0.input
#
# aws s3 cp screenlog.0 s3://crownproject/cptac/logs/cptac_crc.log

aws s3 cp s3://crownproject/cptac/logs/cptac_crc.log ./
cat cptac_crc.log
date -u

# Run completed successfully!
# Out:
# download: s3://crownproject/cptac/logs/cptac_crc.log to ./cptac_crc.log
# kec2-user@ip-172-31-40-172:~\[ec2-user@ip-172-31-40-172 ~]$ cat queenB.sh
# #!/bin/bash
# # queenB.sh
# # 20180814 build
# # EC2 Launch / Control Script
# #
#
# # 1. queenB script is initialized locally and input files
# #    are parsed ready for cluster analaysis
# # 2. queenB launches instances, logs in to it and runs the
# #    droneB.sh script remotely.
# # 3. The droneB script is executed on the instance and it
# #    launches a `screen` on the instance and loads and
# #    starts to perform the $TASK (gather.sh) script.
# # 4. TASK script should include a instance shut-down
# #    command to close instance upon completion.
# #
#
# # Control Panel =========================
# # Amazon AWS S3 Home URL
# S3URL='s3://crownproject/cptac'
#
# # EC2 TASK Script - script for droneB to execute
# TASK="$S3URL/scripts/hgr1_align_v4.cptac.sh"
#
# # Parameter file:
# # Each line of PARAMETERS will be input to STDIN of
# # the droneB script which can then be used to run the
# # TASK script.
# # i.e. bash droneB.sh <line_N_of_PARAMETERS>
# # PARAMETERS="tcga0_input.txt"
# PARAMETERS=$1
#
# # EC2 Set-up
# instanceTYPE='c4.xlarge'
# imageID='ami-0b375c9c58cb4a7a2' #AMI Crown CCLE/SRA
#
# devNAME='/dev/sda1' # /dev/sda1 for Crown-AMI
# volSIZE='300' # in Gb
#
# # Maximum number of EC2 instances to run simultaniously
# MAX_INSTANCE='45'
#
# # Number of instances to launch
# #COUNT=2 # predetermined number
# COUNT=$(awk 'END{print NR}' $PARAMETERS) # for each input argument
#
# # Security
# keyNAME='CrownKey'
# keyPATH="/home/ec2-user/.ssh/CrownKey.pem"
# secGROUP='crown-group'
#
# # Input Validation ======================
# # Test input file for duplicate sample ID (which will cause file collisions downstream)
# # exit with error 1 if collision exists
#
# SAMPLEIDS=$(cut -f1 $1 | uniq -d )
#
# if [ -n "$SAMPLEIDS" ]
# then
#   # If there are duplicate sample IDs exit
#   echo "Error 02 - Duplicate Sample ID detected in input"
#   echo " I hope you know what you're doing"
#   echo " script will not exit in this version"
#   echo " re-run with unique ID or outputs will overwrite"
#   echo ""
#   #echo "$SAMPLEIDS"
#   #exit 2
# fi
#
# # Script Core ===========================
#
# for ITER in $(seq 1 $COUNT)
# do
#
#   # Count the total number of instances
#   running_instance=$(aws ec2 describe-instances |\
#     grep '"Name": "running"' - |\
#     wc -l - | cut -f1 -d' ' - )
#
#   while [ $running_instance -ge $MAX_INSTANCE ];
#   do
#
#   	echo "Reached max of $running_instance, wait."
#   	echo ''
#
#   	# If there are greater then 25 instances
#   	# wait for instance to close
#   	sleep 5m
#
#   	running_instance=$(aws ec2 describe-instances |\
#     grep '"Name": "running"' - |\
#     wc -l - | cut -f1 -d' ' - )
#   done
#
#   # Extract Parameters/Arguments ----------
#
#   ARGS=$(sed -n "$ITER"p $PARAMETERS | sed 's/\t/ /g' - )
#
#   echo "Launch instance # $ITER"
#   date
#   echo "Instance Type: $instanceTYPE"
#   echo "AMI Image: $imageID"
#   echo "Run Script: $TASK"
#   echo "Parameters: $ARGS"
#
#   # Launch an instance --------------------
#   # NOTE: each iteration of the for loop launches one instance
#   # therefore each loop launches only one instance
#   aws ec2 run-instances --image-id $imageID --count 1 \
#    --instance-type $instanceTYPE --key-name $keyNAME \
#    --block-device-mappings DeviceName=$devNAME,Ebs={VolumeSize=$volSIZE} \
#    --security-groups $secGROUP > launch.tmp
#
#   # Another alternative is to use --user-data droneB.sh
#   # which will run at instance boot-up
#   # passing arguments to it may be challenging
#
#   # Retrieve instance ID
#   instanceID=$(cat launch.tmp | \
#     egrep -o -e 'InstanceId[":/A-Za-z0-9_ \\-]*' - |\
#     cut -f2 -d' ' - | xargs)
#
#   echo "Instance ID: $instanceID"
#
#
#   # Add a few minute wait here to allow for Public DNS to be assigned
#   # otherwise ssh doesn't work
#   # CURRENT BOTTLENECK
#   sleep 180s
#
#   # Check that the instance is 'running' and not pending
#   pending_instance=$(aws ec2 describe-instances |\
#    grep '"Name": "pending"' - |\
#    wc -l - | cut -f1 -d' ' - )
#
#   while [ $pending_instance -gt 0 ];
#   do
#
#   	echo "Launchign instance not ready yet, chill"
#   	# Instance still pending
#   	sleep 180s
#
#     pending_instance=$(aws ec2 describe-instances |\
#      grep '"Name": "pending"' - |\
#      wc -l - | cut -f1 -d' ' - )
#   done
#
#
#   # Retrieve public DNS
#   aws ec2 describe-instances --instance-ids $instanceID > launch2.tmp
#
#   pubDNS=$(cat launch2.tmp | \
#     egrep -o -m 1 -e 'PublicDnsName[.":/A-Za-z0-9_ \\-]*' - |\
#     cut -f2 -d' ' - | xargs)
#
#   echo "Public DNS: $pubDNS"
#
#   # Access the instance -------------------
#
#   LOGIN="ubuntu@$pubDNS"
#
#   ssh -i $keyPATH \
#     -o StrictHostKeyChecking=no \
#     $LOGIN 'bash -s' < droneB.sh $TASK $(echo $ARGS)
#
#   # Cleanup
#   rm *.tmp
#
#   echo ''
#   echo ''
#
# done
#
# # end of scriptkec2-user@ip-172-31-40-172:~\[ec2-user@ip-172-31-40-172 ~]$ ls
# ADcalc_ccle2.sh  cptac_pilot0.input  dbgap.key	hgr1_align_v4.cptac.sh	screenlog.0
# cptac_crc.input  CrownKey.pem	     droneB.sh	queenB.sh
# queenB.sh cptac_crc.input
# Launch instance # 1
# Thu Oct  3 21:13:02 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01CO006 crc5 SAMN04111321 SRR2518440 SRX1288089
# Instance ID: i-0ec2ef93f4d655825
# Public DNS: ec2-34-219-38-168.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-219-38-168.us-west-2.compute.amazonaws.com,172.31.30.173' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 2
# Thu Oct  3 21:16:08 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01CO008 crc5 SAMN04111439 SRR2518441 SRX1288090
# Instance ID: i-02daad767301ecd80
# Public DNS: ec2-54-191-175-236.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-191-175-236.us-west-2.compute.amazonaws.com,172.31.26.138' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 3
# Thu Oct  3 21:19:14 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01CO013 crc5 SAMN05127283 SRR9861902 SRX6616551
# Instance ID: i-06a9849ce4597b7a7
# Public DNS: ec2-54-189-170-77.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-189-170-77.us-west-2.compute.amazonaws.com,172.31.20.225' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 4
# Thu Oct  3 21:22:20 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01CO014 crc5 SAMN06208758 SRR9861950 SRX6616680
# Instance ID: i-05586f25bed2995b9
# Public DNS: ec2-34-217-24-255.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-217-24-255.us-west-2.compute.amazonaws.com,172.31.29.239' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 5
# Thu Oct  3 21:25:26 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01CO019 crc5 SAMN05127298 SRR9862138 SRX6615968
# Instance ID: i-02145560db51355c4
# Public DNS: ec2-34-214-150-121.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-214-150-121.us-west-2.compute.amazonaws.com,172.31.21.82' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 6
# Thu Oct  3 21:28:32 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01CO022 crc5 SAMN06208530 SRR9861951 SRX6616681
# Instance ID: i-0d576814c795ab599
# Public DNS: ec2-54-188-5-54.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54
UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 14CO002 crc5 SAMN05127427 SRR9861894 SRX6615523
# Instance ID: i-0bbd0e358ddd0a41b
# Public DNS: ec2-54-190-144-202.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-190-144-202.us-west-2.compute.amazonaws.com,172.31.43.226' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 57
# Fri Oct  4 00:06:29 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 14CO003 crc5 SAMN05127272 SRR9861895 SRX6615524
# Instance ID: i-061fa90ade9a5bdb2
# Public DNS: ec2-34-219-216-161.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-219-216-161.us-west-2.compute.amazonaws.com,172.31.43.26' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 58
# Fri Oct  4 00:09:36 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 15CO001 crc5 SAMN05127128 SRR9861897 SRX6615526
# Instance ID: i-0d28b20beabb53089
# Public DNS: ec2-52-38-229-39.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-38-229-39.us-west-2.compute.amazonaws.com,172.31.46.129' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 59
# Fri Oct  4 00:12:42 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 16CO012 crc5 SAMN06208455 SRR9862026 SRX6615661
# Instance ID: i-0ea08cd7a01672081
# Public DNS: ec2-34-220-77-202.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-220-77-202.us-west-2.compute.amazonaws.com,172.31.33.174' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 60
# Fri Oct  4 00:15:48 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 20CO001 crc5 SAMN04111332 SRR2518477 SRX1288126
# Instance ID: i-004d92b015294420d
# Public DNS: ec2-54-71-132-211.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-71-132-211.us-west-2.compute.amazonaws.com,172.31.40.82' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 61
# Fri Oct  4 00:18:53 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 20CO003 crc5 SAMN05127329 SRR9861898 SRX6616547
# Instance ID: i-02f67d5a3531a9401
# Public DNS: ec2-34-223-244-162.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-223-244-162.us-west-2.compute.amazonaws.com,172.31.40.7' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 62
# Fri Oct  4 00:21:59 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 20CO004 crc5 SAMN06208698 SRR9861993 SRX6615542
# Instance ID: i-05af157daa785accb
# Public DNS: ec2-34-219-228-170.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-219-228-170.us-west-2.compute.amazonaws.com,172.31.42.4' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 63
# Fri Oct  4 00:25:05 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 20CO007 crc5 SAMN06208628 SRR9861994 SRX6615574
# Instance ID: i-0f6c454161ade4463
# Public DNS: ec2-34-216-131-222.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-216-131-222.us-west-2.compute.amazonaws.com,172.31.36.14' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 64
# Fri Oct  4 00:28:11 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 22CO006 crc5 SAMN05127402 SRR9861900 SRX6616549
# Instance ID: i-090fbc91a1b1be513
# Public DNS: ec2-52-36-47-186.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-36-47-186.us-west-2.compute.amazonaws.com,172.31.8.113' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Fri Oct  4 02:03:39 UTC 2019

# %% [markdown]
# ## Materials and Methods
#
# `ADcalc_cptac.sh`

# %%
#!/bin/bash
# ADcalc_cptac.sh
# Allelic Depth Calculator
# for a position
#
# s3://crownproject/hCAGE/ADcalc_hcage.sh

# Controls -----------------
DEPTH='100000' #Max per file DP

# Regions in hgr1.fa reference genome
REGIONS=('chr13:1003660-1005529' 'chr13:1005529-1005629' \
        'chr13:10219-10340' 'chr13:1006622-1006779' 'chr13:1007948-1013018')

# Corresponding region/gene names
GENES=('18S' '18SE' '5S' '5.8S' '28S')

# 18S  1870
# 18SE 101
# 5S   122
# 5.8S 158
# 28S  5071

# Terminate instances upon completion (for debugging)
TERMINATE='FALSE'

# S3 Output directory
S3DIR='s3://crownproject/cptac/gvcf/'
BAMLIST='bam.list.tmp'

# Script ------------------ ------------------------------
cd ~/cptac/
mkdir -p GVCF #Output Folder
TYPE='cptac_crc' # hardcode single ccle run
cd BAM

#for TYPE in $(echo "hgr1")
#do
    echo Analyzing $TYPE...
    #cd $TYPE

    ls *.bam > bam.list.tmp
    ls *.bam > ../GVCF/$TYPE.bamlist
          
    for index in ${!GENES[*]}
    do
      printf "Started processing %s\n" ${GENES[$index]}
      OUTPUT="../GVCF/$TYPE.${GENES[$index]}.gvcf"

      # Iterate through every bam file in directory
      # look-up position and return VCF
      bcftools mpileup -f ~/resources/hgr1/hgr1.fa \
        --max-depth $DEPTH -A --min-BQ 30 \
        -a FORMAT/DP,AD \
        -r ${REGIONS[$index]} \
        --ignore-RG \
        -b $BAMLIST | \
        bcftools annotate -x INFO,FORMAT/PL - | \
        bcftools view -O v - \
        >> $OUTPUT

      RESULTS+=("$OUTPUT")
      printf "Done with %s \n" ${GENES[$index]}
      printf "%s\n" ${REGIONS[$index]}

    done

    rm bam.list.tmp

#    cd .. # move to tcga folder to reset
#done

# Copy GVCF output to AWS S3
cd ../GVCF
aws s3 cp --recursive ./ $S3DIR

# %%
#QED

# %% [markdown]
# ## Addendum - CPTAC_BRCA, CPTAC_OV, CPTAC_LUNG

# %% [markdown]
# ### Initialize

# %%
# Set WD
WORKDIR='/home/artem/Crown/data2/crc_cptac/scripts'
cd $WORKDIR

# Amazon AWS S3 Home URL
S3URL='s3://crownproject/cptac'

# %%
# Input list
INPUT='cptac_2.input'
# Note the different column requirements from CCLE

cat $INPUT
# Out:
# 11BR020	cptac_brca	SAMN05127287	SRR9861882	SRX6615511
# 11BR022	cptac_brca	SAMN05127344	SRR9861883	SRX6615512
# 11BR023	cptac_brca	SAMN05127208	SRR9861884	SRX6615513
# 14BR005	cptac_brca	SAMN05127452	SRR9861893	SRX6615522
# 14OV011	cptac_ov	SAMN05127182	SRR9861896	SRX6615525
# 17OV010	cptac_ov	SAMN05127403	SRR9861901	SRX6616550
# 05BR031	cptac_brca	SAMN05127237	SRR9861905	SRX6616554
# 11BR055	cptac_brca	SAMN05127177	SRR9861923	SRX6616600
# 11BR058	cptac_brca	SAMN05127293	SRR9861925	SRX6616602
# 16BR012	cptac_brca	SAMN05127303	SRR9861940	SRX6616645
# 18BR004	cptac_brca	SAMN05127178	SRR9861945	SRX6616650
# 18BR007	cptac_brca	SAMN05127455	SRR9861947	SRX6616677
# 09BR005	cptac_brca	SAMN06208486	SRR9861957	SRX6616687
# 11BR044	cptac_brca	SAMN06208809	SRR9861964	SRX6616723
# 18BR009	cptac_brca	SAMN06208601	SRR9861991	SRX6615540
# 18BR010	cptac_brca	SAMN06208579	SRR9861992	SRX6615541
# 01BR033	cptac_brca	SAMN06208795	SRR9861997	SRX6615577
# 01OV045	cptac_ov	SAMN06208449	SRR9861998	SRX6615578
# 02OV029	cptac_ov	SAMN06208682	SRR9861999	SRX6615579
# 02OV035	cptac_ov	SAMN06208739	SRR9862001	SRX6615581
# 04OV023	cptac_ov	SAMN06208510	SRR9862003	SRX6615583
# 04OV024	cptac_ov	SAMN06208409	SRR9862004	SRX6615584
# 04OV027	cptac_ov	SAMN06208457	SRR9862005	SRX6615585
# 04OV028	cptac_ov	SAMN06208440	SRR9862006	SRX6615586
# 06BR014	cptac_brca	SAMN06208602	SRR9862008	SRX6615588
# 11BR036	cptac_brca	SAMN06208473	SRR9862009	SRX6615589
# 11BR040	cptac_brca	SAMN06208846	SRR9862010	SRX6615617
# 11BR050	cptac_brca	SAMN06208784	SRR9862011	SRX6615618
# 11BR053	cptac_brca	SAMN06208748	SRR9862012	SRX6615619
# 11BR069	cptac_brca	SAMN06208737	SRR9862013	SRX6615620
# 11BR072	cptac_brca	SAMN06208535	SRR9862014	SRX6615621
# 05BR009	cptac_brca	SAMN04111387	SRR2518458	SRX1288107
# 05BR016	cptac_brca	SAMN04111393	SRR2518459	SRX1288108
# 06BR003	cptac_brca	SAMN04111369	SRR2518465	SRX1288114
# 06BR005	cptac_brca	SAMN04111310	SRR2518466	SRX1288115
# 06BR006	cptac_brca	SAMN04111309	SRR2518467	SRX1288116
# 11BR003	cptac_brca	SAMN04111417	SRR2518473	SRX1288122
# 11BR009	cptac_brca	SAMN04111390	SRR2518474	SRX1288123
# 17OV001	cptac_ov	SAMN04111328	SRR2518475	SRX1288124
# 17OV002	cptac_ov	SAMN04111370	SRR2518476	SRX1288125

# %%
# Echo scripts to be used for this analysis for version control.

cat hgr1_align_v4.cptac.sh
echo 
echo
cat queenB.sh
echo 
echo
cat droneB.sh
echo 
echo
# Out:
# #!/bin/bash
# # hgr1_align_v4.ccle.sh
# # rDNA alignment pipeline - SRA version
# PIPE_VERSION='191003 build -- CPTAC'
# AMI_VERSION='crown-190601 - ami-0b375c9c58cb4a7a2'
# # EC2: c4.2xlarge (8cpu / 15 gb)
# # EC2: c4.xlarge  (4cpu / 8  gb)
# # Storage: 200 Gb
# #
#
# # Input Requirements --------------------------
#
# # $1 : Library name + Output name(unique)
# # $2 : Seq-read type (wgs|rna)
# # $3 : BioSample ID
# # $4 : Library SRA Accession
#
# # Control Panel -------------------------------
# # Amazon AWS S3 Home URL
#   S3URL='s3://crownproject/cptac'
#
# # CPU
# 	THREADS='3'
#
# # Terminate instances upon completion (for debuggin)
#   TERMINATE='TRUE'
#
# # Read Group Data
#   LIBRARY=$1    # Library Name / File prefix / patient ID
#   TYPE=$2       # wgs OR rna data-type (using crc5 here)
# 	RGPO='cptac-crc'  # Patient Population - CPTAC
# 	RGSM=$3       # Sample ID
# 	RGID=$4       # Read Group ID. SRA Accession Number
#   RGLB=$LIBRARY # Library Name. Accession Number
#   RGPL='ILLUMINA'   # Seq Platform
#   RGPU=$5       # Read Group. Platform Unit (SRA Experiment)
#
#   SRA=$4
#   OUTPUT="$LIBRARY.$TYPE" # Output filename
#
#   # Fastq files from fastq-dump
#   # FQ1=<SRR>_1.fastq.gz
#   # FQ2=<SRR>_2.fastq.gz
#
# echo " -- hgr1 Alignment Pipeline -- "
# echo " version: $PIPE_VERSION "
# echo " ami:     $AMI_VERSION  "
# echo " s3:      $S3URL  "
# echo " library: $LIBRARY -- $TYPE"
# echo " date:    $(date)"
# echo ''
#
# # Initialize wordir ---------------------------
# echo 'Initializing ...'
#
# # Make working directory
# mkdir -p align; cd align
#
# # Copy hgrX genome and create bowtie2 index
# cp ~/resources/hgr1/* ./
#
# # GDC --- Load updated GDC token to instance
# #  aws s3 cp $S3URL/scripts/gdc.token gdc.token
# #  chmod 600 gdc.token
#
# # dbGAP --- Download dbGAP access key to instance
#   cd ~/ncbi/
#   aws s3 cp $S3URL/scripts/dbgap.key dbgap.key
#   $HOME/bin/vdb-config --import dbgap.key
#   cd dbGaP*
#
#   echo "Download SRA file: $SRA"
#   echo "  cmd: prefetch -X 200G --ascp-path <PATH> $SRA"
#
#   $HOME/bin/prefetch -X 200G --ascp-path \
#     "$HOME/.aspera/connect/bin/ascp|$HOME/.aspera/connect/etc/asperaweb_id_dsa.openssh"\
#     $SRA
#
#   $HOME/bin/fastq-dump --split-3 --gzip $SRA
#
#   FQ1=$(ls *_1*)
#   FQ2=$(ls *_2*)
#
#   mv *.gz ~/align/
#   cd ~/align
#
# # SRA -- no additional resources needed
#
# # SRA INPUT ====================================================
# cd ~/align
#
# #if [ -s $FQ1 ]
# #then
#     echo "SRA Input Pipe"
#     echo ''
#     echo "Starting hgr1 alignment"
#     # Paired-End Extracted Reads Alignment
#
#     echo "~/bin/bowtie2 --very-sensitive-local -p $THREADS \
#       --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \
#       --rg PL:$RGPL --rg PU:$RGPU \
#       -x hgr1 --sra-acc $SRA | \
#       ~/bin/samtools view -bS - > aligned_unsorted.bam"
#
#     # Bowtie2: align to genome
#     ~/bin/bowtie2 --very-sensitive-local -p $THREADS \
#       --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \
#       --rg PL:$RGPL --rg PU:$RGPU \
#       -x hgr1 -1 $FQ1 -2 $FQ2 | \
#       ~/bin/samtools view -bS - > aligned_unsorted.bam
#
#     echo "Alignment complete."
#     echo "Calculate flagstats."
#
#     # Calcualte library flagstats
#       ~/bin/samtools flagstat aligned_unsorted.bam > aligned_unsorted.flagstat
#
#     # Read Subset ------------------------------
#     echo "Subset reads (retain mapped & their pairs, remove unmapped)."
#
#     # Extract mapped reads, and their unmapped pairs
#
#       # Extract Header
#       ~/bin/samtools view -H aligned_unsorted.bam > align.header.tmp
#
#       # Unmapped reads with mapped pairs
#       # Extract Mapped Reads
#       # and their unmapped pairs
#       ~/bin/samtools view -b -F 4 aligned_unsorted.bam > align.F4.bam #mapped
#       ~/bin/samtools view -b -f 4 -F 8 aligned_unsorted.bam > align.f4F8.bam #unmapped pairs
#
#       echo "Recompiling mapped bam file."
#
#       # Re-compile bam file
#       ~/bin/samtools cat -h align.header.tmp -o align.hgr1.tmp.bam align.F4.bam align.f4F8.bam
#         ~/bin/samtools sort -@ $THREADS -O BAM align.hgr1.tmp.bam > align.hgr1.bam
#         ~/bin/samtools index align.hgr1.bam
#         ~/bin/samtools flagstat align.hgr1.bam > align.hgr1.flagstat
#
#       # Clean up
#       rm *tmp* align.F4.bam align.f4F8.bam
#
#     echo "Processing complete. Copy files to S3"
#     # Rename the total Bam Files
#       mv aligned_unsorted.bam $OUTPUT.bam
#       #mv aligned_unsorted.bam.bai $OUTPUT.bam.bai
#       mv aligned_unsorted.flagstat $OUTPUT.flagstat
#
#     # Rename the hgr-aligned Bam files
#       mv align.hgr1.bam $OUTPUT.hgr1.bam
#       mv align.hgr1.bam.bai $OUTPUT.hgr1.bam.bai
#       mv align.hgr1.flagstat $OUTPUT.hgr1.flagstat
#
#     # Copy output to AWS S3
#     # Alignments (Full)
#       aws s3 cp $OUTPUT.flagstat $S3URL/hgr1/
#
#     # Alignments (Aligned)
#       aws s3 cp $OUTPUT.hgr1.bam $S3URL/hgr1/
#       aws s3 cp $OUTPUT.hgr1.bam.bai $S3URL/hgr1/
#       aws s3 cp $OUTPUT.hgr1.flagstat $S3URL/hgr1/
#
# #fi
#
# echo "Create log files and copy to S3"
# # Copy screen log file to AWS S3
# cp ~/screenlog.0 ./$OUTPUT.screenlog
# aws s3 cp $OUTPUT.screenlog $S3URL/logs/
#
# # Shutdown and Terminate instance
# EC2ID=$(ec2metadata --instance-id)
# sleep 20s # to catch errors
#
# if [ "$TERMINATE" = TRUE ]
# then
#   echo "Run Complete -- Shutting down instance."
#   aws ec2 terminate-instances --instance-ids $EC2ID
# else
#   echo "Run Complete -- Instance is online."
# fi
#
# # Script complete
#
#
# #!/bin/bash
# # queenB.sh
# # 20180814 build
# # EC2 Launch / Control Script
# #
#
# # 1. queenB script is initialized locally and input files
# #    are parsed ready for cluster analaysis
# # 2. queenB launches instances, logs in to it and runs the
# #    droneB.sh script remotely.
# # 3. The droneB script is executed on the instance and it
# #    launches a `screen` on the instance and loads and
# #    starts to perform the $TASK (gather.sh) script.
# # 4. TASK script should include a instance shut-down
# #    command to close instance upon completion.
# #
#
# # Control Panel =========================
# # Amazon AWS S3 Home URL
# S3URL='s3://crownproject/cptac'
#
# # EC2 TASK Script - script for droneB to execute
# TASK="$S3URL/scripts/hgr1_align_v4.cptac.sh"
#
# # Parameter file:
# # Each line of PARAMETERS will be input to STDIN of
# # the droneB script which can then be used to run the
# # TASK script.
# # i.e. bash droneB.sh <line_N_of_PARAMETERS>
# # PARAMETERS="tcga0_input.txt"
# PARAMETERS=$1
#
# # EC2 Set-up
# instanceTYPE='c4.xlarge'
# imageID='ami-0b375c9c58cb4a7a2' #AMI Crown CCLE/SRA
#
# devNAME='/dev/sda1' # /dev/sda1 for Crown-AMI
# volSIZE='300' # in Gb
#
# # Maximum number of EC2 instances to run simultaniously
# MAX_INSTANCE='45'
#
# # Number of instances to launch
# #COUNT=2 # predetermined number
# COUNT=$(awk 'END{print NR}' $PARAMETERS) # for each input argument
#
# # Security
# keyNAME='CrownKey'
# keyPATH="/home/ec2-user/.ssh/CrownKey.pem"
# secGROUP='crown-group'
#
# # Input Validation ======================
# # Test input file for duplicate sample ID (which will cause file collisions downstream)
# # exit with error 1 if collision exists
#
# SAMPLEIDS=$(cut -f1 $1 | uniq -d )
#
# if [ -n "$SAMPLEIDS" ]
# then
#   # If there are duplicate sample IDs exit
#   echo "Error 02 - Duplicate Sample ID detected in input"
#   echo " I hope you know what you're doing"
#   echo " script will not exit in this version"
#   echo " re-run with unique ID or outputs will overwrite"
#   echo ""
#   #echo "$SAMPLEIDS"
#   #exit 2
# fi
#
# # Script Core ===========================
#
# for ITER in $(seq 1 $COUNT)
# do
#
#   # Count the total number of instances
#   running_instance=$(aws ec2 describe-instances |\
#     grep '"Name": "running"' - |\
#     wc -l - | cut -f1 -d' ' - )
#
#   while [ $running_instance -ge $MAX_INSTANCE ];
#   do
#
#   	echo "Reached max of $running_instance, wait."
#   	echo ''
#
#   	# If there are greater then 25 instances
#   	# wait for instance to close
#   	sleep 5m
#
#   	running_instance=$(aws ec2 describe-instances |\
#     grep '"Name": "running"' - |\
#     wc -l - | cut -f1 -d' ' - )
#   done
#
#   # Extract Parameters/Arguments ----------
#
#   ARGS=$(sed -n "$ITER"p $PARAMETERS | sed 's/\t/ /g' - )
#
#   echo "Launch instance # $ITER"
#   date
#   echo "Instance Type: $instanceTYPE"
#   echo "AMI Image: $imageID"
#   echo "Run Script: $TASK"
#   echo "Parameters: $ARGS"
#
#   # Launch an instance --------------------
#   # NOTE: each iteration of the for loop launches one instance
#   # therefore each loop launches only one instance
#   aws ec2 run-instances --image-id $imageID --count 1 \
#    --instance-type $instanceTYPE --key-name $keyNAME \
#    --block-device-mappings DeviceName=$devNAME,Ebs={VolumeSize=$volSIZE} \
#    --security-groups $secGROUP > launch.tmp
#
#   # Another alternative is to use --user-data droneB.sh
#   # which will run at instance boot-up
#   # passing arguments to it may be challenging
#
#   # Retrieve instance ID
#   instanceID=$(cat launch.tmp | \
#     egrep -o -e 'InstanceId[":/A-Za-z0-9_ \\-]*' - |\
#     cut -f2 -d' ' - | xargs)
#
#   echo "Instance ID: $instanceID"
#
#
#   # Add a few minute wait here to allow for Public DNS to be assigned
#   # otherwise ssh doesn't work
#   # CURRENT BOTTLENECK
#   sleep 180s
#
#   # Check that the instance is 'running' and not pending
#   pending_instance=$(aws ec2 describe-instances |\
#    grep '"Name": "pending"' - |\
#    wc -l - | cut -f1 -d' ' - )
#
#   while [ $pending_instance -gt 0 ];
#   do
#
#   	echo "Launchign instance not ready yet, chill"
#   	# Instance still pending
#   	sleep 180s
#
#     pending_instance=$(aws ec2 describe-instances |\
#      grep '"Name": "pending"' - |\
#      wc -l - | cut -f1 -d' ' - )
#   done
#
#
#   # Retrieve public DNS
#   aws ec2 describe-instances --instance-ids $instanceID > launch2.tmp
#
#   pubDNS=$(cat launch2.tmp | \
#     egrep -o -m 1 -e 'PublicDnsName[.":/A-Za-z0-9_ \\-]*' - |\
#     cut -f2 -d' ' - | xargs)
#
#   echo "Public DNS: $pubDNS"
#
#   # Access the instance -------------------
#
#   LOGIN="ubuntu@$pubDNS"
#
#   ssh -i $keyPATH \
#     -o StrictHostKeyChecking=no \
#     $LOGIN 'bash -s' < droneB.sh $TASK $(echo $ARGS)
#
#   # Cleanup
#   rm *.tmp
#
#   echo ''
#   echo ''
#
# done
#
# # end of script
#
# #!/bin/bash
# # droneB.sh
# #
#
# # This script-layer is neccesary to launch a screen session
# # on each ec2-machine. The pipeline is run within that session
# # and the output is logged. This allows 'looking in' on sessions
# # as they are running.
#
# # Commands to run on server-side
# # ===============================================================
#
# SCRIPTPATH=$1
#
# SCRIPT=$(basename $1)
#
# shift # drop first (TASK or SCRIPT variable)
#
# # Download pipeline / droneB's function
#   aws s3 cp $SCRIPTPATH ./
#
#   chmod 777 *.sh
#
# # open screen; run gather.sh function. -L logged
#   screen -Ldmt sh ~/$SCRIPT $@
#
#
# # ===============================================================

# %%
aws s3 cp queenB.sh $S3URL/scripts/
aws s3 cp droneB.sh $S3URL/scripts/
aws s3 cp hgr1_align_v4.cptac.sh $S3URL/scripts/
aws s3 cp $INPUT $S3URL/scripts/
aws s3 cp dbgap.key $S3URL/scripts/
# Out:
# upload: ./queenB.sh to s3://crownproject/cptac/scripts/queenB.sh
# upload: ./droneB.sh to s3://crownproject/cptac/scripts/droneB.sh
# upload: ./hgr1_align_v4.cptac.sh to s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# upload: ./cptac_2.input to s3://crownproject/cptac/scripts/cptac_2.input
# upload: ./dbgap.key to s3://crownproject/cptac/scripts/dbgap.key

# %%
# start
date
date -u
# Out:
# Fri Oct  4 06:25:51 PDT 2019
# Fri Oct  4 13:25:51 UTC 2019

# %% [markdown]
# ### Run

# %%
# Remote EC2 Instance Operations ----------------------

# Remote:
# Manually open an Amazon Linux 2 AMI
# ami-061392db613a6357b
# t2.micro
#
# ssh login:
# ssh -i "crown.pem" ec2-user@PUBLICDNS
#

# Commands on EC2 machine to set-up AWS
# enter personal login info:

# REMOTE:
#aws configure
  # AWS Key ID
  # AWS Secret Key ID
  # Region: us-west-2
  
# Copy local run files to S3 and download them on EC2

# REMOTE:
# aws s3 cp --recursive s3://crownproject/cptac/scripts/ ./
#
# mv <KEY>.pem ~/.ssh/
# chmod 400 ~/.ssh/<KEY>.pem

# REMOTE:
# Open logging screen and being launchign EC2 instances
# screen -L
# 
# bash queenB.sh cptac_2.input
#
# aws s3 cp screenlog.0 s3://crownproject/cptac/logs/cptac_2.log

aws s3 cp s3://crownproject/cptac/logs/cptac_2.log ./
cat cptac_2.log
date -u
# Out:
# download: s3://crownproject/cptac/logs/cptac_2.log to ./cptac_2.log
# kec2-user@ip-172-31-43-66:~\[ec2-user@ip-172-31-43-66 ~]$ bash queenB.sh cptac_2.input
# Launch instance # 1
# Fri Oct  4 13:27:04 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR020 cptac_brca SAMN05127287 SRR9861882 SRX6615511
# Instance ID: i-0d0bf2078a685f49a
# Public DNS: ec2-34-220-73-123.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-220-73-123.us-west-2.compute.amazonaws.com,172.31.43.9' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 2
# Fri Oct  4 13:30:11 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR022 cptac_brca SAMN05127344 SRR9861883 SRX6615512
# Instance ID: i-01927f3dd5f211f2d
# Public DNS: ec2-34-219-204-154.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-219-204-154.us-west-2.compute.amazonaws.com,172.31.46.178' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 3
# Fri Oct  4 13:33:18 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR023 cptac_brca SAMN05127208 SRR9861884 SRX6615513
# Instance ID: i-0fb79a7775bd5d0f9
# Public DNS: ec2-54-68-169-41.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-68-169-41.us-west-2.compute.amazonaws.com,172.31.36.171' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 4
# Fri Oct  4 13:36:24 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 14BR005 cptac_brca SAMN05127452 SRR9861893 SRX6615522
# Instance ID: i-0e2236be545cbce54
# Public DNS: ec2-34-210-79-105.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-210-79-105.us-west-2.compute.amazonaws.com,172.31.45.81' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 5
# Fri Oct  4 13:39:29 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 14OV011 cptac_ov SAMN05127182 SRR9861896 SRX6615525
# Instance ID: i-0ef27aeecacf0d25f
# Public DNS: ec2-52-13-53-225.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-13-53-225.us-west-2.compute.amazonaws.com,172.31.45.80' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 6
# Fri Oct  4 13:42:35 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 17OV010 cptac_ov SAMN05127403 SRR9861901 SRX6616550
# Instance ID: i-03a33a8796e2f773b
# Public DNS: ec2-54-184-62-173.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-184-62-173.us-west-2.compute.amazonaws.com,172.31.38.251' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 7
# Fri Oct  4 13:45:40 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 05BR031 cptac_brca SAMN05127237 SRR9861905 SRX6616554
# Instance ID: i-006dbb97171f2f079
# Public DNS: ec2-34-214-182-37.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-214-182-37.us-west-2.compute.amazonaws.com,172.31.38.103' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 8
# Fri Oct  4 13:48:46 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR055 cptac_brca SAMN05127177 SRR9861923 SRX6616600
# Instance ID: i-0866bd6beb36584bc
# Public DNS: ec2-34-220-83-154.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-220-83-154.us-west-2.compute.amazonaws.com,172.31.35.67' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 9
# Fri Oct  4 13:51:52 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR058 cptac_brca SAMN05127293 SRR9861925 SRX6616602
# Instance ID: i-0664a66f42e5dd86f
# Public DNS: ec2-34-221-212-56.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-221-212-56.us-west-2.compute.amazonaws.com,172.31.40.131' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 10
# Fri Oct  4 13:54:57 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 16BR012 cptac_brca SAMN05127303 SRR9861940 SRX6616645
# Instance ID: i-0fb7c67f64a11cf6c
# Public DNS: ec2-34-210-80-223.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-210-80-223.us-west-2.compute.amazonaws.com,172.31.44.110' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 11
# Fri Oct  4 13:58:02 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 18BR004 cptac_brca SAMN05127178 SRR9861945 SRX6616650
# Instance ID: i-08dafbbb86ea177ce
# Public DNS: ec2-54-202-37-228.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-202-37-228.us-west-2.compute.amazonaws.com,172.31.32.153' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 12
# Fri Oct  4 14:01:08 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 18BR007 cptac_brca SAMN05127455 SRR9861947 SRX6616677
# Instance ID: i-0b369ecf29bcd8175
# Public DNS: ec2-54-202-20-71.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-202-20-71.us-west-2.compute.amazonaws.com,172.31.35.173' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 13
# Fri Oct  4 14:04:13 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 09BR005 cptac_brca SAMN06208486 SRR9861957 SRX6616687
# Instance ID: i-0e84fd055750f0bba
# Public DNS: ec2-34-209-234-188.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-209-234-188.us-west-2.compute.amazonaws.com,172.31.3.34' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 14
# Fri Oct  4 14:07:19 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR044 cptac_brca SAMN06208809 SRR9861964 SRX6616723
# Instance ID: i-05db3c77af1211857
# Public DNS: ec2-34-221-6-249.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-221-6-249.us-west-2.compute.amazonaws.com,172.31.15.43' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 15
# Fri Oct  4 14:10:25 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 18BR009 cptac_brca SAMN06208601 SRR9861991 SRX6615540
# Instance ID: i-0b1d6e16c3d0bf728
# Public DNS: ec2-34-209-25-199.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-209-25-199.us-west-2.compute.amazonaws.com,172.31.9.231' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 16
# Fri Oct  4 14:13:30 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 18BR010 cptac_brca SAMN06208579 SRR9861992 SRX6615541
# Instance ID: i-06836c3c7c351ac01
# Public DNS: ec2-18-237-26-201.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-237-26-201.us-west-2.compute.amazonaws.com,172.31.7.198' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 17
# Fri Oct  4 14:16:36 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01BR033 cptac_brca SAMN06208795 SRR9861997 SRX6615577
# Instance ID: i-0bec70cb74ddc6f24
# Public DNS: ec2-52-26-20-83.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-26-20-83.us-west-2.compute.amazonaws.com,172.31.10.119' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 18
# Fri Oct  4 14:19:41 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01OV045 cptac_ov SAMN06208449 SRR9861998 SRX6615578
# Instance ID: i-099b1f2b124010262
# Public DNS: ec2-18-237-62-170.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-237-62-170.us-west-2.compute.amazonaws.com,172.31.4.132' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 19
# Fri Oct  4 14:22:47 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 02OV029 cptac_ov SAMN06208682 SRR9861999 SRX6615579
# Instance ID: i-074104a74e374cebe
# Public DNS: ec2-54-212-218-67.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-212-218-67.us-west-2.compute.amazonaws.com,172.31.11.166' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 20
# Fri Oct  4 14:25:52 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 02OV035 cptac_ov SAMN06208739 SRR9862001 SRX6615581
# Instance ID: i-04803720224999b02
# Public DNS: ec2-34-208-94-177.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-208-94-177.us-west-2.compute.amazonaws.com,172.31.12.156' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 21
# Fri Oct  4 14:28:58 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV023 cptac_ov SAMN06208510 SRR9862003 SRX6615583
# Instance ID: i-02f3741bac1e46bc5
# Public DNS: ec2-18-237-228-106.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-237-228-106.us-west-2.compute.amazonaws.com,172.31.2.148' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 22
# Fri Oct  4 14:32:03 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV024 cptac_ov SAMN06208409 SRR9862004 SRX6615584
# Instance ID: i-05a94343801a946d2
# Public DNS: ec2-34-209-152-64.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-209-152-64.us-west-2.compute.amazonaws.com,172.31.10.150' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 23
# Fri Oct  4 14:35:09 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV027 cptac_ov SAMN06208457 SRR9862005 SRX6615585
# Instance ID: i-0b753e8562f5a7332
# Public DNS: ec2-34-212-37-23.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-212-37-23.us-west-2.compute.amazonaws.com,172.31.6.140' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 24
# Fri Oct  4 14:38:14 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV028 cptac_ov SAMN06208440 SRR9862006 SRX6615586
# Instance ID: i-04f146115ba7c3625
# Public DNS: ec2-54-149-185-40.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-149-185-40.us-west-2.compute.amazonaws.com,172.31.6.10' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 25
# Fri Oct  4 14:41:20 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 06BR014 cptac_brca SAMN06208602 SRR9862008 SRX6615588
# Instance ID: i-04792842a9a54a6c5
# Public DNS: ec2-54-70-156-253.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-70-156-253.us-west-2.compute.amazonaws.com,172.31.9.132' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 26
# Fri Oct  4 14:44:25 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR036 cptac_brca SAMN06208473 SRR9862009 SRX6615589
# Instance ID: i-0cdb9ca4bd2da0b62
# Public DNS: ec2-34-212-236-132.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-212-236-132.us-west-2.compute.amazonaws.com,172.31.15.114' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 27
# Fri Oct  4 14:47:30 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR040 cptac_brca SAMN06208846 SRR9862010 SRX6615617
# Instance ID: i-043f9f7596714341f
# Public DNS: ec2-35-163-153-242.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-163-153-242.us-west-2.compute.amazonaws.com,172.31.1.190' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 28
# Fri Oct  4 14:50:35 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR050 cptac_brca SAMN06208784 SRR9862011 SRX6615618
# Instance ID: i-0b9e5d5824ff5b861
# Public DNS: ec2-34-210-110-105.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-210-110-105.us-west-2.compute.amazonaws.com,172.31.6.49' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 29
# Fri Oct  4 14:53:41 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR053 cptac_brca SAMN06208748 SRR9862012 SRX6615619
# Instance ID: i-0f9e063e2687eb175
# Public DNS: ec2-54-212-159-29.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-212-159-29.us-west-2.compute.amazonaws.com,172.31.3.210' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 30
# Fri Oct  4 14:56:46 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR069 cptac_brca SAMN06208737 SRR9862013 SRX6615620
# Instance ID: i-0c5f48eee7ace9138
# Public DNS: ec2-52-12-233-96.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-12-233-96.us-west-2.compute.amazonaws.com,172.31.10.222' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 31
# Fri Oct  4 14:59:51 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR072 cptac_brca SAMN06208535 SRR9862014 SRX6615621
# Instance ID: i-01a9293af32999237
# Public DNS: ec2-52-24-95-182.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-24-95-182.us-west-2.compute.amazonaws.com,172.31.11.164' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 32
# Fri Oct  4 15:02:57 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR074 cptac_brca SAMN06208708 SRR9862016 SRX6615623
# Instance ID: i-03f26962c337ae054
# Public DNS: ec2-34-216-233-0.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-216-233-0.us-west-2.compute.amazonaws.com,172.31.7.239' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 33
# Fri Oct  4 15:06:02 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 13BR009 cptac_brca SAMN06208398 SRR9862020 SRX6615627
# Instance ID: i-024a656d1bf45d230
# Public DNS: ec2-34-219-11-56.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-219-11-56.us-west-2.compute.amazonaws.com,172.31.11.58' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 34
# Fri Oct  4 15:09:08 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 13OV003 cptac_ov SAMN06208747 SRR9862021 SRX6615628
# Instance ID: i-066a10568c48a3dea
# Public DNS: ec2-54-186-152-123.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-186-152-123.us-west-2.compute.amazonaws.com,172.31.10.74' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 35
# Fri Oct  4 15:12:14 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 13OV004 cptac_ov SAMN06208456 SRR9862022 SRX6615629
# Instance ID: i-0a5f762e4d8b478ba
# Public DNS: ec2-18-236-236-34.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-236-236-34.us-west-2.compute.amazonaws.com,172.31.5.236' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 36
# Fri Oct  4 15:15:20 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 14BR014 cptac_brca SAMN06208847 SRR9862023 SRX6615630
# Instance ID: i-0112aa062cd97f1f5
# Public DNS: ec2-54-186-148-57.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-186-148-57.us-west-2.compute.amazonaws.com,172.31.2.139' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 37
# Fri Oct  4 15:18:25 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 15BR003 cptac_brca SAMN06208527 SRR9862024 SRX6615631
# Instance ID: i-0162a3abcedebc456
# Public DNS: ec2-54-149-198-134.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-149-198-134.us-west-2.compute.amazonaws.com,172.31.11.224' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 38
# Fri Oct  4 15:21:30 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 15OV001 cptac_ov SAMN06208777 SRR9862025 SRX6615632
# Instance ID: i-047e2038ebda02683
# Public DNS: ec2-52-40-188-108.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-40-188-108.us-west-2.compute.amazonaws.com,172.31.3.171' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 39
# Fri Oct  4 15:24:36 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 17OV011 cptac_ov SAMN06208603 SRR9862027 SRX6615662
# Instance ID: i-0127c1c5e22266560
# Public DNS: ec2-34-209-236-119.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-209-236-119.us-west-2.compute.amazonaws.com,172.31.14.242' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 40
# Fri Oct  4 15:27:41 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 17OV013 cptac_ov SAMN06208705 SRR9862028 SRX6615663
# Instance ID: i-0d2499f2ff292e91e
# Public DNS: ec2-18-237-225-84.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-237-225-84.us-west-2.compute.amazonaws.com,172.31.3.95' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 41
# Fri Oct  4 15:30:48 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 18BR016 cptac_brca SAMN06208807 SRR9862030 SRX6615665
# Instance ID: i-0361258e2e709406e
# Public DNS: ec2-34-219-93-255.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-219-93-255.us-west-2.compute.amazonaws.com,172.31.4.229' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 42
# Fri Oct  4 15:33:54 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 18BR017 cptac_brca SAMN06208526 SRR9862031 SRX6615666
# Instance ID: i-046ab688d662d79d8
# Public DNS: ec2-54-202-55-215.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-202-55-215.us-west-2.compute.amazonaws.com,172.31.1.172' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 43
# Fri Oct  4 15:36:59 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 18BR019 cptac_brca SAMN06208448 SRR9862032 SRX6615667
# Instance ID: i-0ba26d2121b1787eb
# Public DNS: ec2-18-237-157-114.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-237-157-114.us-west-2.compute.amazonaws.com,172.31.7.212' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 44
# Fri Oct  4 15:40:05 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 20BR001 cptac_brca SAMN06208683 SRR9862033 SRX6615668
# Instance ID: i-049b1050ae14538a0
# Public DNS: ec2-34-209-124-147.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-209-124-147.us-west-2.compute.amazonaws.com,172.31.4.47' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 45
# Fri Oct  4 15:43:10 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 20BR002 cptac_brca SAMN06208591 SRR9862034 SRX6615669
# Instance ID: i-04ff1aeac0405b8cf
# Public DNS: ec2-18-237-24-17.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-237-24-17.us-west-2.compute.amazonaws.com,172.31.8.180' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 46
# Fri Oct  4 15:46:16 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 20BR005 cptac_brca SAMN06208766 SRR9862035 SRX6615670
# Instance ID: i-0b431ca3627f8d059
# Public DNS: ec2-54-202-102-194.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-202-102-194.us-west-2.compute.amazonaws.com,172.31.12.102' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 47
# Fri Oct  4 15:49:21 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 20BR006 cptac_brca SAMN06208763 SRR9862036 SRX6615671
# Instance ID: i-0055cc8e14b8c601b
# Public DNS: ec2-54-212-122-128.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-212-122-128.us-west-2.compute.amazonaws.com,172.31.46.95' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 48
# Fri Oct  4 15:52:27 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 20BR008 cptac_brca SAMN06208624 SRR9862038 SRX6615673
# Instance ID: i-07b1048f063475bf3
# Public DNS: ec2-35-162-208-86.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-162-208-86.us-west-2.compute.amazonaws.com,172.31.41.70' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 49
# Fri Oct  4 15:55:33 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 21BR010 cptac_brca SAMN06208539 SRR9862039 SRX6615674
# Instance ID: i-0ea794388ceb0f32b
# Public DNS: ec2-34-222-80-29.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-222-80-29.us-west-2.compute.amazonaws.com,172.31.8.149' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 50
# Fri Oct  4 15:58:38 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 22BR005 cptac_brca SAMN06208468 SRR9862040 SRX6615675
# Instance ID: i-0893d6817559fbc5b
# Public DNS: ec2-52-10-79-193.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-10-79-193.us-west-2.compute.amazonaws.com,172.31.12.142' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 51
# Fri Oct  4 16:01:43 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 22BR006 cptac_brca SAMN06208835 SRR9862041 SRX6615676
# Instance ID: i-09db5e7a2aad572da
# Public DNS: ec2-34-219-100-70.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-219-100-70.us-west-2.compute.amazonaws.com,172.31.9.224' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 52
# Fri Oct  4 16:04:49 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01OV046 cptac_ov SAMN06208650 SRR9862043 SRX6615705
# Instance ID: i-0e9ef3de4347503fa
# Public DNS: ec2-34-221-230-40.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-221-230-40.us-west-2.compute.amazonaws.com,172.31.12.21' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 53
# Fri Oct  4 16:07:54 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01OV047 cptac_ov SAMN06208433 SRR9862044 SRX6615706
# Instance ID: i-064119029d162810e
# Public DNS: ec2-18-237-62-152.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-237-62-152.us-west-2.compute.amazonaws.com,172.31.13.181' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 54
# Fri Oct  4 16:11:00 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01OV049 cptac_ov SAMN06208598 SRR9862045 SRX6615707
# Instance ID: i-018f2dc1e3b833f58
# Public DNS: ec2-18-237-138-18.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-237-138-18.us-west-2.compute.amazonaws.com,172.31.2.199' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 55
# Fri Oct  4 16:14:05 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 02OV036 cptac_ov SAMN06208610 SRR9862046 SRX6615708
# Instance ID: i-0e645dd79a191bb68
# Public DNS: ec2-54-185-119-66.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-185-119-66.us-west-2.compute.amazonaws.com,172.31.8.8' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 56
# Fri Oct  4 16:17:11 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 02OV040 cptac_ov SAMN06208630 SRR9862047 SRX6615709
# Instance ID: i-061dc226ac0679f88
# Public DNS: ec2-35-167-209-236.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-167-209-236.us-west-2.compute.amazonaws.com,172.31.3.145' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 57
# Fri Oct  4 16:20:17 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 02OV041 cptac_ov SAMN06208666 SRR9862048 SRX6615710
# Instance ID: i-079a58f47ddcfcc71
# Public DNS: ec2-54-202-73-148.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-202-73-148.us-west-2.compute.amazonaws.com,172.31.1.199' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 58
# Fri Oct  4 16:23:22 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 02OV044 cptac_ov SAMN06208541 SRR9862050 SRX6615712
# Instance ID: i-09ed3663bd8ac68a6
# Public DNS: ec2-52-41-40-127.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-41-40-127.us-west-2.compute.amazonaws.com,172.31.36.183' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 59
# Fri Oct  4 16:26:28 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 02OV045 cptac_ov SAMN06208518 SRR9862051 SRX6615713
# Instance ID: i-02d312243edb422d7
# Public DNS: ec2-34-221-241-107.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-221-241-107.us-west-2.compute.amazonaws.com,172.31.0.30' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 60
# Fri Oct  4 16:29:34 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 02OV046 cptac_ov SAMN06208396 SRR9862052 SRX6615714
# Instance ID: i-0beb7ebe37a15af9e
# Public DNS: ec2-52-38-152-32.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-38-152-32.us-west-2.compute.amazonaws.com,172.31.11.253' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 61
# Fri Oct  4 16:32:39 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV031 cptac_ov SAMN06208431 SRR9862053 SRX6615715
# Instance ID: i-09d283e801394cdd3
# Public DNS: ec2-35-164-114-131.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-164-114-131.us-west-2.compute.amazonaws.com,172.31.2.79' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 62
# Fri Oct  4 16:35:44 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV033 cptac_ov SAMN06208558 SRR9862054 SRX6615716
# Instance ID: i-01ab9dd3bb34ae17b
# Public DNS: ec2-54-187-49-28.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-187-49-28.us-west-2.compute.amazonaws.com,172.31.8.179' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 63
# Fri Oct  4 16:38:50 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV036 cptac_ov SAMN06208547 SRR9862055 SRX6615717
# Instance ID: i-09d0a60fd4ca376a4
# Public DNS: ec2-52-24-35-183.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-24-35-183.us-west-2.compute.amazonaws.com,172.31.15.131' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 64
# Fri Oct  4 16:41:56 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV037 cptac_ov SAMN06208648 SRR9862056 SRX6615718
# Instance ID: i-02c8e4a4f503c69c4
# Public DNS: ec2-52-36-213-199.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-36-213-199.us-west-2.compute.amazonaws.com,172.31.11.61' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 65
# Fri Oct  4 16:45:01 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV039 cptac_ov SAMN06208649 SRR9862057 SRX6615719
# Instance ID: i-0812e61f14d5a8f23
# ^[[A^[[BPublic DNS: ec2-35-162-250-100.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-162-250-100.us-west-2.compute.amazonaws.com,172.31.13.77' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 66
# Fri Oct  4 16:48:07 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV040 cptac_ov SAMN06208633 SRR9862058 SRX6615749
# Instance ID: i-0de58dcd2000b9d10
# Public DNS: ec2-35-165-254-200.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-165-254-200.us-west-2.compute.amazonaws.com,172.31.8.162' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 67
# Fri Oct  4 16:51:12 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV041 cptac_ov SAMN06208389 SRR9862059 SRX6615750
# Instance ID: i-065816bf99f524d04
# Public DNS: ec2-54-218-25-79.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-218-25-79.us-west-2.compute.amazonaws.com,172.31.5.160' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 68
# Fri Oct  4 16:54:18 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV044 cptac_ov SAMN06208429 SRR9862060 SRX6615751
# Instance ID: i-005edf1689d27a6c1
# Public DNS: ec2-35-162-84-58.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-162-84-58.us-west-2.compute.amazonaws.com,172.31.10.67' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 69
# Fri Oct  4 16:57:24 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV045 cptac_ov SAMN06208793 SRR9862061 SRX6615752
# Instance ID: i-0a97239dee6ef10a7
# Public DNS: ec2-34-211-143-30.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-211-143-30.us-west-2.compute.amazonaws.com,172.31.15.93' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 70
# Fri Oct  4 17:00:29 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV048 cptac_ov SAMN06208459 SRR9862062 SRX6615753
# Instance ID: i-012cff32c4f7155a2
# Public DNS: ec2-34-220-80-175.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-220-80-175.us-west-2.compute.amazonaws.com,172.31.40.145' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 71
# Fri Oct  4 17:03:35 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV049 cptac_ov SAMN06208571 SRR9862063 SRX6615754
# Instance ID: i-0d9cf82d7c07a1a4f
# Public DNS: ec2-54-245-61-7.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-245-61-7.us-west-2.compute.amazonaws.com,172.31.11.107' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 72
# Fri Oct  4 17:06:41 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV050 cptac_ov SAMN06208576 SRR9862064 SRX6615755
# Instance ID: i-0a7bd0abb1259e94f
# Public DNS: ec2-52-39-240-151.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-39-240-151.us-west-2.compute.amazonaws.com,172.31.1.60' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 73
# Fri Oct  4 17:09:47 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV051 cptac_ov SAMN06208815 SRR9862065 SRX6615756
# Instance ID: i-043b841c16fa9d9a2
# Public DNS: ec2-52-11-77-19.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-11-77-19.us-west-2.compute.amazonaws.com,172.31.42.80' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 74
# Fri Oct  4 17:12:52 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV053 cptac_ov SAMN06208810 SRR9862066 SRX6615757
# Instance ID: i-03913456d45814a3f
# Public DNS: ec2-35-161-46-35.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-161-46-35.us-west-2.compute.amazonaws.com,172.31.46.33' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 75
# Fri Oct  4 17:15:59 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV054 cptac_ov SAMN06208414 SRR9862067 SRX6615758
# Instance ID: i-0cf42b2ad46da3ba4
# Public DNS: ec2-54-71-71-98.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-71-71-98.us-west-2.compute.amazonaws.com,172.31.34.203' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 76
# Fri Oct  4 17:19:04 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV055 cptac_ov SAMN06208426 SRR9862068 SRX6615759
# Instance ID: i-01a83cc08d8b347a9
# Public DNS: ec2-54-187-63-67.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-187-63-67.us-west-2.compute.amazonaws.com,172.31.34.84' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 77
# Fri Oct  4 17:22:10 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV057 cptac_ov SAMN06208485 SRR9862069 SRX6615760
# Instance ID: i-0befcba700cfb9bc5
# Public DNS: ec2-54-190-139-104.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-190-139-104.us-west-2.compute.amazonaws.com,172.31.33.1' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 78
# Fri Oct  4 17:25:16 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV058 cptac_ov SAMN06208577 SRR9862070 SRX6615761
# Instance ID: i-0de42497718c62dd3
# Public DNS: ec2-34-220-144-43.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-220-144-43.us-west-2.compute.amazonaws.com,172.31.42.209' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 79
# Fri Oct  4 17:28:21 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV063 cptac_ov SAMN06208757 SRR9862071 SRX6615762
# Instance ID: i-0fed0b225211da4c3
# Public DNS: ec2-34-220-48-80.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-220-48-80.us-west-2.compute.amazonaws.com,172.31.32.244' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 80
# Fri Oct  4 17:31:27 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 05BR005 cptac_brca SAMN06208421 SRR9862072 SRX6615763
# Instance ID: i-03a9dbc3c090c997f
# Public DNS: ec2-54-245-9-200.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-245-9-200.us-west-2.compute.amazonaws.com,172.31.36.246' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 81
# Fri Oct  4 17:34:32 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 05BR038 cptac_brca SAMN06208827 SRR9862073 SRX6615764
# Instance ID: i-04f6324279ccc5ec0
# Public DNS: ec2-34-212-52-244.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-212-52-244.us-west-2.compute.amazonaws.com,172.31.32.180' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 82
# Fri Oct  4 17:37:38 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR049 cptac_brca SAMN06208393 SRR9862074 SRX6615793
# Instance ID: i-014790feebed8df5b
# Public DNS: ec2-34-211-30-131.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-211-30-131.us-west-2.compute.amazonaws.com,172.31.45.27' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 83
# Fri Oct  4 17:40:44 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR075 cptac_brca SAMN06208808 SRR9862075 SRX6615794
# Instance ID: i-037d471189a576159
# Public DNS: ec2-54-212-71-123.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-212-71-123.us-west-2.compute.amazonaws.com,172.31.40.237' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 84
# Fri Oct  4 17:43:50 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11LU013 cptac_lung SAMN06208436 SRR9862076 SRX6615795
# Instance ID: i-0239f29483f5b32e1
# Public DNS: ec2-18-237-6-75.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-237-6-75.us-west-2.compute.amazonaws.com,172.31.37.89' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 85
# Fri Oct  4 17:46:56 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11LU016 cptac_lung SAMN06208834 SRR9862077 SRX6615796
# Instance ID: i-0cd9156a07aa6163e
# Public DNS: ec2-52-34-48-204.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-34-48-204.us-west-2.compute.amazonaws.com,172.31.33.83' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 86
# Fri Oct  4 17:50:02 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11LU022 cptac_lung SAMN06208463 SRR9862078 SRX6615797
# Instance ID: i-01a5abe2f443ec8fe
# Public DNS: ec2-34-219-198-210.us-west-2.compute.amazonaws.com
# ...
# Warning: Permanently added 'ec2-35-167-132-210.us-west-2.compute.amazonaws.com,172.31.3.219' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 141
# Fri Oct  4 20:40:16 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01BR018 cptac_brca SAMN04111348 SRR2518437 SRX1288086
# Instance ID: i-08bc86c5f67ca0cd6
# Public DNS: ec2-18-237-152-26.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-237-152-26.us-west-2.compute.amazonaws.com,172.31.6.155' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 142
# Fri Oct  4 20:43:21 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01BR025 cptac_brca SAMN04111419 SRR2518438 SRX1288087
# Instance ID: i-0d3457470b38a0bac
# Public DNS: ec2-34-222-30-56.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-222-30-56.us-west-2.compute.amazonaws.com,172.31.4.66' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 143
# Fri Oct  4 20:46:26 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01BR027 cptac_brca SAMN04111437 SRR2518439 SRX1288088
# Instance ID: i-04fc756251620efe2
# Public DNS: ec2-52-89-255-157.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-89-255-157.us-west-2.compute.amazonaws.com,172.31.2.34' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 144
# Fri Oct  4 20:49:32 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01OV023 cptac_ov SAMN04111438 SRR2518442 SRX1288091
# Instance ID: i-0d2841da0729868be
# Public DNS: ec2-34-208-46-158.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-208-46-158.us-west-2.compute.amazonaws.com,172.31.10.226' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 145
# Fri Oct  4 20:52:37 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 01OV030 cptac_ov SAMN04111374 SRR2518443 SRX1288092
# Instance ID: i-0f8aa44de77ab1797
# Public DNS: ec2-34-221-134-230.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-221-134-230.us-west-2.compute.amazonaws.com,172.31.3.246' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 146
# Fri Oct  4 20:55:43 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 02OV008 cptac_ov SAMN04111368 SRR2518444 SRX1288093
# Instance ID: i-079ba8dfc21340979
# Public DNS: ec2-35-163-13-192.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-163-13-192.us-west-2.compute.amazonaws.com,172.31.3.194' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 147
# Fri Oct  4 20:58:48 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 02OV015 cptac_ov SAMN04111367 SRR2518445 SRX1288094
# Instance ID: i-0066d11a730a258bf
# Public DNS: ec2-34-216-238-37.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-216-238-37.us-west-2.compute.amazonaws.com,172.31.0.175' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 148
# Fri Oct  4 21:01:54 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 02OV022 cptac_ov SAMN04111424 SRR2518446 SRX1288095
# Instance ID: i-0ae21c50c4f67c0b3
# Public DNS: ec2-35-160-16-159.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-160-16-159.us-west-2.compute.amazonaws.com,172.31.2.25' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 149
# Fri Oct  4 21:04:59 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 02OV023 cptac_ov SAMN04111311 SRR2518447 SRX1288096
# Instance ID: i-0b79ebd8a1dae99dd
# Public DNS: ec2-18-236-224-210.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-236-224-210.us-west-2.compute.amazonaws.com,172.31.7.221' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 150
# Fri Oct  4 21:08:05 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 03BR002 cptac_brca SAMN04111349 SRR2518448 SRX1288097
# Instance ID: i-0ddbc80cef120df9c
# Public DNS: ec2-54-212-146-39.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-212-146-39.us-west-2.compute.amazonaws.com,172.31.15.213' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 151
# Fri Oct  4 21:11:11 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 03BR004 cptac_brca SAMN04111337 SRR2518449 SRX1288098
# Instance ID: i-04a96e05306e4b9ac
# Public DNS: ec2-18-236-238-211.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-236-238-211.us-west-2.compute.amazonaws.com,172.31.9.21' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 152
# Fri Oct  4 21:14:16 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 03BR005 cptac_brca SAMN04111395 SRR2518450 SRX1288099
# Instance ID: i-0bc9e922fbdacbdac
# Public DNS: ec2-34-211-56-72.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-211-56-72.us-west-2.compute.amazonaws.com,172.31.12.120' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 153
# Fri Oct  4 21:17:21 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 03BR010 cptac_brca SAMN04111313 SRR2518451 SRX1288100
# Instance ID: i-0586066362d8c318f
# Public DNS: ec2-34-211-147-119.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-211-147-119.us-west-2.compute.amazonaws.com,172.31.3.107' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 154
# Fri Oct  4 21:20:27 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV008 cptac_ov SAMN04111379 SRR2518452 SRX1288101
# Instance ID: i-022de1cec5f300733
# Public DNS: ec2-34-221-103-146.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-221-103-146.us-west-2.compute.amazonaws.com,172.31.42.144' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 155
# Fri Oct  4 21:23:33 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV011 cptac_ov SAMN04111351 SRR2518453 SRX1288102
# Instance ID: i-0c78b4090d71af081
# Public DNS: ec2-52-34-64-158.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-34-64-158.us-west-2.compute.amazonaws.com,172.31.47.200' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 156
# Fri Oct  4 21:26:39 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV012 cptac_ov SAMN04111381 SRR2518454 SRX1288103
# Instance ID: i-0d1bcd0e568aa444c
# Public DNS: ec2-54-245-214-32.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-245-214-32.us-west-2.compute.amazonaws.com,172.31.39.107' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 157
# Fri Oct  4 21:29:45 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 04OV013 cptac_ov SAMN04111406 SRR2518455 SRX1288104
# Instance ID: i-0169d8fb4041c07f7
# Public DNS: ec2-34-212-127-175.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-212-127-175.us-west-2.compute.amazonaws.com,172.31.36.234' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 158
# Fri Oct  4 21:32:51 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 05BR001 cptac_brca SAMN04111398 SRR2518456 SRX1288105
# Instance ID: i-0722a0783f1e6e476
# Public DNS: ec2-54-202-26-122.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-202-26-122.us-west-2.compute.amazonaws.com,172.31.32.30' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 159
# Fri Oct  4 21:35:56 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 05BR003 cptac_brca SAMN04111343 SRR2518457 SRX1288106
# Instance ID: i-0c8680a894373c159
# Public DNS: ec2-54-201-85-122.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-201-85-122.us-west-2.compute.amazonaws.com,172.31.45.158' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 160
# Fri Oct  4 21:39:02 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 05BR009 cptac_brca SAMN04111387 SRR2518458 SRX1288107
# Instance ID: i-00073778a2ba3f11c
# Public DNS: ec2-34-218-79-232.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-218-79-232.us-west-2.compute.amazonaws.com,172.31.46.96' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 161
# Fri Oct  4 21:42:09 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 05BR016 cptac_brca SAMN04111393 SRR2518459 SRX1288108
# Instance ID: i-040e2980e575a63a5
# Public DNS: ec2-54-187-239-230.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-187-239-230.us-west-2.compute.amazonaws.com,172.31.13.215' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 162
# Fri Oct  4 21:45:15 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 06BR003 cptac_brca SAMN04111369 SRR2518465 SRX1288114
# Instance ID: i-01dc725b0bcd6913c
# Public DNS: ec2-54-189-121-141.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-189-121-141.us-west-2.compute.amazonaws.com,172.31.9.61' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 163
# Fri Oct  4 21:48:20 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 06BR005 cptac_brca SAMN04111310 SRR2518466 SRX1288115
# Instance ID: i-0fa95959b2bee34f3
# Public DNS: ec2-54-245-147-252.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-245-147-252.us-west-2.compute.amazonaws.com,172.31.2.179' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 164
# Fri Oct  4 21:51:26 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 06BR006 cptac_brca SAMN04111309 SRR2518467 SRX1288116
# Instance ID: i-0d625425238e6076a
# Public DNS: ec2-54-201-101-233.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-201-101-233.us-west-2.compute.amazonaws.com,172.31.2.233' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 165
# Fri Oct  4 21:54:31 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR003 cptac_brca SAMN04111417 SRR2518473 SRX1288122
# Instance ID: i-04cd8ce7392986530
# Public DNS: ec2-54-149-204-81.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-149-204-81.us-west-2.compute.amazonaws.com,172.31.11.80' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 166
# Fri Oct  4 21:57:37 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 11BR009 cptac_brca SAMN04111390 SRR2518474 SRX1288123
# Instance ID: i-03f5baef12a129719
# Public DNS: ec2-54-201-35-215.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-201-35-215.us-west-2.compute.amazonaws.com,172.31.7.143' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 167
# Fri Oct  4 22:00:42 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 17OV001 cptac_ov SAMN04111328 SRR2518475 SRX1288124
# Instance ID: i-09003bd9273bd8663
# Public DNS: ec2-54-185-121-187.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-185-121-187.us-west-2.compute.amazonaws.com,172.31.5.224' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# Launch instance # 168
# Fri Oct  4 22:03:48 UTC 2019
# Instance Type: c4.xlarge
# AMI Image: ami-0b375c9c58cb4a7a2
# Run Script: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh
# Parameters: 17OV002 cptac_ov SAMN04111370 SRR2518476 SRX1288125
# Instance ID: i-025b89310328c4f87
# Public DNS: ec2-35-165-125-210.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-165-125-210.us-west-2.compute.amazonaws.com,172.31.3.140' (ECDSA) to the list of known hosts.
# download: s3://crownproject/cptac/scripts/hgr1_align_v4.cptac.sh to ./hgr1_align_v4.cptac.sh
#
#
# [ec2-user@ip-172-31-43-66 ~]$ Fri Oct  4 22:24:22 UTC 2019

# %% [markdown]
# #### Adcalc CPTAC II
#
# `ADcalc_cptac2.sh`

# %%
#!/bin/bash
# ADcalc_cptac.sh
# Allelic Depth Calculator
# for a position
#
# s3://crownproject/hCAGE/ADcalc_hcage.sh

# Controls -----------------
DEPTH='100000' #Max per file DP

# Regions in hgr1.fa reference genome
REGIONS=('chr13:1003660-1005529' 'chr13:1005529-1005629' \
        'chr13:10219-10340' 'chr13:1006622-1006779' 'chr13:1007948-1013018')

# Corresponding region/gene names
GENES=('18S' '18SE' '5S' '5.8S' '28S')

# 18S  1870
# 18SE 101
# 5S   122
# 5.8S 158
# 28S  5071

# Terminate instances upon completion (for debugging)
TERMINATE='FALSE'

# S3 Output directory
S3DIR='s3://crownproject/cptac/gvcf/'
BAMLIST='bam.list.tmp'

# Script ------------------ ------------------------------
cd ~/cptac/
mkdir -p GVCF #Output Folder
TYPE='cptac_brca' # hardcode single ccle run
cd bam

    echo Analyzing $TYPE...
    #cd $TYPE

    ls *brca*.bam > bam.list.tmp
    ls *.bam > ../GVCF/$TYPE.bamlist
          
    for index in ${!GENES[*]}
    do
      printf "Started processing %s\n" ${GENES[$index]}
      OUTPUT="../GVCF/$TYPE.${GENES[$index]}.gvcf"

      # Iterate through every bam file in directory
      # look-up position and return VCF
      bcftools mpileup -f ~/resources/hgr1/hgr1.fa \
        --max-depth $DEPTH -A --min-BQ 30 \
        -a FORMAT/DP,AD \
        -r ${REGIONS[$index]} \
        --ignore-RG \
        -b $BAMLIST | \
        bcftools annotate -x INFO,FORMAT/PL - | \
        bcftools view -O v - \
        >> $OUTPUT

      RESULTS+=("$OUTPUT")
      printf "Done with %s \n" ${GENES[$index]}
      printf "%s\n" ${REGIONS[$index]}

    done

    rm bam.list.tmp


# Script ------------------ ------------------------------
cd ~/cptac/
mkdir -p GVCF #Output Folder
TYPE='cptac_ov' # hardcode single ccle run
cd bam

    echo Analyzing $TYPE...
    #cd $TYPE

    ls *ov*.bam > bam.list.tmp
    ls *.bam > ../GVCF/$TYPE.bamlist
          
    for index in ${!GENES[*]}
    do
      printf "Started processing %s\n" ${GENES[$index]}
      OUTPUT="../GVCF/$TYPE.${GENES[$index]}.gvcf"

      # Iterate through every bam file in directory
      # look-up position and return VCF
      bcftools mpileup -f ~/resources/hgr1/hgr1.fa \
        --max-depth $DEPTH -A --min-BQ 30 \
        -a FORMAT/DP,AD \
        -r ${REGIONS[$index]} \
        --ignore-RG \
        -b $BAMLIST | \
        bcftools annotate -x INFO,FORMAT/PL - | \
        bcftools view -O v - \
        >> $OUTPUT

      RESULTS+=("$OUTPUT")
      printf "Done with %s \n" ${GENES[$index]}
      printf "%s\n" ${REGIONS[$index]}

    done

    rm bam.list.tmp
    
# Script ------------------ ------------------------------
cd ~/cptac/
mkdir -p GVCF #Output Folder
TYPE='cptac_lung' # hardcode single ccle run
cd bam

    echo Analyzing $TYPE...
    #cd $TYPE

    ls *lung*.bam > bam.list.tmp
    ls *.bam > ../GVCF/$TYPE.bamlist
          
    for index in ${!GENES[*]}
    do
      printf "Started processing %s\n" ${GENES[$index]}
      OUTPUT="../GVCF/$TYPE.${GENES[$index]}.gvcf"

      # Iterate through every bam file in directory
      # look-up position and return VCF
      bcftools mpileup -f ~/resources/hgr1/hgr1.fa \
        --max-depth $DEPTH -A --min-BQ 30 \
        -a FORMAT/DP,AD \
        -r ${REGIONS[$index]} \
        --ignore-RG \
        -b $BAMLIST | \
        bcftools annotate -x INFO,FORMAT/PL - | \
        bcftools view -O v - \
        >> $OUTPUT

      RESULTS+=("$OUTPUT")
      printf "Done with %s \n" ${GENES[$index]}
      printf "%s\n" ${REGIONS[$index]}

    done

    rm bam.list.tmp

# Copy GVCF output to AWS S3
cd ../GVCF
aws s3 cp --recursive ./ $S3DIR
