# %% [markdown]
# # TCGA-5 COAD Complete RNA-seq hgr1 alignments
# ```
# pi:ababaian
# files: ~/Crown/data2/tcga_5_coad2
# start: 2018 11 20
# complete : 2018 .. ..
# ```
#
# ## Introduction
#
# Download and align the complete set of TCGA-COAD data (all Cancer RNA-seq, even those excluding normal controls).
#
# This complete set will form the basis of doing group-based analysis of normo- vs. hypo-macp differential gene expression and survival analysis, it will be a large data-set which hopefully will give robust differential expression analyses.

# %% [markdown]
# ## Materials and Methods
#
# #### TCGA Data Input
#
# Search Term for limiting files
# ```
# cases.project.project_id in ["TCGA-COAD"] and files.data_category in ["Raw Sequencing Data","Transcriptome Profiling"] and files.data_format in ["BAM"] and files.experimental_strategy in ["RNA-Seq"]
# ```
#
# - Yields 521 files in 456 cases
# - Metadata and manifest downloaded and saved to `../data2/tcga_5_coad2/metadata/`
# - 434 Files will be analyzed in coad2 run (excludes those already analyzed)
#
# Data selection saved in `COAD2_input.xlsx`

# %%
# New GDC Token downloaded - 181120

# %%
WORKDIR='/home/artem/Crown/data2/tcga_5_coad2'

cd $WORKDIR
ls
# Out:
# coad2_input.txt   hgr1_align_v2.tcga.sh  tcga_5_coad_pilot.log
# COAD2_input.xlsx  metadata               tcga_5_coad_pilot.txt
# droneB.sh         queenB.sh              tcga_5_coad_run1.txt

# %%
INPUT_ALL='coad2_input.txt'

cat $INPUT_ALL

# Pilot set
INPUT0='tcga_5_coad_pilot.txt'
sed -n 1,3p $INPUT_ALL > $INPUT0
# Out:
# TCGA-3L-AA1B-01A	TCGA-COAD	c1c36a5e-5410-45ef-8954-70c26ef27066
# TCGA-4N-A93T-01A	TCGA-COAD	fd9ac46f-2517-446c-9325-06f8db2ab89c
# TCGA-4T-AA8H-01A	TCGA-COAD	06921a3a-5c30-4fb0-8ed0-347f51af459d
# TCGA-5M-AAT4-01A	TCGA-COAD	ef99b87e-4d27-4689-be93-6a55f20ca577
# TCGA-5M-AAT5-01A	TCGA-COAD	f1b27b36-e2c0-42da-beb1-2bc2bc61abb9
# TCGA-5M-AAT6-01A	TCGA-COAD	b80f2f67-842c-4b6d-9b8c-936c6f03ac96
# TCGA-5M-AATA-01A	TCGA-COAD	cbbd47c7-cc50-479d-a1a9-7199f0bdb9eb
# TCGA-5M-AATE-01A	TCGA-COAD	8315040e-4201-42fe-9c4e-10ff635672cf
# TCGA-A6-2672-01A	TCGA-COAD	f08dc7f4-3cc3-4743-a84e-d586d74af8d1
# TCGA-A6-2672-01B	TCGA-COAD	ff6d6688-c19c-4a7f-8058-4d1bc0249d83
# TCGA-A6-2674-01A	TCGA-COAD	9d537202-d436-48de-8ee8-2d417576705f
# TCGA-A6-2674-01A	TCGA-COAD	0c02bf18-3f95-468a-bdb8-408ad4e77e6a
# TCGA-A6-2674-01B	TCGA-COAD	f9745437-1d51-43f3-940d-0086a1912aec
# TCGA-A6-2676-01A	TCGA-COAD	2e48e315-5cdf-4fee-aa5d-3c7baa4030ad
# TCGA-A6-2677-01A	TCGA-COAD	90832632-cf57-463b-9d08-c76975066f56
# %%
cd $WORKDIR
# Echo 

cat hgr1_align_v2.tcga.sh
echo 
echo
cat queenB.sh
echo 
echo
cat droneB.sh
echo 
echo
# Out:
# #!/bin/bash
# # 1kg_align_v2.tcga.sh
# # rDNA alignment pipeline
# # 180831 build -- TCGA
# # AMI: crown-180813 - ami-0031fd61f932bdef9
# # EC2: c4.2xlarge (8cpu / 15 gb)
# # EC2: c4.xlarge  (4cpu / 8  gb)
# # Storage: 200 Gb
# #
#
# # Input Requirements --------------------------
#
# # $1 : Library name and file-output name
# # $2 : Library population/analysis set
# # $3 : Library UUID
#
# # Control Panel -------------------------------
# # CPU
# 	THREADS='3'
#
# # Sequencing Data
# 	LIBRARY=$1 # Library/ File name
#
# # TCGA FILE UUID
#   UUID=$3
#
#  # FastQ File-names
#     FQ0="$LIBRARY.tmp.sort.0.fq"
#     FQ1="$LIBRARY.tmp.sort.1.fq"
#     FQ2="$LIBRARY.tmp.sort.2.fq"
#
# # Read Group Data
# # Extract from downloaded BAM file / input
# 	RGPO=$2 # Patient Population
#
# 	#RGSM= # Sample. Patient Identifer
# 	#RGID= # Read Group ID. Accession Number
#
# 	RGLB=$LIBRARY # Library Name. Accession Number
# 	RGPL='ILLUMINA'  # Sequencing Platform.
#
# 	# Extract Sequencing Run Info
# 	#  RGPU=$(gzip -dc $FQ1 | head -n1 - | cut -f1 -d':' | cut -f2 -d' ')
#
# # Initialize wordir ---------------------------
#
# # Make working directory
#   mkdir -p align; cd align
#
# # Copy hgrX genome and create bowtie2 index
#   cp ~/resources/hgr1/* ./
#
# # Load updated GDC token to instance
# aws s3 cp s3://crownproject/tcga/scripts/gdc.token gdc.token
# chmod 600 gdc.token
#
# # Download RNAseq BAM file
# # with a UUID as input
#   ~/bin/gdc-client download -t gdc.token -d ./ \
#   -n $THREADS $UUID
#
# # Link the RNA-seq bamfile which is called by its UID to workdir
#   ln -s */*.bam input.bam
#
# # Extract ReadGroup Sample Name (SM)
#   RGSM=$(~/bin/samtools view -H input.bam | grep '^@RG' | sed "s/.*SM:\([^\t]*\).*/\1/g" | uniq )
#
# # Extract ReadGroup identifier (ID)
#   #RGID=$(~/bin/samtools view -H input.bam | grep '^@RG' | sed "s/.*ID:\([^\t]*\).*/\1/g" | uniq )
#   RGID=$(~/bin/samtools view -H input.bam | grep '^@RG' | sed "s/.*ID:\([^\t]*\).*/\1/g" | head -n1 - )
#
# # Convert input bam file to fastq files for re-alignment
# ~/bin/samtools sort -@ $THREADS-n input.bam | \
#     ~/bin/samtools fastq -@ $THREADS -O \
#     -0 $FQ0 \
#     -1 $FQ1 \
#     -2 $FQ2 -
#
# # SINGLE END READS ====================================================
#
# if [ -s $FQ0 ]
# then
#     # Single-End Extracted Reads Alignment
#
#     # Extract Sequencing Run Info
#     #RGPU=$(gzip -dc $FQ0| head -n1 - | cut -f1 -d':' | cut -f2 -d' ')
#     RGPU=$(head -n1 $FQ0 | cut -f1 -d':' | cut -f2 -d' ')
#
#     # Bowtie2: align to genome
#     bowtie2 --very-sensitive-local -p $THREADS \
#       --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \
#       --rg PL:$RGPL --rg PU:$RGPU \
#       -x hgr1 -U $FQ0 | \
#       ~/bin/samtools view -bS - > aligned_unsorted.bam
#
#     # Calculate library flagstats
#       ~/bin/samtools flagstat aligned_unsorted.bam > aligned_unsorted.flagstat
#       rm $FQ0 # Remove fastq files to save space
#
#     # Read Subset ------------------------------
#     # Extract mapped reads, and their unmapped pairs
#
#       # Extract Header
#       ~/bin/samtools view -H aligned_unsorted.bam > align.header.tmp
#
#       # Extract Mapped Reads
#       ~/bin/samtools view -b -F 4 aligned_unsorted.bam | \
#       ~/bin/samtools sort -@ $THREADS -O BAM - > align.hgr1.bam #mapped
#
#     # Calcualte library flagstats
#     ~/bin/samtools index align.hgr1.bam
#     ~/bin/samtools flagstat align.hgr1.bam > align.hgr1.flagstat
#
#     # Rename the total Bam Files
#       #mv aligned_unsorted.bam $LIBRARY.se.bam
#       #mv aligned_unsorted.bam.bai $LIBRARY.se.bam.bai
#       mv aligned_unsorted.flagstat $LIBRARY.se.flagstat
#
#     # Rename the hgr-aligned Bam files
#       mv align.hgr1.bam $LIBRARY.hgr1.se.bam
#       mv align.hgr1.bam.bai $LIBRARY.hgr1.se.bam.bai
#       mv align.hgr1.flagstat $LIBRARY.hgr1.se.flagstat
#
#     # Alignments (Full)
#     aws s3 cp $LIBRARY.se.flagstat s3://crownproject/tcga/$RGPO/
#
#     # Alignments (Aligned)
#     aws s3 cp $LIBRARY.hgr1.se.bam s3://crownproject/tcga/$RGPO/
#     aws s3 cp $LIBRARY.hgr1.se.bam.bai s3://crownproject/tcga/$RGPO/
#     aws s3 cp $LIBRARY.hgr1.se.flagstat s3://crownproject/tcga/$RGPO/
#
#
# fi
#
# # PAIRED END READS ====================================================
#
#
# if [ -s $FQ1 ]
# then
#     # Paired-End Extracted Reads Alignment
#
#     # Extract Sequencing Run Info
#     #RGPU=$(gzip -dc $FQ1| head -n1 $FQ1 | cut -f1 -d':' | cut -f2 -d' ')
#     RGPU=$(head -n1 $FQ1 | cut -f1 -d':' | cut -f2 -d' ')
#
#     # Bowtie2: align to genome
#     bowtie2 --very-sensitive-local -p $THREADS \
#       --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \
#       --rg PL:$RGPL --rg PU:$RGPU \
#       -x hgr1 -1 $FQ1 -2 $FQ2 | \
#       ~/bin/samtools view -bS - > aligned_unsorted.bam
#
#     # Calcualte library flagstats
#       ~/bin/samtools flagstat aligned_unsorted.bam > aligned_unsorted.flagstat
#
#       rm $FQ1 $FQ2 # Remove fastq files to save space
#
#
#     # Read Subset ------------------------------
#     # Extract mapped reads, and their unmapped pairs
#
#       # Extract Header
#       ~/bin/samtools view -H aligned_unsorted.bam > align.header.tmp
#
#       # Unmapped reads with mapped pairs
#       # Extract Mapped Reads
#       # and their unmapped pairs
#       ~/bin/samtools view -b -F 4 aligned_unsorted.bam > align.F4.bam #mapped
#       ~/bin/samtools view -b -f 4 -F 8 aligned_unsorted.bam > align.f4F8.bam #unmapped pairs
#
#       # Re-compile bam file
#       ~/bin/samtools cat -h align.header.tmp -o align.hgr1.tmp.bam align.F4.bam align.f4F8.bam
#         ~/bin/samtools sort -@ $THREADS -O BAM align.hgr1.tmp.bam > align.hgr1.bam
#         ~/bin/samtools index align.hgr1.bam
#         ~/bin/samtools flagstat align.hgr1.bam > align.hgr1.flagstat
#
#       # Clean up
#       rm *tmp* align.F4.bam align.f4F8.bam
#
#     # Rename the total Bam Files
#       mv aligned_unsorted.bam $LIBRARY.bam
#       #mv aligned_unsorted.bam.bai $LIBRARY.bam.bai
#       mv aligned_unsorted.flagstat $LIBRARY.flagstat
#
#     # Rename the hgr-aligned Bam files
#       mv align.hgr1.bam $LIBRARY.hgr1.bam
#       mv align.hgr1.bam.bai $LIBRARY.hgr1.bam.bai
#       mv align.hgr1.flagstat $LIBRARY.hgr1.flagstat
#
#     # Copy output to AWS S3
#     # Alignments (Full)
#       aws s3 cp $LIBRARY.flagstat s3://crownproject/tcga/$RGPO/
#
#     # Alignments (Aligned)
#       aws s3 cp $LIBRARY.hgr1.bam s3://crownproject/tcga/$RGPO/
#       aws s3 cp $LIBRARY.hgr1.bam.bai s3://crownproject/tcga/$RGPO/
#       aws s3 cp $LIBRARY.hgr1.flagstat s3://crownproject/tcga/$RGPO/
#
# fi
#
#
# # Copy screen log file to AWS S3
# cp ~/screenlog.0 ./$LIBRARY.screenlog
# aws s3 cp $LIBRARY.screenlog s3://crownproject/tcga/logs/
#
# # Shutdown and Terminate instance
# EC2ID=$(ec2metadata --instance-id)
# sleep 20s # to catch errors
#
# #aws ec2 terminate-instances --instance-ids $EC2ID
#
# # Script complete
#
#
# #!/bin/bash
# # queenB.sh
# # 20180814 build
# # EC2 Launch / Control Script
# #
#
# # 1. queenB script is initialized locally and input files
# #    are parsed ready for cluster analaysis
# # 2. queenB launches instances, logs in to it and runs the
# #    droneB.sh script remotely.
# # 3. The droneB script is executed on the instance and it
# #    launches a `screen` on the instance and loads and
# #    starts to perform the $TASK (gather.sh) script.
# # 4. TASK script should include a instance shut-down
# #    command to close instance upon completion.
# #
#
# # Control Panel =========================
# # EC2 TASK Script - script for droneB to execute
# TASK="s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh"
#
# # Parameter file:
# # Each line of PARAMETERS will be input to STDIN of
# # the droneB script which can then be used to run the
# # TASK script.
# # i.e. bash droneB.sh <line_N_of_PARAMETERS>
# # PARAMETERS="tcga0_input.txt"
# PARAMETERS=$1
#
# # EC2 Set-up
# instanceTYPE='c4.xlarge'
# imageID='ami-0031fd61f932bdef9' #AMI TCGA
#
# devNAME='/dev/sda1' # /dev/sda1 for Crown-AMI
# volSIZE='120' # in Gb
#
# # Number of instances to launch
# #COUNT=2 # predetermined number
# COUNT=$(awk 'END{print NR}' $PARAMETERS) # for each input argument
#
# # Security
# keyNAME='CrownKey'
# keyPATH="/home/ec2-user/.ssh/CrownKey.pem"
# secGROUP='crown-group'
#
# # =======================================
#
# for ITER in $(seq 1 $COUNT)
# do
#
#   # Count the total number of instances
#   running_instance=$(aws ec2 describe-instances |\
#     grep '"Name": "running"' - |\
#     wc -l - | cut -f1 -d' ' - )
#
#   while [ $running_instance -ge 25 ];
#   do
#
#   	echo "Reached max of $running_instance, wait."
#   	echo ''
#
#   	# If there are greater then 25 instances
#   	# wait for instance to close
#   	sleep 5m
#
#   	running_instance=$(aws ec2 describe-instances |\
#     grep '"Name": "running"' - |\
#     wc -l - | cut -f1 -d' ' - )
#   done
#
#   # Extract Parameters/Arguments ----------
#
#   ARGS=$(sed -n "$ITER"p $PARAMETERS | sed 's/\t/ /g' - )
#
#   echo "Launch instance # $ITER"
#   date
#   echo "Instance Type: $instanceTYPE"
#   echo "AMI Image: $imageID"
#   echo "Run Script: $TASK"
#   echo "Parameters: $ARGS"
#
#   # Launch an instance --------------------
#   # NOTE: each iteration of the for loop launches one instance
#   # therefore each loop launches only one instance
#   aws ec2 run-instances --image-id $imageID --count 1 \
#    --instance-type $instanceTYPE --key-name $keyNAME \
#    --block-device-mappings DeviceName=$devNAME,Ebs={VolumeSize=$volSIZE} \
#    --security-groups $secGROUP > launch.tmp
#
#   # Another alternative is to use --user-data droneB.sh
#   # which will run at instance boot-up
#   # passing arguments to it may be challenging
#
#   # Retrieve instance ID
#   instanceID=$(cat launch.tmp | \
#     egrep -o -e 'InstanceId[":/A-Za-z0-9_ \\-]*' - |\
#     cut -f2 -d' ' - | xargs)
#
#   echo "Instance ID: $instanceID"
#
#
#   # Add a few minute wait here to allow for Public DNS to be assigned
#   # otherwise ssh doesn't work
#   sleep 180s
#
#   # Check that the instance is 'running' and not pending
#   pending_instance=$(aws ec2 describe-instances |\
#    grep '"Name": "pending"' - |\
#    wc -l - | cut -f1 -d' ' - )
#
#   while [ $pending_instance -gt 0 ];
#   do
#
#   	echo "Launchign instance not ready yet, chill"
#   	# Instance still pending
#   	sleep 180s
#
#     pending_instance=$(aws ec2 describe-instances |\
#      grep '"Name": "pending"' - |\
#      wc -l - | cut -f1 -d' ' - )
#   done
#
#
#   # Retrieve public DNS
#   aws ec2 describe-instances --instance-ids $instanceID > launch2.tmp
#
#   pubDNS=$(cat launch2.tmp | \
#     egrep -o -m 1 -e 'PublicDnsName[.":/A-Za-z0-9_ \\-]*' - |\
#     cut -f2 -d' ' - | xargs)
#
#   echo "Public DNS: $pubDNS"
#
#   # Access the instance -------------------
#
#   LOGIN="ubuntu@$pubDNS"
#
#   ssh -i $keyPATH \
#     -o StrictHostKeyChecking=no \
#     $LOGIN 'bash -s' < droneB.sh $TASK $(echo $ARGS)
#
#   # Cleanup
#   rm *.tmp
#
#   echo ''
#   echo ''
#
# done
#
# # end of script
#
# #!/bin/bash
# # droneB.sh
# #
#
# # This script-layer is neccesary to launch a screen session
# # on each ec2-machine. The pipeline is run within that session
# # and the output is logged. This allows 'looking in' on sessions
# # as they are running.
#
# # Commands to run on server-side
# # ===============================================================
#
# SCRIPTPATH=$1
#
# SCRIPT=$(basename $1)
#
# shift # drop first (TASK or SCRIPT variable)
#
# # Download pipeline / droneB's function
#   aws s3 cp $SCRIPTPATH ./
#
#   chmod 777 *.sh
#
# # open screen; run gather.sh function. -L logged
#   screen -Ldmt sh ~/$SCRIPT $@
#
#
# # ===============================================================

# %% [markdown]
# ### Results -- COAD-2 Pilot Run
#
# Run first three libraries as a pilot to ensure pipeline is operational

# %%
# Local Folder Operations -----------------------------
# also re-ran with update
# LOCAL:
cd $WORKDIR

#NOTE For pilot run, AWS s3 shutdown commented out. Re-upload hgr1 script upon full run

aws s3 cp queenB.sh s3://crownproject/tcga/scripts/
aws s3 cp droneB.sh s3://crownproject/tcga/scripts/
aws s3 cp hgr1_align_v2.tcga.sh s3://crownproject/tcga/scripts/
aws s3 cp $INPUT0 s3://crownproject/tcga/scripts/
aws s3 cp ../../gdc.token.txt s3://crownproject/tcga/scripts/gdc.token
# Out:
# upload: ./queenB.sh to s3://crownproject/tcga/scripts/queenB.sh
# upload: ./droneB.sh to s3://crownproject/tcga/scripts/droneB.sh
# upload: ./hgr1_align_v2.tcga.sh to s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# upload: ./tcga_5_coad_pilot.txt to s3://crownproject/tcga/scripts/tcga_5_coad_pilot.txt
# upload: ../../gdc.token.txt to s3://crownproject/tcga/scripts/gdc.token

# %%
# Remote EC2 Instance Operations ----------------------

# Remote:
# Manually open an Amazon Linux 2 AMI
# ami-6cd6f714
# t2.micro
#
# ssh login:
# ssh -i "crown.pem" ec2-user@PUBLICDNS
#

# Commands on EC2 machine to set-up AWS
# enter personal login info:

# REMOTE:
#aws configure
  # AWS Key ID
  # AWS Secret Key ID
  # Region: us-west-2
  
# Copy local run files to S3 and download them on EC2

# REMOTE:
# aws s3 cp --recursive s3://crownproject/tcga/scripts/ ./
#
# mv <KEY>.pem ~/.ssh/
# chmod 400 ~/.ssh/<KEY>.pem

# REMOTE:
# Open logging screen and being launchign EC2 instances
# screen -L
# 
# bash queenB.sh tcga_5_coad_pilot.txt
#
# aws s3 cp screenlog.0 s3://crownproject/tcga/logs/tcga_5_coad_pilot.log

aws s3 cp s3://crownproject/tcga/logs/tcga_5_coad_pilot.log ./
cat tcga_5_coad_pilot.log

# Run completed successfully
# Out:
# download: s3://crownproject/tcga/logs/tcga_5_coad_pilot.log to ./tcga_5_coad_pilot.log
# bash queenB.sh tcga_5_coad_pilot.txt
# Launch instance # 1
# Tue Nov 20 22:05:52 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-3L-AA1B-01A TCGA-COAD c1c36a5e-5410-45ef-8954-70c26ef27066
# Instance ID: i-0a1665d37becb1e64
# Public DNS: ec2-34-221-231-57.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-221-231-57.us-west-2.compute.amazonaws.com,172.31.31.167' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 2
# Tue Nov 20 22:08:59 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-4N-A93T-01A TCGA-COAD fd9ac46f-2517-446c-9325-06f8db2ab89c
# Instance ID: i-0dcc93092a196374d
# Public DNS: ec2-54-186-165-164.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-186-165-164.us-west-2.compute.amazonaws.com,172.31.22.133' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 3
# Tue Nov 20 22:12:08 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-4T-AA8H-01A TCGA-COAD 06921a3a-5c30-4fb0-8ed0-347f51af459d
# Instance ID: i-096e7eef7cdcb82a0
# Public DNS: ec2-34-209-48-89.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-209-48-89.us-west-2.compute.amazonaws.com,172.31.16.240' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# kec2-user@ip-172-31-32-142:~\[ec2-user@ip-172-31-32-142 ~]$ [ec2-user@ip-172-31-32-142 ~]$ ls
# droneB.sh  gdc.token  hgr1_align_v2.tcga.sh  queenB.sh	screenlog.0  tcga_5_coad_pilot.txt
# kec2-user@ip-172-31-32-142:~\[ec2-user@ip-172-31-32-142 ~]$

# %% [markdown]
# ### TCGA 5 - COAD Run set 1
#
# Run files 4 - 100

# %%
# Uncomment EC2 shutdown
cat hgr1_align_v2.tcga.sh
aws s3 cp hgr1_align_v2.tcga.sh s3://crownproject/tcga/scripts/

# Run tcga5 files 4-100
sed -n 4,100p coad2_input.txt > tcga_5_coad_run1.txt
aws s3 cp tcga_5_coad_run1.txt s3://crownproject/tcga/scripts/
# Out:
# #!/bin/bash
# # 1kg_align_v2.tcga.sh
# # rDNA alignment pipeline
# # 180831 build -- TCGA
# # AMI: crown-180813 - ami-0031fd61f932bdef9
# # EC2: c4.2xlarge (8cpu / 15 gb)
# # EC2: c4.xlarge  (4cpu / 8  gb)
# # Storage: 200 Gb
# #
#
# # Input Requirements --------------------------
#
# # $1 : Library name and file-output name
# # $2 : Library population/analysis set
# # $3 : Library UUID
#
# # Control Panel -------------------------------
# # CPU
# 	THREADS='3'
#
# # Sequencing Data
# 	LIBRARY=$1 # Library/ File name
#
# # TCGA FILE UUID
#   UUID=$3
#
#  # FastQ File-names
#     FQ0="$LIBRARY.tmp.sort.0.fq"
#     FQ1="$LIBRARY.tmp.sort.1.fq"
#     FQ2="$LIBRARY.tmp.sort.2.fq"
#
# # Read Group Data
# # Extract from downloaded BAM file / input
# 	RGPO=$2 # Patient Population
#
# 	#RGSM= # Sample. Patient Identifer
# 	#RGID= # Read Group ID. Accession Number
#
# 	RGLB=$LIBRARY # Library Name. Accession Number
# 	RGPL='ILLUMINA'  # Sequencing Platform.
#
# 	# Extract Sequencing Run Info
# 	#  RGPU=$(gzip -dc $FQ1 | head -n1 - | cut -f1 -d':' | cut -f2 -d' ')
#
# # Initialize wordir ---------------------------
#
# # Make working directory
#   mkdir -p align; cd align
#
# # Copy hgrX genome and create bowtie2 index
#   cp ~/resources/hgr1/* ./
#
# # Load updated GDC token to instance
# aws s3 cp s3://crownproject/tcga/scripts/gdc.token gdc.token
# chmod 600 gdc.token
#
# # Download RNAseq BAM file
# # with a UUID as input
#   ~/bin/gdc-client download -t gdc.token -d ./ \
#   -n $THREADS $UUID
#
# # Link the RNA-seq bamfile which is called by its UID to workdir
#   ln -s */*.bam input.bam
#
# # Extract ReadGroup Sample Name (SM)
#   RGSM=$(~/bin/samtools view -H input.bam | grep '^@RG' | sed "s/.*SM:\([^\t]*\).*/\1/g" | uniq )
#
# # Extract ReadGroup identifier (ID)
#   #RGID=$(~/bin/samtools view -H input.bam | grep '^@RG' | sed "s/.*ID:\([^\t]*\).*/\1/g" | uniq )
#   RGID=$(~/bin/samtools view -H input.bam | grep '^@RG' | sed "s/.*ID:\([^\t]*\).*/\1/g" | head -n1 - )
#
# # Convert input bam file to fastq files for re-alignment
# ~/bin/samtools sort -@ $THREADS-n input.bam | \
#     ~/bin/samtools fastq -@ $THREADS -O \
#     -0 $FQ0 \
#     -1 $FQ1 \
#     -2 $FQ2 -
#
# # SINGLE END READS ====================================================
#
# if [ -s $FQ0 ]
# then
#     # Single-End Extracted Reads Alignment
#
#     # Extract Sequencing Run Info
#     #RGPU=$(gzip -dc $FQ0| head -n1 - | cut -f1 -d':' | cut -f2 -d' ')
#     RGPU=$(head -n1 $FQ0 | cut -f1 -d':' | cut -f2 -d' ')
#
#     # Bowtie2: align to genome
#     bowtie2 --very-sensitive-local -p $THREADS \
#       --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \
#       --rg PL:$RGPL --rg PU:$RGPU \
#       -x hgr1 -U $FQ0 | \
#       ~/bin/samtools view -bS - > aligned_unsorted.bam
#
#     # Calculate library flagstats
#       ~/bin/samtools flagstat aligned_unsorted.bam > aligned_unsorted.flagstat
#       rm $FQ0 # Remove fastq files to save space
#
#     # Read Subset ------------------------------
#     # Extract mapped reads, and their unmapped pairs
#
#       # Extract Header
#       ~/bin/samtools view -H aligned_unsorted.bam > align.header.tmp
#
#       # Extract Mapped Reads
#       ~/bin/samtools view -b -F 4 aligned_unsorted.bam | \
#       ~/bin/samtools sort -@ $THREADS -O BAM - > align.hgr1.bam #mapped
#
#     # Calcualte library flagstats
#     ~/bin/samtools index align.hgr1.bam
#     ~/bin/samtools flagstat align.hgr1.bam > align.hgr1.flagstat
#
#     # Rename the total Bam Files
#       #mv aligned_unsorted.bam $LIBRARY.se.bam
#       #mv aligned_unsorted.bam.bai $LIBRARY.se.bam.bai
#       mv aligned_unsorted.flagstat $LIBRARY.se.flagstat
#
#     # Rename the hgr-aligned Bam files
#       mv align.hgr1.bam $LIBRARY.hgr1.se.bam
#       mv align.hgr1.bam.bai $LIBRARY.hgr1.se.bam.bai
#       mv align.hgr1.flagstat $LIBRARY.hgr1.se.flagstat
#
#     # Alignments (Full)
#     aws s3 cp $LIBRARY.se.flagstat s3://crownproject/tcga/$RGPO/
#
#     # Alignments (Aligned)
#     aws s3 cp $LIBRARY.hgr1.se.bam s3://crownproject/tcga/$RGPO/
#     aws s3 cp $LIBRARY.hgr1.se.bam.bai s3://crownproject/tcga/$RGPO/
#     aws s3 cp $LIBRARY.hgr1.se.flagstat s3://crownproject/tcga/$RGPO/
#
#
# fi
#
# # PAIRED END READS ====================================================
#
#
# if [ -s $FQ1 ]
# then
#     # Paired-End Extracted Reads Alignment
#
#     # Extract Sequencing Run Info
#     #RGPU=$(gzip -dc $FQ1| head -n1 $FQ1 | cut -f1 -d':' | cut -f2 -d' ')
#     RGPU=$(head -n1 $FQ1 | cut -f1 -d':' | cut -f2 -d' ')
#
#     # Bowtie2: align to genome
#     bowtie2 --very-sensitive-local -p $THREADS \
#       --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \
#       --rg PL:$RGPL --rg PU:$RGPU \
#       -x hgr1 -1 $FQ1 -2 $FQ2 | \
#       ~/bin/samtools view -bS - > aligned_unsorted.bam
#
#     # Calcualte library flagstats
#       ~/bin/samtools flagstat aligned_unsorted.bam > aligned_unsorted.flagstat
#
#       rm $FQ1 $FQ2 # Remove fastq files to save space
#
#
#     # Read Subset ------------------------------
#     # Extract mapped reads, and their unmapped pairs
#
#       # Extract Header
#       ~/bin/samtools view -H aligned_unsorted.bam > align.header.tmp
#
#       # Unmapped reads with mapped pairs
#       # Extract Mapped Reads
#       # and their unmapped pairs
#       ~/bin/samtools view -b -F 4 aligned_unsorted.bam > align.F4.bam #mapped
#       ~/bin/samtools view -b -f 4 -F 8 aligned_unsorted.bam > align.f4F8.bam #unmapped pairs
#
#       # Re-compile bam file
#       ~/bin/samtools cat -h align.header.tmp -o align.hgr1.tmp.bam align.F4.bam align.f4F8.bam
#         ~/bin/samtools sort -@ $THREADS -O BAM align.hgr1.tmp.bam > align.hgr1.bam
#         ~/bin/samtools index align.hgr1.bam
#         ~/bin/samtools flagstat align.hgr1.bam > align.hgr1.flagstat
#
#       # Clean up
#       rm *tmp* align.F4.bam align.f4F8.bam
#
#     # Rename the total Bam Files
#       mv aligned_unsorted.bam $LIBRARY.bam
#       #mv aligned_unsorted.bam.bai $LIBRARY.bam.bai
#       mv aligned_unsorted.flagstat $LIBRARY.flagstat
#
#     # Rename the hgr-aligned Bam files
#       mv align.hgr1.bam $LIBRARY.hgr1.bam
#       mv align.hgr1.bam.bai $LIBRARY.hgr1.bam.bai
#       mv align.hgr1.flagstat $LIBRARY.hgr1.flagstat
#
#     # Copy output to AWS S3
#     # Alignments (Full)
#       aws s3 cp $LIBRARY.flagstat s3://crownproject/tcga/$RGPO/
#
#     # Alignments (Aligned)
#       aws s3 cp $LIBRARY.hgr1.bam s3://crownproject/tcga/$RGPO/
#       aws s3 cp $LIBRARY.hgr1.bam.bai s3://crownproject/tcga/$RGPO/
#       aws s3 cp $LIBRARY.hgr1.flagstat s3://crownproject/tcga/$RGPO/
#
# fi
#
#
# # Copy screen log file to AWS S3
# cp ~/screenlog.0 ./$LIBRARY.screenlog
# aws s3 cp $LIBRARY.screenlog s3://crownproject/tcga/logs/
#
# # Shutdown and Terminate instance
# EC2ID=$(ec2metadata --instance-id)
# sleep 20s # to catch errors
#
# aws ec2 terminate-instances --instance-ids $EC2ID
#
# # Script complete
# upload: ./hgr1_align_v2.tcga.sh to s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# upload: ./tcga_5_coad_run1.txt to s3://crownproject/tcga/scripts/tcga_5_coad_run1.txt

# %%
# REMOTE:
# aws s3 cp --recursive s3://crownproject/tcga/scripts/ ./

# REMOTE:
# Open logging screen and being launchign EC2 instances
# screen -L
# 
# bash queenB.sh tcga_5_coad_run1.txt
#
# aws s3 cp screenlog.0 s3://crownproject/tcga/logs/tcga_5_coad_run1.log

aws s3 cp s3://crownproject/tcga/logs/tcga_5_coad_run1.log ./
cat tcga_5_coad_run1.log
# Out:
# download: s3://crownproject/tcga/logs/tcga_5_coad_run1.log to ./tcga_5_coad_run1.log
# kec2-user@ip-172-31-32-142:~\[ec2-user@ip-172-31-32-142 ~]$ bash queenB.sh tcga_5_coad_run1.txt
# Launch instance # 1
# Tue Nov 20 23:47:35 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-5M-AAT4-01A TCGA-COAD ef99b87e-4d27-4689-be93-6a55f20ca577
# Instance ID: i-052c816e10176b89a
# Public DNS: ec2-18-236-82-109.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-236-82-109.us-west-2.compute.amazonaws.com,172.31.18.141' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 2
# Tue Nov 20 23:50:43 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-5M-AAT5-01A TCGA-COAD f1b27b36-e2c0-42da-beb1-2bc2bc61abb9
# Instance ID: i-0b789cb4d7263e70a
# Public DNS: ec2-54-190-44-187.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-190-44-187.us-west-2.compute.amazonaws.com,172.31.24.175' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 3
# Tue Nov 20 23:53:50 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-5M-AAT6-01A TCGA-COAD b80f2f67-842c-4b6d-9b8c-936c6f03ac96
# Instance ID: i-0372280de1caf798f
# Public DNS: ec2-35-167-25-52.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-167-25-52.us-west-2.compute.amazonaws.com,172.31.25.244' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 4
# Tue Nov 20 23:56:57 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-5M-AATA-01A TCGA-COAD cbbd47c7-cc50-479d-a1a9-7199f0bdb9eb
# Instance ID: i-0a173da92361709a2
# Public DNS: ec2-34-219-118-85.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-219-118-85.us-west-2.compute.amazonaws.com,172.31.25.228' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 5
# Wed Nov 21 00:00:04 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-5M-AATE-01A TCGA-COAD 8315040e-4201-42fe-9c4e-10ff635672cf
# Instance ID: i-05369c7f11cce15f5
# Public DNS: ec2-34-222-41-213.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-222-41-213.us-west-2.compute.amazonaws.com,172.31.21.7' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 6
# Wed Nov 21 00:03:11 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-2672-01A TCGA-COAD f08dc7f4-3cc3-4743-a84e-d586d74af8d1
# Instance ID: i-01cb5336c851af4af
# Public DNS: ec2-34-222-6-244.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-222-6-244.us-west-2.compute.amazonaws.com,172.31.31.76' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 7
# Wed Nov 21 00:06:22 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-2672-01B TCGA-COAD ff6d6688-c19c-4a7f-8058-4d1bc0249d83
# Instance ID: i-0a4956e06405428fb
# Public DNS: ec2-34-223-208-252.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-223-208-252.us-west-2.compute.amazonaws.com,172.31.25.118' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 8
# Wed Nov 21 00:09:31 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-
(ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 90
# Wed Nov 21 05:11:18 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3561-01A TCGA-COAD 4b2fc72d-87f6-43ec-87b2-64c2a028f26b
# Instance ID: i-069236960889744ae
# Public DNS: ec2-54-184-82-53.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-184-82-53.us-west-2.compute.amazonaws.com,172.31.18.206' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 91
# Wed Nov 21 05:14:25 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3562-01A TCGA-COAD 6fbeb1e7-a565-4898-a440-5e39173af186
# Instance ID: i-0dae8382ed644ccea
# Public DNS: ec2-52-40-9-95.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-40-9-95.us-west-2.compute.amazonaws.com,172.31.24.10' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 92
# Wed Nov 21 05:17:31 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3664-01A TCGA-COAD eba4bb88-f729-4cc5-81fd-ed3d2926a241
# Instance ID: i-0692695d4da98acb8
# Public DNS: ec2-34-218-231-134.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-218-231-134.us-west-2.compute.amazonaws.com,172.31.30.216' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 93
# Wed Nov 21 05:20:38 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3666-01A TCGA-COAD 2c4e832a-7fe0-40d6-95fc-910a409f15ce
# Instance ID: i-0c8e97983faa0ebf2
# Public DNS: ec2-34-208-111-206.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-208-111-206.us-west-2.compute.amazonaws.com,172.31.19.82' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 94
# Wed Nov 21 05:23:45 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3667-01A TCGA-COAD c02e2722-deaf-4ae9-a56a-e1b2f99c2857
# Instance ID: i-076df2c1e3a187e61
# Public DNS: ec2-54-188-34-158.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-188-34-158.us-west-2.compute.amazonaws.com,172.31.30.191' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 95
# Wed Nov 21 05:26:52 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3672-01A TCGA-COAD 187e1335-5dbf-4234-8fc1-5d0494aaf296
# Instance ID: i-05108bd35927d9b11
# Public DNS: ec2-54-70-22-70.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-70-22-70.us-west-2.compute.amazonaws.com,172.31.20.3' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 96
# Wed Nov 21 05:30:00 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3673-01A TCGA-COAD 2e2cf870-a954-4e62-973a-875b7da7b226
# Instance ID: i-0a7ff63cbac1fa214
# Public DNS: ec2-54-202-148-196.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-202-148-196.us-west-2.compute.amazonaws.com,172.31.17.9' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 97
# Wed Nov 21 05:33:07 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3675-01A TCGA-COAD 4413144e-0daa-4c76-99ef-26c3447f426e
# Instance ID: i-0bc7dcc0dd4b25842
# Public DNS: ec2-54-187-212-220.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-187-212-220.us-west-2.compute.amazonaws.com,172.31.22.96' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# kec2-user@ip-172-31-32-142:~\[ec2-user@ip-172-31-32-142 ~]$

# %% [markdown]
# ## GVCF Analysis of TCGA-COAD Complete Set
#
# (Note: Incocomplete, only contains Pilot + COAD-2-Run1)

# %%
# Ran on Remote:
# Download TCGA-COAD Data
aws s3 cp --recursive "s3://crownproject/tcga/tcga-coad0"  ./TCGA-COAD/
aws s3 cp --recursive "s3://crownproject/tcga/tcga-coad-1" ./TCGA-COAD/
aws s3 cp --recursive "s3://crownproject/tcga/TCGA-COAD"   ./TCGA-COAD/

cd tcga
bash ~/scripts/ADcalc_c.sh

# Copied to s3:///crownproject/tcga/181120_tcga4_gvcf/

# %%
#!/bin/bash
# ADcalc_c.sh
# Allelic Depth Calculator
# for a position

cd ~/tcga/

# Controls -----------------
DEPTH='100000'
BAMLIST='bam.list.tmp'

#regions in hgr1.fa reference genome
REGIONS=('chr13:1003660-1005529' 'chr13:10219-10340' \
	'chr13:1006622-1006779' 'chr13:1007948-1013018')

#corresponding gene names
GENES=('18S' '5S' '5.8S' '28S')

# Iterate through every TCGA Cancer Type
for TYPE in $(echo "TCGA-COAD")
do
    echo Analyzing $TYPE...
    cd $TYPE

    ls *.bam > bam.list.tmp
    ls *.bam >> ../$OUTPUT.bamlist
    ls *.bam >> ../tcga.bamlist

    for index in ${!GENES[*]}
    do
      printf "Started processing %s\n" ${GENES[$index]}
      OUTPUT="../$TYPE.${GENES[$index]}.gvcf"

      # Iterate through every bam file in directory
      # look-up position and return VCF
      bcftools mpileup -f ~/resources/hgr1/hgr1.fa \
        --max-depth $DEPTH -A --min-BQ 30 \
        -a FORMAT/DP,AD \
        -r ${REGIONS[$index]} \
        --ignore-RG \
        -b $BAMLIST | \
        bcftools annotate -x INFO,FORMAT/PL - | \
        bcftools view -O v - \
        >> $OUTPUT

      RESULTS+=("$OUTPUT")
      printf "Done with %s \n" ${GENES[$index]}
      printf "%s\n" ${REGIONS[$index]}

    done
      
    rm bam.list.tmp
    
    cd ..
done

# %%
WORKDIR='/home/artem/Desktop/Crown/data2/tcga_analysis/181120_tcga4_gvcf'
cd $WORKDIR

aws s3 cp s3://crownproject/tcga/181120_tcga4_gvcf/tcga-coad.bamlist ./

aws s3 cp s3://crownproject/tcga/181120_tcga4_gvcf/TCGA-COAD.18S.gvcf ./
aws s3 cp s3://crownproject/tcga/181120_tcga4_gvcf/TCGA-COAD.5S.gvcf ./
aws s3 cp s3://crownproject/tcga/181120_tcga4_gvcf/TCGA-COAD.5.8S.gvcf ./
aws s3 cp s3://crownproject/tcga/181120_tcga4_gvcf/TCGA-COAD.28S.gvcf ./

# Note: updated data will be in 181123 capture
# Out:
# download: s3://crownproject/tcga/181120_tcga4_gvcf/tcga-coad.bamlist to ./tcga-coad.bamlist
# download: s3://crownproject/tcga/181120_tcga4_gvcf/TCGA-COAD.18S.gvcf to ./TCGA-COAD.18S.gvcf
# download: s3://crownproject/tcga/181120_tcga4_gvcf/TCGA-COAD.5S.gvcf to ./TCGA-COAD.5S.gvcf
# download: s3://crownproject/tcga/181120_tcga4_gvcf/TCGA-COAD.5.8S.gvcf to ./TCGA-COAD.5.8S.gvcf
# download: s3://crownproject/tcga/181120_tcga4_gvcf/TCGA-COAD.28S.gvcf to ./TCGA-COAD.28S.gvcf

# %%
## After TCGA-COAD-2 Run2 Complete - Re-run above analysis
## Launched m4.xlarge
## AMI: crown-180914 ami-096bcb9d18c32d4d5
## 250 Gb SSD

# Ran on Remote:
screen
cd tcga
rm -r TCGA-COAD/*

# Download TCGA-COAD Data
aws s3 cp --recursive "s3://crownproject/tcga/tcga-coad0"  ./TCGA-COAD/
aws s3 cp --recursive "s3://crownproject/tcga/tcga-coad-1" ./TCGA-COAD/
aws s3 cp --recursive "s3://crownproject/tcga/TCGA-COAD"   ./TCGA-COAD/

rm -r ./TCGA-COAD/logs/*
rmdir ./TCGA-COAD/logs

screen -L
cd tcga
bash ~/scripts/ADcalc_c.sh

# Copied to s3:///crownproject/tcga/181120_tcga4_gvcf/

# %% [markdown]
# ## TCGA-COAD-2 Run 2
#
# Files 101 - end

# %%
cd /home/artem/Crown/data2/tcga_5_coad2

# Run tcga5 files 101 - 434
sed -n 101,434p coad2_input.txt > tcga_5_coad_run2.txt
aws s3 cp tcga_5_coad_run2.txt s3://crownproject/tcga/scripts/
# Out:
# upload: ./tcga_5_coad_run2.txt to s3://crownproject/tcga/scripts/tcga_5_coad_run2.txt

# %%
# Remote EC2 Instance Operations ----------------------
# REMOTE:
# aws s3 cp --recursive s3://crownproject/tcga/scripts/ ./
#
# mv <KEY>.pem ~/.ssh/
# chmod 400 ~/.ssh/<KEY>.pem

# REMOTE:
# Open logging screen and being launching EC2 instances
# screen -L
# 
# bash queenB.sh tcga_5_coad_run2.txt
#
# aws s3 cp screenlog.0 s3://crownproject/tcga/logs/tcga_5_coad_run2.log


# Local: 
cd /home/artem/Crown/data2/tcga_5_coad2
aws s3 cp s3://crownproject/tcga/logs/tcga_5_coad_run2.log ./
cat tcga_5_coad_run2.log

# Run completed successfully
# Out:
# download: s3://crownproject/tcga/logs/tcga_5_coad_run2.log to ./tcga_5_coad_run2.log
# g
# upload: ./screenlog.0 to s3://crownproject/tcga/logs/tcga_5_coad_run2.log
# kec2-user@ip-172-31-26-254:~\[ec2-user@ip-172-31-26-254 ~]$ [ec2-user@ip-172-31-26-254 ~]$ bash queenB.sh tcga_5_coad_run2.txt
# Launch instance # 1
# Thu Nov 22 18:47:55 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3678-01A TCGA-COAD b9861b19-9008-4381-b6fc-1119427b93fd
# Instance ID: i-0a81b90263c98cb9f
# Public DNS: ec2-52-40-102-61.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-40-102-61.us-west-2.compute.amazonaws.com,172.31.21.201' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 2
# Thu Nov 22 18:51:10 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3679-01A TCGA-COAD 9ebf2c7e-9d60-40d9-a245-7890824a0e1e
# Instance ID: i-0f3c7b31469a01b64
# Public DNS: ec2-52-39-69-67.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-39-69-67.us-west-2.compute.amazonaws.com,172.31.18.11' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 3
# Thu Nov 22 18:54:17 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3680-01A TCGA-COAD bc9268ed-46e3-4d54-bf2a-d43bfbd362cb
# Instance ID: i-0fe0216c3838ed525
# Public DNS: ec2-54-202-77-32.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-202-77-32.us-west-2.compute.amazonaws.com,172.31.20.201' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 4
# Thu Nov 22 18:57:27 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3681-01A TCGA-COAD 4764761e-61a5-4c07-8b2e-1ee57c256c72
# Instance ID: i-087c4c43f1c689c73
# Public DNS: ec2-54-202-202-174.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-202-202-174.us-west-2.compute.amazonaws.com,172.31.20.213' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 5
# Thu Nov 22 19:00:34 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3684-01A TCGA-COAD 34692553-cc9e-454e-a003-85618f12e15b
# Instance ID: i-041f5d8f4104bd863
# Public DNS: ec2-54-189-165-203.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-189-165-203.us-west-2.compute.amazonaws.com,172.31.17.77' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 6
# Thu Nov 22 19:03:41 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3685-01A TCGA-COAD 4e452bb5-9f7c-437e-8a2b-65d8b59bdaf7
# Instance ID: i-036a1068ffb6e9bb0
# Public DNS: ec2-54-244-173-227.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-244-173-227.us-west-2.compute.amazonaws.com,172.31.27.28' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 7
# Thu Nov 22 19:06:48 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-
us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-201-253-142.us-west-2.compute.amazonaws.com,172.31.21.25' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 31
# Thu Nov 22 20:21:45 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3852-01A TCGA-COAD f0894c89-ad5e-4e0e-8289-0a0dcc5e5d28
# Instance ID: i-0b30640224bcfdeaf
# Public DNS: ec2-52-13-101-53.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-13-101-53.us-west-2.compute.amazonaws.com,172.31.25.132' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 32
# Thu Nov 22 20:24:52 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3854-01A TCGA-COAD aafcafb3-e20e-4fec-8741-7517554db974
# Instance ID: i-029be61e4ea4c4101
# Public DNS: ec2-52-36-133-78.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-36-133-78.us-west-2.compute.amazonaws.com,172.31.30.81' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 33
# Thu Nov 22 20:27:59 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3855-01A TCGA-COAD 6b6f1710-30a2-4b2f-bc4b-5087b04b8d50
# Instance ID: i-0d39cc2fd8efddd51
# Public DNS: ec2-54-200-62-209.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-200-62-209.us-west-2.compute.amazonaws.com,172.31.28.17' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 34
# Thu Nov 22 20:31:07 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3856-01A TCGA-COAD d5e613f0-c95b-421c-95a3-c59bdda5d673
# Instance ID: i-01ba2202830b41061
# Public DNS: ec2-52-43-220-202.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-43-220-202.us-west-2.compute.amazonaws.com,172.31.30.115' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 35
# Thu Nov 22 20:34:14 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3858-01A TCGA-COAD af1c2e70-da31-4d53-a651-e3d55df5797a
# Instance ID: i-0e346ed99c5e0a65d
# Public DNS: ec2-34-218-241-8.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-218-241-8.us-west-2.compute.amazonaws.com,172.31.27.116' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 36
# Thu Nov 22 20:37:21 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3860-01A TCGA-COAD 8a15a700-3831-4c50-aad0-b2354c90389b
# Instance ID: i-010c6dd0e9772f398
# Public DNS: ec2-34-220-225-13.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-220-225-13.us-west-2.compute.amazonaws.com,172.31.24.245' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 37
# Thu Nov 22 20:40:28 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3861-01A TCGA-COAD c43c8100-92b1-4ad1-8f64-465299c53113
# Instance ID: i-014f79c6cedadf049
# Public DNS: ec2-52-25-221-121.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-25-221-121.us-west-2.compute.amazonaws.com,172.31.21.90' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 38
# Thu Nov 22 20:43:36 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3862-01A TCGA-COAD 8ff632af-e89d-4f9a-a3fa-9db3b5df6a05
# Instance ID: i-017ed6ae399c0c0c0
# Public DNS: ec2-34-219-61-238.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-219-61-238.us-west-2.compute.amazonaws.com,172.31.27.84' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 39
# Thu Nov 22 20:46:44 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3864-01A TCGA-COAD 53a795d9-cf28-4d5e-9d2a-c1fed7a7f6e7
# Instance ID: i-048fc6d06a787d0f2
# Public DNS: ec2-18-236-171-26.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-236-171-26.us-west-2.compute.amazonaws.com,172.31.24.79' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 40
# Thu Nov 22 20:49:51 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3866-01A TCGA-COAD 100cd7f5-9a5a-40c0-b116-00c683d3a1ed
# Instance ID: i-0c1ef6613d1aa8ed1
# Public DNS: ec2-18-236-105-192.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-236-105-192.us-west-2.compute.amazonaws.com,172.31.30.194' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 41
# Thu Nov 22 20:52:57 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3867-01A TCGA-COAD 4f70e838-3eba-4bb0-809e-4f1dcb85f1c6
# Instance ID: i-0d2989b18ea0a846e
# Public DNS: ec2-34-213-121-222.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-213-121-222.us-west-2.compute.amazonaws.com,172.31.26.236' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 42
# Thu Nov 22 20:56:04 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-
us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-244-22-254.us-west-2.compute.amazonaws.com,172.31.30.65' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 54
# Thu Nov 22 21:33:27 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3955-01A TCGA-COAD 350edcf5-8891-4e39-af05-950f03742fb7
# Instance ID: i-009edc871170b7401
# Public DNS: ec2-34-213-168-149.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-213-168-149.us-west-2.compute.amazonaws.com,172.31.20.93' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 55
# Thu Nov 22 21:36:34 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3956-01A TCGA-COAD 86a2d12d-990f-4637-b4d4-b2e12687be0b
# Instance ID: i-022881a7a643257a1
# Public DNS: ec2-34-215-197-72.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-215-197-72.us-west-2.compute.amazonaws.com,172.31.18.156' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 56
# Thu Nov 22 21:39:41 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3966-01A TCGA-COAD 34a3a402-11f0-462c-a5fc-4ec58921a05f
# Instance ID: i-0accf70b343c78aee
# Public DNS: ec2-34-219-58-67.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-219-58-67.us-west-2.compute.amazonaws.com,172.31.28.4' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 57
# Thu Nov 22 21:42:49 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3968-01A TCGA-COAD a2a38aac-ed6f-4547-a791-9b7a1947787d
# Instance ID: i-03fd95062e2b15344
# Public DNS: ec2-35-165-0-12.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-165-0-12.us-west-2.compute.amazonaws.com,172.31.23.90' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 58
# Thu Nov 22 21:45:56 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3970-01A TCGA-COAD 9dc6c567-88ea-47de-a40b-e9053624166f
# Instance ID: i-0cc55863423994d2d
# Public DNS: ec2-54-185-36-182.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-185-36-182.us-west-2.compute.amazonaws.com,172.31.28.131' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 59
# Thu Nov 22 21:49:03 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3971-01A TCGA-COAD 6dd62715-02e0-4539-ac02-4937d31b33d1
# Instance ID: i-042e9c128c73efe19
# Public DNS: ec2-52-39-77-56.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-39-77-56.us-west-2.compute.amazonaws.com,172.31.23.242' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 60
# Thu Nov 22 21:52:10 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3972-01A TCGA-COAD b0b7a16b-a600-46d0-98ec-cdd707456446
# Instance ID: i-014047cc50f1f16f2
# Public DNS: ec2-34-215-131-159.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-215-131-159.us-west-2.compute.amazonaws.com,172.31.26.59' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 61
# Thu Nov 22 21:55:17 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3973-01A TCGA-COAD 6be318a8-5b6a-4387-83e5-e04150bd4f99
# Instance ID: i-00d058341b152d0a4
# Public DNS: ec2-52-37-79-43.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-37-79-43.us-west-2.compute.amazonaws.com,172.31.19.120' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 62
# Thu Nov 22 21:58:27 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3975-01A TCGA-COAD c73f13d8-98ce-4447-b735-2ea883e617a2
# Instance ID: i-0593703fe85785ce8
# Public DNS: ec2-54-70-149-134.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-70-149-134.us-west-2.compute.amazonaws.com,172.31.25.186' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 63
# Thu Nov 22 22:01:35 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3976-01A TCGA-COAD a347c627-0f46-4eaa-b5a4-2c1caeb70c97
# Instance ID: i-001b5ae9b2de51705
# Public DNS: ec2-54-218-86-146.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-218-86-146.us-west-2.compute.amazonaws.com,172.31.26.67' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 64
# Thu Nov 22 22:04:42 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3977-01A TCGA-COAD 2844f55e-41d5-4588-8b09-52d497c597bb
# Instance ID: i-066c85e203e98c662
# Public DNS: ec2-34-212-207-5.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-212-207-5.us-west-2.compute.amazonaws.com,172.31.26.221' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 65
# Thu Nov 22 22:07:49 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3979-01A TCGA-COAD fef3e110-f837-4d6d-9937-17db17417017
# Instance ID: i-08e0f8d23c47689b8
# Public DNS: ec2-52-33-154-98.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-33-154-98.us-west-2.compute.amazonaws.com,172.31.24.197' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 66
# Thu Nov 22 22:10:56 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3980-01A TCGA-COAD 594bcc55-4605-4369-889a-50940c93cd29
# Instance ID: i-0b6f57fd84e1e1ab4
# Public DNS: ec2-54-214-132-137.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-214-132-137.us-west-2.compute.amazonaws.com,172.31.25.221' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 67
# Thu Nov 22 22:14:04 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3982-01A TCGA-COAD 739f4d3b-d73e-4cd7-862e-1f843c0f73c3
# Instance ID: i-033a93cd9a6997b41
# Public DNS: ec2-52-38-17-9.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-38-17-9.us-west-2.compute.amazonaws.com,172.31.26.113' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 68
# Thu Nov 22 22:17:10 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3984-01A TCGA-COAD 3c0e5d60-4dd9-437b-834f-536208a0fb1d
# Instance ID: i-064ae3fa98cbeac84
# Public DNS: ec2-54-70-153-65.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-70-153-65.us-west-2.compute.amazonaws.com,172.31.27.8' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 69
# Thu Nov 22 22:20:17 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3986-01A TCGA-COAD 3172233b-064c-49e7-81e4-e1fa38556c59
# Instance ID: i-07a42a9803c2460e3
# Public DNS: ec2-18-236-154-32.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-236-154-32.us-west-2.compute.amazonaws.com,172.31.23.103' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 70
# Thu Nov 22 22:23:24 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3989-01A TCGA-COAD 340dee79-7f93-4b4e-9137-98eeaa113f78
# Instance ID: i-0cd2934d5d7f6bed9
# Public DNS: ec2-54-184-111-135.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-184-111-135.us-west-2.compute.amazonaws.com,172.31.17.184' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 71
# Thu Nov 22 22:26:31 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3994-01A TCGA-COAD ae1581e5-446c-4537-8c94-4f2df8f46308
# Instance ID: i-075529a2fd6b2f181
# Public DNS: ec2-34-216-92-81.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-216-92-81.us-west-2.compute.amazonaws.com,172.31.22.107' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 72
# Thu Nov 22 22:29:38 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-A004-01A TCGA-COAD c7672ae4-5d9d-4f82-b24c-97b306e833a6
# Instance ID: i-0d9abc8fb14d197c7
# Public DNS: ec2-52-32-41-153.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-32-41-153.us-west-2.compute.amazonaws.com,172.31.29.166' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 73
# Thu Nov 22 22:32:45 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-A00A-01A TCGA-COAD d9967737-1c82-4ebf-9596-2035b957261e
# Instance ID: i-0657827b52f4b0854
# Public DNS: ec2-18-237-70-185.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-237-70-185.us-west-2.compute.amazonaws.com,172.31.28.10' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 74
# Thu Nov 22 22:35:52 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-A00D-01A TCGA-COAD 3d25c72a-da13-4330-b198-41b3aa049f50
# Instance ID: i-00b5306da829102d9
# Public DNS: ec2-34-217-23-153.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-217-23-153.us-west-2.compute.amazonaws.com,172.31.29.231' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 75
# Thu Nov 22 22:38:59 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-A00E-01A TCGA-COAD cb21f8e0-9231-4fa5-95cb-90d44a2fc994
# Instance ID: i-09b8d1273923a6b23
# Public DNS: ec2-18-236-71-255.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-236-71-255.us-west-2.compute.amazonaws.com' (ECDSA) to the list of known hosts.
# Warning: the ECDSA host key for 'ec2-18-236-71-255.us-west-2.compute.amazonaws.com' differs from the key for the IP address '172.31.24.245'
# Offending key for IP in /home/ec2-user/.ssh/known_hosts:36
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 76
# Thu Nov 22 22:42:08 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-A00F-01A TCGA-COAD 5ac7d2fa-4458-40bd-9023-69d9aa0d0b75
# Instance ID: i-0d1e189c09ba8f448
# Public DNS: ec2-34-220-146-88.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-220-146-88.us-west-2.compute.amazonaws.com,172.31.21.58' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 77
# Thu Nov 22 22:45:15 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-A00J-01A TCGA-COAD 2cbe4b2b-1e1f-4249-8501-1c1db85e2cd5
# Instance ID: i-085a8b0fe47a04505
# Public DNS: ec2-18-236-181-228.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-236-181-228.us-west-2.compute.amazonaws.com,172.31.20.21' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 78
# Thu Nov 22 22:48:22 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-A00K-01A TCGA-COAD 3643e79b-34d3-4645-953c-648f97cdf9d4
# Instance ID: i-04368e609ed5dc272
# Public DNS: ec2-34-219-142-188.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-219-142-188.us-west-2.compute.amazonaws.com,172.31.28.24' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 79
# Thu Nov 22 22:51:29 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-A00L-01A TCGA-COAD 9fd4295c-5b8f-48ab-9d5a-57800ba4f5b2
# Instance ID: i-0b42b62672f83e202
# Public DNS: ec2-34-220-100-201.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-220-100-201.us-west-2.compute.amazonaws.com,172.31.31.82' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 80
# Thu Nov 22 22:54:35 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-A00N-01A TCGA-COAD c4eab08a-4001-49fa-a818-3484ac8ba56d
# Instance ID: i-0054ec983fbe99633
# Public DNS: ec2-54-149-201-139.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-149-201-139.us-west-2.compute.amazonaws.com,172.31.19.105' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 81
# Thu Nov 22 22:57:42 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-A00O-01A TCGA-COAD 7b0908c3-8bca-49ff-b157-5de397f8b0bd
# Instance ID: i-040620922dea45ffa
# Public DNS: ec2-34-214-244-16.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-214-244-16.us-west-2.compute.amazonaws.com,172.31.29.132' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 82
# Thu Nov 22 23:00:49 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-A00Q-01A TCGA-COAD d74cd87c-6889-4bea-aae2-6aca8878a630
# Instance ID: i-01b33e3f3e51799f8
# Public DNS: ec2-54-184-126-216.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-184-126-216.us-west-2.compute.amazonaws.com,172.31.30.110' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 83
# Thu Nov 22 23:03:56 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-A00R-01A TCGA-COAD 8b8d854f-ab06-43ff-83c6-cb404c6fd5cd
# Instance ID: i-02e401da0e35d9684
# Public DNS: ec2-34-210-101-163.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-210-101-163.us-west-2.compute.amazonaws.com,172.31.28.214' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 84
# Thu Nov 22 23:07:03 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-A00U-01A TCGA-COAD b1f7c9bf-daa2-485d-b849-ad74c6e49c45
# Instance ID: i-0304bbb56284b11e0
# Public DNS: ec2-18-236-74-40.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-236-74-40.us-west-2.compute.amazonaws.com,172.31.26.86' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 85
# Thu Nov 22 23:10:11 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# ...
# Warning: Permanently added 'ec2-52-39-44-161.us-west-2.compute.amazonaws.com,172.31.30.117' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 308
# Fri Nov 23 11:07:49 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-G4-6322-01A TCGA-COAD 1c491437-900d-4a9b-88d0-7668ee41f052
# Instance ID: i-040ea3bf6d5881298
# Public DNS: ec2-34-221-206-196.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-221-206-196.us-west-2.compute.amazonaws.com,172.31.19.83' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 309
# Fri Nov 23 11:10:57 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-G4-6323-01A TCGA-COAD af862835-d908-4ee8-8753-78a612d419be
# Instance ID: i-05a0a7c29ed3be8cc
# Public DNS: ec2-18-236-89-209.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-236-89-209.us-west-2.compute.amazonaws.com,172.31.24.48' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 310
# Fri Nov 23 11:14:04 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-G4-6586-01A TCGA-COAD 040e1058-9e1d-4b27-a481-4db1a75e0266
# Instance ID: i-08dee69baed7f76ea
# Public DNS: ec2-18-236-183-215.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-236-183-215.us-west-2.compute.amazonaws.com,172.31.25.116' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 311
# Fri Nov 23 11:17:12 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA
us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-202-118-204.us-west-2.compute.amazonaws.com,172.31.25.48' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 334
# Fri Nov 23 12:29:08 UTC 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-WS-AB45-01A TCGA-COAD 7a7e8f81-f0fb-497c-85b3-80a2c805b456
# Instance ID: i-01713a260d68d5500
# Public DNS: ec2-18-236-128-99.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-236-128-99.us-west-2.compute.amazonaws.com,172.31.19.181' (ECDSA) to the list of known hosts.
# download: s3://crownproject/tcga/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# kec2-user@ip-172-31-26-254:~\[ec2-user@ip-172-31-26-254 ~]$

# %% [markdown]
# ## TCGA-COAD-2 Analysis
#
# Preliminary analysis using `TCGA-COAD-1` and `TCGA-COAD-2-Run1` datasets only.
#
# Downloaded `TCGA-COAD.18S.gvcf`, extracted VCF data, analyzed initially in `/home/artem/Desktop/Crown/data2/tcga_analysis/pilot/TCGA-18S_1248.xlsx`
#
# Note: There IS a very large difference between `TCGA-NN-XXXX-01A` and `TCGA-NN-XXXX-01B` samples, I can't locate what the difference between these two types of samples are.
#
# This may be a substantial techincal confounding effect in the data; ensure that all analyses are done comparing 01A vs 11A in the future.
#
# ```
# SampleID	RAF	VAF	SubmitterID	sample
# TCGA-A6-2674-01A	85.66552901	14.33447099	TCGA-A6-2674	01A
# TCGA-A6-2677-01A	93.750000	6.250000	TCGA-A6-2677	01A
# TCGA-A6-2684-01A	64.19308357	35.80691643	TCGA-A6-2684	01A
# TCGA-A6-3809-01A	65.21478521	34.78521479	TCGA-A6-3809	01A
# TCGA-A6-3810-01A	44.64922711	55.35077289	TCGA-A6-3810	01A
# TCGA-A6-5656-01A	72.45129135	27.54870865	TCGA-A6-5656	01A
# TCGA-A6-5659-01A	66.33076467	33.66923533	TCGA-A6-5659	01A
# TCGA-A6-5661-01A	53.61972951	46.38027049	TCGA-A6-5661	01A
# TCGA-A6-5665-01A	59.06011854	40.93988146	TCGA-A6-5665	01A
# TCGA-A6-6780-01A	96.88378632	3.116213683	TCGA-A6-6780	01A
# TCGA-A6-6781-01A	50.15587115	49.84412885	TCGA-A6-6781	01A
#
# TCGA-A6-2674-01B	98.49981512	1.500184882	TCGA-A6-2674	01B
# TCGA-A6-2677-01B	97.51013318	2.489866821	TCGA-A6-2677	01B
# TCGA-A6-3809-01B	98.58570552	1.414294476	TCGA-A6-3809	01B
# TCGA-A6-5656-01B	98.8341379	1.1658621	TCGA-A6-5656	01B
# TCGA-A6-5659-01B	98.8868536	1.1131464	TCGA-A6-5659	01B
# TCGA-A6-5661-01B	99.4146838	0.585316198	TCGA-A6-5661	01B
# TCGA-A6-5665-01B	99.02525275	0.974747246	TCGA-A6-5665	01B
# TCGA-A6-6650-01B	97.95766803	2.042331972	TCGA-A6-6650	01B
# TCGA-A6-6780-01B	96.80881107	3.19118893	TCGA-A6-6780	01B
# TCGA-A6-6781-01B	98.45925376	1.540746241	TCGA-A6-6781	01B
# TCGA-A6-2684-01C	98.36116505	1.638834951	TCGA-A6-2684	01C
# ```
