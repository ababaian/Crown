# %% [markdown]
# #  File Split
# ```
# pi:ababaian
# files: ~/Crown/data/ and ~/Crown/data2/
# start: 2017 06 19 + 2018 01 04
# ```
#
# ## NOTE:
#
# To prevent too many files/analysis being piled up in one folder I've split and am beginning to organize the experimental data at a 'higher' folder levels. This also segregates the data and notebook into public-facing and private while working with potentially sensitive data. Public data in the `master` branch will be pushed to github remote; while the `private` branch will remain only on local systems.
#
# ### Crown/data & Crown/wiki/notebook
#
# This folder will keep all hgr1 sequence variation and normal human variation data and experiments.
#
# This includes 'normal' paralog rRNA research.
#
# ### Crown/data2 & Crown/wiki/notebook2
#
# This folder is for cancer-specific variation and cancer-specific paralog research. CRC / T-ALL and such data will be stored here. Data in this folder will remain private and not published until it's srapped of all IDs and safe to move to data/

# %%
date

cd ~/Crown/
du -ch
# Out:
# 48K	./sessions
# 1.1M	./data2/Breast
# 2.5G	./data2/cml/align
# 2.5G	./data2/cml
# 76K	./data2/MRPko/plot
# 928K	./data2/MRPko
# 3.4G	./data2/dlbcl
# 85M	./data2/mcf7/align
# 464K	./data2/mcf7/plot
# 12K	./data2/mcf7/flagstat
# 85M	./data2/mcf7
# 6.1M	./data2/aml
# 562M	./data2/crc2/align
# 565M	./data2/crc2
# 348K	./data2/TALL2/andydoc
# 1.3G	./data2/TALL2/full_bam
# 1.3G	./data2/TALL2/fq
# 292K	./data2/TALL2/lenti_align
# 369M	./data2/TALL2/run1
# 104M	./data2/TALL2/lenti
# 3.1G	./data2/TALL2
# 1.1M	./data2/hCAGE/cell_lines/flagstat
# 12M	./data2/hCAGE/cell_lines
# 2.1M	./data2/hCAGE/primary/flagstat
# 13M	./data2/hCAGE/primary
# 27M	./data2/hCAGE
# 244K	./data2/macp/yeastAssay
# 20K	./data2/macp/fa
# 208K	./data2/macp/files
# 23M	./data2/macp/plot
# 23M	./data2/macp
# 5.9G	./data2/crc4/align
# 120K	./data2/crc4/hg19r/ncol4_13/logs
# 3.6G	./data2/crc4/hg19r/ncol4_13
# 140K	./data2/crc4/hg19r/crc4_2/logs
# 5.2G	./data2/crc4/hg19r/crc4_2
# 140K	./data2/crc4/hg19r/ncol4_18/logs
# ...
