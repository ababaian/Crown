# %% [markdown]
# # TCGA-COAD RNA-seq hgr1 alignments
# ```
# pi:ababaian
# files: ~/Crown/data2/tcga_1_coad
# start: 2018 08 16
# complete : 2018 08 22
# ```
# ## Introduction
#
# hgr1 Alignment of the TCGA-COAD data. Only libraries for which there is a matched-normal from the same sample (41 patients and 82 libraries).

# %% [markdown]
# ## Materials and Methods
#
# ### Scripts

# %% [markdown]
# #### hgr1 Alignment

# %%
#!/bin/bash
# 1kg_align_v2.tcga.1.sh
# rDNA alignment pipeline
# 180816 build -- TCGA
# AMI: crown-180813 - ami-0031fd61f932bdef9
# EC2: c4.2xlarge (8cpu / 15 gb)
# EC2: c4.xlarge  (4cpu / 8  gb)
# Storage: 300 Gb
#

# Input Requirements --------------------------

# $1 : Library name and file-output name
# $2 : Library population/analysis set
# $3 : Library UUID

# Control Panel -------------------------------
# CPU
	THREADS='3'

# Sequencing Data
	LIBRARY=$1 # Library/ File name

# TCGA FILE UUID
  UUID=$3

 # FastQ File-names
    FQ0="$LIBRARY.tmp.sort.0.fq"
    FQ1="$LIBRARY.tmp.sort.1.fq"
    FQ2="$LIBRARY.tmp.sort.2.fq"
    
# Read Group Data
# Extract from downloaded BAM file / input
	RGPO=$2 # Patient Population

	#RGSM= # Sample. Patient Identifer
	#RGID= # Read Group ID. Accession Number
    
	RGLB=$LIBRARY # Library Name. Accession Number
	RGPL='ILLUMINA'  # Sequencing Platform.
    
	# Extract Sequencing Run Info
	#  RGPU=$(gzip -dc $FQ1 | head -n1 - | cut -f1 -d':' | cut -f2 -d' ')

# Initialize wordir ---------------------------

# Make working directory
  mkdir -p align; cd align

# Copy hgrX genome and create bowtie2 index
  cp ~/resources/hgr1/* ./
  
# Download RNAseq BAM file
# with a UUID as input
  ~/bin/gdc-client download -t ~/resources/gdc.token -d ./ \
  -n $THREADS $UUID
  
# Link the RNA-seq bamfile which is called by its UID to workdir
  ln -s */*.bam input.bam
  
# Extract ReadGroup Sample Name (SM)
  RGSM=$(~/bin/samtools view -H input.bam | grep '^@RG' | sed "s/.*SM:\([^\t]*\).*/\1/g" | uniq )

# Extract ReadGroup identifier (ID)
  RGID=$(~/bin/samtools view -H input.bam | grep '^@RG' | sed "s/.*ID:\([^\t]*\).*/\1/g" | uniq )

# Convert input bam file to fastq files for re-alignment
~/bin/samtools sort -@ $THREADS-n input.bam | \
    ~/bin/samtools fastq -@ $THREADS -O \
    -0 $FQ0 \
    -1 $FQ1 \
    -2 $FQ2 -

# SINGLE END READS ====================================================

if [ -s $FQ0 ]
then
    # Single-End Extracted Reads Alignment

    # Extract Sequencing Run Info
    #RGPU=$(gzip -dc $FQ0| head -n1 - | cut -f1 -d':' | cut -f2 -d' ')
    RGPU=$(head -n1 $FQ0 | cut -f1 -d':' | cut -f2 -d' ')

    # Bowtie2: align to genome
    bowtie2 --very-sensitive-local -p $THREADS \
      --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \
      --rg PL:$RGPL --rg PU:$RGPU \
      -x hgr1 -U $FQ0 | \
      ~/bin/samtools view -bS - > aligned_unsorted.bam
     
    # Calculate library flagstats
      ~/bin/samtools flagstat aligned_unsorted.bam > aligned_unsorted.flagstat
      rm $FQ0 # Remove fastq files to save space

    # Read Subset ------------------------------
    # Extract mapped reads, and their unmapped pairs

      # Extract Header
      ~/bin/samtools view -H aligned_unsorted.bam > align.header.tmp

      # Extract Mapped Reads
      ~/bin/samtools view -b -F 4 aligned_unsorted.bam | \
      ~/bin/samtools sort -@ $THREADS -O BAM - > align.hgr1.bam #mapped
      
    # Calcualte library flagstats
    ~/bin/samtools index align.hgr1.bam
    ~/bin/samtools flagstat align.hgr1.bam > align.hgr1.flagstat

    # Rename the total Bam Files
      #mv aligned_unsorted.bam $LIBRARY.se.bam
      #mv aligned_unsorted.bam.bai $LIBRARY.se.bam.bai
      mv aligned_unsorted.flagstat $LIBRARY.se.flagstat

    # Rename the hgr-aligned Bam files
      mv align.hgr1.bam $LIBRARY.hgr1.se.bam
      mv align.hgr1.bam.bai $LIBRARY.hgr1.se.bam.bai
      mv align.hgr1.flagstat $LIBRARY.hgr1.se.flagstat
      
    # Alignments (Full)
    aws s3 cp $LIBRARY.se.flagstat s3://crownproject/tcga/

    # Alignments (Aligned)
    aws s3 cp $LIBRARY.hgr1.se.bam s3://crownproject/tcga/
    aws s3 cp $LIBRARY.hgr1.se.bam.bai s3://crownproject/tcga/
    aws s3 cp $LIBRARY.hgr1.se.flagstat s3://crownproject/tcga/

fi

# PAIRED END READS ====================================================


if [ -s $FQ1 ]
then
    # Paired-End Extracted Reads Alignment

    # Extract Sequencing Run Info
    #RGPU=$(gzip -dc $FQ1| head -n1 $FQ1 | cut -f1 -d':' | cut -f2 -d' ')
    RGPU=$(head -n1 $FQ1 | cut -f1 -d':' | cut -f2 -d' ')
    
    # Bowtie2: align to genome
    bowtie2 --very-sensitive-local -p $THREADS \
      --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \
      --rg PL:$RGPL --rg PU:$RGPU \
      -x hgr1 -1 $FQ1 -2 $FQ2 | \
      ~/bin/samtools view -bS - > aligned_unsorted.bam
      
    # Calcualte library flagstats
      ~/bin/samtools flagstat aligned_unsorted.bam > aligned_unsorted.flagstat
      
      rm $FQ1 $FQ2 # Remove fastq files to save space

      
    # Read Subset ------------------------------
    # Extract mapped reads, and their unmapped pairs

      # Extract Header
      ~/bin/samtools view -H aligned_unsorted.bam > align.header.tmp

      # Unmapped reads with mapped pairs
      # Extract Mapped Reads
      # and their unmapped pairs
      ~/bin/samtools view -b -F 4 aligned_unsorted.bam > align.F4.bam #mapped
      ~/bin/samtools view -b -f 4 -F 8 aligned_unsorted.bam > align.f4F8.bam #unmapped pairs

      # Extract just the 45S unit
      #aws s3 cp s3://crownproject/resources/rDNA_45s.bed ./
      #~/bin/samtools view -b -L rDNA_45s.bed align.F4.bam > align.F4.45s.bam

      # What are the mapped readnames
      ~/bin/samtools view align.F4.bam | cut -f1 - > read.names.tmp

      # Extract mapped reads
      ~/bin/samtools view align.F4.bam | grep -Ff read.names.tmp - > align.F4.tmp.sam


      # Extract cases of read pairs mapped on edge of region of interest
      # -------|======= R O I ======| ----------
      # read:                  ====---====
      ~/bin/samtools view align.F4.bam | grep -Ff read.names.tmp - > align.F4.tmp.sam

      # Complete mapped reads list
      #cut -f1 align.F4.tmp.sam > read.names.45s.long.tmp

      # Extract unmapped reads with a mapped pair
      ~/bin/samtools view align.f4F8.bam | grep -Ff read.names.tmp - > align.f4F8.tmp.sam

      # Re-compile bam file
      cat align.header.tmp align.F4.tmp.sam align.f4F8.tmp.sam | ~/bin/samtools view -bS - > align.hgr1.tmp.bam
        ~/bin/samtools sort -@ $THREADS -O BAM align.hgr1.tmp.bam > align.hgr1.bam
        ~/bin/samtools index align.hgr1.bam
        ~/bin/samtools flagstat align.hgr1.bam > align.hgr1.flagstat

      # Clean up 
      rm *tmp* align.F4.bam align.f4F8.bam

    # Rename the total Bam Files
      mv aligned_unsorted.bam $LIBRARY.bam
      #mv aligned_unsorted.bam.bai $LIBRARY.bam.bai
      mv aligned_unsorted.flagstat $LIBRARY.flagstat

    # Rename the hgr-aligned Bam files
      mv align.hgr1.bam $LIBRARY.hgr1.bam
      mv align.hgr1.bam.bai $LIBRARY.hgr1.bam.bai
      mv align.hgr1.flagstat $LIBRARY.hgr1.flagstat
      
    # Copy output to AWS S3 
    # Alignments (Full)
      aws s3 cp $LIBRARY.flagstat s3://crownproject/tcga/

    # Alignments (Aligned)
      aws s3 cp $LIBRARY.hgr1.bam s3://crownproject/tcga/
      aws s3 cp $LIBRARY.hgr1.bam.bai s3://crownproject/tcga/
      aws s3 cp $LIBRARY.hgr1.flagstat s3://crownproject/tcga/

fi
 

# Copy screen log file to AWS S3
cp ~/screenlog.0 ./$LIBRARY.screenlog
aws s3 cp $LIBRARY.screenlog s3://crownproject/tcga/logs/

# Shutdown and Terminate instance
EC2ID=$(ec2metadata --instance-id)
aws ec2 terminate-instances --instance-ids $EC2ID

# Script complete

# %% [markdown]
# #### queenB.sh script

# %%
#!/bin/bash
# queenB.sh
# 20180814 build
# EC2 Launch / Control Script
#

# 1. queenB script is initialized locally and input files
#    are parsed ready for cluster analaysis
# 2. queenB launches instances, logs in to it and runs the
#    droneB.sh script remotely.
# 3. The droneB script is executed on the instance and it
#    launches a `screen` on the instance and loads and 
#    starts to perform the $TASK (gather.sh) script.
# 4. TASK script should include a instance shut-down
#    command to close instance upon completion.
#

# Control Panel =========================
# EC2 TASK Script - script for droneB to execute
TASK="s3://crownproject/scripts/hgr1_align_v2.tcga.sh"

# Parameter file:
# Each line of PARAMETERS will be input to STDIN of
# the droneB script which can then be used to run the
# TASK script.
# i.e. bash droneB.sh <line_N_of_PARAMETERS>
# PARAMETERS="tcga0_input.txt"
PARAMETERS=$1

# EC2 Set-up
instanceTYPE='c4.xlarge'
imageID='ami-0031fd61f932bdef9' #AMI TCGA

devNAME='/dev/sda1' # /dev/sda1 for Crown-AMI
volSIZE='200' # in Gb

# Number of instances to launch
#COUNT=2 # predetermined number
COUNT=$(awk 'END{print NR}' $PARAMETERS) # for each input argument

# Security
keyNAME='CrownKey'
keyPATH="/home/artem/.ssh/CrownKey.pem"
secGROUP='crown-group'

# =======================================

for ITER in $(seq 1 $COUNT)
do

  # Extract Parameters/Arguments ----------

  ARGS=$(sed -n "$ITER"p $PARAMETERS | sed 's/\t/ /g' - )

  echo "Launch instance # $ITER"
  date
  echo "Instance Type: $instanceTYPE"
  echo "AMI Image: $imageID"
  echo "Run Script: $TASK"
  echo "Parameters: $ARGS"

  # Launch an instance --------------------
  # NOTE: each iteration of the for loop launches one instance
  # therefore each loop launches only one instance
  aws ec2 run-instances --image-id $imageID --count 1 \
   --instance-type $instanceTYPE --key-name $keyNAME \
   --block-device-mappings DeviceName=$devNAME,Ebs={VolumeSize=$volSIZE} \
   --security-groups $secGROUP > launch.tmp

  # Another alternative is to use --user-data droneB.sh 
  # which will run at instance boot-up
  # passing arguments to it may be challenging

  # Retrieve instance ID
  instanceID=$(cat launch.tmp | \
    egrep -o -e 'InstanceId[":/A-Za-z0-9_ \\-]*' - |\
    cut -f2 -d' ' - | xargs)

  echo "Instance ID: $instanceID"


  # Add a few minute wait here to allow for Public DNS to be assigned
  # otherwise ssh doesn't work
  sleep 180s

  # Retrieve public DNS
  aws ec2 describe-instances --instance-ids $instanceID > launch2.tmp

  pubDNS=$(cat launch2.tmp | \
    egrep -o -m 1 -e 'PublicDnsName[.":/A-Za-z0-9_ \\-]*' - |\
    cut -f2 -d' ' - | xargs)

  echo "Public DNS: $pubDNS"

  # Access the instance -------------------

  LOGIN="ubuntu@$pubDNS" 

  ssh -i $keyPATH \
    -o StrictHostKeyChecking=no \
    $LOGIN 'bash -s' < droneB.sh $TASK $(echo $ARGS)

  # Cleanup
  rm *.tmp

  echo ''
  echo ''

done

# end of script

# %% [markdown]
# #### droneB.sh script

# %%
#!/bin/bash
# droneB.sh
#

# This script-layer is neccesary to launch a screen session
# on each ec2-machine. The pipeline is run within that session
# and the output is logged. This allows 'looking in' on sessions
# as they are running.

# Commands to run on server-side
# ===============================================================

SCRIPTPATH=$1

SCRIPT=$(basename $1)

shift # drop first (TASK or SCRIPT variable)

# Download pipeline / droneB's function
  aws s3 cp $SCRIPTPATH ./

  chmod 777 *.sh

# open screen; run gather.sh function. -L logged
  screen -Ldmt sh ~/$SCRIPT $@


# ===============================================================

# %% [markdown]
# #### TCGA files
#
# Search Terms
# ```
# cases.primary_site in ["Colorectal"] and cases.project.project_id in ["TCGA-COAD"] and files.data_category in ["Raw Sequencing Data","Transcriptome Profiling"] and files.data_format in ["BAM"] and files.experimental_strategy in ["RNA-Seq"]
# ```

# %%
cd /home/artem/Desktop/Crown/data2/tcga_1_coad

cat tcga_run1A.txt
echo ' '
echo '---------------------------------------'
cat tcga_run1B.txt
echo ' '
echo '---------------------------------------'
cat tcga_run1C.txt
# Out:
# TCGA-A6-2671-11A TCGA-COAD 3bc30231-3fbd-4992-9088-1a83efa1a31e
# TCGA-A6-2671-01A TCGA-COAD 80ff8844-3c90-4c66-b6d9-a72ea86219ed
# TCGA-A6-2675-11A TCGA-COAD 3e0ae536-e178-433b-95b8-a52e14c17f14
# TCGA-A6-2675-01A TCGA-COAD c1c3ed06-d423-46bf-8b43-77f7817c59bd
# TCGA-A6-2678-11A TCGA-COAD 2d9c8cc3-d56a-4920-b86c-2389ca913e97
# TCGA-A6-2678-01A TCGA-COAD 670e9a3d-5a6e-4ddb-a1bf-6e48e3786fb1
# TCGA-AZ-6598-11A TCGA-COAD 823d6de4-51f2-449c-af2f-2b7f3fd028f2
# TCGA-AZ-6598-01A TCGA-COAD 8468a033-502f-4085-a7f4-de4c1922b2fa
# TCGA-AZ-6599-01A TCGA-COAD 0188bc58-2deb-4978-98c3-3028d6fa61f8
# TCGA-AZ-6599-11A TCGA-COAD fa5e83a0-4d1d-46fe-9f11-fb4a5bc2a87f
# TCGA-AZ-6600-01A TCGA-COAD b22d685f-f23b-4f9e-802e-9615d6ed5484
# TCGA-AZ-6600-11A TCGA-COAD ee631538-5004-4d37-b089-61458c3d638e
# TCGA-AZ-6601-11A TCGA-COAD 606e4d3b-f02f-4349-bafa-804180766782
# TCGA-AZ-6601-01A TCGA-COAD b5e81d7c-13d2-47d2-ade8-16a9d9f52f54
# TCGA-AZ-6603-11A TCGA-COAD 5b225e8b-014b-4407-bc80-8566b10d9103
# TCGA-AZ-6603-01A TCGA-COAD b12289f8-8259-428c-ae3e-39190e67a8d1
# TCGA-AZ-6605-11A TCGA-COAD 8828647d-29ac-4ef0-9085-96846c5f1731
# TCGA-AZ-6605-01A TCGA-COAD d366f4e7-0eaf-4c32-a080-864679e1a6ef
# TCGA-F4-6704-11A TCGA-COAD f2e8d1e1-001b-4a31-a4ee-23936f5f3022
# TCGA-F4-6704-01A TCGA-COAD f815284b-74a2-4ad8-9f1b-aa1ec54fe579

# %% [markdown]
# ### Running Launcher off of AWS
#
# Changes to scripts above required for running off of AWS servers (if the internet connection for instance launching is inconsistent).
#
# `queenB.sh` script
#
# 1. Launch logged screen instance for STDOUT logging `screen -Ldmt`
# 2. Lines 41-44: Security group certification for instance launch needs to be uploaded to launch instance.
# 3. Check if `aws` / `ec2` commands are available on Crown AMI.

# %% [markdown]
# ### Results

# %%
# TCGA-COAD Run 1A
cd ~/Crown/data2/tcga_1_coad/
INPUT='tcga_run1A.txt'

# run...
echo ''; cat $INPUT; echo ''
aws s3 cp hgr1_align_v2.tcga.sh s3://crownproject/scripts/hgr1_align_v2.tcga.sh
bash queenB.sh $INPUT
# Out:
# TCGA-A6-2671-11A TCGA-COAD 3bc30231-3fbd-4992-9088-1a83efa1a31e
# TCGA-A6-2671-01A TCGA-COAD 80ff8844-3c90-4c66-b6d9-a72ea86219ed
# TCGA-A6-2675-11A TCGA-COAD 3e0ae536-e178-433b-95b8-a52e14c17f14
# TCGA-A6-2675-01A TCGA-COAD c1c3ed06-d423-46bf-8b43-77f7817c59bd
# TCGA-A6-2678-11A TCGA-COAD 2d9c8cc3-d56a-4920-b86c-2389ca913e97
# TCGA-A6-2678-01A TCGA-COAD 670e9a3d-5a6e-4ddb-a1bf-6e48e3786fb1
# TCGA-A6-2679-01A TCGA-COAD 51932ec0-8c19-4c51-89ee-445e9a84c913
# TCGA-A6-2679-11A TCGA-COAD 662a73d1-ef4d-482d-b427-7dfbca525571
# TCGA-A6-2680-01A TCGA-COAD 13dea3ca-0454-465e-963b-9a33fafd098d
# TCGA-A6-2680-11A TCGA-COAD afb3c381-bf54-453f-ae30-b0c1fc0e55fc
# upload: ./hgr1_align_v2.tcga.sh to s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Launch instance # 1
# Thu Aug 16 15:34:22 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-2671-11A TCGA-COAD 3bc30231-3fbd-4992-9088-1a83efa1a31e
# Instance ID: i-0a64aef6ded431f01
# Public DNS: ec2-54-186-163-99.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-186-163-99.us-west-2.compute.amazonaws.com,54.186.163.99' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 2
# Thu Aug 16 15:37:35 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-2671-01A TCGA-COAD 80ff8844-3c90-4c66-b6d9-a72ea86219ed
# Instance ID: i-0bee045b32a2cbd50
# Public DNS: ec2-54-186-98-117.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-186-98-117.us-west-2.compute.amazonaws.com,54.186.98.117' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 3
# Thu Aug 16 15:40:44 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-2675-11A TCGA-COAD 3e0ae536-e178-433b-95b8-a52e14c17f14
# Instance ID: i-0257c7c3589ab3a75
# Public DNS: ec2-34-213-169-68.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-213-169-68.us-west-2.compute.amazonaws.com,34.213.169.68' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 4
# Thu Aug 16 15:43:52 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-2675-01A TCGA-COAD c1c3ed06-d423-46bf-8b43-77f7817c59bd
# Instance ID: i-0731aa725ce9533ff
# Public DNS: ec2-18-236-171-16.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-236-171-16.us-west-2.compute.amazonaws.com,18.236.171.16' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 5
# Thu Aug 16 15:46:59 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-2678-11A TCGA-COAD 2d9c8cc3-d56a-4920-b86c-2389ca913e97
# Instance ID: i-041883bd945a01108
# Public DNS: ec2-54-185-253-51.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-185-253-51.us-west-2.compute.amazonaws.com,54.185.253.51' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 6
# Thu Aug 16 15:50:06 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-2678-01A TCGA-COAD 670e9a3d-5a6e-4ddb-a1bf-6e48e3786fb1
# Instance ID: i-082840dca69a12a13
# Public DNS: ec2-34-208-208-251.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-208-208-251.us-west-2.compute.amazonaws.com,34.208.208.251' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 7
# Thu Aug 16 15:53:18 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-2679-01A TCGA-COAD 51932ec0-8c19-4c51-89ee-445e9a84c913
# Instance ID: i-0a977bbfd0be9b24f
# Public DNS: ec2-34-212-34-124.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-212-34-124.us-west-2.compute.amazonaws.com,34.212.34.124' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 8
# Thu Aug 16 15:56:31 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-2679-11A TCGA-COAD 662a73d1-ef4d-482d-b427-7dfbca525571
# Instance ID: i-0a9b96f5bdc1d35b7
# Public DNS: ec2-54-202-64-157.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-202-64-157.us-west-2.compute.amazonaws.com,54.202.64.157' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 9
# Thu Aug 16 15:59:38 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-2680-01A TCGA-COAD 13dea3ca-0454-465e-963b-9a33fafd098d
# Instance ID: i-0f5507100006c366a
# Public DNS: ec2-34-209-205-101.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-209-205-101.us-west-2.compute.amazonaws.com,34.209.205.101' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 10
# Thu Aug 16 16:02:47 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-2680-11A TCGA-COAD afb3c381-bf54-453f-ae30-b0c1fc0e55fc
# Instance ID: i-0a7b5c09c35f8306f
# Public DNS: ec2-54-188-112-189.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-188-112-189.us-west-2.compute.amazonaws.com,54.188.112.189' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh

# %%
# TCGA-COAD Run 1B
cd ~/Crown/data2/tcga_1_coad/
INPUT='tcga_run1B1.txt'

# run...
echo ''; cat $INPUT; echo ''
aws s3 cp hgr1_align_v2.tcga.sh s3://crownproject/scripts/hgr1_align_v2.tcga.sh
bash queenB.sh $INPUT
# Out:
# TCGA-A6-2682-01A TCGA-COAD 6491c24d-93a1-42e4-8317-4999aaa264b8
PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-2685-11A TCGA-COAD 60b762e2-d8e2-4f1c-a005-65a221e035b4
# Instance ID: i-086eafd779fa07dfa
# Public DNS: ec2-34-210-9-186.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-210-9-186.us-west-2.compute.amazonaws.com,34.210.9.186' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 8
# Wed Aug 22 10:26:22 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-2685-01A TCGA-COAD 69fffc3d-f1af-450f-a1a9-979111aee040
# Instance ID: i-0add7be0a63c1330f
# Public DNS: ec2-54-185-252-255.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-185-252-255.us-west-2.compute.amazonaws.com,54.185.252.255' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 9
# Wed Aug 22 10:29:47 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-2686-11A TCGA-COAD 818274b6-5103-4689-9d71-7dbff7ea62d6
# Instance ID: i-03537092eb4588a53
# Public DNS: ec2-35-160-102-220.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-160-102-220.us-west-2.compute.amazonaws.com,35.160.102.220' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 10
# Wed Aug 22 10:32:57 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-2686-01A TCGA-COAD ed77b3cf-a543-439f-8e11-7c1fb9efb157
# Instance ID: i-01f878889c559e0d0
# Public DNS: ec2-54-186-171-215.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-186-171-215.us-west-2.compute.amazonaws.com,54.186.171.215' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 11
# Wed Aug 22 10:36:05 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-5659-11A TCGA-COAD 3f26333a-9c85-4f55-8a3e-6f78d91cc553
# Instance ID: i-0052cfc5ba4f00a5c
# Public DNS: ec2-54-149-121-252.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-149-121-252.us-west-2.compute.amazonaws.com,54.149.121.252' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 12
# Wed Aug 22 10:39:14 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-5659-01A TCGA-COAD aabe673a-9363-45ce-98f6-4fddbb6a6a31
# Instance ID: i-00d585a35ff45b5c7
# Public DNS: ec2-54-189-179-114.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-189-179-114.us-west-2.compute.amazonaws.com,54.189.179.114' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 13
# Wed Aug 22 10:42:23 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-5662-11A TCGA-COAD 891d4b89-492a-4fdf-aadb-92e5f3eb2175
# Instance ID: i-0f07169ee0a2458e8
# Public DNS: ec2-34-220-123-133.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-220-123-133.us-west-2.compute.amazonaws.com,34.220.123.133' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 14
# Wed Aug 22 10:45:32 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-A6-5662-01A TCGA-COAD da61c732-293d-41aa-821c-caba4b248276
# Instance ID: i-097bfc2a77238622f
# Public DNS: ec2-54-212-62-28.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-212-62-28.us-west-2.compute.amazonaws.com,54.212.62.28' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh

# %%
# TCGA-COAD Run 1B
cd ~/Crown/data2/tcga_1_coad/
INPUT='tcga_run1B2.txt'

# run...
echo ''; cat $INPUT; echo ''
aws s3 cp hgr1_align_v2.tcga.sh s3://crownproject/scripts/hgr1_align_v2.tcga.sh
bash queenB.sh $INPUT
# Out:
# TCGA-A6-5665-01A TCGA-COAD 9b2dd3c7-9101-4fb1-bc2c-17d5e24f6bfb
# TCGA-A6-5665-11A TCGA-COAD fde66458-b58b-40e6-89cc-97970b566b85
# TCGA-A6-5667-01A TCGA-COAD 7d10f16e-737a-4351-ab41-9e9794b92785
# TCGA-A6-5667-11A TCGA-COAD d1f1002d-525b-4b8b-b52f-376bf792d74e
# TCGA-AA-3489-01A TCGA-COAD 611afd21-d36c-4bcd-8de1-45d63c1d449d
# TCGA-AA-3489-11A TCGA-COAD 7219d9a8-634e-471b-82dd-9316b7b28ff2
# TCGA-AA-3496-01A TCGA-COAD bf18b4eb-ff17-4632-a0ca-9a1c0f002156
# TCGA-AA-3496-11A TCGA-COAD e3adceb2-6d55-4812-b972-e46d843cb261
PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3511-01A TCGA-COAD 24dc3d9d-9011-4752-bf86-7308f89fd27d
# Instance ID: i-081001dbda2b25ae1
# Public DNS: ec2-34-221-139-35.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-221-139-35.us-west-2.compute.amazonaws.com,34.221.139.35' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 10
# Wed Aug 22 11:48:43 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3511-11A TCGA-COAD c77b629b-ae40-450e-8154-f4fc0b6bb6e3
# Instance ID: i-0a5da2726b5a7f5e8
# Public DNS: ec2-34-219-60-63.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-219-60-63.us-west-2.compute.amazonaws.com,34.219.60.63' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 11
# Wed Aug 22 11:52:02 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3514-01A TCGA-COAD 5dfd07db-48b5-4e2a-8079-9ff267002b6a
# Instance ID: i-06384bec14ada3ada
# Public DNS: ec2-35-160-84-192.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-160-84-192.us-west-2.compute.amazonaws.com,35.160.84.192' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 12
# Wed Aug 22 11:55:10 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3514-11A TCGA-COAD 7adde6fc-7b62-4f26-b327-d225b429823a
# Instance ID: i-0105b665f73bbb09b
# Public DNS: ec2-52-11-226-118.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-11-226-118.us-west-2.compute.amazonaws.com,52.11.226.118' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 13
# Wed Aug 22 11:58:18 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3516-01A TCGA-COAD 53654dfb-9885-413a-b5bb-49b19a6a0f8c
# Instance ID: i-01195c10db05b2366
# Public DNS: ec2-18-237-248-183.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-18-237-248-183.us-west-2.compute.amazonaws.com,18.237.248.183' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 14
# Wed Aug 22 12:01:29 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3516-11A TCGA-COAD 9081de60-839a-4e20-8702-02909e90cc71
# Instance ID: i-026e7ab0a6bae7358
# Public DNS: ec2-34-211-125-72.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-211-125-72.us-west-2.compute.amazonaws.com,34.211.125.72' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 15
# Wed Aug 22 12:04:38 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3517-11A TCGA-COAD a4d598d7-896b-495c-9e6b-fef43193f9e8
# Instance ID: i-0ce8c6e61491abbab
# Public DNS: ec2-34-217-126-111.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-217-126-111.us-west-2.compute.amazonaws.com,34.217.126.111' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 16
# Wed Aug 22 12:07:46 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3517-01A TCGA-COAD c4d62f18-52a9-4753-93c4-547bdbf0abea
# Instance ID: i-043e5ede7ace44a78
# Public DNS: ec2-54-200-226-177.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-200-226-177.us-west-2.compute.amazonaws.com,54.200.226.177' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh

# %%
# TCGA-COAD Run 1C
cd ~/Crown/data2/tcga_1_coad/
INPUT='tcga_run1C.txt'

# run...
echo ''; cat $INPUT; echo ''
aws s3 cp hgr1_align_v2.tcga.sh s3://crownproject/scripts/hgr1_align_v2.tcga.sh
bash queenB.sh $INPUT
# Out:
# Launch instance # 1
# Wed Aug 22 13:48:04 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3518-01A TCGA-COAD 03d5c3cb-f41c-40fd-b1e3-2c95292c59d5
# Instance ID: i-011030672c16e46d6
# Public DNS: ec2-34-209-216-249.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-209-216-249.us-west-2.compute.amazonaws.com,34.209.216.249' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 2
# Wed Aug 22 13:51:18 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3518-11A TCGA-COAD 8e3f0481-0e27-48aa-a178-9c17c78c05d1
# Instance ID: i-0103c846924d67737
# Public DNS: ec2-35-160-230-165.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-160-230-165.us-west-2.compute.amazonaws.com,35.160.230.165' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 3
# Wed Aug 22 13:54:27 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3520-01A TCGA-COAD 9d8f2b87-a61d-44db-b3e8-39a3d66e6e16
# Instance ID: i-09c0b5d174e9be5eb
# Public DNS: ec2-34-216-223-86.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34
(ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 27
# Wed Aug 22 15:09:56 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3713-01A TCGA-COAD 29c6bd2a-d4db-40db-9249-bb2b7f24c7bf
# Instance ID: i-0def35d2fcfd91f18
# Public DNS: ec2-52-43-209-182.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-43-209-182.us-west-2.compute.amazonaws.com,52.43.209.182' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 28
# Wed Aug 22 15:13:35 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AA-3713-11A TCGA-COAD 34df9d7b-935c-4298-bee1-cd2d03cd7950
#
# [Errno 104] Connection reset by peer
# Instance ID:
# cat: write error: Broken pipe
# Public DNS: ec2-34-219-168-19.us-west-2.compute.amazonaws.com
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 29
# Wed Aug 22 15:19:08 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AZ-6598-11A TCGA-COAD 823d6de4-51f2-449c-af2f-2b7f3fd028f2
# Instance ID: i-02235d85abcbfc588
# Public DNS: ec2-34-212-60-7.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-212-60-7.us-west-2.compute.amazonaws.com,34.212.60.7' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 30
# Wed Aug 22 15:22:17 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AZ-6598-01A TCGA-COAD 8468a033-502f-4085-a7f4-de4c1922b2fa
# Instance ID: i-0da08795c9801360b
# Public DNS: ec2-54-187-253-35.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-187-253-35.us-west-2.compute.amazonaws.com,54.187.253.35' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 31
# Wed Aug 22 15:25:27 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AZ-6599-01A TCGA-COAD 0188bc58-2deb-4978-98c3-3028d6fa61f8
# Instance ID: i-0329fdcb8bbf3fbcf
# Public DNS: ec2-54-202-50-243.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-202-50-243.us-west-2.compute.amazonaws.com,54.202.50.243' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 32
# Wed Aug 22 15:28:36 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AZ-6599-11A TCGA-COAD fa5e83a0-4d1d-46fe-9f11-fb4a5bc2a87f
# Instance ID: i-0a6d50c6ee7a49d8e
# Public DNS: ec2-54-191-2-123.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-191-2-123.us-west-2.compute.amazonaws.com,54.191.2.123' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 33
# Wed Aug 22 15:31:43 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AZ-6600-01A TCGA-COAD b22d685f-f23b-4f9e-802e-9615d6ed5484
# Instance ID: i-0b5a38452a8ac67bc
# Public DNS: ec2-52-27-10-86.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-27-10-86.us-west-2.compute.amazonaws.com,52.27.10.86' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 34
# Wed Aug 22 15:34:51 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AZ-6600-11A TCGA-COAD ee631538-5004-4d37-b089-61458c3d638e
# Instance ID: i-0c120d45d0c6df154
# Public DNS: ec2-52-27-117-139.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-27-117-139.us-west-2.compute.amazonaws.com,52.27.117.139' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 35
# Wed Aug 22 15:38:00 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AZ-6601-11A TCGA-COAD 606e4d3b-f02f-4349-bafa-804180766782
# Instance ID: i-0eaad7ea1fae49ab0
# Public DNS: ec2-35-166-41-61.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-166-41-61.us-west-2.compute.amazonaws.com,35.166.41.61' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 36
# Wed Aug 22 15:41:08 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AZ-6601-01A TCGA-COAD b5e81d7c-13d2-47d2-ade8-16a9d9f52f54
# Instance ID: i-06d7e7e9b0771d991
# Public DNS: ec2-54-245-182-233.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-245-182-233.us-west-2.compute.amazonaws.com,54.245.182.233' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 37
# Wed Aug 22 15:44:14 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AZ-6603-11A TCGA-COAD 5b225e8b-014b-4407-bc80-8566b10d9103
# Instance ID: i-04c6d05686389df73
# Public DNS: ec2-54-212-47-13.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-212-47-13.us-west-2.compute.amazonaws.com,54.212.47.13' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 38
# Wed Aug 22 15:47:20 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AZ-6603-01A TCGA-COAD b12289f8-8259-428c-ae3e-39190e67a8d1
# Instance ID: i-0dbd89f50573e2501
# Public DNS: ec2-54-244-58-131.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-244-58-131.us-west-2.compute.amazonaws.com,54.244.58.131' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 39
# Wed Aug 22 15:50:27 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AZ-6605-11A TCGA-COAD 8828647d-29ac-4ef0-9085-96846c5f1731
# Instance ID: i-039f22e84b6e2dc50

# %%
# TCGA-COAD Run 1C -- 2
# interrupted last run at run 39
cd ~/Crown/data2/tcga_1_coad/
INPUT='tcga_run1C2.txt'

# run...
echo ''; cat $INPUT; echo ''
aws s3 cp hgr1_align_v2.tcga.sh s3://crownproject/scripts/hgr1_align_v2.tcga.sh
bash queenB.sh $INPUT
# Out:
# TCGA-AZ-6605-11A TCGA-COAD 8828647d-29ac-4ef0-9085-96846c5f1731
# TCGA-AZ-6605-01A TCGA-COAD d366f4e7-0eaf-4c32-a080-864679e1a6ef
# TCGA-F4-6704-11A TCGA-COAD f2e8d1e1-001b-4a31-a4ee-23936f5f3022
# TCGA-F4-6704-01A TCGA-COAD f815284b-74a2-4ad8-9f1b-aa1ec54fe579
# upload: ./hgr1_align_v2.tcga.sh to s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Launch instance # 1
# Wed Aug 22 16:01:56 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AZ-6605-11A TCGA-COAD 8828647d-29ac-4ef0-9085-96846c5f1731
# Instance ID: i-0c4441c447403087e
# Public DNS: ec2-34-219-127-177.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-34-219-127-177.us-west-2.compute.amazonaws.com,34.219.127.177' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 2
# Wed Aug 22 16:05:08 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-AZ-6605-01A TCGA-COAD d366f4e7-0eaf-4c32-a080-864679e1a6ef
# Instance ID: i-0e8b42c90be2fc443
# Public DNS: ec2-54-201-117-58.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-201-117-58.us-west-2.compute.amazonaws.com,54.201.117.58' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 3
# Wed Aug 22 16:08:17 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-F4-6704-11A TCGA-COAD f2e8d1e1-001b-4a31-a4ee-23936f5f3022
# Instance ID: i-0a234c296510fc64e
# Public DNS: ec2-54-68-72-183.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-68-72-183.us-west-2.compute.amazonaws.com,54.68.72.183' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh
#
#
# Launch instance # 4
# Wed Aug 22 16:11:24 PDT 2018
# Instance Type: c4.xlarge
# AMI Image: ami-0031fd61f932bdef9
# Run Script: s3://crownproject/scripts/hgr1_align_v2.tcga.sh
# Parameters: TCGA-F4-6704-01A TCGA-COAD f815284b-74a2-4ad8-9f1b-aa1ec54fe579
# Instance ID: i-0ea0c0669198c6c9e
# Public DNS: ec2-54-200-133-148.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-200-133-148.us-west-2.compute.amazonaws.com,54.200.133.148' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/hgr1_align_v2.tcga.sh to ./hgr1_align_v2.tcga.sh

# %% [markdown]
# ## Discussion
#
# Archive to seperate coad_1 folder
# ```
# aws s3 mv --recursive --include "*hgr1*bam" --exclude "*/*" s3://crownproject/tcga/ s3://crownproject/tcga/tcga-coad-1/
# ```
#
# #### Library Preperations
# There is a bit of a discord between some of the library preps (single end vs. paired end) across the individual samples. This extends to the unfortunate point where the normal control and cancer sample are discordant and therefore may have to be flagged for exclusion in downstream analysis since variant calling is likely to behave quite differently across these samples.
