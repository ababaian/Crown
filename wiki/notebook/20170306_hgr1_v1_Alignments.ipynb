# %% [markdown]
# # 100 Genomes Alignment to hgr1 -- version 1
# ```
# pi:ababaian
# files: ~/Crown/data/1kg_hgr1/
# start: 2017 03 06
# complete : 2017 03 10
# ```
# ## Introduction
#
# The CEPH-1436 trio provides good, high quality sequencing to measure intra-individual variation. To measure global inter-individual variation in humans, 104 genomes from the 1000 genomes project (4 people x 26 populations) will be processed through the hgr1 pipeline.
#
# Of highest interest are the so-called 'conserved variants' in RNA45S, like 28S.r.59A>G which seem to be maintained at ~50% allele frequency.
#
# ### Hypothesis
# - rDNA variants will be distirbuted into two distinct populations; conserved variants which are maintained at a certain frequency in all humans; variable variants which change frequency, reaching 0.0 or 1.0 in differenent individuals.
# - The conserved variants make up distinct 'ribotypes' of rRNA

# %% [markdown]
# ## Objective
#
# - Align the PCR-Free, deep WGS data from CEPH-1436 trio to `hgr1`
# - Align 100 low-coverage genomes from all 1000 genomes populations to `hgr1`
# - Measure the variation/change in allele frequency of rDNA and it's change amongst populations.

# %% [markdown]
# ## Materials and Methods
#
# ~ Data-sets
#
# ~ Scripts
#
# ~ CEPH-1436 Alignments
#
# ~ 100 Genomes Alignments

# %% [markdown]
# ### Data-sets
#
# Data-sets are cataloged in `~/Crown/data/1kg_hgr1/1kg_hgr1_datasets.xlsx`. Freeze of data-sets `170306_dataFreezetsv.tar.gz` made at Mon Mar  6 11:51:16 PST 2017.
#
# #### 100 Genomes data
#
# - 104 genomes were choosen from the 1000 genomes project data. 4 x 26 populations.
# - From the 1kg [sequence.index](https://s3.amazonaws.com/1000genomes/sequence.index), samples were filtered for:
# ```
# INSTRUMENT_PLATFORM: ILLUMINA
# INSTRUMENT_MODEL: Illumina HiSeq 2000
# LIBRARY_LAYOUT: PAIRED
# WITHDRAWN: 0
# READ_COUNT: >20,000,000
# ANALYSIS_GROUP: low coverage
# ```
# - From this filtered list four individuals from each population were randomly choosen for inclusion.
# - The fastq files were moved relative to what is written in that path. New ftp paths for each file were generated using the [current.tree](ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/current.tree) file on the ftp.1000genomes.ebi.ac.uk server; all data was manually parsed into main sheet of 1kg_hgr1_datasets.xlsx.
#
# convert.sh
# ```
# #!/bin/bash
# # Lookup current file path
# # using filenames
# # (1kg_files is from sequence.index)
#
# LINES=$(wc -l 1kg_files | cut -f 1 -d ' ' )
#
# echo $LINES
#
# for LINE in $(seq 1 $LINES)
# do
# 	RETURN='MT'
#
# 	SEARCH=$(sed -n "$LINE"p 1kg_files)
# 	SEARCH2=$(basename $SEARCH)
#
# 	RETURN=$(grep "$SEARCH2" current.tree)
#
# 	echo $RETURN >> 1kg_files.newpath
# done
# ```

# %% [markdown]
# ### Scripts
#
# `1kg_align_v1.sh` - Core alignment script for hgr1 alignment and VCF

# %%
#!/bin/bash
# 1kg_align_v1.sh
# rDNA alignment pipeline
# 170305 build
# AMI: crown-170220 - ami-66129306
# EC2: c4.2xlarge (8cpu / 15 gb)
# EC2: c4.xlarge  (4cpu / 8  gb)
# Storage: 300 Gb
#

# Control Panel -------------------------------
# CPU
	THREADS='3'

# Sequencing Data
	LIBRARY=$1 # Library/ File name
	FASTQ1=$5
	FASTQ2=$6

    # File-names
    FQ1=$(basename $FASTQ1)
    FQ2=$(basename $FASTQ2)

# Read Group Data
	RGSM=$2   # Sample. Patient Identifer
	RGID=$3 # Read Group ID. Accession Number
	RGLB=$LIBRARY # Library Name. Accession Number
	RGPL='ILLUMINA'  # Sequencing Platform.
	RGPO=$4 # Patient Population
	# Extract Sequencing Run Info
	#  RGPU=$(gzip -dc $FQ1 | head -n1 - | cut -f1 -d':' | cut -f2 -d' ')

# Initialize wordir ---------------------------

# Make working directory
  mkdir -p align; cd align

# Copy hgrX genome and create bowtie2 index
  aws s3 cp s3://crownproject/resources/hgr1.fa ./
  samtools faidx hgr1.fa
  
  bowtie2-build hgr1.fa hgr1
  
# Download Genome Sequencing Data
  wget $FASTQ1
  wget $FASTQ2

    # Extract Sequencing Run Info
    RGPU=$(gzip -dc $FQ1| head -n1 - | cut -f1 -d':' | cut -f2 -d' ')

# Primary Alignment -------------------------

# Bowtie2: align to genome

bowtie2 --very-sensitive-local -p $THREADS --rg-id $RGID --rg LB:$RGLB --rg SM:$RGSM \
--rg PL:$RGPL --rg PU:$RGPU -x hgr1 -1 $FQ1 -2 $FQ2 | samtools view -bS - > aligned_unsorted.bam

rm $FQ1 $FQ2 # Remove fastq files to save space

# Calcualte library flagstats
  samtools flagstat aligned_unsorted.bam > aligned_unsorted.flagstat
  
# Read Subset ------------------------------
# Extract mapped reads, and their unmapped pairs

  # Extract Header
  samtools view -H aligned_unsorted.bam > align.header.tmp

  # Unmapped reads with mapped pairs
  # Extract Mapped Reads
  # and their unmapped pairs
  samtools view -b -F 4 aligned_unsorted.bam > align.F4.bam #mapped
  samtools view -b -f 4 -F 8 aligned_unsorted.bam > align.f4F8.bam #unmapped pairs
  
  # Extract just the 45S unit
  #aws s3 cp s3://crownproject/resources/rDNA_45s.bed ./
  #samtools view -b -L rDNA_45s.bed align.F4.bam > align.F4.45s.bam
  
  # What are the mapped readnames
  samtools view align.F4.bam | cut -f1 - > read.names.tmp
  
  # Extract mapped reads
  samtools view align.F4.bam | grep -Ff read.names.tmp - > align.F4.tmp.sam

  
  # Extract cases of read pairs mapped on edge of region of interest
  # -------|======= R O I ======| ----------
  # read:                  ====---====
  samtools view align.F4.bam | grep -Ff read.names.tmp - > align.F4.tmp.sam

  # Complete mapped reads list
  #cut -f1 align.F4.tmp.sam > read.names.45s.long.tmp

  # Extract unmapped reads with a mapped pair
  samtools view align.f4F8.bam | grep -Ff read.names.tmp - > align.f4F8.tmp.sam

  # Re-compile bam file
  cat align.header.tmp align.F4.tmp.sam align.f4F8.tmp.sam | samtools view -bS - > align.hgr1.tmp.bam
    samtools sort align.hgr1.tmp.bam align.hgr1
    samtools index align.hgr1.bam
    samtools flagstat align.hgr1.bam > align.hgr1.flagstat
    
  # Clean up 
  rm *tmp* align.F4.bam align.f4F8.bam

# Rename the total Bam Files
  mv aligned_unsorted.bam $LIBRARY.bam
  mv aligned_unsorted.bam.bai $LIBRARY.bam.bai
  mv aligned_unsorted.flagstat $LIBRARY.flagstat

# Rename the hgr-aligned Bam files
  mv align.hgr1.bam $LIBRARY.hgr1.bam
  mv align.hgr1.bam.bai $LIBRARY.hgr1.bam.bai
  mv align.hgr1.flagstat $LIBRARY.hgr1.flagstat
  
# Primary VCF ----------------------------

# GATK variant calling
  aws s3 cp s3://crownproject/resources/hgr1.gatk.fa ./
  aws s3 cp s3://crownproject/resources/hgr1.gatk.fa.fai ./
  aws s3 cp s3://crownproject/resources/hgr1.gatk.dict ./
  
  java -Xmx12G -jar /home/ubuntu/software/GenomeAnalysisTK.jar \
  -R hgr1.gatk.fa -T HaplotypeCaller \
  -ploidy 2 --max_alternate_alleles 6 \
  -I $LIBRARY.hgr1.bam -o $LIBRARY.hgr1.vcf

   # Memory issues, restrict to 45S region only hgr2
     # -ploidy 100, 50, 20 failed... do 2 and analyze 45S further
     
# Upload final output files to S3
 
# Alignments (Full)
 #aws s3 cp $LIBRARY.bam s3://crownproject/1kg_hgr1/
 #aws s3 cp $LIBRARY.bam.bai s3://crownproject/1kg_hgr1/
 aws s3 cp $LIBRARY.flagstat s3://crownproject/1kg_hgr1/

# Alignments (Aligned)
  aws s3 cp $LIBRARY.hgr1.bam s3://crownproject/1kg_hgr1/
  aws s3 cp $LIBRARY.hgr1.bam.bai s3://crownproject/1kg_hgr1/
  aws s3 cp $LIBRARY.hgr1.flagstat s3://crownproject/1kg_hgr1/

# VCF
 aws s3 cp $LIBRARY.hgr1.vcf s3://crownproject/1kg_hgr1/
 aws s3 cp $LIBRARY.hgr1.vcf.idx s3://crownproject/1kg_hgr1/
 
# Shutdown and Terminate instance
EC2ID=$(ec2metadata --instance-id)
aws ec2 terminate-instances --instance-ids $EC2ID

# Script complete

# %% [markdown]
# `queenB.sh` - ec2 auto-launch script for high-throughput

# %%
#!/bin/bash
# queenB.sh
# 20170306a build
# EC2 Launch / Control Script
#

# Control Panel =========================
# EC2 Run Script - script for droneB to execute
TASK="s3://crownproject/scripts/1kg_align_v1.sh"

# Parameter file, each line is given to a droneB to execute
# gather.sh by
PARAMETERS="hgr1_test.txt"
# PARAMETERS=$1 # changed in build 20170306b

# EC2 Set-up
instanceTYPE='c4.xlarge'
imageID='ami-66129306' #AMI

devNAME='/dev/sda1' # /dev/sda1 for Crown-AMI
volSIZE='300' # in Gb

# Number of instances to launch
#COUNT=2 # predetermined number
COUNT=$(wc -l $PARAMETERS | cut -f 1 -d' ' ) # for each input argument

# Security
keyNAME='CrownKey'
keyPATH="/home/artem/.ssh/CrownKey.pem"
secGROUP='crown-group'

# =======================================

for ITER in $(seq 1 $COUNT)
do

  # Extract Parameters/Arguments ----------

  ARGS=$(sed -n "$ITER"p $PARAMETERS | sed 's/\t/ /g' - )

  echo "Launch instance # $ITER"
  echo "Instance Type: $instanceTYPE"
  echo "AMI Image: $imageID"
  echo "Run Script: $TASK"
  echo "Parameters: $ARGS"

  # Launch an instance --------------------
  # NOTE: each iteration of the for loop launches one instance
  # therefore each loop launches only one instance
  aws ec2 run-instances --image-id $imageID --count 1 \
   --instance-type $instanceTYPE --key-name $keyNAME \
   --block-device-mappings DeviceName=$devNAME,Ebs={VolumeSize=$volSIZE} \
   --security-groups $secGROUP > launch.tmp

  # Another alternative is to use --user-data droneB.sh 
  # which will run at instance boot-up
  # passing arguments to it may be challenging

  # Retrieve instance ID
  instanceID=$(cat launch.tmp | \
    egrep -o -e 'InstanceId[":/A-Za-z0-9_ \\-]*' - |\
    cut -f2 -d' ' - | xargs)

  echo "Instance ID: $instanceID"


  # Add a few minute wait here to allow for Public DNS to be assigned
  # otherwise ssh doesn't work
  sleep 180s

  # Retrieve public DNS
  aws ec2 describe-instances --instance-ids $instanceID > launch2.tmp

  pubDNS=$(cat launch2.tmp | \
    egrep -o -m 1 -e 'PublicDnsName[.":/A-Za-z0-9_ \\-]*' - |\
    cut -f2 -d' ' - | xargs)

  echo "Public DNS: $pubDNS"

  # Access the instance -------------------

  LOGIN="ubuntu@$pubDNS" 

  ssh -i $keyPATH \
    -o StrictHostKeyChecking=no \
    $LOGIN 'bash -s' < droneB.sh $TASK $(echo $ARGS)

  # Cleanup
  rm *.tmp

  echo ''
  echo ''

done

# end of script

# %% [markdown]
# ### CEPH-1436 Trio Alignment
#
# NA12878 and NA12891
#
# ```
# ## ec2-52-34-12-139.us-west-2.compute.amazonaws.com
#
# aws s3 cp s3://crownproject/scripts/1kg_align_v1.sh ./
# screen
# # modify to not-redownload data
#
# sh 1kg_align_v1.sh NA12878_pp NA12878 ERR194147 CEU \
#  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR194/ERR194147/ERR194147_1.fastq.gz \
#  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR194/ERR194147/ERR194147_2.fastq.gz
#
#
# ## ec2-52-27-70-31.us-west-2.compute.amazonaws.com
#
# sh 1kg_align_v1.sh NA12891_pp NA12891 ERR194160 CEU \
#  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR194/ERR194160/ERR194160_1.fastq.gz \
#  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR194/ERR194160/ERR194160_1.fastq.gz
#
#
# # There was a bug in the script
# # first line of gatk was commented out so vcf wasn't genereted
# # manually ran the commands below. Fixed in version above
#
#   java -Xmx12G -jar /home/ubuntu/software/GenomeAnalysisTK.jar \
#   -R hgr1.gatk.fa -T HaplotypeCaller \
#   -ploidy 2 --max_alternate_alleles 6 \
#   -I $LIBRARY.hgr1.bam -o $LIBRARY.hgr1.vcf
#
# ```
#
# NA12892 was ran via queenB.sh launch script
# ```
# artem@glitch[tmp] sh queenB.sh                                               [12:03PM]
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA12892_pp NA12892 ERR194161 CEU ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR194/ERR194161/ERR194161_1.fastq.gz ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR194/ERR194161/ERR194161_2.fastq.gz
# Instance ID: i-05369ae4edd7bde5f
# Public DNS: ec2-35-165-87-54.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-165-87-54.us-west-2.compute.amazonaws.com,35.165.87.54' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
# ```

# %% [markdown]
# ### 100 Genomes Runs
#
# queenB.sh run for low coverage genomes
#
# hgr1_batch1.txt
#
# ```
# HG02283	HG02283	SRR401071	ACB	ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG
(ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 3
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA19984 NA19984 SRR768211 ASW ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19984/sequence_read/SRR768211_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19984/sequence_read/SRR768211_2.filt.fastq.gz
# Instance ID: i-0cc46dd6c2387836e
# Public DNS: ec2-52-26-134-26.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-26-134-26.us-west-2.compute.amazonaws.com,52.26.134.26' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 4
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG03607 HG03607 ERR185162 BEB ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03607/sequence_read/ERR185162_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03607/sequence_read/ERR185162_2.filt.fastq.gz
# Instance ID: i-023f7af38eb582291
# Public DNS: ec2-35-161-205-200.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-161-205-200.us-west-2.compute.amazonaws.com,35.161.205.200' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 5
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG03604 HG03604 ERR251410 BEB ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03604/sequence_read/ERR251410_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03604/sequence_read/ERR251410_2.filt.fastq.gz
#
# An error occurred (InstanceLimitExceeded) when calling the RunInstances operation: You have requested more instances (6) than your current instance limit of 5 allows for the specified instance type. Please visit http://aws.amazon.com/contact-us/ec2-request to request an adjustment to this limit.
# Instance ID:
# Public DNS: ec2-52-10-114-143.us-west-2.compute.amazonaws.com
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 6
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG04162 HG04162 ERR251485 BEB ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG04162/sequence_read/ERR251485_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG04162/sequence_read/ERR251485_2.filt.fastq.gz
#
# An error occurred (InstanceLimitExceeded) when calling the RunInstances operation: You have requested more instances (6) than your current instance limit of 5 allows for the specified instance type. Please visit http://aws.amazon.com/contact-us/ec2-request to request an adjustment to this limit.
# Instance ID:
# Public DNS: ec2-52-10-114-143.us-west-2.compute.amazonaws.com
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 7
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG03616 HG03616 SRR787084 BEB ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03616/sequence_read/SRR787084_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03616/sequence_read/SRR787084_2.filt.fastq.gz
#
# An error occurred (InstanceLimitExceeded) when calling the RunInstances operation: You have requested more instances (6) than your current instance limit of 5 allows for the specified instance type. Please visit http://aws.amazon.com/contact-us/ec2-request to request an adjustment to this limit.
# Instance ID:
# Public DNS: ec2-52-10-114-143.us-west-2.compute.amazonaws.com
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 8
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG02190 HG02190 ERR050151 CDX ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG02190/sequence_read/ERR050151_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG02190/sequence_read/ERR050151_2.filt.fastq.gz
#
# An error occurred (InstanceLimitExceeded) when calling the RunInstances operation: You have requested more instances (6) than your current instance limit of 5 allows for the specified instance type. Please visit http://aws.amazon.com/contact-us/ec2-request to request an adjustment to this limit.
# Instance ID:
# Public DNS: ec2-52-10-114-143.us-west-2.compute.amazonaws.com
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 9
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG00851 HG00851 ERR251128 CDX ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00851/sequence_read/ERR251128_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00851/sequence_read/ERR251128_2.filt.fastq.gz
#
# An error occurred (InstanceLimitExceeded) when calling the RunInstances operation: You have requested more instances (6) than your current instance limit of 5 allows for the specified instance type. Please visit http://aws.amazon.com/contact-us/ec2-request to request an adjustment to this limit.
# Instance ID:
# Public DNS: ec2-52-10-114-143.us-west-2.compute.amazonaws.com
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 10
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG00978 HG00978 ERR251136 CDX ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00978/sequence_read/ERR251136_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00978/sequence_read/ERR251136_2.filt.fastq.gz
#
# An error occurred (InstanceLimitExceeded) when calling the RunInstances operation: You have requested more instances (6) than your current instance limit of 5 allows for the specified instance type. Please visit http://aws.amazon.com/contact-us/ec2-request to request an adjustment to this limit.
# Instance ID:
# Public DNS: ec2-52-10-114-143.us-west-2.compute.amazonaws.com
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %% [markdown]
# sent request to amazon for upto 25 instances at once. Will re-run launch 5-7 as batch2.5 once these complete. Then 8-10 as batch2.9.

# %%
# queenB run for 1kg_batch2.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch2.5.txt
# Out:
# 1kg_align_v0.sh  droneB.sh	    hgr1_batch2.9.txt  queenB.sh
# 1kg_align_v1.sh  hgr1_batch1.txt    hgr1_batch2.txt
# 1kg_runs_1.txt	 hgr1_batch2.5.txt  hgr1_test.txt
#
# Mon Mar  6 19:34:40 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG03604 HG03604 ERR251410 BEB ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03604/sequence_read/ERR251410_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03604/sequence_read/ERR251410_2.filt.fastq.gz
# Instance ID: i-0b964d0215971f537
# Public DNS: ec2-35-163-93-161.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-163-93-161.us-west-2.compute.amazonaws.com,35.163.93.161' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 2
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG04162 HG04162 ERR251485 BEB ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG04162/sequence_read/ERR251485_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG04162/sequence_read/ERR251485_2.filt.fastq.gz
# Instance ID: i-0456d21000b924c9b
# Public DNS: ec2-52-41-242-8.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-41-242-8.us-west-2.compute.amazonaws.com,52.41.242.8' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 3
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG03616 HG03616 SRR787084 BEB ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03616/sequence_read/SRR787084_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03616/sequence_read/SRR787084_2.filt.fastq.gz
# Instance ID: i-0f13f5dc80632b185
# Public DNS: ec2-52-24-84-66.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-24-84-66.us-west-2.compute.amazonaws.com,52.24.84.66' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %%
# queenB run for 1kg_batch2.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch2.9.txt
# Out:
# 1kg_align_v0.sh  droneB.sh	    hgr1_batch2.9.txt  queenB.sh
# 1kg_align_v1.sh  hgr1_batch1.txt    hgr1_batch2.txt
# 1kg_runs_1.txt	 hgr1_batch2.5.txt  hgr1_test.txt
#
# Mon Mar  6 21:41:50 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG02190 HG02190 ERR050151 CDX ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG02190/sequence_read/ERR050151_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG02190/sequence_read/ERR050151_2.filt.fastq.gz
# Instance ID: i-0d8f9267f2b4d9f96
# Public DNS: ec2-52-40-43-94.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-40-43-94.us-west-2.compute.amazonaws.com,52.40.43.94' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 2
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG00851 HG00851 ERR251128 CDX ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00851/sequence_read/ERR251128_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00851/sequence_read/ERR251128_2.filt.fastq.gz
# Instance ID: i-0f776d6ed64dfff02
# Public DNS: ec2-52-24-48-206.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-24-48-206.us-west-2.compute.amazonaws.com,52.24.48.206' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 3
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG00978 HG00978 ERR251136 CDX ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00978/sequence_read/ERR251136_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00978/sequence_read/ERR251136_2.filt.fastq.gz
# Instance ID: i-08ba29b7e0b0d034a
# Public DNS: ec2-52-32-234-206.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-32-234-206.us-west-2.compute.amazonaws.com,52.32.234.206' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %%
# queenB run for 1kg_batch3.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch3.txt
# Out:
# 1kg_align_v0.sh  droneB.sh	    hgr1_batch2.9.txt  hgr1_test.txt
# 1kg_align_v1.sh  hgr1_batch1.txt    hgr1_batch2.txt    queenB.sh
# 1kg_runs_1.txt	 hgr1_batch2.5.txt  hgr1_batch3.txt
#
# Tue Mar  7 10:04:28 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG00982 HG00982 ERR251138 CDX ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00982/sequence_read/ERR251138_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00982/sequence_read/ERR251138_2.filt.fastq.gz
# Instance ID: i-0ad3c29a055275d49
# Public DNS: ec2-52-43-178-115.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-43-178-115.us-west-2.compute.amazonaws.com,52.43.178.115' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 2
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA06985 NA06985 ERR050082 CEU ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA06985/sequence_read/ERR050082_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA06985/sequence_read/ERR050082_2.filt.fastq.gz
# Instance ID: i-06677981f2767bb06
# Public DNS: ec2-52-41-139-38.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-41-139-38.us-west-2.compute.amazonaws.com,52.41.139.38' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 3
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA11881 NA11881 ERR068362 CEU ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA11881/sequence_read/ERR068362_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA11881/sequence_read/ERR068362_2.filt.fastq.gz
# Instance ID: i-05dcd5f6c2dd784f0
# Public DNS: ec2-35-163-60-174.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-163-60-174.us-west-2.compute.amazonaws.com,35.163.60.174' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 4
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA12234 NA12234 ERR233302 CEU ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA12234/sequence_read/ERR233302_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA12234/sequence_read/ERR233302_2.filt.fastq.gz
# Instance ID: i-0a7832bc0a4bc1e32
# Public DNS: ec2-35-162-84-38.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-162-84-38.us-west-2.compute.amazonaws.com,35.162.84.38' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 5
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA12283 NA12283 ERR239334 CEU ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA12283/sequence_read/ERR239334_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA12283/sequence_read/ERR239334_2.filt.fastq.gz
# Instance ID: i-062a5028c74e07021
# Public DNS: ec2-52-37-3-137.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-37-3-137.us-west-2.compute.amazonaws.com,52.37.3.137' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %%
# queenB run for 1kg_batch3.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch4a.txt
# Out:
# 1kg_align_v0.sh  hgr1_batch1.txt    hgr1_batch3.txt   queenB.sh
# 1kg_align_v1.sh  hgr1_batch2.5.txt  hgr1_batch4a.txt
# 1kg_runs_1.txt	 hgr1_batch2.9.txt  hgr1_batch4b.txt
# droneB.sh	 hgr1_batch2.txt    hgr1_test.txt
#
# Tue Mar  7 11:51:10 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA18622 NA18622 ERR251602 CHB ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA18622/sequence_read/ERR251602_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA18622/sequence_read/ERR251602_2.filt.fastq.gz
# Instance ID: i-09bca830fb3b6bb12
# Public DNS: ec2-35-165-95-150.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-165-95-150.us-west-2.compute.amazonaws.com,35.165.95.150' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 2
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA18632 NA18632 ERR251607 CHB ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA18632/sequence_read/ERR251607_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA18632/sequence_read/ERR251607_2.filt.fastq.gz
# Instance ID: i-055355d90ef1dc82c
# Public DNS: ec2-52-40-250-162.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-40-250-162.us-west-2.compute.amazonaws.com,52.40.250.162' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 3
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA18533 NA18533 SRR189816 CHB ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA18533/sequence_read/SRR189816_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA18533/sequence_read/SRR189816_2.filt.fastq.gz
# Instance ID: i-0b470733a4e8fb87a
# Public DNS: ec2-52-33-211-214.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-33-211-214.us-west-2.compute.amazonaws.com,52.33.211.214' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %%
# queenB run for 1kg_batch3.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch4b.txt
# Out:
# 1kg_align_v0.sh  hgr1_batch1.txt    hgr1_batch3.txt   queenB.sh
# 1kg_align_v1.sh  hgr1_batch2.5.txt  hgr1_batch4a.txt
# 1kg_runs_1.txt	 hgr1_batch2.9.txt  hgr1_batch4b.txt
# droneB.sh	 hgr1_batch2.txt    hgr1_test.txt
#
# Tue Mar  7 13:11:18 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA18647 NA18647 SRR741398 CHB ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA18647/sequence_read/SRR741398_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA18647/sequence_read/SRR741398_2.filt.fastq.gz
# Instance ID: i-04b7767e17a86449d
# Public DNS: ec2-52-41-46-32.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-41-46-32.us-west-2.compute.amazonaws.com,52.41.46.32' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 2
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG00478 HG00478 ERR251108 CHS ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00478/sequence_read/ERR251108_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00478/sequence_read/ERR251108_2.filt.fastq.gz
# Instance ID: i-06b332f62eab08ec6
# Public DNS: ec2-35-164-252-113.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-164-252-113.us-west-2.compute.amazonaws.com,35.164.252.113' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %%
# queenB run for 1kg_batch3.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch5a.txt
# Out:
# 1kg_align_v0.sh  hgr1_batch1.txt    hgr1_batch3.txt   hgr1_batch5b.txt
# 1kg_align_v1.sh  hgr1_batch2.5.txt  hgr1_batch4a.txt  hgr1_test.txt
# 1kg_runs_1.txt	 hgr1_batch2.9.txt  hgr1_batch4b.txt  queenB.sh
# droneB.sh	 hgr1_batch2.txt    hgr1_batch5a.txt
#
# Tue Mar  7 14:51:01 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG00536 HG00536 ERR251115 CHS ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00536/sequence_read/ERR251115_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00536/sequence_read/ERR251115_2.filt.fastq.gz
# Instance ID: i-03c0095dfef7a415a
# Public DNS: ec2-52-26-246-152.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-26-246-152.us-west-2.compute.amazonaws.com,52.26.246.152' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 2
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG00557 HG00557 ERR251120 CHS ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00557/sequence_read/ERR251120_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00557/sequence_read/ERR251120_2.filt.fastq.gz
# Instance ID: i-03a610b1958576d06
# Public DNS: ec2-52-34-117-221.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-34-117-221.us-west-2.compute.amazonaws.com,52.34.117.221' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 3
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG00717 HG00717 SRR794066 CHS ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00717/sequence_read/SRR794066_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00717/sequence_read/SRR794066_2.filt.fastq.gz
# Instance ID: i-01d62dc7cf58b031b
# Public DNS: ec2-52-34-147-176.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-34-147-176.us-west-2.compute.amazonaws.com,52.34.147.176' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %%
# queenB run for 1kg_batch3.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch5b.txt
# Out:
# 1kg_align_v0.sh  hgr1_batch1.txt    hgr1_batch3.txt   hgr1_batch5b.txt
# 1kg_align_v1.sh  hgr1_batch2.5.txt  hgr1_batch4a.txt  hgr1_test.txt
# 1kg_runs_1.txt	 hgr1_batch2.9.txt  hgr1_batch4b.txt  queenB.sh
# droneB.sh	 hgr1_batch2.txt    hgr1_batch5a.txt
#
# Tue Mar  7 16:43:19 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG01125 HG01125 ERR022454 CLM ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01125/sequence_read/ERR022454_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01125/sequence_read/ERR022454_2.filt.fastq.gz
# Instance ID: i-037c54be6c31e4537
# Public DNS: ec2-52-34-189-20.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-34-189-20.us-west-2.compute.amazonaws.com,52.34.189.20' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 2
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG01464 HG01464 SRR407617 CLM ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01464/sequence_read/SRR407617_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01464/sequence_read/SRR407617_2.filt.fastq.gz
# Instance ID: i-09eb831381c190880
# Public DNS: ec2-35-160-128-225.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-160-128-225.us-west-2.compute.amazonaws.com,35.160.128.225' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %%
# queenB run for 1kg_batch3.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch6.txt
# Out:
# 1kg_align_v0.sh  hgr1_batch2.5.txt  hgr1_batch4b.txt  hgr1_test.txt
# 1kg_align_v1.sh  hgr1_batch2.9.txt  hgr1_batch5a.txt  queenB.sh
# 1kg_runs_1.txt	 hgr1_batch2.txt    hgr1_batch5b.txt
# droneB.sh	 hgr1_batch3.txt    hgr1_batch6a.txt
# hgr1_batch1.txt  hgr1_batch4a.txt   hgr1_batch6.txt
#
# Tue Mar  7 20:25:23 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG01348 HG01348 SRR702042 CLM ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01348/sequence_read/SRR702042_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01348/sequence_read/SRR702042_2.filt.fastq.gz
# Instance ID: i-02daaaff8b3ac278e
# Public DNS: ec2-52-40-14-97.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-40
us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-39-19-180.us-west-2.compute.amazonaws.com,52.39.19.180' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %%
# queenB run for 1kg_batch3.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch13.txt
# Out:
# 1kg_align_v0.sh   hgr1_batch12.txt   hgr1_batch3.txt   hgr1_batch6.txt
# 1kg_align_v1.sh   hgr1_batch13.txt   hgr1_batch4a.txt  hgr1_batch7.txt
# 1kg_runs_1.txt	  hgr1_batch1.txt    hgr1_batch4b.txt  hgr1_batch8.txt
# droneB.sh	  hgr1_batch2.5.txt  hgr1_batch5a.txt  hgr1_batch9.txt
# hgr1_batch10.txt  hgr1_batch2.9.txt  hgr1_batch5b.txt  hgr1_test.txt
# hgr1_batch11.txt  hgr1_batch2.txt    hgr1_batch6a.txt  queenB.sh
#
# Wed Mar  8 22:54:49 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG02046 HG02046 ERR070052 KHV ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG02046/sequence_read/ERR070052_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG02046/sequence_read/ERR070052_2.filt.fastq.gz
# Instance ID: i-0549ecd57dbd9987c
# Public DNS: ec2-52-37-224-191.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-37-224-191.us-west-2.compute.amazonaws.com,52.37.224.191' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 2
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG02035 HG02035 ERR070050 KHV ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG02035/sequence_read/ERR070050_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG02035/sequence_read/ERR070050_2.filt.fastq.gz
# Instance ID: i-07f1ec87e7739fc7e
# Public DNS: ec2-52-38-7-151.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-38-7-151.us-west-2.compute.amazonaws.com,52.38.7.151' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 3
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG02040 HG02040 ERR065366 KHV ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG02040/sequence_read/ERR065366_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG02040/sequence_read/ERR065366_2.filt.fastq.gz
# Instance ID: i-0049c78ca1dee22b5
# Public DNS: ec2-35-160-159-63.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-160-159-63.us-west-2.compute.amazonaws.com,35.160.159.63' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %%
# queenB run for 1kg_batch3.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch14.txt
# Out:
# 1kg_align_v0.sh   hgr1_batch13.txt   hgr1_batch4a.txt  hgr1_batch8.txt
# 1kg_align_v1.sh   hgr1_batch14.txt   hgr1_batch4b.txt  hgr1_batch9.txt
# 1kg_runs_1.txt	  hgr1_batch1.txt    hgr1_batch5a.txt  hgr1_test.txt
# droneB.sh	  hgr1_batch2.5.txt  hgr1_batch5b.txt  queenB.sh
# hgr1_batch10.txt  hgr1_batch2.9.txt  hgr1_batch6a.txt
# hgr1_batch11.txt  hgr1_batch2.txt    hgr1_batch6.txt
# hgr1_batch12.txt  hgr1_batch3.txt    hgr1_batch7.txt
#
# Thu Mar  9 00:24:40 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG02078 HG02078 ERR055341 KHV ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG02078/sequence_read/ERR055341_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG02078/sequence_read/ERR055341_2.filt.fastq.gz
# Instance ID: i-0ed0254037e36821e
# Public DNS: ec2-52-89-36-89.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-89-36-89.us-west-2.compute.amazonaws.com,52.89.36.89' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 2
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA19475 NA19475 ERR251649 LWK ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19475/sequence_read/ERR251649_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19475/sequence_read/ERR251649_2.filt.fastq.gz
# Instance ID: i-0f9227882adf6ffe1
# Public DNS: ec2-52-26-30-112.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-26-30-112.us-west-2.compute.amazonaws.com,52.26.30.112' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 3
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA19320 NA19320 ERR251647 LWK ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19320/sequence_read/ERR251647_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19320/sequence_read/ERR251647_2.filt.fastq.gz
# Instance ID: i-06a38b5ddd7edefe7
# Public DNS: ec2-52-42-55-20.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-42-55-20.us-west-2.compute.amazonaws.com,52.42.55.20' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 4
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA19351 NA19351 ERR229817 LWK ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19351/sequence_read/ERR229817_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19351/sequence_read/ERR229817_2.filt.fastq.gz
# Instance ID: i-0a6d932029c239b96
# Public DNS: ec2-35-167-140-137.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-167-140-137.us-west-2.compute.amazonaws.com,35.167.140.137' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 5
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA19042 NA19042 ERR251640 LWK ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19042/sequence_read/ERR251640_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19042/sequence_read/ERR251640_2.filt.fastq.gz
# Instance ID: i-0b5132ac5e505e8a9
# Public DNS: ec2-35-167-201-7.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-167-201-7.us-west-2.compute.amazonaws.com,35.167.201.7' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %%
# queenB run for 1kg_batchX.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch15.txt
# Out:
# 1kg_align_v0.sh   hgr1_batch13.txt   hgr1_batch3.txt   hgr1_batch7.txt
# 1kg_align_v1.sh   hgr1_batch14.txt   hgr1_batch4a.txt  hgr1_batch8.txt
# 1kg_runs_1.txt	  hgr1_batch15.txt   hgr1_batch4b.txt  hgr1_batch9.txt
# droneB.sh	  hgr1_batch1.txt    hgr1_batch5a.txt  hgr1_test.txt
# hgr1_batch10.txt  hgr1_batch2.5.txt  hgr1_batch5b.txt  queenB.sh
# hgr1_batch11.txt  hgr1_batch2.9.txt  hgr1_batch6a.txt
# hgr1_batch12.txt  hgr1_batch2.txt    hgr1_batch6.txt
#
# Thu Mar  9 10:00:46 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG03432 HG03432 SRR793290 MSL ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03432/sequence_read/SRR793290_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03432/sequence_read/SRR793290_2.filt.fastq.gz
# Instance ID: i-003308b7973de4135
# Public DNS: ec2-54-68-193-174.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-68-193-174.us-west-2.compute.amazonaws.com,54.68.193.174' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 2
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG03558 HG03558 SRR792324 MSL ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03558/sequence_read/SRR792324_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03558/sequence_read/SRR792324_2.filt.fastq.gz
# Instance ID: i-08c399ced8188cf35
# Public DNS: ec2-54-68-59-178.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-68-59-178.us-west-2.compute.amazonaws.com,54.68.59.178' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 3
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG03470 HG03470 ERR187342 MSL ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03470/sequence_read/ERR187342_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03470/sequence_read/ERR187342_2.filt.fastq.gz
# Instance ID: i-03b5cb9c5ee49b1f9
# Public DNS: ec2-54-68-231-48.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54-68-231-48.us-west-2.compute.amazonaws.com,54.68.231.48' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 4
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG03548 HG03548 ERR205113 MSL ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03548/sequence_read/ERR205113_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03548/sequence_read/ERR205113_2.filt.fastq.gz
# Instance ID: i-01c8a43223b97a131
# Public DNS: ec2-35-166-253-201.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-166-253-201.us-west-2.compute.amazonaws.com,35.166.253.201' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %%
# queenB run for 1kg_batchX.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch16.txt
# Out:
# 1kg_align_v0.sh   hgr1_batch13.txt   hgr1_batch2.txt   hgr1_batch6.txt
# 1kg_align_v1.sh   hgr1_batch14.txt   hgr1_batch3.txt   hgr1_batch7.txt
# 1kg_runs_1.txt	  hgr1_batch15.txt   hgr1_batch4a.txt  hgr1_batch8.txt
# droneB.sh	  hgr1_batch16.txt   hgr1_batch4b.txt  hgr1_batch9.txt
# hgr1_batch10.txt  hgr1_batch1.txt    hgr1_batch5a.txt  hgr1_test.txt
# hgr1_batch11.txt  hgr1_batch2.5.txt  hgr1_batch5b.txt  queenB.sh
# hgr1_batch12.txt  hgr1_batch2.9.txt  hgr1_batch6a.txt
#
# Thu Mar  9 11:12:11 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA19795 NA19795 SRR768206 MXL ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19795/sequence_read/SRR768206_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19795/sequence_read/SRR768206_2.filt.fastq.gz
# Instance ID: i-03e289b9ef5efa0e9
# Public DNS: ec2-54-68-153-86.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-54
us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-40-42-241.us-west-2.compute.amazonaws.com,52.40.42.241' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %%
# queenB run for 1kg_batchX.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch18.txt
# Out:
# 1kg_align_v0.sh   hgr1_batch15.txt  hgr1_batch2.5.txt  hgr1_batch6.txt
# 1kg_align_v1.sh   hgr1_batch16.txt  hgr1_batch2.9.txt  hgr1_batch7.txt
# 1kg_runs_1.txt	  hgr1_batch17.txt  hgr1_batch2.txt    hgr1_batch8.txt
# droneB.sh	  hgr1_batch18.txt  hgr1_batch3.txt    hgr1_batch9.txt
# hgr1_batch10.txt  hgr1_batch19.txt  hgr1_batch4a.txt   hgr1_test.txt
# hgr1_batch11.txt  hgr1_batch1.txt   hgr1_batch4b.txt   queenB.sh
# hgr1_batch12.txt  hgr1_batch20.txt  hgr1_batch5a.txt
# hgr1_batch13.txt  hgr1_batch21.txt  hgr1_batch5b.txt
# hgr1_batch14.txt  hgr1_batch22.txt  hgr1_batch6a.txt
#
# Thu Mar  9 16:41:02 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG03624 HG03624 SRR794019 PJL ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03624/sequence_read/SRR794019_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03624/sequence_read/SRR794019_2.filt.fastq.gz
# Instance ID: i-0317e81039a5f2f27
# Public DNS: ec2-52-89-73-96.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-89-73-96.us-west-2.compute.amazonaws.com,52.89.73.96' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 2
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG03019 HG03019 SRR793547 PJL ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03019/sequence_read/SRR793547_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03019/sequence_read/SRR793547_2.filt.fastq.gz
# Instance ID: i-0a5d86e31a7472d6a
# Public DNS: ec2-52-43-231-250.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-43-231-250.us-west-2.compute.amazonaws.com,52.43.231.250' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 3
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG02780 HG02780 SRR793427 PJL ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG02780/sequence_read/SRR793427_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG02780/sequence_read/SRR793427_2.filt.fastq.gz
# Instance ID: i-0184e3fe6c2226f80
# Public DNS: ec2-35-165-192-105.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-165-192-105.us-west-2.compute.amazonaws.com,35.165.192.105' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 4
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG01176 HG01176 SRR350165 PUR ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01176/sequence_read/SRR350165_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01176/sequence_read/SRR350165_2.filt.fastq.gz
# Instance ID: i-04da70cfa1420820d
# Public DNS: ec2-52-37-69-84.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-37-69-84.us-west-2.compute.amazonaws.com,52.37.69.84' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %%
# queenB run for 1kg_batchX.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch19.txt
# Out:
# 1kg_align_v0.sh   hgr1_batch15.txt  hgr1_batch2.5.txt  hgr1_batch6.txt
# 1kg_align_v1.sh   hgr1_batch16.txt  hgr1_batch2.9.txt  hgr1_batch7.txt
# 1kg_runs_1.txt	  hgr1_batch17.txt  hgr1_batch2.txt    hgr1_batch8.txt
# droneB.sh	  hgr1_batch18.txt  hgr1_batch3.txt    hgr1_batch9.txt
# hgr1_batch10.txt  hgr1_batch19.txt  hgr1_batch4a.txt   hgr1_test.txt
# hgr1_batch11.txt  hgr1_batch1.txt   hgr1_batch4b.txt   queenB.sh
# hgr1_batch12.txt  hgr1_batch20.txt  hgr1_batch5a.txt
# hgr1_batch13.txt  hgr1_batch21.txt  hgr1_batch5b.txt
# hgr1_batch14.txt  hgr1_batch22.txt  hgr1_batch6a.txt
#
# Thu Mar  9 17:41:35 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG00740 HG00740 SRR069532 PUR ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00740/sequence_read/SRR069532_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00740/sequence_read/SRR069532_2.filt.fastq.gz
# Instance ID: i-07fa49838fab506e1
# Public DNS: ec2-35-163-162-255.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-163-162-255.us-west-2.compute.amazonaws.com,35.163.162.255' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 2
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG01066 HG01066 SRR069528 PUR ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01066/sequence_read/SRR069528_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG01066/sequence_read/SRR069528_2.filt.fastq.gz
# Instance ID: i-07713739cc563e545
# Public DNS: ec2-35-166-73-12.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-166-73-12.us-west-2.compute.amazonaws.com,35.166.73.12' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 3
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG00734 HG00734 SRR069522 PUR ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00734/sequence_read/SRR069522_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG00734/sequence_read/SRR069522_2.filt.fastq.gz
# Instance ID: i-00e812ccde132a4af
# Public DNS: ec2-52-41-52-125.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-41-52-125.us-west-2.compute.amazonaws.com,52.41.52.125' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 4
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG03753 HG03753 ERR183459 STU ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03753/sequence_read/ERR183459_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03753/sequence_read/ERR183459_2.filt.fastq.gz
# Instance ID: i-055e72028d91b671b
# Public DNS: ec2-35-166-147-209.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-166-147-209.us-west-2.compute.amazonaws.com,35.166.147.209' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %%
# queenB run for 1kg_batchX.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch20.txt
# Out:
# 1kg_align_v0.sh   hgr1_batch15.txt  hgr1_batch2.5.txt  hgr1_batch6.txt
# 1kg_align_v1.sh   hgr1_batch16.txt  hgr1_batch2.9.txt  hgr1_batch7.txt
# 1kg_runs_1.txt	  hgr1_batch17.txt  hgr1_batch2.txt    hgr1_batch8.txt
# droneB.sh	  hgr1_batch18.txt  hgr1_batch3.txt    hgr1_batch9.txt
# hgr1_batch10.txt  hgr1_batch19.txt  hgr1_batch4a.txt   hgr1_test.txt
# hgr1_batch11.txt  hgr1_batch1.txt   hgr1_batch4b.txt   queenB.sh
# hgr1_batch12.txt  hgr1_batch20.txt  hgr1_batch5a.txt
# hgr1_batch13.txt  hgr1_batch21.txt  hgr1_batch5b.txt
# hgr1_batch14.txt  hgr1_batch22.txt  hgr1_batch6a.txt
#
# Thu Mar  9 19:52:27 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG03836 HG03836 ERR181380 STU ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03836/sequence_read/ERR181380_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03836/sequence_read/ERR181380_2.filt.fastq.gz
# Instance ID: i-0dffe3739936dd733
# Public DNS: ec2-52-39-13-119.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-39-13-119.us-west-2.compute.amazonaws.com,52.39.13.119' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 2
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG03856 HG03856 ERR184533 STU ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03856/sequence_read/ERR184533_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03856/sequence_read/ERR184533_2.filt.fastq.gz
# Instance ID: i-09cf2709c6003eedf
# Public DNS: ec2-52-39-216-99.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-39-216-99.us-west-2.compute.amazonaws.com,52.39.216.99' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 3
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: HG03890 HG03890 ERR184527 STU ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03890/sequence_read/ERR184527_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/HG03890/sequence_read/ERR184527_2.filt.fastq.gz
# Instance ID: i-061bf38edfe75b835
# Public DNS: ec2-52-37-149-91.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-37-149-91.us-west-2.compute.amazonaws.com,52.37.149.91' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 4
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA20827 NA20827 SRR794343 TSI ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA20827/sequence_read/SRR794343_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA20827/sequence_read/SRR794343_2.filt.fastq.gz
# Instance ID: i-067ffda6375cc178c
# Public DNS: ec2-52-88-136-250.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-88-136-250.us-west-2.compute.amazonaws.com,52.88.136.250' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %%
# queenB run for 1kg_batchX.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch21.txt
# Out:
# 1kg_align_v0.sh   hgr1_batch15.txt  hgr1_batch2.5.txt  hgr1_batch6.txt
# 1kg_align_v1.sh   hgr1_batch16.txt  hgr1_batch2.9.txt  hgr1_batch7.txt
# 1kg_runs_1.txt	  hgr1_batch17.txt  hgr1_batch2.txt    hgr1_batch8.txt
# droneB.sh	  hgr1_batch18.txt  hgr1_batch3.txt    hgr1_batch9.txt
# hgr1_batch10.txt  hgr1_batch19.txt  hgr1_batch4a.txt   hgr1_test.txt
# hgr1_batch11.txt  hgr1_batch1.txt   hgr1_batch4b.txt   queenB.sh
# hgr1_batch12.txt  hgr1_batch20.txt  hgr1_batch5a.txt
# hgr1_batch13.txt  hgr1_batch21.txt  hgr1_batch5b.txt
# hgr1_batch14.txt  hgr1_batch22.txt  hgr1_batch6a.txt
#
# Thu Mar  9 21:38:09 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA20514 NA20514 ERR229823 TSI ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA20514/sequence_read/ERR229823_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA20514/sequence_read/ERR229823_2.filt.fastq.gz
# Instance ID: i-0f278f5bd09863501
# Public DNS: ec2-35-162-48-190.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-162-48-190.us-west-2.compute.amazonaws.com,35.162.48.190' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 2
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA20503 NA20503 ERR229821 TSI ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA20503/sequence_read/ERR229821_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA20503/sequence_read/ERR229821_2.filt.fastq.gz
# Instance ID: i-0f9f36e4b3bd1a163
# Public DNS: ec2-52-37-49-127.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-37-49-127.us-west-2.compute.amazonaws.com,52.37.49.127' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 3
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA20832 NA20832 SRR794275 TSI ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA20832/sequence_read/SRR794275_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA20832/sequence_read/SRR794275_2.filt.fastq.gz
# Instance ID: i-07144513892582074
# Public DNS: ec2-52-38-1-78.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-38-1-78.us-west-2.compute.amazonaws.com,52.38.1.78' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 4
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA19159 NA19159 SRR794453 YRI ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19159/sequence_read/SRR794453_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19159/sequence_read/SRR794453_2.filt.fastq.gz
# Instance ID: i-0535e76cbcdba4e66
# Public DNS: ec2-35-166-9-227.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-166-9-227.us-west-2.compute.amazonaws.com,35.166.9.227' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %%
# queenB run for 1kg_batchX.txt
# made PARAMETERS=$1
cd ~/Crown/data/tmp/
ls; echo ''
date

sh queenB.sh hgr1_batch22.txt
# Out:
# 1kg_align_v0.sh   hgr1_batch15.txt  hgr1_batch2.5.txt  hgr1_batch6.txt
# 1kg_align_v1.sh   hgr1_batch16.txt  hgr1_batch2.9.txt  hgr1_batch7.txt
# 1kg_runs_1.txt	  hgr1_batch17.txt  hgr1_batch2.txt    hgr1_batch8.txt
# droneB.sh	  hgr1_batch18.txt  hgr1_batch3.txt    hgr1_batch9.txt
# hgr1_batch10.txt  hgr1_batch19.txt  hgr1_batch4a.txt   hgr1_test.txt
# hgr1_batch11.txt  hgr1_batch1.txt   hgr1_batch4b.txt   queenB.sh
# hgr1_batch12.txt  hgr1_batch20.txt  hgr1_batch5a.txt
# hgr1_batch13.txt  hgr1_batch21.txt  hgr1_batch5b.txt
# hgr1_batch14.txt  hgr1_batch22.txt  hgr1_batch6a.txt
#
# Fri Mar 10 00:27:10 PST 2017
# Launch instance # 1
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA19153 NA19153 SRR794367 YRI ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19153/sequence_read/SRR794367_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19153/sequence_read/SRR794367_2.filt.fastq.gz
# Instance ID: i-0f353652ade970056
# Public DNS: ec2-52-88-45-9.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-88-45-9.us-west-2.compute.amazonaws.com,52.88.45.9' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 2
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA19098 NA19098 SRR794353 YRI ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19098/sequence_read/SRR794353_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19098/sequence_read/SRR794353_2.filt.fastq.gz
# Instance ID: i-0f33172c8a17eb5a4
# Public DNS: ec2-52-43-13-105.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-43-13-105.us-west-2.compute.amazonaws.com,52.43.13.105' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 3
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA19144 NA19144 SRR794324 YRI ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19144/sequence_read/SRR794324_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19144/sequence_read/SRR794324_2.filt.fastq.gz
# Instance ID: i-030b375e333fecb7a
# Public DNS: ec2-35-163-127-92.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-35-163-127-92.us-west-2.compute.amazonaws.com,35.163.127.92' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh
#
#
# Launch instance # 4
# Instance Type: c4.xlarge
# AMI Image: ami-66129306
# Run Script: s3://crownproject/scripts/1kg_align_v1.sh
# Parameters: NA19240 NA19240 SRR794330 YRI ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19240/sequence_read/SRR794330_1.filt.fastq.gz ftp://ftp.1000genomes.ebi.ac.uk/vol1/ftp/phase3/data/NA19240/sequence_read/SRR794330_2.filt.fastq.gz
# Instance ID: i-0e6c9bdac1e54d552
# Public DNS: ec2-52-32-220-246.us-west-2.compute.amazonaws.com
# Warning: Permanently added 'ec2-52-32-220-246.us-west-2.compute.amazonaws.com,52.32.220.246' (ECDSA) to the list of known hosts.
# download: s3://crownproject/scripts/1kg_align_v1.sh to ./1kg_align_v1.sh

# %% [markdown]
# ## File stats
#
# on AWS.

# %%
aws s3 ls s3://crownproject/1kg_hgr1/
# Out:
# 2017-03-04 19:05:22          0
# 2017-03-08 12:31:13        386 HG00128.flagstat
# 2017-03-08 12:31:13    2634032 HG00128.hgr1.bam
# 2017-03-08 12:31:14        656 HG00128.hgr1.bam.bai
# 2017-03-08 12:31:14        375 HG00128.hgr1.flagstat
# 2017-03-08 12:31:14      39989 HG00128.hgr1.vcf
# 2017-03-08 12:31:15        781 HG00128.hgr1.vcf.idx
# 2017-03-08 12:41:07        387 HG00139.flagstat
# 2017-03-08 12:41:07    7258373 HG00139.hgr1.bam
# 2017-03-08 12:41:08        688 HG00139.hgr1.bam.bai
# 2017-03-08 12:41:08        376 HG00139.hgr1.flagstat
# 2017-03-08 12:41:08      26601 HG00139.hgr1.vcf
# 2017-03-08 12:41:09        282 HG00139.hgr1.vcf.idx
# 2017-03-08 13:53:27        388 HG00234.flagstat
# 2017-03-08 13:53:27    3879715 HG00234.hgr1.bam
# 2017-03-08 13:53:28        632 HG00234.hgr1.bam.bai
# 2017-03-08 13:53:28        374 HG00234.hgr1.flagstat
# 2017-03-08 13:53:28      60138 HG00234.hgr1.vcf
# 2017-03-08 13:53:29       2300 HG00234.hgr1.vcf.idx
# 2017-03-08 12:17:22        386 HG00253.flagstat
# 2017-03-08 12:17:23    6352307 HG00253.hgr1.bam
# 2017-03-08 12:17:23        688 HG00253.hgr1.bam.bai
# 2017-03-08 12:17:23        374 HG00253.hgr1.flagstat
# 2017-03-08 12:17:24      22863 HG00253.hgr1.vcf
# 2017-03-08 12:17:24        282 HG00253.hgr1.vcf.idx
# 2017-03-08 00:48:55        386 HG00337.flagstat
# 2017-03-08 00:48:55    3116469 HG00337.hgr1.bam
# 2017-03-08 00:48:56        656 HG00337.hgr1.bam.bai
# 2017-03-08 00:48:56        375 HG00337.hgr1.flagstat
