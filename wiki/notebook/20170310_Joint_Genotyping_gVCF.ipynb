# %% [markdown]
# # Joint Genotyping gVCF
# ```
# pi:ababaian
# files: ~/Crown/data/..
# start: 2017 03 10
# complete : 2017 03 20
# ```
# ## Introduction
#
# Reviewing the arrays of variation one of the most important distinctions to be made is that there is an important difference between; a called non-variant (reference sequence only) and no-data. Some sites like A59G are really amenable to sequencing/coverage and so in 100% of the samples it's detected. Other (many) variant positions are variant in 50%+ of samples but there's 'no data' in the VCF file format of why no variant was called in the other data sets, either it's truely the reference sequence or there's no sequencing depth or the reads there are trashy.
#
# I found a very useful [guide](http://gatkforums.broadinstitute.org/gatk/discussion/6925/understanding-and-adapting-the-generic-hard-filtering-recommendations) on variant calling which led me to [another guide](https://software.broadinstitute.org/gatk/documentation/topic?name=methods) which outlines how to address exactly this problem. Essentially what I want is a `gVCF` file as shown [here](http://gatkforums.broadinstitute.org/gatk/discussion/4017/what-is-a-gvcf-and-how-is-it-different-from-a-regular-vcf) to retain this information.
#
# The idea is to load up all the aligned bam files to an EC2 instance and re-run HaplotypeCaller and generate a 'gVCF' file for the 107 genomes. (Includes the Utah Trio platinum genomes).
#
# The hypothesis being that there are multiple '100% present' variant sites in rDNA besides A59G but the data is missing because of high GC content.
#
# Essentially I want a rate of 'calling' reference alleles at the ~1,600 variant sites.

# %% [markdown]
# ## Objective
#
# - Generate a gVCF file for 100genomes data

# %% [markdown]
# ## Materials and Methods
#
# ### EC2 Instance
#
# Opened up a C4.2xlarge instance with 400 Gb of space.
#
# DNS: ec2-52-26-25-196.us-west-2.compute.amazonaws.com
#
# ### Guide
#
# I'm essentially going to follow this [guide](https://software.broadinstitute.org/gatk/guide/article?id=3893) for doing this.
#
# #### Manual Filter Cutoffs (roughly)
# [Good read](http://gatkforums.broadinstitute.org/gatk/discussion/6925/understanding-and-adapting-the-generic-hard-filtering-recommendations)
#
# - FS > 55
# - DP < 30
# - QD < 2

# %%
## EC2 instance Code
## Up and running! May take some hours
## ec2-52-26-25-196.us-west-2.compute.amazonaws.com

# Make folder for analysis
  mkdir -p work; cd work;
  
# Download resource files
# GATK variant calling
  aws s3 cp s3://crownproject/resources/hgr1.gatk.fa ./
  aws s3 cp s3://crownproject/resources/hgr1.gatk.fa.fai ./
  aws s3 cp s3://crownproject/resources/hgr1.gatk.dict ./


# Download all the hgr1 bam files and their index
# ~ 1 Gb
  aws s3 cp s3://crownproject/1kg_hgr1/ ./ --recursive --exclude "*" --include "*.bam"
  aws s3 cp s3://crownproject/1kg_hgr1/ ./ --recursive --exclude "*" --include "*.bam.bai"

rm testGenome.hgr1.bam
rm testGenome.hgr1.bam.bai

# BAM files
#BAM=$(ls *.bam)

ls *.bam > bams.list

# Run HaplotypeCaller to make VCF file (unified)
  
  java -Xmx12G -jar /home/ubuntu/software/GenomeAnalysisTK.jar \
  -R hgr1.gatk.fa -T HaplotypeCaller \
  -ploidy 2 --max_alternate_alleles 6 \
  -I bams.list \
  -o 100g.hgr1_all.vcf

# Re-run with (unified)
# -ploidy 10 --max_alternate_alleles 10
  
  java -Xmx12G -jar /home/ubuntu/software/GenomeAnalysisTK.jar \
  -R hgr1.gatk.fa -T HaplotypeCaller \
  -ploidy 10 --max_alternate_alleles 10 \
  -I bams.list \
  -o 100g.hgr1_all.ploidy10.vcf

aws s3 cp 100g.hgr1_all.vcf s3://crownproject/1kg_hgr1/reVCF/
aws s3 cp 100g.hgr1_all.vcf.idx s3://crownproject/1kg_hgr1/reVCF/

aws s3 cp 100g.hgr1_all.ploidy10.vcf s3://crownproject/1kg_hgr1/reVCF/
aws s3 cp 100g.hgr1_all.ploidy10.vcf.idx s3://crownproject/1kg_hgr1/reVCF/


# Re-make g.vcf files for each bam library

for BAMFILE in $(ls *.bam)
do

   # Sample ID
   sampleID=$(echo $BAMFILE | cut -f1 -d'.' -)
   
   java -Xmx12G -jar /home/ubuntu/software/GenomeAnalysisTK.jar \
  -R hgr1.gatk.fa -T HaplotypeCaller \
  -ERC BP_RESOLUTION \
  -ploidy 2 --max_alternate_alleles 6 \
  -I $BAMFILE \
  -o $sampleID.g.vcf
  
  aws s3 cp $sampleID.g.vcf s3://crownproject/1kg_hgr1/reVCF/
  aws s3 cp $sampleID.g.vcf.idx s3://crownproject/1kg_hgr1/reVCF/

done

# QED

# %%
## EC2 instance Code
# m4.xlarge 400 Gb
# ec2-52-38-47-116.us-west-2.compute.amazonaws.com
## I'm worried the script above will take a LONG time to run
## alternative approach will be to run full BP_RESOLUTION
## vcf files for EACH VCF and merge them last.

# Make folder for analysis
  mkdir -p work; cd work;
  
# Download resource files
# GATK variant calling
  aws s3 cp s3://crownproject/resources/hgr1.gatk.fa ./
  aws s3 cp s3://crownproject/resources/hgr1.gatk.fa.fai ./
  aws s3 cp s3://crownproject/resources/hgr1.gatk.dict ./


# Download all the hgr1 bam files and their index
# ~ 1 Gb
  aws s3 cp s3://crownproject/1kg_hgr1/ ./ --recursive --exclude "*" --include "*.bam"
  aws s3 cp s3://crownproject/1kg_hgr1/ ./ --recursive --exclude "*" --include "*.bam.bai"

rm testGenome.hgr1.bam
rm testGenome.hgr1.bam.bai

# BAM files
#BAM=$(ls *.bam)

ls *.bam > bams.list

# Re-make g.vcf files for each bam library

for BAMFILE in $(ls *.bam)
do

   # Sample ID
   sampleID=$(echo $BAMFILE | cut -f1 -d'.' -)
   
   java -Xmx12G -jar /home/ubuntu/software/GenomeAnalysisTK.jar \
  -R hgr1.gatk.fa -T HaplotypeCaller \
  -ERC BP_RESOLUTION \
  -ploidy 2 --max_alternate_alleles 6 \
  -I $BAMFILE \
  -o $sampleID.g.vcf
  
  gzip $sampleID.g.vcf
  aws s3 cp $sampleID.g.vcf.gz s3://crownproject/1kg_hgr1/reVCF/
  aws s3 cp $sampleID.g.vcf.idx s3://crownproject/1kg_hgr1/reVCF/

done

# QED

# %%
aws s3 ls s3://crownproject/1kg_hgr1/reVCF/
# Out:
# 2017-03-10 21:09:42          0
# 2017-03-11 12:18:11   10380413 100g.hgr1_all.ploidy10.vcf
# 2017-03-11 16:26:40    3483506 100g.hgr1_all.ploidy10.vcf.gz
# 2017-03-11 12:18:10    2778272 100g.hgr1_all.vcf
# 2017-03-11 16:26:54     902300 100g.hgr1_all.vcf.gz
# 2017-03-11 12:18:11       4326 100g.hgr1_all.vcf.idx
# 2017-03-11 12:18:48   67604874 HG00128.g.vcf
# 2017-03-10 22:00:12    2725466 HG00128.g.vcf.gz
# 2017-03-11 12:18:50        190 HG00128.g.vcf.idx
# 2017-03-11 12:19:56   67641800 HG00139.g.vcf
# 2017-03-10 22:01:31    2746535 HG00139.g.vcf.gz
# 2017-03-11 12:19:58        190 HG00139.g.vcf.idx
# 2017-03-11 12:21:26   67618954 HG00234.g.vcf
# 2017-03-10 22:03:17    2730628 HG00234.g.vcf.gz
# 2017-03-11 12:21:28        190 HG00234.g.vcf.idx
# 2017-03-11 12:22:14   67631559 HG00253.g.vcf
# 2017-03-10 22:04:14    2741457 HG00253.g.vcf.gz
# 2017-03-11 12:22:15        190 HG00253.g.vcf.idx
# 2017-03-11 12:23:11   67623799 HG00337.g.vcf
# 2017-03-10 22:05:21    2737871 HG00337.g.vcf.gz
# 2017-03-11 12:23:11        190 HG00337.g.vcf.idx
# 2017-03-11 12:23:52   67633452 HG00353.g.vcf
# 2017-03-10 22:06:14    2736129 HG00353.g.vcf.gz
# 2017-03-11 12:23:53        190 HG00353.g.vcf.idx
# 2017-03-11 12:25:14   67611199 HG00358.g.vcf
# 2017-03-10 22:07:57    2729682 HG00358.g.vcf.gz
# 2017-03-11 12:25:15        190 HG00358.g.vcf.idx
# 2017-03-11 12:26:13   67647624 HG00362.g.vcf
# 2017-03-10 22:09:09    2752051 HG00362.g.vcf.gz
# 2017-03-11 12:26:15        190 HG00362.g.vcf.idx
# 2017-03-11 12:26:55   67639347 HG00478.g.vcf
# 2017-03-10 22:09:57    2737805 HG00478.g.vcf.gz
# 2017-03-11 12:26:56        190 HG00478.g.vcf.idx
# 2017-03-11 12:27:40   67622011 HG00536.g.vcf
# 2017-03-10 22:10:52    2731738 HG00536.g.vcf.gz
# 2017-03-11 12:27:41        190 HG00536.g.vcf.idx
# 2017-03-11 12:28:18   67615449 HG00557.g.vcf
# 2017-03-10 22:11:37    2731670 HG00557.g.vcf.gz
# 2017-03-11 12:28:19        190 HG00557.g.vcf.idx
# 2017-03-11 12:29:07   67620059 HG00717.g.vcf
# 2017-03-10 22:12:39    2736610 HG00717.g.vcf.gz
# 2017-03-11 12:29:08        190 HG00717.g.vcf.idx
# 2017-03-11 12:29:46   67637303 HG00734.g.vcf
# 2017-03-10 22:13:26    2736723 HG00734.g.vcf.gz
# 2017-03-11 12:29:47        190 HG00734.g.vcf.idx
# 2017-03-11 12:30:48   67643356 HG00740.g.vcf
# 2017-03-10 22:14:42    2739989 HG00740.g.vcf.gz
# 2017-03-11 12:30:49        190 HG00740.g.vcf.idx
# 2017-03-11 12:31:21   67645059 HG00851.g.vcf
# 2017-03-10 22:15:24    2740665 HG00851.g.vcf.gz
# 2017-03-11 12:31:22        190 HG00851.g.vcf.idx
# 2017-03-11 12:31:49   67627993 HG00978.g.vcf
# 2017-03-10 22:16:00    2736204 HG00978.g.vcf.gz
# 2017-03-11 12:31:51        190 HG00978.g.vcf.idx
# 2017-03-11 12:32:18   67620490 HG00982.g.vcf
# 2017-03-11 13:23:07        190 HG03268.g.vcf.idx
# 2017-03-11 13:24:59   67669170 HG03295.g.vcf
# 2017-03-10 23:19:41    2759399 HG03295.g.vcf.gz
# 2017-03-11 13:25:01        190 HG03295.g.vcf.idx
# 2017-03-11 13:25:58   67629537 HG03432.g.vcf
# 2017-03-10 23:20:52    2739580 HG03432.g.vcf.gz
# 2017-03-11 13:25:59        190 HG03432.g.vcf.idx
# 2017-03-11 13:27:29   67671063 HG03470.g.vcf
# 2017-03-10 23:22:40    2757334 HG03470.g.vcf.gz
# 2017-03-11 13:27:30        190 HG03470.g.vcf.idx
# 2017-03-11 13:28:22   67659117 HG03548.g.vcf
# 2017-03-10 23:23:45    2745093 HG03548.g.vcf.gz
# 2017-03-11 13:28:24        190 HG03548.g.vcf.idx
# 2017-03-11 13:28:57   67622296 HG03558.g.vcf
# 2017-03-10 23:24:30    2732978 HG03558.g.vcf.gz
# 2017-03-11 13:29:00        190 HG03558.g.vcf.idx
# 2017-03-11 13:29:32   67631489 HG03604.g.vcf
# 2017-03-10 23:25:11    2738020 HG03604.g.vcf.gz
# 2017-03-11 13:29:35        190 HG03604.g.vcf.idx
# 2017-03-11 13:31:05   67670260 HG03607.g.vcf
# 2017-03-10 23:27:00    2762422 HG03607.g.vcf.gz
# 2017-03-11 13:31:06        190 HG03607.g.vcf.idx
# 2017-03-11 13:35:42   67679090 HG03616.g.vcf
# 2017-03-10 23:32:25    2766496 HG03616.g.vcf.gz
# 2017-03-11 13:35:43        190 HG03616.g.vcf.idx
# 2017-03-11 13:36:32   67628997 HG03624.g.vcf
# 2017-03-10 23:33:25    2738634 HG03624.g.vcf.gz
# 2017-03-11 13:36:33        190 HG03624.g.vcf.idx
# 2017-03-11 13:37:19   67650745 HG03720.g.vcf
# 2017-03-10 23:34:23    2736196 HG03720.g.vcf.gz
# 2017-03-11 13:37:21        190 HG03720.g.vcf.idx
# 2017-03-11 13:38:54   67660027 HG03753.g.vcf
# 2017-03-10 23:36:16    2748788 HG03753.g.vcf.gz
# 2017-03-11 13:38:55        190 HG03753.g.vcf.idx
# 2017-03-11 13:40:28   67671229 HG03790.g.vcf
# 2017-03-10 23:38:09    2763925 HG03790.g.vcf.gz
# 2017-03-11 13:40:29        190 HG03790.g.vcf.idx
# 2017-03-11 13:41:53   67672507 HG03836.g.vcf
# 2017-03-10 23:39:51    2761457 HG03836.g.vcf.gz
# 2017-03-11 13:41:54        190 HG03836.g.vcf.idx
# 2017-03-11 13:43:01   67656085 HG03856.g.vcf
# 2017-03-10 23:41:12    2743209 HG03856.g.vcf.gz
# 2017-03-11 13:43:02        190 HG03856.g.vcf.idx
# 2017-03-11 13:44:12   67658285 HG03861.g.vcf
# 2017-03-10 23:42:42    2744365 HG03861.g.vcf.gz
# 2017-03-11 13:44:13        190 HG03861.g.vcf.idx
# 2017-03-11 13:45:02   67663801 HG03867.g.vcf
# 2017-03-10 23:43:44    2762770 HG03867.g.vcf.gz
# 2017-03-11 13:45:03        190 HG03867.g.vcf.idx
# 2017-03-11 13:46:33   67659955 HG03890.g.vcf
# 2017-03-10 23:45:35    2749869 HG03890.g.vcf.gz
# 2017-03-11 14:56:57        190 NA20503.g.vcf.idx
# 2017-03-11 14:58:05   67646826 NA20514.g.vcf
# 2017-03-11 01:10:27    2750560 NA20514.g.vcf.gz
# 2017-03-11 14:58:08        190 NA20514.g.vcf.idx
# 2017-03-11 14:59:03   67636538 NA20827.g.vcf
# 2017-03-11 01:11:37    2742679 NA20827.g.vcf.gz
# 2017-03-11 14:59:05        190 NA20827.g.vcf.idx
# 2017-03-11 14:59:49   67625446 NA20832.g.vcf
# 2017-03-11 01:12:34    2738311 NA20832.g.vcf.gz
# 2017-03-11 14:59:50        190 NA20832.g.vcf.idx
# 2017-03-11 15:00:46   67591871 NA21109.g.vcf
# 2017-03-11 01:13:43    2724413 NA21109.g.vcf.gz
# 2017-03-11 15:00:47        190 NA21109.g.vcf.idx
# 2017-03-11 15:02:23   67607858 NA21112.g.vcf
# 2017-03-11 01:15:39    2732232 NA21112.g.vcf.gz
# 2017-03-11 15:02:28        190 NA21112.g.vcf.idx
# 2017-03-11 15:03:16   67584301 NA21113.g.vcf
# 2017-03-11 01:16:36    2713034 NA21113.g.vcf.gz
# 2017-03-11 15:03:17        190 NA21113.g.vcf.idx
# 2017-03-11 15:08:20   67674376 NA21125.g.vcf
# 2017-03-11 01:22:31    2763559 NA21125.g.vcf.gz
# 2017-03-11 15:08:22        190 NA21125.g.vcf.idx

# %% [markdown]
# ### Runs Finished
#
# Lots of analysis files; for now stick to the total g.vcf file for variant analysis.

# %%
cd ~/Crown/data/hgr1_vcf/

mkdir -p 100g_gvcf; cd 100g_gvcf

aws s3 cp s3://crownproject/1kg_hgr1/reVCF/100g.hgr1_all.vcf.gz ./
aws s3 cp s3://crownproject/1kg_hgr1/reVCF/100g.hgr1_all.ploidy10.vcf.gz ./

gzip -d 100g.hgr1_all.vcf.gz
# Out:
# download: s3://crownproject/1kg_hgr1/reVCF/100g.hgr1_all.vcf.gz to ./100g.hgr1_all.vcf.gz

# %%
## Plot vcfStats

bcftools stats 100g.hgr1_all.vcf > 100gvcf.vcfplot
plot-vcfstats -p plot/100gvcf 100gvcf.vcfplot
# Out:
# Parsing bcftools stats output: 100gvcf.vcfplot
# Plotting graphs: python plot/100gvcf-plot.py
# Creating PDF: pdflatex 100gvcf-summary.tex >100gvcf-plot-vcfstats.log 2>&1
# Finished: plot/100gvcf-summary.pdf

# %% [markdown]
# #### Quality Metrics of g.vcf Genotype Qualities
#
# Standard vcfR Quality Control for the `100g.hgr1_all.vcf` joint genotyping. Script: `~/Crown/data/vcfR_analysis/gvcf_100g.r`
#
# ![100g hgr1 QC](../figure/20170313_QC_hgr1_100gvcf.png)
#
# Note: The 'Quality' metric is the PHRED score (-log( p_alt_genotype_DNE ) ) and has a huge range in this file: 30.44 555697.96 so it was re-plotted on a log scale.
#
# ![100g hgr1 Quality Log Replot](../figure/20170313_QC_AltGeno_Quality.png)

# %% [markdown]
# ### Individual VCF File per library
#
# For detailed analysis, each individual VCF file was also generated. (above)

# %%
# Download individual VCF files from each library
cd ~/Crown/data/hgr1_vcf/
mkdir -p 100g_gvcf/gvcf_individual
cd 100g_gvcf/gvcf_individual

aws s3 cp s3://crownproject/1kg_hgr1/reVCF ./ --recursive --exclude "*" --include "*.vcf.gz"
# Out:
# download: s3://crownproject/1kg_hgr1/reVCF/100g.hgr1_all.vcf.gz to ./100g.hgr1_all.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00234.g.vcf.gz to ./HG00234.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00128.g.vcf.gz to ./HG00128.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00478.g.vcf.gz to ./HG00478.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00253.g.vcf.gz to ./HG00253.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00353.g.vcf.gz to ./HG00353.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00362.g.vcf.gz to ./HG00362.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00337.g.vcf.gz to ./HG00337.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00139.g.vcf.gz to ./HG00139.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/100g.hgr1_all.ploidy10.vcf.gz to ./100g.hgr1_all.ploidy10.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00717.g.vcf.gz to ./HG00717.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00557.g.vcf.gz to ./HG00557.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00358.g.vcf.gz to ./HG00358.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00536.g.vcf.gz to ./HG00536.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00740.g.vcf.gz to ./HG00740.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00978.g.vcf.gz to ./HG00978.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG01066.g.vcf.gz to ./HG01066.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00734.g.vcf.gz to ./HG00734.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00851.g.vcf.gz to ./HG00851.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG01277.g.vcf.gz to ./HG01277.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG00982.g.vcf.gz to ./HG00982.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG01125.g.vcf.gz to ./HG01125.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG01348.g.vcf.gz to ./HG01348.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG01620.g.vcf.gz to ./HG01620.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG01589.g.vcf.gz to ./HG01589.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG01464.g.vcf.gz to ./HG01464.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG01630.g.vcf.gz to ./HG01630.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG01626.g.vcf.gz to ./HG01626.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02035.g.vcf.gz to ./HG02035.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02090.g.vcf.gz to ./HG02090.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02040.g.vcf.gz to ./HG02040.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG01176.g.vcf.gz to ./HG01176.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02046.g.vcf.gz to ./HG02046.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02272.g.vcf.gz to ./HG02272.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02078.g.vcf.gz to ./HG02078.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02190.g.vcf.gz to ./HG02190.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02219.g.vcf.gz to ./HG02219.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02286.g.vcf.gz to ./HG02286.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02283.g.vcf.gz to ./HG02283.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02277.g.vcf.gz to ./HG02277.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02343.g.vcf.gz to ./HG02343.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02508.g.vcf.gz to ./HG02508.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02780.g.vcf.gz to ./HG02780.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02839.g.vcf.gz to ./HG02839.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02891.g.vcf.gz to ./HG02891.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03240.g.vcf.gz to ./HG03240.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02946.g.vcf.gz to ./HG02946.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03019.g.vcf.gz to ./HG03019.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02888.g.vcf.gz to ./HG02888.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03432.g.vcf.gz to ./HG03432.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03195.g.vcf.gz to ./HG03195.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03268.g.vcf.gz to ./HG03268.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG02479.g.vcf.gz to ./HG02479.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03295.g.vcf.gz to ./HG03295.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03470.g.vcf.gz to ./HG03470.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03558.g.vcf.gz to ./HG03558.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03616.g.vcf.gz to ./HG03616.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03548.g.vcf.gz to ./HG03548.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03607.g.vcf.gz to ./HG03607.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03604.g.vcf.gz to ./HG03604.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03890.g.vcf.gz to ./HG03890.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03753.g.vcf.gz to ./HG03753.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03624.g.vcf.gz to ./HG03624.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03790.g.vcf.gz to ./HG03790.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG04162.g.vcf.gz to ./HG04162.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03867.g.vcf.gz to ./HG03867.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03836.g.vcf.gz to ./HG03836.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03856.g.vcf.gz to ./HG03856.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03861.g.vcf.gz to ./HG03861.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA06985.g.vcf.gz to ./NA06985.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA11881.g.vcf.gz to ./NA11881.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA12283.g.vcf.gz to ./NA12283.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/HG03720.g.vcf.gz to ./HG03720.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA18622.g.vcf.gz to ./NA18622.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA12878_pp.g.vcf.gz to ./NA12878_pp.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA12234.g.vcf.gz to ./NA12234.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA18533.g.vcf.gz to ./NA18533.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA12891_pp.g.vcf.gz to ./NA12891_pp.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA12892_pp.g.vcf.gz to ./NA12892_pp.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA18632.g.vcf.gz to ./NA18632.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA18647.g.vcf.gz to ./NA18647.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA18981.g.vcf.gz to ./NA18981.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19042.g.vcf.gz to ./NA19042.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19098.g.vcf.gz to ./NA19098.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19144.g.vcf.gz to ./NA19144.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19091.g.vcf.gz to ./NA19091.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19153.g.vcf.gz to ./NA19153.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19006.g.vcf.gz to ./NA19006.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19159.g.vcf.gz to ./NA19159.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19240.g.vcf.gz to ./NA19240.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19984.g.vcf.gz to ./NA19984.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19351.g.vcf.gz to ./NA19351.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19001.g.vcf.gz to ./NA19001.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19734.g.vcf.gz to ./NA19734.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19658.g.vcf.gz to ./NA19658.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19320.g.vcf.gz to ./NA19320.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19475.g.vcf.gz to ./NA19475.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19670.g.vcf.gz to ./NA19670.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA20359.g.vcf.gz to ./NA20359.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA19795.g.vcf.gz to ./NA19795.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA20514.g.vcf.gz to ./NA20514.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA20357.g.vcf.gz to ./NA20357.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA21112.g.vcf.gz to ./NA21112.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA20827.g.vcf.gz to ./NA20827.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA21109.g.vcf.gz to ./NA21109.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA20832.g.vcf.gz to ./NA20832.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA20503.g.vcf.gz to ./NA20503.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA21125.g.vcf.gz to ./NA21125.g.vcf.gz
# download: s3://crownproject/1kg_hgr1/reVCF/NA21113.g.vcf.gz to ./NA21113.g.vcf.gz

# %% [markdown]
# ### Renaming libraries for figure
#
# For the `~/Crown/data/hgr1_vcf/100g.hgr1.g.vcf` file (quality metrics above), make a renamed version with sample names converted to include population identifiers.

# %%
# Sample Order
cd ~/Crown/data/hgr1_vcf/

cut -f 5 nameConversion_figure.txt > alpha.order.tmp

# search and replaced \n with , in gedit

# %%
## Renaming Sample IDs to include population information
cd ~/Crown/data/hgr1_vcf/

FILE='100g.hgr1.g.vcf'
OUTPUT_VCF='POPID_100g.hgr1.g.vcf'
CONVERSION='nameConversion_figure.txt'

cp $FILE $OUTPUT_VCF

N_LINES=$(wc -l $CONVERSION | cut -f1 -d' ' -)

for N in $(seq 1 $N_LINES)
do

    originalID=$(sed -n "$N"p $CONVERSION | cut -f 1 -)
    convertID=$(sed -n "$N"p $CONVERSION | cut -f 5 - )
        
    #echo "Converting $originalID to $convertID"
    
    # Within VCF file, convert ID
    sed -i "s/\t$originalID/\t$convertID/g" $OUTPUT_VCF
    
done

cp $OUTPUT_VCF holder.tmp.vcf

bcftools view -s $(cat alpha.order.tmp) holder.tmp.vcf > $OUTPUT_VCF

#gzip $OUTPUT_VCF

# %%
## Note: Sample AFR ASW NA20362 is not included in gvcf file.
## it was dropped out somewhere. Since I included 5 yoruba samples
## to have NA19240 in the analysis I was miscounting the sum
## for now continue analysis with the 107 genomes available. In next major
## analysis pipeline I'll include more genomes anyways.
## requires manually removing NA20362 from conversion table.

# %% [markdown]
# ## Discussion
