# %% [markdown]
# # AWS Cleanup
# ```
# pi:ababaian
# files: ~/Crown/data/..
# start: 2017 10 02
# complete : 2017 10 02
# ```
# ## Introduction
#
# Cleaning up some AWS S3 / Glacier resources to minimize the amount of $$$ I have to pay monthly as I'm running out of credits.

# %% [markdown]
# ## Results
#
# ### Initial Settings

# %%
aws s3 ls s3://crownproject --recursive --human-readable --summarize
# Out:
# 2017-02-20 21:44:09    0 Bytes 1kg_hgr0/
# 2017-03-03 23:55:04  392 Bytes 1kg_hgr0/HG00096.flagstat
# 2017-03-03 23:55:05   59.8 MiB 1kg_hgr0/HG00096.hgr0.bam
# 2017-03-03 23:55:07    1.4 KiB 1kg_hgr0/HG00096.hgr0.bam.bai
# 2017-03-03 23:55:07  382 Bytes 1kg_hgr0/HG00096.hgr0.flagstat
# 2017-03-03 23:55:08   34.3 KiB 1kg_hgr0/HG00096.hgr0.vcf
# 2017-03-03 23:55:08  284 Bytes 1kg_hgr0/HG00096.hgr0.vcf.idx
# 2017-03-03 15:31:53  386 Bytes 1kg_hgr0/HG00268.flagstat
# 2017-03-03 15:31:53    1.3 MiB 1kg_hgr0/HG00268.hgr0.bam
# 2017-03-03 15:31:54  608 Bytes 1kg_hgr0/HG00268.hgr0.bam.bai
# 2017-03-03 15:31:54  375 Bytes 1kg_hgr0/HG00268.hgr0.flagstat
# 2017-03-03 15:31:54   10.1 KiB 1kg_hgr0/HG00268.hgr0.vcf
# 2017-03-03 15:31:55  286 Bytes 1kg_hgr0/HG00268.hgr0.vcf.idx
# 2017-03-03 22:34:12  391 Bytes 1kg_hgr0/HG00731_pcr.flagstat
# 2017-03-03 22:34:13   34.1 MiB 1kg_hgr0/HG00731_pcr.hgr0.bam
# 2017-03-03 22:34:14  848 Bytes 1kg_hgr0/HG00731_pcr.hgr0.bam.bai
# ...

# %% [markdown]
# ### Deleting

# %%
aws s3 rm "s3://crownproject/1kg_hgr0/fullbam/*.bam" --recursive
aws s3 rm "s3://crownproject/1kg_hgr0/na19240_trio/*.bam"
aws s3 rm "s3://crownproject/1kg_pilot/na12878/*"

# %% [markdown]
# ## Discussion
