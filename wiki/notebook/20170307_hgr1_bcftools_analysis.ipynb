# %% [markdown]
# # hgr1 bcftools analysis / variant analysis
# ```
# pi:ababaian
# files: ~/Crown/data/hgr1_vcf/
# start: 2017 03 07
# complete : 2017 03 13
# ```
# ## Introduction
#
# I have the hgr1_v1 pipeline up and running; part of the output includes variant calling from GATK.
#
# ```
#   java -Xmx12G -jar /home/ubuntu/software/GenomeAnalysisTK.jar \
#   -R hgr1.gatk.fa -T HaplotypeCaller \
#   -ploidy 2 --max_alternate_alleles 6 \
#   -I $LIBRARY.hgr1.bam -o $LIBRARY.hgr1.vcf
# ```
#
# This is the downstream analysis of those files to broadly describe variation in rDNA across many individuals.

# %% [markdown]
# ## Objective
#
# - Automate VCF analysis
# - Calculate which intra-individual variants are found in the population and which are maintained in humans
# - Calculate the frequency of variation in different regions of the rDNA loci

# %% [markdown]
# ## Materials and Methods
#
# ### Key Files
#
# - `100g_hgr1_individual.tar.gz` : Each individual hgr1_v1 output vcf file from 107 genomes (3 platinum + 104 population)
# -
#
# ### Current VCF files - 30 genomes
#
# #### Manipulation of VCF files

# %%
cd ~/Crown/data/
mkdir -p hgr1_vcf/; cd hgr1_vcf

# %%
date # this is in flux, will be updated
aws s3 ls s3://crownproject/1kg_hgr1/ | grep ".vcf" -
# Out:
# Tue Mar  7 16:55:32 PST 2017
# 2017-03-07 14:24:07      61563 HG00478.hgr1.vcf
# 2017-03-07 14:24:07       4324 HG00478.hgr1.vcf.idx
# 2017-03-07 16:08:21      58909 HG00536.hgr1.vcf
# 2017-03-07 16:08:22       2298 HG00536.hgr1.vcf.idx
# 2017-03-07 16:09:22      37016 HG00557.hgr1.vcf
# 2017-03-07 16:09:22        782 HG00557.hgr1.vcf.idx
# 2017-03-07 16:11:04      17098 HG00717.hgr1.vcf
# 2017-03-07 16:11:05        284 HG00717.hgr1.vcf.idx
# 2017-03-06 23:18:53      63888 HG00851.hgr1.vcf
# 2017-03-06 23:18:53       4325 HG00851.hgr1.vcf.idx
# 2017-03-06 22:54:06      43098 HG00978.hgr1.vcf
# 2017-03-06 22:54:07        781 HG00978.hgr1.vcf.idx
# 2017-03-07 11:28:46      53048 HG00982.hgr1.vcf
# 2017-03-07 11:28:46       2301 HG00982.hgr1.vcf.idx
# 2017-03-06 22:18:41      28059 HG02190.hgr1.vcf
# 2017-03-06 22:18:42        284 HG02190.hgr1.vcf.idx
# 2017-03-06 16:16:48      26310 HG02283.hgr1.vcf
# 2017-03-06 16:16:49        283 HG02283.hgr1.vcf.idx
# 2017-03-06 16:03:32      23316 HG02343.hgr1.vcf
# 2017-03-06 16:03:33        284 HG02343.hgr1.vcf.idx
# 2017-03-06 17:22:04      42688 HG02479.hgr1.vcf
# 2017-03-06 17:22:04       1284 HG02479.hgr1.vcf.idx
# 2017-03-06 17:18:00      44321 HG02508.hgr1.vcf
# 2017-03-06 17:18:00        782 HG02508.hgr1.vcf.idx
# 2017-03-06 20:39:59      27550 HG03604.hgr1.vcf
# 2017-03-06 20:40:00        283 HG03604.hgr1.vcf.idx
# 2017-03-06 18:45:52      29420 HG03607.hgr1.vcf
# 2017-03-06 18:45:53        284 HG03607.hgr1.vcf.idx
# 2017-03-06 23:35:54      28702 HG03616.hgr1.vcf
# 2017-03-06 23:35:54        283 HG03616.hgr1.vcf.idx
# 2017-03-06 20:56:57      26647 HG04162.hgr1.vcf
# 2017-03-06 20:56:57        284 HG04162.hgr1.vcf.idx
# 2017-03-07 11:09:14      27959 NA06985.hgr1.vcf
# 2017-03-07 11:09:14        282 NA06985.hgr1.vcf.idx
# 2017-03-07 11:40:47      31776 NA11881.hgr1.vcf
# 2017-03-07 11:40:47        284 NA11881.hgr1.vcf.idx
# 2017-03-07 12:47:51      36404 NA12234.hgr1.vcf
# 2017-03-07 12:47:52        780 NA12234.hgr1.vcf.idx
# 2017-03-07 12:41:01      23532 NA12283.hgr1.vcf
# 2017-03-07 12:41:02        283 NA12283.hgr1.vcf.idx
# 2017-03-05 11:16:48      33001 NA12878_pp.hgr1.vcf
# 2017-03-05 11:31:26        288 NA12878_pp.hgr1.vcf.idx
# 2017-03-05 11:15:19      30814 NA12891_pp.hgr1.vcf
# 2017-03-05 11:15:19        287 NA12891_pp.hgr1.vcf.idx
# 2017-03-06 00:14:00      29637 NA12892_pp.hgr1.vcf
# 2017-03-06 00:14:00        286 NA12892_pp.hgr1.vcf.idx
# 2017-03-07 14:36:12      19482 NA18533.hgr1.vcf
# 2017-03-07 14:36:13        282 NA18533.hgr1.vcf.idx
# 2017-03-07 13:23:47      48767 NA18622.hgr1.vcf
# 2017-03-07 13:23:47       2301 NA18622.hgr1.vcf.idx
# 2017-03-07 13:24:24      32073 NA18632.hgr1.vcf
# 2017-03-07 13:24:24        272 NA18632.hgr1.vcf.idx
# 2017-03-07 14:36:35      54286 NA18647.hgr1.vcf
# 2017-03-07 14:36:36        782 NA18647.hgr1.vcf.idx
# 2017-03-06 19:27:14      37320 NA19984.hgr1.vcf
# 2017-03-06 19:27:14        780 NA19984.hgr1.vcf.idx
# 2017-03-06 18:11:22      24555 NA20357.hgr1.vcf
# 2017-03-06 18:11:23        285 NA20357.hgr1.vcf.idx
# 2017-03-06 19:29:44      29104 NA20359.hgr1.vcf
# 2017-03-06 19:29:45        281 NA20359.hgr1.vcf.idx
# 2017-03-05 23:18:07      28970 testGenome.hgr1.vcf
# 2017-03-05 23:18:07        288 testGenome.hgr1.vcf.idx

# %%
aws s3 cp s3://crownproject/1kg_hgr1/ ./ --recursive --exclude "*" --include "*.vcf"

rm testGenome.hgr1.vcf
# Out:
# download: s3://crownproject/1kg_hgr1/HG00717.hgr1.vcf to ./HG00717.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02283.hgr1.vcf to ./HG02283.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00557.hgr1.vcf to ./HG00557.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02190.hgr1.vcf to ./HG02190.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00851.hgr1.vcf to ./HG00851.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02479.hgr1.vcf to ./HG02479.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00536.hgr1.vcf to ./HG00536.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02343.hgr1.vcf to ./HG02343.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00978.hgr1.vcf to ./HG00978.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00478.hgr1.vcf to ./HG00478.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03616.hgr1.vcf to ./HG03616.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03604.hgr1.vcf to ./HG03604.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03607.hgr1.vcf to ./HG03607.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02508.hgr1.vcf to ./HG02508.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA12283.hgr1.vcf to ./NA12283.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA12891_pp.hgr1.vcf to ./NA12891_pp.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG04162.hgr1.vcf to ./HG04162.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA11881.hgr1.vcf to ./NA11881.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA06985.hgr1.vcf to ./NA06985.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA12234.hgr1.vcf to ./NA12234.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA18533.hgr1.vcf to ./NA18533.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA12878_pp.hgr1.vcf to ./NA12878_pp.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA12892_pp.hgr1.vcf to ./NA12892_pp.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA20359.hgr1.vcf to ./NA20359.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/testGenome.hgr1.vcf to ./testGenome.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA18622.hgr1.vcf to ./NA18622.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19984.hgr1.vcf to ./NA19984.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA18647.hgr1.vcf to ./NA18647.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00982.hgr1.vcf to ./HG00982.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA18632.hgr1.vcf to ./NA18632.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA20357.hgr1.vcf to ./NA20357.hgr1.vcf

# %%
# convert files to BCF
VCF=$(ls *.vcf)

for FILE in $(ls *.vcf)
do
    # Convert VCF to BCF File
    bcftools view -O b $FILE -o $FILE.bcf
    bcftools index $FILE.bcf
done

bcftools merge $(ls *.bcf) -o 100genomes_merged.vcf
bcftools view -O b 100genomes_merged.vcf -o 100genomes_merged.bcf
bcftools index 100genomes_merged.bcf

# %%
# Filter for variants with 30x coverage

bcftools view -i "DP>=30" 100genomes_merged.vcf -o 100genomes_DP30.vcf
bcftools index 100genomes_DP30.vcf
#bcftools filter -i "DP>=30" 100genomes_merged.bcf | bcftools view -O b 100genomes.DP30.bcf
# Out:
# [E::main_vcfindex] unknown filetype; expected bgzip compressed VCF or BCF
# [E::main_vcfindex] was the VCF/BCF compressed with bgzip?

# %% [markdown]
# #### Summary Plots for VCF

# %%
## vcfplot (summary stats)

# DP30 filtered
bcftools stats 100genomes_DP30.vcf > 100g.dp30.vcfplot
plot-vcfstats -p plot_dp30/100g 100g.dp30.vcfplot

# nonDP30 filtered
bcftools stats 100genomes_merged.vcf > 100g.vcfplot
plot-vcfstats -p plot/100g 100g.vcfplot
# Out:
# Parsing bcftools stats output: 100g.dp30.vcfplot
# Plotting graphs: python plot_dp30/100g-plot.py
# Creating PDF: pdflatex 100g-summary.tex >100g-plot-vcfstats.log 2>&1
# Finished: plot_dp30/100g-summary.pdf
# Parsing bcftools stats output: 100g.vcfplot
# Plotting graphs: python plot/100g-plot.py
# Creating PDF: pdflatex 100g-summary.tex >100g-plot-vcfstats.log 2>&1
# Finished: plot/100g-summary.pdf

# %%
## Measure the density of variants in each region

# %% [markdown]
# #### vcfR Analysis - statistical analysis in R
#
# To do the heavy lifting number-wise I went to an R based package called `vcfR` it's actually really good!
#
# Still I have to do some custom code stuff for rRNA variation analysis since it's outside the norm but I can extract information from the VCF file into a data.frame fairly quiickly with vcfR. Script copy below, subject to change on disk.
#
# ` cd ~/Crown/data/vcfR_analysis/`
#
# vcf_100g.r - script for analysis
#
# ```
# # vcfR analysis
# # 100 genomes hgr1
# # 170308
# #
# # hgr1_v1 vcf (variant input only) analysis
#
# # Install vcfR
# #install.packages("vcfR")
# library("vcfR")
# library("ggplot2")
# library("reshape2")
#
# # File pointers
#
#   vcf_file = '30genomes_merged.vcf.gz'
#   dna_file = 'rDNA.fa'
#   gff_file = 'rDNA.gff'
#
# # output Prefix (for plots)
#
#   outPrefix='30genomes'
#
# # SCRIPT ============================================================
# #====================================================================
# # Import VCF / DNA / GFF
#   VCF = read.vcfR(vcf_file)
#   DNA = ape::read.dna(dna_file, format = 'fasta')
#   GFF = read.table(gff_file, sep="\t", quote = "")
#
#
# # Create chromR Object
#   chrom = create.chromR(name="rDNA", vcf=VCF, seq=DNA, ann=GFF)
#
#   #plot(chrom)
#  #chromoqc(chrom, dp.alpha = 22)
#
#
# # Variant Statistics ================================================
#
# # Intra-individual variation (_i)
#
#   # Depth of coverage at each variant
#   DP = extract.gt(chrom, element="DP", as.numeric=TRUE)
#
#   # Reference allele-only depth
#   RAD = extract.gt(chrom, element="AD", as.numeric=TRUE)
#
#   # Variant allele frequency (intra-individual)
#   iVAF = (DP-RAD)/DP
#
#
# # Population variation (called variants)
#
#   # Number of individual genomes in total population
#   N_pop = length(DP[1,])
#
#   # Called Variant allele count (population)
#   pV = rowSums(!is.na(iVAF))
#   pVAF = pV / N_pop
#
#   # Average intra-genomic variant allele frequency
#   mean_iVAF = apply(iVAF,1,mean, na.rm = T)
#   sd_iVAF = apply(iVAF,1,sd, na.rm = T)
#
# # Population Variant Statistics
#
# POPVAR = data.frame(pVAF, mean_iVAF, sd_iVAF)
#
# # Plot--------------------------------------------------------------
# # Mean Intra-individual Variant Allele Frequency vs.
# # Population-level Variant Allele Frequency (called vs not called)
#
# # open PDF device
# pdf(file = paste0(outPrefix,".MeaniVAF_pVAF.pdf"), width = 5, height = 5)
#
# PLOT1 = ggplot(POPVAR, aes(mean_iVAF, pVAF))
# PLOT1 = PLOT1 + geom_point(alpha = 2/10, stroke = 0, aes(size = 0.5))
# PLOT1 = PLOT1 + theme_bw()
# PLOT1 = PLOT1 + theme(legend.position="none")
# PLOT1 = PLOT1 + xlab('Mean Intra-individual Variant Allele Frequency')
# PLOT1 = PLOT1 + ylab('Population Variant Allele Frequency')
# PLOT1
#
# dev.off()
# # ------------------------------------------------------------------
#
# # Stratify variants by their mean Intra-individual allele frequency
# # the hypothesis was that there are two classes of variants;
# # Directional Variants, which can range from 0 - 1
# # Stabilized Variants, which are maintained in a narrower range
#
# # strat0_2 =  which(mean_iVAF <= 0.2)
# # strat2_4 =  which(mean_iVAF > 0.2 & mean_iVAF <= 0.4)
# # strat4_6 =  which(mean_iVAF > 0.4 & mean_iVAF <= 0.6)
# # strat6_8 =  which(mean_iVAF > 0.6 & mean_iVAF <= 0.8)
# # strat8_1 =  which(mean_iVAF > 0.8)
#
#
# Stratify = function(iVAF, minVAF, maxVAF){
#
#   # calcualte the average intra-individual VAF for each variant
#   mean_iVAF = apply(iVAF,1, mean, na.rm = T)
#
#   # Subselect (index) mean iVAF between a range of values
#   strat_lim = which(mean_iVAF > minVAF & mean_iVAF <= maxVAF)
#
#   # Actually subselect by stratification
#   iVAF_str = apply(iVAF[strat_lim,], 1, sort, decreasing = TRUE)
#
#   N_strats = length(iVAF_str) # number of variants in this stratification
#   N_samples = length(iVAF[1,]) # number of samples in the analysis (people)
#
#   iVAF_str_matrix = matrix( rep(0, N_strats * N_samples), nrow = N_strats)
#
#   for (X in 1:N_strats){
#     LINE_VALUES = unlist(iVAF_str[X])
#     length(LINE_VALUES) = N_samples
#     LINE_VALUES[is.na(LINE_VALUES)] <- 0
#
#     iVAF_str_matrix[X,] = iVAF_str_matrix[X,] + LINE_VALUES
#   }
#
#   return(iVAF_str_matrix)
#
# }
#
# Stratify_rownames = function(iVAF, minVAF, maxVAF){
#   # calcualte the average intra-individual VAF for each variant
#   mean_iVAF = apply(iVAF,1, mean, na.rm = T)
#
#   # Subselect (index) mean iVAF between a range of values
#   strat_lim = which(mean_iVAF > minVAF & mean_iVAF <= maxVAF)
#
#   return(names(strat_lim))
# }
#
# StratifyPlot = function(iVAF, minVAF, maxVAF){
#
#   ## Stratify variants by intra-individual variant allele frequency
#   iVAF_SUB_matrix = data.frame(Stratify(iVAF, minVAF, maxVAF), row.names = Stratify_rownames(iVAF, minVAF, maxVAF))
#
#   # Shape data to be plotted
#   iVAF_SUB_matrix = melt(iVAF_SUB_matrix)
#   iVAF_SUB_matrix$rowid = Stratify_rownames(iVAF, minVAF, maxVAF)
#
#     # Plot--------------------------------------------------------------
#     # Mean Intra-individual Variant Allele Frequency vs.
#     # Population-level Variant Allele Frequency (called vs not called)
#     plotTitle = paste0("Mean VAF: ",minVAF," - ",maxVAF)
#
#     PLOT2 = ggplot(iVAF_SUB_matrix, aes(variable, value, group = factor(rowid)))
#     PLOT2 = PLOT2 + geom_line(aes(color = factor(rowid)))
#     PLOT2 = PLOT2 + theme_bw()
#     PLOT2 = PLOT2 + theme(legend.position="none")
#     PLOT2 = PLOT2 + ylim(0,1)
#     PLOT2 = PLOT2 + scale_x_discrete(breaks = c(1,N_pop))
#     PLOT2 = PLOT2 + ggtitle(plotTitle)
#     #PLOT2 = PLOT2 + ylab('Intra-individual Variant Allele Frequency')
#     #PLOT2 = PLOT2 + xlab('Genomes')
#     ## -----------------------------------------------------------------
#     #PLOT2
#
#     return(PLOT2)
# }
#
#
# # Plot Stratify for multiple ranges
# minVAF=0 # initialize with min VAF at 0
# nStratification=5 # How many equal parts to divide the VAF from 0-1
#
# # range width of each stratification
# widthStratification=1/nStratification
#
# for (nS in 1:nStratification){
#
#   maxVAF = minVAF + widthStratification
#
#   # Generate Plot
#   PLOT_VAF = StratifyPlot(iVAF, minVAF, maxVAF)
#
#   # Open PDF file to write to
#   pdf(file = paste0(outPrefix,".",nS,".strat.pdf"),
#      width = 5, height = 5)
#
#     print(PLOT_VAF)
#
#   dev.off()
#
#   minVAF = minVAF + widthStratification
# }
#
#
# # Heatmap ================================================
# # Log transform depth-data at each variant
# logDP = log(DP)
#
# # # chrom from tutotrial
#
# heatmap.bp(iVAF, cbarplot = F, rbarplot = F, rlabels = F)
#
# heatmap.bp(logDP, cbarplot = F, rbarplot = F, rlabels = F)
#
# ```

# %% [markdown]
# #### Output from vcfR analysis + plotVCF
#
# Summary Statistics (read-depth 30 filtered) for 30 genomes
# ![Summary Statistics (read-depth 30) for 30 genomes](../figure/20170308_summary_30g.png)
#
# Intra-genomic Variant Allele Frequency (VAF) vs. Population VAF
# ![iVAF vs. pVAF](../figure/20170308_30g_iVAF_v_pVAF.png)
#
# - Bottom right panel is iVAF vs. pVAF for every variant in the dataset.
# - Note the variants which are variable within a high fraction of genomes, namely at (0.48,1.0) which is the 28S.A49G variation. It's present in 100% of genomes. Evidence for stabalizing selection of this allele in all humans
# - The line graphs are little involved. Variants were stratified by their average intra-genomic VAF. In the 0.4 - 0.6 graph this is best exemplified. The vast majority of individual variants (lines) are present at a high intragenomic frequency (y-axis) in a few individuals (x-axis) and absent in others. The exception is again 28S.A49G which is intra-genomically variant in all genomes.
# - Keep in mind this doesn't account for 'allelic dropout' when sequencing depth is poor over high GC regions so other 'stabalized' intragenomic variants may have individual samples where that variant looks 'fixed' or 'absent'. This needs to be refined a little bit but it's incredibly strong evidence for paralogous rRNA in humans
#
# 30 Genomes - Intra-genomic variant allele frequency for each called variant
# ![30g iVAF heatmap](../figure/20170308_30g_iVAF_hm.png)
#
# 30 Genomes - Read depth of each called variant.
# ![30g DP heatmap](../figure/20170308_30g_log_DP_hm.png)
#
# - Column = individual genome
# - Row = individual variants
# - Scale = logDP 1 - 3200; iVAF 0.0 - 1.0

# %% [markdown]
# ### Full dataset - 107 genomes
#
# I moved the joined 30 genomes VCF file (and renamed it) to the 30g folder in ~/Crown/data/hgr1_vcf
#
# Download the complete set of .vcf files from 104 genomes and re-analyze as above.

# %%
# Move to hgr1_vcf folder
cd ~/Crown/data/hgr1_vcf/; ls
mkdir -p 100g; cd 100g
mkdir -p vcf; cd vcf

date

aws s3 ls s3://crownproject/1kg_hgr1/ | grep ".vcf" -

aws s3 cp s3://crownproject/1kg_hgr1/ ./ --recursive --exclude "*" --include "*.vcf"
aws s3 cp s3://crownproject/1kg_hgr1/ ./ --recursive --exclude "*" --include "*.vcf.idx"


rm testGenome.hgr1.vcf testGenome.hgr1.vcf.idx
# Out:
# 30g.dp30.vcfplot    30genomes_DP30.bcf.csi  30genomes_merged.vcf  plot
# 30genomes_DP30.bcf  30genomes_DP30.vcf	    30g.vcfplot		  plot_dp30
# Fri Mar 10 10:19:47 PST 2017
# 2017-03-08 12:31:14      39989 HG00128.hgr1.vcf
# 2017-03-08 12:31:15        781 HG00128.hgr1.vcf.idx
# 2017-03-08 12:41:08      26601 HG00139.hgr1.vcf
# 2017-03-08 12:41:09        282 HG00139.hgr1.vcf.idx
# 2017-03-08 13:53:28      60138 HG00234.hgr1.vcf
# 2017-03-08 13:53:29       2300 HG00234.hgr1.vcf.idx
# 2017-03-08 12:17:24      22863 HG00253.hgr1.vcf
# 2017-03-08 12:17:24        282 HG00253.hgr1.vcf.idx
# 2017-03-08 00:48:57      41492 HG00337.hgr1.vcf
# 2017-03-08 00:48:57        782 HG00337.hgr1.vcf.idx
# 2017-03-08 00:15:02      67236 HG00353.hgr1.vcf
# 2017-03-08 00:15:02       4325 HG00353.hgr1.vcf.idx
# 2017-03-08 00:13:24      49655 HG00358.hgr1.vcf
# 2017-03-08 00:13:24        780 HG00358.hgr1.vcf.idx
# 2017-03-08 01:07:43      27207 HG00362.hgr1.vcf
# 2017-03-08 01:07:43        281 HG00362.hgr1.vcf.idx
# 2017-03-07 14:24:07      61563 HG00478.hgr1.vcf
# 2017-03-07 14:24:07       4324 HG00478.hgr1.vcf.idx
# 2017-03-07 16:08:21      58909 HG00536.hgr1.vcf
# 2017-03-07 16:08:22       2298 HG00536.hgr1.vcf.idx
# 2017-03-07 16:09:22      37016 HG00557.hgr1.vcf
# 2017-03-07 16:09:22        782 HG00557.hgr1.vcf.idx
# 2017-03-07 16:11:04      17098 HG00717.hgr1.vcf
# 2017-03-07 16:11:05        284 HG00717.hgr1.vcf.idx
# 2017-03-09 19:43:26      23630 HG00734.hgr1.vcf
# 2017-03-09 19:43:26        281 HG00734.hgr1.vcf.idx
# 2017-03-09 19:11:00      22875 HG00740.hgr1.vcf
# 2017-03-09 19:11:00        283 HG00740.hgr1.vcf.idx
# 2017-03-06 23:18:53      63888 HG00851.hgr1.vcf
# 2017-03-06 23:18:53       4325 HG00851.hgr1.vcf.idx
# 2017-03-06 22:54:06      43098 HG00978.hgr1.vcf
# 2017-03-06 22:54:07        781 HG00978.hgr1.vcf.idx
# 2017-03-07 11:28:46      53048 HG00982.hgr1.vcf
# 2017-03-07 11:28:46       2301 HG00982.hgr1.vcf.idx
# 2017-03-09 19:48:39      24915 HG01066.hgr1.vcf
# 2017-03-09 19:48:40        284 HG01066.hgr1.vcf.idx
# 2017-03-07 18:17:56      24663 HG01125.hgr1.vcf
# 2017-03-07 18:17:56        283 HG01125.hgr1.vcf.idx
# 2017-03-09 21:26:17      28607 HG01176.hgr1.vcf
# 2017-03-09 21:26:17        285 HG01176.hgr1.vcf.idx
# 2017-03-07 21:55:31      63904 HG01277.hgr1.vcf
# 2017-03-07 21:55:32       1285 HG01277.hgr1.vcf.idx
# 2017-03-07 21:52:28      22165 HG01348.hgr1.vcf
# 2017-03-07 21:52:28        270 HG01348.hgr1.vcf.idx
# 2017-03-07 20:20:28      27827 HG01464.hgr1.vcf
# 2017-03-07 20:20:28        283 HG01464.hgr1.vcf.idx
# 2017-03-09 15:22:45      18594 HG01589.hgr1.vcf
# 2017-03-09 15:22:45        285 HG01589.hgr1.vcf.idx
# 2017-03-08 21:05:54      39140 HG01620.hgr1.vcf
# 2017-03-08 21:05:54        780 HG01620.hgr1.vcf.idx
# 2017-03-08 18:02:22      18830 HG01626.hgr1.vcf
# 2017-03-08 18:02:22        283 HG01626.hgr1.vcf.idx
# 2017-03-08 20:50:21      49106 HG01630.hgr1.vcf
# 2017-03-08 20:50:21        779 HG01630.hgr1.vcf.idx
# 2017-03-08 23:48:17      28264 HG02035.hgr1.vcf
# 2017-03-08 23:48:17        284 HG02035.hgr1.vcf.idx
# 2017-03-08 23:43:32      27762 HG02040.hgr1.vcf
# 2017-03-08 23:43:33        283 HG02040.hgr1.vcf.idx
# 2017-03-08 23:49:06      30633 HG02046.hgr1.vcf
# 2017-03-08 23:49:06        283 HG02046.hgr1.vcf.idx
# 2017-03-09 04:20:28      24893 HG02078.hgr1.vcf
# 2017-03-09 04:20:29        284 HG02078.hgr1.vcf.idx
# 2017-03-09 15:33:28      56000 HG02090.hgr1.vcf
# 2017-03-09 15:33:28       4326 HG02090.hgr1.vcf.idx
# 2017-03-06 22:18:41      28059 HG02190.hgr1.vcf
# 2017-03-06 22:18:42        284 HG02190.hgr1.vcf.idx
# 2017-03-08 18:01:42      18158 HG02219.hgr1.vcf
# 2017-03-08 18:01:42        283 HG02219.hgr1.vcf.idx
# 2017-03-09 13:45:14      45077 HG02272.hgr1.vcf
# 2017-03-09 13:45:15        779 HG02272.hgr1.vcf.idx
# 2017-03-09 15:56:54      45271 HG02277.hgr1.vcf
# 2017-03-09 15:56:55       1285 HG02277.hgr1.vcf.idx
# 2017-03-06 16:16:48      26310 HG02283.hgr1.vcf
# 2017-03-06 16:16:49        283 HG02283.hgr1.vcf.idx
# 2017-03-09 15:56:34      60943 HG02286.hgr1.vcf
# 2017-03-09 15:56:34       1285 HG02286.hgr1.vcf.idx
# 2017-03-06 16:03:32      23316 HG02343.hgr1.vcf
# 2017-03-06 16:03:33        284 HG02343.hgr1.vcf.idx
# 2017-03-06 17:22:04      42688 HG02479.hgr1.vcf
# 2017-03-06 17:22:04       1284 HG02479.hgr1.vcf.idx
# 2017-03-06 17:18:00      44321 HG02508.hgr1.vcf
# 2017-03-06 17:18:00        782 HG02508.hgr1.vcf.idx
# 2017-03-09 17:33:48      17293 HG02780.hgr1.vcf
# 2017-03-09 17:33:48        283 HG02780.hgr1.vcf.idx
# 2017-03-08 17:24:07      28047 HG02839.hgr1.vcf
# 2017-03-08 17:24:08        283 HG02839.hgr1.vcf.idx
# 2017-03-08 17:16:29      29529 HG02888.hgr1.vcf
# 2017-03-08 17:16:29        283 HG02888.hgr1.vcf.idx
# 2017-03-08 15:11:59      26174 HG02891.hgr1.vcf
# 2017-03-08 15:11:59        284 HG02891.hgr1.vcf.idx
# 2017-03-07 21:26:50      26285 HG02946.hgr1.vcf
# 2017-03-07 21:26:50        283 HG02946.hgr1.vcf.idx
# 2017-03-09 17:37:23      23782 HG03019.hgr1.vcf
# 2017-03-09 17:37:23        283 HG03019.hgr1.vcf.idx
# 2017-03-07 21:14:57      25991 HG03195.hgr1.vcf
# 2017-03-07 21:14:57        283 HG03195.hgr1.vcf.idx
# 2017-03-08 15:16:28      29320 HG03240.hgr1.vcf
# 2017-03-08 15:16:28        283 HG03240.hgr1.vcf.idx
# 2017-03-07 23:16:32      27708 HG03268.hgr1.vcf
# 2017-03-07 23:16:33        282 HG03268.hgr1.vcf.idx
# 2017-03-07 21:21:04      33232 HG03295.hgr1.vcf
# 2017-03-07 21:21:05        781 HG03295.hgr1.vcf.idx
# 2017-03-09 10:53:21      21186 HG03432.hgr1.vcf
# 2017-03-09 10:53:22        283 HG03432.hgr1.vcf.idx
# 2017-03-09 11:01:12      32407 HG03470.hgr1.vcf
# 2017-03-09 11:01:13        781 HG03470.hgr1.vcf.idx
# 2017-03-09 10:44:51      23790 HG03548.hgr1.vcf
# 2017-03-09 10:44:51        283 HG03548.hgr1.vcf.idx
# 2017-03-09 10:44:09      20503 HG03558.hgr1.vcf
# 2017-03-09 10:44:09        283 HG03558.hgr1.vcf.idx
# 2017-03-06 20:39:59      27550 HG03604.hgr1.vcf
# 2017-03-06 20:40:00        283 HG03604.hgr1.vcf.idx
# 2017-03-06 18:45:52      29420 HG03607.hgr1.vcf
# 2017-03-06 18:45:53        284 HG03607.hgr1.vcf.idx
# 2017-03-06 23:35:54      28702 HG03616.hgr1.vcf
# 2017-03-06 23:35:54        283 HG03616.hgr1.vcf.idx
# 2017-03-09 17:32:22      24340 HG03624.hgr1.vcf
# 2017-03-09 17:32:22        283 HG03624.hgr1.vcf.idx
# 2017-03-08 20:23:17      25961 HG03720.hgr1.vcf
# 2017-03-08 20:23:17        283 HG03720.hgr1.vcf.idx
# 2017-03-09 18:29:49      27921 HG03753.hgr1.vcf
# 2017-03-09 18:29:50        284 HG03753.hgr1.vcf.idx
# 2017-03-08 21:59:38      26051 HG03790.hgr1.vcf
# 2017-03-08 21:59:39        283 HG03790.hgr1.vcf.idx
# 2017-03-09 20:28:40      29064 HG03836.hgr1.vcf
# 2017-03-09 20:28:41        284 HG03836.hgr1.vcf.idx
# 2017-03-09 20:32:27      25195 HG03856.hgr1.vcf
# 2017-03-09 20:32:27        281 HG03856.hgr1.vcf.idx
# 2017-03-08 20:33:40      28377 HG03861.hgr1.vcf
# 2017-03-08 20:33:40        284 HG03861.hgr1.vcf.idx
# 2017-03-08 20:31:06      33622 HG03867.hgr1.vcf
# 2017-03-08 20:31:07        780 HG03867.hgr1.vcf.idx
# 2017-03-09 20:35:00      24319 HG03890.hgr1.vcf
# 2017-03-09 20:35:00        283 HG03890.hgr1.vcf.idx
# 2017-03-06 20:56:57      26647 HG04162.hgr1.vcf
# 2017-03-06 20:56:57        284 HG04162.hgr1.vcf.idx
# 2017-03-07 11:09:14      27959 NA06985.hgr1.vcf
# 2017-03-07 11:09:14        282 NA06985.hgr1.vcf.idx
# 2017-03-07 11:40:47      31776 NA11881.hgr1.vcf
# 2017-03-07 11:40:47        284 NA11881.hgr1.vcf.idx
# 2017-03-07 12:47:51      36404 NA12234.hgr1.vcf
# 2017-03-07 12:47:52        780 NA12234.hgr1.vcf.idx
# 2017-03-07 12:41:01      23532 NA12283.hgr1.vcf
# 2017-03-07 12:41:02        283 NA12283.hgr1.vcf.idx
# 2017-03-05 11:16:48      33001 NA12878_pp.hgr1.vcf
# 2017-03-05 11:31:26        288 NA12878_pp.hgr1.vcf.idx
# 2017-03-05 11:15:19      30814 NA12891_pp.hgr1.vcf
# 2017-03-05 11:15:19        287 NA12891_pp.hgr1.vcf.idx
# 2017-03-06 00:14:00      29637 NA12892_pp.hgr1.vcf
# 2017-03-06 00:14:00        286 NA12892_pp.hgr1.vcf.idx
# 2017-03-07 14:36:12      19482 NA18533.hgr1.vcf
# 2017-03-07 14:36:13        282 NA18533.hgr1.vcf.idx
# 2017-03-07 13:23:47      48767 NA18622.hgr1.vcf
# 2017-03-07 13:23:47       2301 NA18622.hgr1.vcf.idx
# 2017-03-07 13:24:24      32073 NA18632.hgr1.vcf
# 2017-03-07 13:24:24        272 NA18632.hgr1.vcf.idx
# 2017-03-07 14:36:35      54286 NA18647.hgr1.vcf
# 2017-03-07 14:36:36        782 NA18647.hgr1.vcf.idx
# 2017-03-08 23:50:10      26879 NA18981.hgr1.vcf
# 2017-03-08 23:50:11        283 NA18981.hgr1.vcf.idx
# 2017-03-08 23:04:20      46039 NA19001.hgr1.vcf
# 2017-03-08 23:04:21        780 NA19001.hgr1.vcf.idx
# 2017-03-08 22:48:56      28963 NA19006.hgr1.vcf
# 2017-03-08 22:48:57        283 NA19006.hgr1.vcf.idx
# 2017-03-09 02:07:23      25184 NA19042.hgr1.vcf
# 2017-03-09 02:07:23        283 NA19042.hgr1.vcf.idx
# 2017-03-08 22:41:18      45156 NA19091.hgr1.vcf
# 2017-03-08 22:41:18        781 NA19091.hgr1.vcf.idx
# 2017-03-10 01:35:16      21253 NA19098.hgr1.vcf
# 2017-03-10 01:35:16        283 NA19098.hgr1.vcf.idx
# 2017-03-10 01:28:35      20513 NA19144.hgr1.vcf
# 2017-03-10 01:28:36        283 NA19144.hgr1.vcf.idx
# 2017-03-10 01:14:41      23136 NA19153.hgr1.vcf
# 2017-03-10 01:14:41        283 NA19153.hgr1.vcf.idx
# 2017-03-09 22:53:41      22115 NA19159.hgr1.vcf
# 2017-03-09 22:53:41        285 NA19159.hgr1.vcf.idx
# 2017-03-10 01:25:01      27899 NA19240.hgr1.vcf
# 2017-03-10 01:25:02        283 NA19240.hgr1.vcf.idx
# 2017-03-09 01:26:39      25162 NA19320.hgr1.vcf
# 2017-03-09 01:26:39        285 NA19320.hgr1.vcf.idx
# 2017-03-09 02:39:57      25154 NA19351.hgr1.vcf
# 2017-03-09 02:39:58        281 NA19351.hgr1.vcf.idx
# 2017-03-09 01:56:52      38055 NA19475.hgr1.vcf
# 2017-03-09 01:56:53        782 NA19475.hgr1.vcf.idx
# 2017-03-09 14:09:41      22693 NA19658.hgr1.vcf
# 2017-03-09 14:09:41        284 NA19658.hgr1.vcf.idx
# 2017-03-09 13:37:50      20161 NA19670.hgr1.vcf
# 2017-03-09 13:37:50        282 NA19670.hgr1.vcf.idx
# 2017-03-09 12:49:22      31541 NA19734.hgr1.vcf
# 2017-03-09 12:49:22        283 NA19734.hgr1.vcf.idx
# 2017-03-09 12:47:11      54940 NA19795.hgr1.vcf
# 2017-03-09 12:47:11       2300 NA19795.hgr1.vcf.idx
# 2017-03-06 19:27:14      37320 NA19984.hgr1.vcf
# 2017-03-06 19:27:14        780 NA19984.hgr1.vcf.idx
# 2017-03-06 18:11:22      24555 NA20357.hgr1.vcf
# 2017-03-06 18:11:23        285 NA20357.hgr1.vcf.idx
# 2017-03-06 19:29:44      29104 NA20359.hgr1.vcf
# 2017-03-06 19:29:45        281 NA20359.hgr1.vcf.idx
# 2017-03-09 23:52:39      21930 NA20503.hgr1.vcf
# 2017-03-09 23:52:39        283 NA20503.hgr1.vcf.idx
# 2017-03-09 23:55:39      24763 NA20514.hgr1.vcf
# 2017-03-09 23:55:40        283 NA20514.hgr1.vcf.idx
# 2017-03-09 20:55:16      20564 NA20827.hgr1.vcf
# 2017-03-09 20:55:16        284 NA20827.hgr1.vcf.idx
# 2017-03-09 22:36:19      20385 NA20832.hgr1.vcf
# 2017-03-09 22:36:19        284 NA20832.hgr1.vcf.idx
# 2017-03-08 12:07:40      31276 NA21109.hgr1.vcf
# 2017-03-08 12:07:40        283 NA21109.hgr1.vcf.idx
# 2017-03-08 16:15:43      34920 NA21112.hgr1.vcf
# 2017-03-08 16:15:43        781 NA21112.hgr1.vcf.idx
# 2017-03-08 15:45:11      35582 NA21113.hgr1.vcf
# 2017-03-08 15:45:11        781 NA21113.hgr1.vcf.idx
# 2017-03-08 18:45:53      26910 NA21125.hgr1.vcf
# 2017-03-08 18:45:53        282 NA21125.hgr1.vcf.idx
# 2017-03-05 23:18:07      28970 testGenome.hgr1.vcf
# 2017-03-05 23:18:07        288 testGenome.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00139.hgr1.vcf to ./HG00139.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00362.hgr1.vcf to ./HG00362.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00234.hgr1.vcf to ./HG00234.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00353.hgr1.vcf to ./HG00353.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00253.hgr1.vcf to ./HG00253.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00337.hgr1.vcf to ./HG00337.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00734.hgr1.vcf to ./HG00734.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00717.hgr1.vcf to ./HG00717.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00557.hgr1.vcf to ./HG00557.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00536.hgr1.vcf to ./HG00536.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00358.hgr1.vcf to ./HG00358.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG01066.hgr1.vcf to ./HG01066.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG01125.hgr1.vcf to ./HG01125.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00978.hgr1.vcf to ./HG00978.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00851.hgr1.vcf to ./HG00851.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG01348.hgr1.vcf to ./HG01348.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG01464.hgr1.vcf to ./HG01464.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG01589.hgr1.vcf to ./HG01589.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00740.hgr1.vcf to ./HG00740.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG01620.hgr1.vcf to ./HG01620.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG01277.hgr1.vcf to ./HG01277.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00982.hgr1.vcf to ./HG00982.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02035.hgr1.vcf to ./HG02035.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00478.hgr1.vcf to ./HG00478.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG01626.hgr1.vcf to ./HG01626.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02046.hgr1.vcf to ./HG02046.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02078.hgr1.vcf to ./HG02078.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02219.hgr1.vcf to ./HG02219.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG01630.hgr1.vcf to ./HG01630.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG01176.hgr1.vcf to ./HG01176.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02283.hgr1.vcf to ./HG02283.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02040.hgr1.vcf to ./HG02040.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02272.hgr1.vcf to ./HG02272.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02343.hgr1.vcf to ./HG02343.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02286.hgr1.vcf to ./HG02286.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02780.hgr1.vcf to ./HG02780.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02479.hgr1.vcf to ./HG02479.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02839.hgr1.vcf to ./HG02839.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02090.hgr1.vcf to ./HG02090.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02891.hgr1.vcf to ./HG02891.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02277.hgr1.vcf to ./HG02277.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02946.hgr1.vcf to ./HG02946.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02888.hgr1.vcf to ./HG02888.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03195.hgr1.vcf to ./HG03195.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03019.hgr1.vcf to ./HG03019.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03295.hgr1.vcf to ./HG03295.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03268.hgr1.vcf to ./HG03268.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03470.hgr1.vcf to ./HG03470.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02190.hgr1.vcf to ./HG02190.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03240.hgr1.vcf to ./HG03240.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03432.hgr1.vcf to ./HG03432.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG02508.hgr1.vcf to ./HG02508.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03604.hgr1.vcf to ./HG03604.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03607.hgr1.vcf to ./HG03607.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03548.hgr1.vcf to ./HG03548.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03616.hgr1.vcf to ./HG03616.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03558.hgr1.vcf to ./HG03558.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03790.hgr1.vcf to ./HG03790.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03624.hgr1.vcf to ./HG03624.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03720.hgr1.vcf to ./HG03720.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03861.hgr1.vcf to ./HG03861.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03753.hgr1.vcf to ./HG03753.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03867.hgr1.vcf to ./HG03867.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03890.hgr1.vcf to ./HG03890.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03856.hgr1.vcf to ./HG03856.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG04162.hgr1.vcf to ./HG04162.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG03836.hgr1.vcf to ./HG03836.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA12283.hgr1.vcf to ./NA12283.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA06985.hgr1.vcf to ./NA06985.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA12878_pp.hgr1.vcf to ./NA12878_pp.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA12891_pp.hgr1.vcf to ./NA12891_pp.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA11881.hgr1.vcf to ./NA11881.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA12234.hgr1.vcf to ./NA12234.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA18981.hgr1.vcf to ./NA18981.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA18632.hgr1.vcf to ./NA18632.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA18533.hgr1.vcf to ./NA18533.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA12892_pp.hgr1.vcf to ./NA12892_pp.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA18647.hgr1.vcf to ./NA18647.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19001.hgr1.vcf to ./NA19001.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19098.hgr1.vcf to ./NA19098.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA18622.hgr1.vcf to ./NA18622.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19042.hgr1.vcf to ./NA19042.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19144.hgr1.vcf to ./NA19144.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19159.hgr1.vcf to ./NA19159.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19240.hgr1.vcf to ./NA19240.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19091.hgr1.vcf to ./NA19091.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19320.hgr1.vcf to ./NA19320.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19153.hgr1.vcf to ./NA19153.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19670.hgr1.vcf to ./NA19670.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19351.hgr1.vcf to ./NA19351.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19475.hgr1.vcf to ./NA19475.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19658.hgr1.vcf to ./NA19658.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19734.hgr1.vcf to ./NA19734.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA20359.hgr1.vcf to ./NA20359.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19984.hgr1.vcf to ./NA19984.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19006.hgr1.vcf to ./NA19006.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA20514.hgr1.vcf to ./NA20514.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA20832.hgr1.vcf to ./NA20832.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA20357.hgr1.vcf to ./NA20357.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA20827.hgr1.vcf to ./NA20827.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA19795.hgr1.vcf to ./NA19795.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA21109.hgr1.vcf to ./NA21109.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA20503.hgr1.vcf to ./NA20503.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/testGenome.hgr1.vcf to ./testGenome.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA21113.hgr1.vcf to ./NA21113.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA21125.hgr1.vcf to ./NA21125.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/NA21112.hgr1.vcf to ./NA21112.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00128.hgr1.vcf to ./HG00128.hgr1.vcf
# download: s3://crownproject/1kg_hgr1/HG00128.hgr1.vcf.idx to ./HG00128.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00139.hgr1.vcf.idx to ./HG00139.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00234.hgr1.vcf.idx to ./HG00234.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00557.hgr1.vcf.idx to ./HG00557.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00734.hgr1.vcf.idx to ./HG00734.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00253.hgr1.vcf.idx to ./HG00253.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00362.hgr1.vcf.idx to ./HG00362.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00358.hgr1.vcf.idx to ./HG00358.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00536.hgr1.vcf.idx to ./HG00536.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00337.hgr1.vcf.idx to ./HG00337.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00478.hgr1.vcf.idx to ./HG00478.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00717.hgr1.vcf.idx to ./HG00717.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00353.hgr1.vcf.idx to ./HG00353.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00851.hgr1.vcf.idx to ./HG00851.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00740.hgr1.vcf.idx to ./HG00740.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00978.hgr1.vcf.idx to ./HG00978.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG00982.hgr1.vcf.idx to ./HG00982.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG01125.hgr1.vcf.idx to ./HG01125.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG01066.hgr1.vcf.idx to ./HG01066.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG01277.hgr1.vcf.idx to ./HG01277.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG01176.hgr1.vcf.idx to ./HG01176.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG01348.hgr1.vcf.idx to ./HG01348.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG01589.hgr1.vcf.idx to ./HG01589.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG01464.hgr1.vcf.idx to ./HG01464.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG01626.hgr1.vcf.idx to ./HG01626.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG01620.hgr1.vcf.idx to ./HG01620.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02040.hgr1.vcf.idx to ./HG02040.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG01630.hgr1.vcf.idx to ./HG01630.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02046.hgr1.vcf.idx to ./HG02046.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02035.hgr1.vcf.idx to ./HG02035.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02190.hgr1.vcf.idx to ./HG02190.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02277.hgr1.vcf.idx to ./HG02277.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02090.hgr1.vcf.idx to ./HG02090.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02219.hgr1.vcf.idx to ./HG02219.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02078.hgr1.vcf.idx to ./HG02078.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02286.hgr1.vcf.idx to ./HG02286.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02343.hgr1.vcf.idx to ./HG02343.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02272.hgr1.vcf.idx to ./HG02272.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02508.hgr1.vcf.idx to ./HG02508.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02283.hgr1.vcf.idx to ./HG02283.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02839.hgr1.vcf.idx to ./HG02839.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02780.hgr1.vcf.idx to ./HG02780.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02479.hgr1.vcf.idx to ./HG02479.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02891.hgr1.vcf.idx to ./HG02891.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03240.hgr1.vcf.idx to ./HG03240.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03019.hgr1.vcf.idx to ./HG03019.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03295.hgr1.vcf.idx to ./HG03295.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03558.hgr1.vcf.idx to ./HG03558.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02946.hgr1.vcf.idx to ./HG02946.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03432.hgr1.vcf.idx to ./HG03432.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03548.hgr1.vcf.idx to ./HG03548.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG02888.hgr1.vcf.idx to ./HG02888.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03268.hgr1.vcf.idx to ./HG03268.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03470.hgr1.vcf.idx to ./HG03470.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03604.hgr1.vcf.idx to ./HG03604.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03607.hgr1.vcf.idx to ./HG03607.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03195.hgr1.vcf.idx to ./HG03195.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03720.hgr1.vcf.idx to ./HG03720.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03836.hgr1.vcf.idx to ./HG03836.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03753.hgr1.vcf.idx to ./HG03753.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03790.hgr1.vcf.idx to ./HG03790.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03624.hgr1.vcf.idx to ./HG03624.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03616.hgr1.vcf.idx to ./HG03616.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03861.hgr1.vcf.idx to ./HG03861.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03856.hgr1.vcf.idx to ./HG03856.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA06985.hgr1.vcf.idx to ./NA06985.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03867.hgr1.vcf.idx to ./HG03867.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG04162.hgr1.vcf.idx to ./HG04162.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA12234.hgr1.vcf.idx to ./NA12234.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA12891_pp.hgr1.vcf.idx to ./NA12891_pp.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA12878_pp.hgr1.vcf.idx to ./NA12878_pp.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA12283.hgr1.vcf.idx to ./NA12283.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA12892_pp.hgr1.vcf.idx to ./NA12892_pp.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA18622.hgr1.vcf.idx to ./NA18622.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA18533.hgr1.vcf.idx to ./NA18533.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/HG03890.hgr1.vcf.idx to ./HG03890.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA18647.hgr1.vcf.idx to ./NA18647.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA11881.hgr1.vcf.idx to ./NA11881.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA18632.hgr1.vcf.idx to ./NA18632.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA18981.hgr1.vcf.idx to ./NA18981.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19042.hgr1.vcf.idx to ./NA19042.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19006.hgr1.vcf.idx to ./NA19006.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19098.hgr1.vcf.idx to ./NA19098.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19091.hgr1.vcf.idx to ./NA19091.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19144.hgr1.vcf.idx to ./NA19144.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19240.hgr1.vcf.idx to ./NA19240.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19475.hgr1.vcf.idx to ./NA19475.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19320.hgr1.vcf.idx to ./NA19320.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19159.hgr1.vcf.idx to ./NA19159.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19153.hgr1.vcf.idx to ./NA19153.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19658.hgr1.vcf.idx to ./NA19658.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19001.hgr1.vcf.idx to ./NA19001.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19795.hgr1.vcf.idx to ./NA19795.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19351.hgr1.vcf.idx to ./NA19351.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19670.hgr1.vcf.idx to ./NA19670.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19984.hgr1.vcf.idx to ./NA19984.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA20357.hgr1.vcf.idx to ./NA20357.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA19734.hgr1.vcf.idx to ./NA19734.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA20359.hgr1.vcf.idx to ./NA20359.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA20503.hgr1.vcf.idx to ./NA20503.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA20514.hgr1.vcf.idx to ./NA20514.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA20832.hgr1.vcf.idx to ./NA20832.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA21113.hgr1.vcf.idx to ./NA21113.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA21109.hgr1.vcf.idx to ./NA21109.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA21112.hgr1.vcf.idx to ./NA21112.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA21125.hgr1.vcf.idx to ./NA21125.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/testGenome.hgr1.vcf.idx to ./testGenome.hgr1.vcf.idx
# download: s3://crownproject/1kg_hgr1/NA20827.hgr1.vcf.idx to ./NA20827.hgr1.vcf.idx

# %%
# convert files to BCF
cd ~/Crown/data/hgr1_vcf/100g_raw/vcf
mkdir -p ../bcf #bcf storage folder

VCF=$(ls *.vcf)

for FILE in $(ls *.vcf)
do
    # Convert VCF to BCF File
    bcftools view -O b $FILE -o ../bcf/$FILE.bcf
    bcftools index ../bcf/$FILE.bcf
done

cd ../bcf

bcftools merge $(ls *.bcf) -o ../100g_hgr1_v1.vcf
bcftools view -O b ../100g_hgr1_v1.vcf -o 100g_hgr1_v1.bcf
bcftools index 100g_hgr1_v1.bcf

# Filter for variants with 30x coverage
cd ..

bcftools view -i "DP>=30" 100g_hgr1_v1.vcf -o 100g_hgr1_v1.dp30.vcf
bcftools index 100g_hgr1_v1.dp30.vcf
# Out:
# Failed to open 100g_hgr1_v1.bcf: could not load index
# [E::main_vcfindex] unknown filetype; expected bgzip compressed VCF or BCF
# [E::main_vcfindex] was the VCF/BCF compressed with bgzip?

# %%
## vcfplot (summary stats)
cd ~/Crown/data/hgr1_vcf/100g_raw/

# nonDP30 filtered
bcftools stats 100g_hgr1_v1.vcf > 100g_hgr1_v1.vcfplot
plot-vcfstats -p plot/100g 100g_hgr1_v1.vcfplot

# DP30 filtered
bcftools stats 100g_hgr1_v1.dp30.vcf > 100g_hgr1_v1.dp30.vcfplot
plot-vcfstats -p plot_dp30/100g 100g_hgr1_v1.dp30.vcfplot
# Out:
# Parsing bcftools stats output: 100g_hgr1_v1.vcfplot
# Plotting graphs: python plot/100g-plot.py
# Creating PDF: pdflatex 100g-summary.tex >100g-plot-vcfstats.log 2>&1
# Finished: plot/100g-summary.pdf
# Parsing bcftools stats output: 100g_hgr1_v1.dp30.vcfplot
# Plotting graphs: python plot_dp30/100g-plot.py
# Creating PDF: pdflatex 100g-summary.tex >100g-plot-vcfstats.log 2>&1
# Finished: plot_dp30/100g-summary.pdf

# %%
# I'd like to re-name the files based on their Super-population_Population_ID
# so they alpha-sort to world populations
# I'll likely set-this up in excel (a conversion table)

cd ~/Crown/data/hgr1_vcf/
mkdir -p renamed_100g

#cp -r 100g_raw/vcf/*.vcf renamed_100g/vcf/
ln -s ln -s $PWD/100g_raw/vcf/ $PWD/renamed_100g/vcf 

cd renamed_100g

# %%
# I made a name conversion table in the main spreadsheet
cat nameConversion.txt
cp nameConversion.txt ../

# I'll be renaming files/ID to
# <SuperPopulation_Number>.<SuperPopulation>.<Population>.<Individual>
#
# This means the vcf files will alpha-sort into populations easily
# as opposed to the chronological order in which theby were entered into
# the project

## For figure make the Utah Trio super-group 0 (they will be 3 genomes at the top)
## in ~/Crown/data/hgr1_vcf/renamed_100g
##
## > nameConversion_figure.txt
##
# Out:
# NA12878_pp	CEU	EUR	4	4.EUR.CEU_NA12878_pp
# NA12891_pp	CEU	EUR	4	4.EUR.CEU_NA12891_pp
# NA12892_pp	CEU	EUR	4	4.EUR.CEU_NA12892_pp
# HG02283	ACB	AFR	1	1.AFR.ACB_HG02283
# HG02343	ACB	AFR	1	1.AFR.ACB_HG02343
# HG02508	ACB	AFR	1	1.AFR.ACB_HG02508
# HG02479	ACB	AFR	1	1.AFR.ACB_HG02479
# NA20357	ASW	AFR	1	1.AFR.ASW_NA20357
# NA20359	ASW	AFR	1	1.AFR.ASW_NA20359
# NA20362	ASW	AFR	1	1.AFR.ASW_NA20362
# NA19984	ASW	AFR	1	1.AFR.ASW_NA19984
# HG03607	BEB	SAS	5	5.SAS.BEB_HG03607
# HG03604	BEB	SAS	5	5.SAS.BEB_HG03604
# HG04162	BEB	SAS	5	5.SAS.BEB_HG04162
# HG03616	BEB	SAS	5	5.SAS.BEB_HG03616
# HG02190	CDX	EAS	3	3.EAS.CDX_HG02190
# HG00851	CDX	EAS	3	3.EAS.CDX_HG00851
# HG00978	CDX	EAS	3	3.EAS.CDX_HG00978
# HG00982	CDX	EAS	3	3.EAS.CDX_HG00982
# NA06985	CEU	EUR	4	4.EUR.CEU_NA06985
# NA11881	CEU	EUR	4	4.EUR.CEU_NA11881
# NA12234	CEU	EUR	4	4.EUR.CEU_NA12234
# NA12283	CEU	EUR	4	4.EUR.CEU_NA12283
# NA18622	CHB	EAS	3	3.EAS.CHB_NA18622
# NA18632	CHB	EAS	3	3.EAS.CHB_NA18632
# NA18533	CHB	EAS	3	3.EAS.CHB_NA18533
# NA18647	CHB	EAS	3	3.EAS.CHB_NA18647
# HG00478	CHS	EAS	3	3.EAS.CHS_HG00478
# HG00536	CHS	EAS	3	3.EAS.CHS_HG00536
# HG00557	CHS	EAS	3	3.EAS.CHS_HG00557
# HG00717	CHS	EAS	3	3.EAS.CHS_HG00717
# HG01125	CLM	AMR	2	2.AMR.CLM_HG01125
# HG01464	CLM	AMR	2	2.AMR.CLM_HG01464
# HG01348	CLM	AMR	2	2.AMR.CLM_HG01348
# HG01277	CLM	AMR	2	2.AMR.CLM_HG01277
# HG03295	ESN	AFR	1	1.AFR.ESN_HG03295
# HG03195	ESN	AFR	1	1.AFR.ESN_HG03195
# HG02946	ESN	AFR	1	1.AFR.ESN_HG02946
# HG03268	ESN	AFR	1	1.AFR.ESN_HG03268
# HG00358	FIN	EUR	4	4.EUR.FIN_HG00358
# HG00353	FIN	EUR	4	4.EUR.FIN_HG00353
# HG00337	FIN	EUR	4	4.EUR.FIN_HG00337
# HG00362	FIN	EUR	4	4.EUR.FIN_HG00362
# HG00234	GBR	EUR	4	4.EUR.GBR_HG00234
# HG00128	GBR	EUR	4	4.EUR.GBR_HG00128
# HG00253	GBR	EUR	4	4.EUR.GBR_HG00253
# HG00139	GBR	EUR	4	4.EUR.GBR_HG00139
# NA21109	GIH	SAS	5	5.SAS.GIH_NA21109
# NA21113	GIH	SAS	5	5.SAS.GIH_NA21113
# NA21112	GIH	SAS	5	5.SAS.GIH_NA21112
# NA21125	GIH	SAS	5	5.SAS.GIH_NA21125
# HG03240	GWD	AFR	1	1.AFR.GWD_HG03240
# HG02891	GWD	AFR	1	1.AFR.GWD_HG02891
# HG02888	GWD	AFR	1	1.AFR.GWD_HG02888
# HG02839	GWD	AFR	1	1.AFR.GWD_HG02839
# HG02219	IBS	EUR	4	4.EUR.IBS_HG02219
# HG01626	IBS	EUR	4	4.EUR.IBS_HG01626
# HG01630	IBS	EUR	4	4.EUR.IBS_HG01630
# HG01620	IBS	EUR	4	4.EUR.IBS_HG01620
# HG03720	ITU	SAS	5	5.SAS.ITU_HG03720
# HG03861	ITU	SAS	5	5.SAS.ITU_HG03861
# HG03867	ITU	SAS	5	5.SAS.ITU_HG03867
# HG03790	ITU	SAS	5	5.SAS.ITU_HG03790
# NA19001	JPT	EAS	3	3.EAS.JPT_NA19001
# NA18981	JPT	EAS	3	3.EAS.JPT_NA18981
# NA19091	JPT	EAS	3	3.EAS.JPT_NA19091
# NA19006	JPT	EAS	3	3.EAS.JPT_NA19006
# HG02046	KHV	EAS	3	3.EAS.KHV_HG02046
# HG02035	KHV	EAS	3	3.EAS.KHV_HG02035
# HG02040	KHV	EAS	3	3.EAS.KHV_HG02040
# HG02078	KHV	EAS	3	3.EAS.KHV_HG02078
# NA19475	LWK	AFR	1	1.AFR.LWK_NA19475
# NA19320	LWK	AFR	1	1.AFR.LWK_NA19320
# NA19351	LWK	AFR	1	1.AFR.LWK_NA19351
# NA19042	LWK	AFR	1	1.AFR.LWK_NA19042
# HG03432	MSL	AFR	1	1.AFR.MSL_HG03432
# HG03558	MSL	AFR	1	1.AFR.MSL_HG03558
# HG03470	MSL	AFR	1	1.AFR.MSL_HG03470
# HG03548	MSL	AFR	1	1.AFR.MSL_HG03548
# NA19795	MXL	AMR	2	2.AMR.MXL_NA19795
# NA19734	MXL	AMR	2	2.AMR.MXL_NA19734
# NA19658	MXL	AMR	2	2.AMR.MXL_NA19658
# NA19670	MXL	AMR	2	2.AMR.MXL_NA19670
# HG02272	PEL	AMR	2	2.AMR.PEL_HG02272
# HG02286	PEL	AMR	2	2.AMR.PEL_HG02286
# HG02090	PEL	AMR	2	2.AMR.PEL_HG02090
# HG02277	PEL	AMR	2	2.AMR.PEL_HG02277
# HG01589	PJL	SAS	5	5.SAS.PJL_HG01589
# HG03624	PJL	SAS	5	5.SAS.PJL_HG03624
# HG03019	PJL	SAS	5	5.SAS.PJL_HG03019
# HG02780	PJL	SAS	5	5.SAS.PJL_HG02780
# HG01176	PUR	AMR	2	2.AMR.PUR_HG01176
# HG00740	PUR	AMR	2	2.AMR.PUR_HG00740
# HG01066	PUR	AMR	2	2.AMR.PUR_HG01066
# HG00734	PUR	AMR	2	2.AMR.PUR_HG00734
# HG03753	STU	SAS	5	5.SAS.STU_HG03753
# HG03836	STU	SAS	5	5.SAS.STU_HG03836
# HG03856	STU	SAS	5	5.SAS.STU_HG03856
# HG03890	STU	SAS	5	5.SAS.STU_HG03890
# NA20827	TSI	EUR	4	4.EUR.TSI_NA20827
# NA20514	TSI	EUR	4	4.EUR.TSI_NA20514
# NA20503	TSI	EUR	4	4.EUR.TSI_NA20503
# NA20832	TSI	EUR	4	4.EUR.TSI_NA20832
# NA19159	YRI	AFR	1	1.AFR.YRI_NA19159
# NA19153	YRI	AFR	1	1.AFR.YRI_NA19153
# NA19098	YRI	AFR	1	1.AFR.YRI_NA19098
# NA19144	YRI	AFR	1	1.AFR.YRI_NA19144
# NA19240	YRI	AFR	1	1.AFR.YRI_NA19240

# %%
# Iterate through every VCF file in the VCF folder;
# rename the file; rename the ID tag in the file
# create VCF index for it
cd ~/Crown/data/hgr1_vcf/renamed_100g/
mkdir -p renaming

cp -r vcf/* renaming/

cd renaming

VCF=$(ls *.vcf)

for FILE in $(ls *.vcf)
do
    originalID=$(echo $FILE | cut -f1 -d'.' -)
    
    convertID=$(grep $originalID ../nameConversion.txt | cut -f 5 - )
    

    # Underscores are removed from contigID so search without it
    dropUnderScore=$(echo $originalID | cut -f1 -d'_' -)
    convertID_ds=$(echo $convertID | cut -f1 -d'_' -)
    
    # Within VCF file, convert ID
    sed -i "s/\t$dropUnderScore/\t$convertID_ds/g" $FILE
    
    # Rename the file itself (retain underscores)
    mv $FILE $convertID.vcf
    
    # Convert to bcf file
    bcftools view -O b $convertID.vcf -o $convertID.bcf
    bcftools index $convertID.bcf
done


bcftools merge $(ls *.bcf) -o ../100g_hgr1_pop.vcf
cd ..

gzip 100g_hgr1_pop.vcf

rm -r renaming
#bcftools view -O b 100g_hgr1_pop.vcf -o 100g_hgr1_pop.bcf
#bcftools index 100g_hgr1_pop.bcf
# Out:
# [E::bcf_hdr_add_sample] Empty sample name: trailing spaces/tabs in the header line?
# Aborted (core dumped)
# [E::hts_open_format] fail to open file '.bcf'
# Failed to read .bcf
# [E::bcf_hdr_add_sample] Empty sample name: trailing spaces/tabs in the header line?
# Aborted (core dumped)
# [E::hts_open_format] fail to open file '.bcf'
# Failed to read .bcf
# [E::bcf_hdr_add_sample] Empty sample name: trailing spaces/tabs in the header line?
# Aborted (core dumped)
# [E::hts_open_format] fail to open file '.bcf'
# Failed to read .bcf

# %% [markdown]
# ## Discussion
#
# Data loaded into IGV and used to make figure. Roughly...
#
# ![Raw 100 genome variants viewed in IGV and made into figure](../figure/20170313_hgr1_100g_raw.png)
#
# The main problem with this data is that it doesn't distinguish 'No Data' with reference allele only. Needs to be re-run using g.vcf file format.
